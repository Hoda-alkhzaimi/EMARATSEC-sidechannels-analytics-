# %%
import sys
import os
from tensorflow.keras import backend as backend
from tensorflow.keras.utils import to_categorical
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import tensorflow as tf
from imblearn.over_sampling import SMOTE
from collections import Counter

#!cp /content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py/
#file_location = "/content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py"
#sys.path.append(os.path.abspath(file_location))
#sys.path.insert(0,'/content/drive/MyDrive/Colab\Notebooks/QEResearch/ches_ctf/')
#sys.path.append('/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf')
#import SCAMetrics
# Out:
# Mounted at /content/drive

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1E9kCFN_Qf6720hbw996x6z0xUSLqQwjg'})

# %%
# !pip install import-ipynb
import import_ipynb

# !pip install -U -q PyDrive
#your_module.GetContentFile('sca_metrics.ipynb')
#from sca_metrics import *
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.3.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (57.4.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.8.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (2.15.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.7.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.4

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
#your_module = drive.CreateFile({'id':'11WgfAW1xTNRX_tl74AcFCnJNh6hhjtrQ'})
your_module = drive.CreateFile({'id':'1t5viOwM1THtGwwGzxVIO1hvrroYqvGdA'})
your_module.GetContentFile('sca_metrics.py') 
import sca_metrics
from sca_metrics import SCAMetrics
#your_module.GetContentFile({'id':'16R_OCUvUjNXD3hnk_XvW0H2CR-MtbpeI'})

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm'})
your_module.GetContentFile('loaddatasetimbalanced.py') #13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm
import loaddatasetimbalanced
from loaddatasetimbalanced import LoadDatasets

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'14CorI66D0y0P-4eXCStsl90Avpb-xtUM'})
your_module.GetContentFile('datasets.py') #14CorI66D0y0P-4eXCStsl90Avpb-xtUM
import datasets
from datasets import SCADatasets

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd'})
your_module.GetContentFile('neural_networks.py') #1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd
import neural_networks
from neural_networks import NeuralNetwork

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import random


class EnsembleAES:

    def __init__(self):
        self.number_of_models = 50
        self.number_of_best_models = 10
        self.ge_all_validation = []
        self.ge_all_attack = []
        self.sr_all_validation = []
        self.sr_all_attack = []
        self.k_ps_all = []
        self.ge_ensemble = None
        self.ge_ensemble_best_models = None
        self.ge_best_model_validation = None
        self.ge_best_model_attack = None
        self.sr_ensemble = None
        self.sr_ensemble_best_models = None
        self.sr_best_model_validation = None
        self.sr_best_model_attack = None
        self.target_dataset = None
        self.l_model = None
        self.target_byte = None
        self.classes = None
        self.epochs = None
        self.mini_batch = None

    def set_dataset(self, target): #function for setting up dataset - ASCAD | ches_ctf
        self.target_dataset = target

    def set_leakage_model(self, leakage_model): #function for setting up leakage model
        self.l_model = leakage_model
        if leakage_model == "HW":
            self.classes = 9
        else:
            self.classes = 256

    def set_target_byte(self, target_byte): #target byte to attack: most of the time, this is 3
        self.target_byte = target_byte

    def set_epochs(self, epochs): #we set no of epochs for our training model
        self.epochs = epochs

    def set_mini_batch(self, mini_batch): #not sure of mini_batch. I guess it means batch
        self.mini_batch = mini_batch

    def __add_if_one(self, value): #don't know when this will be useful
        return 1 if value == 1 else 0

    def get_best_models(self, n_models, result_models_validation, n_traces):
        result_number_of_traces_val = []
        for model_index in range(n_models):
            if result_models_validation[model_index][n_traces - 1] == 1:
                for index in range(n_traces - 1, -1, -1):
                    if result_models_validation[model_index][index] != 1:
                        result_number_of_traces_val.append(
                            [result_models_validation[model_index][n_traces - 1], index + 1,
                             model_index])
                        break
            else:
                result_number_of_traces_val.append(
                    [result_models_validation[model_index][n_traces - 1], n_traces,
                     model_index])

        sorted_models = sorted(result_number_of_traces_val, key=lambda l: l[:])

        list_of_best_models = []
        for model_index in range(n_models):
            list_of_best_models.append(sorted_models[model_index][2])

        return list_of_best_models

    def run_mlp(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)

        model = NeuralNetwork().mlp_random(self.classes, params["number_of_samples"], activation, neurons, layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),       #We train by running MLP and then we use SCA metrics to verify accuracy
            callbacks=[])
                                                                                   #this shows on the window first
        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation, step, fraction)
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)              #this shows on the window after

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def run_cnn(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        X_profiling = X_profiling.reshape((X_profiling.shape[0], X_profiling.shape[1], 1))
        X_validation = X_validation.reshape((X_validation.shape[0], X_validation.shape[1], 1))
        X_attack = X_attack.reshape((X_attack.shape[0], X_attack.shape[1], 1))

        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        dense_layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)
        conv_layers = random.randrange(1, 2, 1)
        filters = random.randrange(8, 32, 4)
        kernel_size = random.randrange(10, 20, 2)
        stride = random.randrange(5, 10, 5)

        model = NeuralNetwork().cnn_random(self.classes, params["number_of_samples"], activation, neurons, conv_layers, filters,
                                           kernel_size, stride, dense_layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),
            callbacks=[])                                         #We train by running CNN and then we use SCA metrics to verify accuracy

        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation,
                                                                      step, fraction)  #this shows on the window first
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)                   #this shows on the window after

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def compute_ensembles(self, kr_nt, correct_key):

        list_of_best_models = self.get_best_models(self.number_of_models, self.ge_all_validation, kr_nt)

        self.ge_best_model_validation = self.ge_all_validation[list_of_best_models[0]]
        self.ge_best_model_attack = self.ge_all_attack[list_of_best_models[0]]
        self.sr_best_model_validation = self.sr_all_validation[list_of_best_models[0]]
        self.sr_best_model_attack = self.sr_all_attack[list_of_best_models[0]]

        kr_ensemble = np.zeros(kr_nt)
        krs_ensemble = np.zeros((100, kr_nt))
        kr_ensemble_best_models = np.zeros(kr_nt)
        krs_ensemble_best_models = np.zeros((100, kr_nt))

        for run in range(100):

            key_p_ensemble = np.zeros(256)
            key_p_ensemble_best_models = np.zeros(256)

            for index in range(kr_nt):
                for model_index in range(self.number_of_models):
                    key_p_ensemble += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)
                for model_index in range(self.number_of_best_models):
                    key_p_ensemble_best_models += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)

                key_p_ensemble_sorted = np.argsort(key_p_ensemble)[::-1]
                key_p_ensemble_best_models_sorted = np.argsort(key_p_ensemble_best_models)[::-1]

                kr_position = list(key_p_ensemble_sorted).index(correct_key) + 1
                kr_ensemble[index] += kr_position
                krs_ensemble[run][index] = kr_position

                kr_position = list(key_p_ensemble_best_models_sorted).index(correct_key) + 1
                kr_ensemble_best_models[index] += kr_position
                krs_ensemble_best_models[run][index] = kr_position

            print("Run {} - GE {} models: {} | GE {} models: {} | ".format(run, self.number_of_models,
                                                                           int(kr_ensemble[kr_nt - 1] / (run + 1)),
                                                                           self.number_of_best_models,
                                                                           int(kr_ensemble_best_models[kr_nt - 1] / (run + 1))))

        ge_ensemble = kr_ensemble / 100
        ge_ensemble_best_models = kr_ensemble_best_models / 100

        sr_ensemble = np.zeros(kr_nt)
        sr_ensemble_best_models = np.zeros(kr_nt)

        for index in range(kr_nt):
            for run in range(100):
                sr_ensemble[index] += self.__add_if_one(krs_ensemble[run][index])
                sr_ensemble_best_models[index] += self.__add_if_one(krs_ensemble_best_models[run][index])

        return ge_ensemble, ge_ensemble_best_models, sr_ensemble/100, sr_ensemble_best_models/100

    def create_z_score_norm(self, dataset):
        z_score_mean = np.mean(dataset, axis=0)
        z_score_std = np.std(dataset, axis=0)
        return z_score_mean, z_score_std

    def apply_z_score_norm(self, dataset, z_score_mean, z_score_std):
        for index in range(len(dataset)):
            dataset[index] = (dataset[index] - z_score_mean) / z_score_std

    def run_ensemble(self, number_of_models, number_of_best_models):

        self.number_of_models = number_of_models
        self.number_of_best_models = number_of_best_models

        target_params = SCADatasets().get_trace_set(self.target_dataset)

        #root_folder = "D:/traces/"
        #root_folder = '/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf/'
        root_folder = '/content/gdrive/MyDrive/QEResearch/ches_ctf/'


        (X_profiling, Y_profiling), (X_validation, Y_validation), (X_attack, Y_attack), ( #go into load_dataset class: apply imbalance
            _, plt_validation, plt_attack) = LoadDatasets().load_dataset(
            root_folder + target_params["file"], target_params["n_profiling"], target_params["n_attack"], self.target_byte, self.l_model)
        print('loaded')

         #measure imbalance of the data here
        oversample = SMOTE()          #added
        X_profilinga, Y_profilinga = oversample.fit_resample(X_profiling, Y_profiling)  #added
        # summarize distribution
        counter = Counter(Y_profilinga)      #added switch betweenn Y_profiling & Y_profilinga
        for k,v in counter.items():   #added
          per = v / len(Y_profilinga) * 100   #added
          print('Class=%d, n=%d (%.3f%%)' % (k, v, per))  #added
        # plot the distribution
        plt.bar(counter.keys(), counter.values())    #added
        #plt.subplot(1, 2, 1)
        #plt.plot(ensemble_aes.get_ge_best_model_validation(), )
        plt.xlabel("Classes")
        plt.ylabel("Frequency")
        plt.legend()
        plt.show()   #added

        


        # normalize with z-score
        z_score_mean, z_score_std = self.create_z_score_norm(X_profiling)
        self.apply_z_score_norm(X_profiling, z_score_mean, z_score_std)
        self.apply_z_score_norm(X_validation, z_score_mean, z_score_std)
        self.apply_z_score_norm(X_attack, z_score_mean, z_score_std)

        # convert labels to categorical labels
        Y_profiling = to_categorical(Y_profiling, num_classes=self.classes)
        Y_validation = to_categorical(Y_validation, num_classes=self.classes)
        Y_attack = to_categorical(Y_attack, num_classes=self.classes)

        X_profiling = X_profiling.astype('float32')
        X_validation = X_validation.astype('float32')
        X_attack = X_attack.astype('float32')

        kr_step = 10  # key rank processed for each kr_step traces
        kr_fraction = 1  # validation or attack sets are divided by kr_fraction before computing key rank

        self.ge_all_validation = []
        self.sr_all_validation = []
        self.ge_all_attack = []
        self.k_ps_all = []

        kr_nt = int(len(X_validation) / (kr_step * kr_fraction))

        # train random MLP
        for model_index in range(self.number_of_models):
            ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_mlp(X_profiling, Y_profiling,
                                                                                      X_validation, Y_validation,
                                                                                      X_attack, Y_attack,
                                                                                      plt_validation, plt_attack,
                                                                                      target_params, kr_step, kr_fraction)
            self.ge_all_validation.append(ge_validation)
            self.ge_all_attack.append(ge_attack)
            self.sr_all_validation.append(sr_validation)
            self.sr_all_attack.append(sr_attack)
            self.k_ps_all.append(kp_krs)

        # train random CNN
        # for model_index in range(self.number_of_models):
        #     ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_cnn(X_profiling, Y_profiling,
        #                                                                               X_validation, Y_validation,
        #                                                                               X_attack, Y_attack,
        #                                                                               plt_validation, plt_attack,
        #                                                                               target_params, kr_step, kr_fraction)
        #     self.ge_all_validation.append(ge_validation)
        #     self.ge_all_attack.append(ge_attack)
        #     self.sr_all_validation.append(sr_validation)
        #     self.sr_all_attack.append(sr_attack)
        #     self.k_ps_all.append(kp_krs)

        ge_ensemble, ge_ensemble_best_models, sr_ensemble, sr_ensemble_best_models = self.compute_ensembles(kr_nt,
                                                                                                            target_params["good_key"])

        self.ge_ensemble = ge_ensemble
        self.ge_ensemble_best_models = ge_ensemble_best_models
        self.sr_ensemble = sr_ensemble
        self.sr_ensemble_best_models = sr_ensemble_best_models

    def get_ge_ensemble(self):
        return self.ge_ensemble

    def get_ge_ensemble_best_models(self):
        return self.ge_ensemble_best_models

    def get_ge_best_model_validation(self):
        return self.ge_best_model_validation

    def get_ge_best_model_attack(self):
        return self.ge_best_model_attack

    def get_sr_ensemble(self):
        return self.sr_ensemble

    def get_sr_ensemble_best_models(self):
        return self.sr_ensemble_best_models

    def get_sr_best_model_validation(self):
        return self.sr_best_model_validation

    def get_sr_best_model_attack(self):
        return self.sr_best_model_attack

# %%
ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
#ensemble_aes.set_dataset("ascad_fixed_key")  #changed from ches_ctf
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
#ensemble_aes.run_ensemble(number_of_models=5, number_of_best_models=[1,2,3,4])
ensemble_aes.run_ensemble(number_of_models=50, number_of_best_models=[1,5,10,20])
# Out:
# loaded
# No handles with labels found to put in legend.
# Class=5, n=12294 (11.111%)
# Class=4, n=12294 (11.111%)
# Class=6, n=12294 (11.111%)
# Class=3, n=12294 (11.111%)
# Class=7, n=12294 (11.111%)
# Class=1, n=12294 (11.111%)
# Class=2, n=12294 (11.111%)
# Class=0, n=12294 (11.111%)
# Class=8, n=12294 (11.111%)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  gaussian_noise (GaussianNoi  (None, 600)              0
#  se)
#
#  dense_4 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,416,609
# Trainable params: 2,412,209
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Streaming output truncated to the last 5000 lines.
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 500)               1100500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  gaussian_noise (GaussianNoi  (None, 500)              0
#  se)
#
#  dense_2 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 1,364,309
# Trainable params: 1,359,909
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 113/113 [==============================] - 3s 20ms/step - loss: 2.0468 - accuracy: 0.2262 - val_loss: 2.0881 - val_accuracy: 0.2152
# Epoch 2/10
# 113/113 [==============================] - 2s 19ms/step - loss: 1.7797 - accuracy: 0.2883 - val_loss: 2.0167 - val_accuracy: 0.2268
# Epoch 3/10
# 113/113 [==============================] - 2s 19ms/step - loss: 1.6751 - accuracy: 0.3354 - val_loss: 2.0419 - val_accuracy: 0.2228
# Epoch 4/10
# 113/113 [==============================] - 2s 20ms/step - loss: 1.5922 - accuracy: 0.3758 - val_loss: 2.0243 - val_accuracy: 0.2296
# Epoch 5/10
# 113/113 [==============================] - 2s 19ms/step - loss: 1.5268 - accuracy: 0.4064 - val_loss: 2.1276 - val_accuracy: 0.2164
# Epoch 6/10
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4646 - accuracy: 0.4413 - val_loss: 2.1102 - val_accuracy: 0.2348
# Epoch 7/10
# 113/113 [==============================] - 2s 20ms/step - loss: 1.4084 - accuracy: 0.4635 - val_loss: 2.2500 - val_accuracy: 0.2312
# Epoch 8/10
# 113/113 [==============================] - 2s 19ms/step - loss: 1.3510 - accuracy: 0.4935 - val_loss: 2.2290 - val_accuracy: 0.2276
# Epoch 9/10
# 113/113 [==============================] - 2s 19ms/step - loss: 1.2961 - accuracy: 0.5173 - val_loss: 2.3721 - val_accuracy: 0.2288
# Epoch 10/10
# 113/113 [==============================] - 2s 19ms/step - loss: 1.2407 - accuracy: 0.5448 - val_loss: 2.5041 - val_accuracy: 0.2252
# KR: 0 | GE for correct key (46): 9.0)
# KR: 1 | GE for correct key (46): 9.0)
# KR: 2 | GE for correct key (46): 9.0)
# KR: 3 | GE for correct key (46): 9.0)
# KR: 4 | GE for correct key (46): 9.0)
# KR: 5 | GE for correct key (46): 9.0)
# KR: 6 | GE for correct key (46): 9.0)
# KR: 7 | GE for correct key (46): 9.0)
# KR: 8 | GE for correct key (46): 9.0)
# KR: 9 | GE for correct key (46): 9.0)
# KR: 10 | GE for correct key (46): 9.0)
# KR: 11 | GE for correct key (46): 9.0)
# KR: 12 | GE for correct key (46): 9.0)
# KR: 13 | GE for correct key (46): 9.0)
# KR: 14 | GE for correct key (46): 9.0)
# KR: 15 | GE for correct key (46): 9.0)
# KR: 16 | GE for correct key (46): 9.0)
# KR: 17 | GE for correct key (46): 9.0)
# KR: 18 | GE for correct key (46): 9.0)
# KR: 19 | GE for correct key (46): 9.0)
# KR: 20 | GE for correct key (46): 9.0)
# KR: 21 | GE for correct key (46): 9.0)
# KR: 22 | GE for correct key (46): 9.0)
# KR: 23 | GE for correct key (46): 9.0)
# KR: 24 | GE for correct key (46): 9.0)
# KR: 25 | GE for correct key (46): 9.0)
# KR: 26 | GE for correct key (46): 9.0)
# KR: 27 | GE for correct key (46): 9.0)
# KR: 28 | GE for correct key (46): 9.0)
# KR: 29 | GE for correct key (46): 9.0)
# KR: 30 | GE for correct key (46): 9.0)
# KR: 31 | GE for correct key (46): 9.0)
# KR: 32 | GE for correct key (46): 9.0)
# KR: 33 | GE for correct key (46): 9.0)
# KR: 34 | GE for correct key (46): 9.0)
# KR: 35 | GE for correct key (46): 9.0)
# KR: 36 | GE for correct key (46): 9.0)
# KR: 37 | GE for correct key (46): 9.0)
# KR: 38 | GE for correct key (46): 9.0)
# KR: 39 | GE for correct key (46): 9.0)
# KR: 40 | GE for correct key (46): 9.0)
# KR: 41 | GE for correct key (46): 9.0)
# KR: 42 | GE for correct key (46): 9.0)
# KR: 43 | GE for correct key (46): 9.0)
# KR: 44 | GE for correct key (46): 9.0)
# KR: 45 | GE for correct key (46): 9.0)
# KR: 46 | GE for correct key (46): 9.0)
# KR: 47 | GE for correct key (46): 9.0)
# KR: 48 | GE for correct key (46): 9.0)
# KR: 49 | GE for correct key (46): 9.0)
# KR: 50 | GE for correct key (46): 9.0)
# KR: 51 | GE for correct key (46): 9.0)
# KR: 52 | GE for correct key (46): 9.0)
# KR: 53 | GE for correct key (46): 9.0)
# KR: 54 | GE for correct key (46): 9.0)
# KR: 55 | GE for correct key (46): 9.0)
# KR: 56 | GE for correct key (46): 9.0)
# KR: 57 | GE for correct key (46): 9.0)
# KR: 58 | GE for correct key (46): 9.0)
# KR: 59 | GE for correct key (46): 9.0)
# KR: 60 | GE for correct key (46): 9.0)
# KR: 61 | GE for correct key (46): 9.0)
# KR: 62 | GE for correct key (46): 9.0)
# KR: 63 | GE for correct key (46): 9.0)
# KR: 64 | GE for correct key (46): 9.0)
# KR: 65 | GE for correct key (46): 9.0)
# KR: 66 | GE for correct key (46): 9.0)
# KR: 67 | GE for correct key (46): 9.0)
# KR: 68 | GE for correct key (46): 9.0)
# KR: 69 | GE for correct key (46): 9.0)
# KR: 70 | GE for correct key (46): 9.0)
# KR: 71 | GE for correct key (46): 9.0)
# KR: 72 | GE for correct key (46): 9.0)
# KR: 73 | GE for correct key (46): 9.0)
# KR: 74 | GE for correct key (46): 9.0)
# KR: 75 | GE for correct key (46): 9.0)
# KR: 76 | GE for correct key (46): 9.0)
# KR: 77 | GE for correct key (46): 9.0)
# KR: 78 | GE for correct key (46): 9.0)
# KR: 79 | GE for correct key (46): 9.0)
# KR: 80 | GE for correct key (46): 9.0)
# KR: 81 | GE for correct key (46): 9.0)
# KR: 82 | GE for correct key (46): 9.0)
# KR: 83 | GE for correct key (46): 9.0)
# KR: 84 | GE for correct key (46): 9.0)
# KR: 85 | GE for correct key (46): 9.0)
# KR: 86 | GE for correct key (46): 9.0)
# KR: 87 | GE for correct key (46): 9.0)
# KR: 88 | GE for correct key (46): 9.0)
# KR: 89 | GE for correct key (46): 9.0)
# KR: 90 | GE for correct key (46): 9.0)
# KR: 91 | GE for correct key (46): 9.0)
# KR: 92 | GE for correct key (46): 9.0)
# KR: 93 | GE for correct key (46): 9.0)
# KR: 94 | GE for correct key (46): 9.0)
# KR: 95 | GE for correct key (46): 9.0)
# KR: 96 | GE for correct key (46): 9.0)
# KR: 97 | GE for correct key (46): 9.0)
# KR: 98 | GE for correct key (46): 9.0)
# KR: 99 | GE for correct key (46): 9.0)
# KR: 0 | GE for correct key (46): 1.0)
# KR: 1 | GE for correct key (46): 1.0)
# KR: 2 | GE for correct key (46): 1.0)
# KR: 3 | GE for correct key (46): 1.0)
# KR: 4 | GE for correct key (46): 1.0)
# KR: 5 | GE for correct key (46): 1.0)
# KR: 6 | GE for correct key (46): 1.0)
# KR: 7 | GE for correct key (46): 1.0)
# KR: 8 | GE for correct key (46): 1.0)
# KR: 9 | GE for correct key (46): 1.0)
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 700)               1540700
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 700)               490700
#
#  dense_3 (Dense)             (None, 700)               490700
#
#  dense_4 (Dense)             (None, 700)               490700
#
#  dense_5 (Dense)             (None, 700)               490700
#
#  gaussian_noise (GaussianNoi  (None, 700)              0
#  se)
#
#  dense_6 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 4,009,309
# Trainable params: 4,004,909
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 113/113 [==============================] - 5s 42ms/step - loss: 2.1071 - accuracy: 0.2294 - val_loss: 1.8991 - val_accuracy: 0.2200
# Epoch 2/10
# 113/113 [==============================] - 5s 41ms/step - loss: 1.6979 - accuracy: 0.3127 - val_loss: 1.8494 - val_accuracy: 0.2444
# Epoch 3/10
# 113/113 [==============================] - 5s 41ms/step - loss: 1.5536 - accuracy: 0.3865 - val_loss: 1.9338 - val_accuracy: 0.2044
# Epoch 4/10
# 113/113 [==============================] - 5s 43ms/step - loss: 1.3459 - accuracy: 0.4836 - val_loss: 2.0832 - val_accuracy: 0.2280
# Epoch 5/10
# 113/113 [==============================] - 5s 41ms/step - loss: 1.0805 - accuracy: 0.5975 - val_loss: 2.5954 - val_accuracy: 0.2444
# Epoch 6/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.7871 - accuracy: 0.7148 - val_loss: 3.0862 - val_accuracy: 0.2048
# Epoch 7/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.5563 - accuracy: 0.8015 - val_loss: 3.3875 - val_accuracy: 0.2124
# Epoch 8/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.4094 - accuracy: 0.8567 - val_loss: 3.6678 - val_accuracy: 0.2272
# Epoch 9/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.3066 - accuracy: 0.8916 - val_loss: 4.2134 - val_accuracy: 0.2132
# Epoch 10/10
# 113/113 [==============================] - 5s 41ms/step - loss: 0.2605 - accuracy: 0.9087 - val_loss: 4.3031 - val_accuracy: 0.2264
# KR: 0 | GE for correct key (46): 1.0)
# KR: 1 | GE for correct key (46): 1.0)
# KR: 2 | GE for correct key (46): 1.0)
# KR: 3 | GE for correct key (46): 1.0)
# KR: 4 | GE for correct key (46): 1.0)
# KR: 5 | GE for correct key (46): 1.0)
# KR: 6 | GE for correct key (46): 1.0)
# KR: 7 | GE for correct key (46): 1.0)
# KR: 8 | GE for correct key (46): 1.0)
# KR: 9 | GE for correct key (46): 1.0)
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# KR: 0 | GE for correct key (46): 1.0)
# KR: 1 | GE for correct key (46): 1.0)
# KR: 2 | GE for correct key (46): 1.0)
# KR: 3 | GE for correct key (46): 1.0)
# KR: 4 | GE for correct key (46): 1.0)
# KR: 5 | GE for correct key (46): 1.0)
# KR: 6 | GE for correct key (46): 1.0)
# KR: 7 | GE for correct key (46): 1.0)
# KR: 8 | GE for correct key (46): 1.0)
# KR: 9 | GE for correct key (46): 1.0)
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 500)               1100500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 500)               250500
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  gaussian_noise (GaussianNoi  (None, 500)              0
#  se)
#
#  dense_6 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 2,366,309
# Trainable params: 2,361,909
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 113/113 [==============================] - 5s 35ms/step - loss: 2.1270 - accuracy: 0.2206 - val_loss: 1.9763 - val_accuracy: 0.2368
# Epoch 2/10
# 113/113 [==============================] - 3s 30ms/step - loss: 1.6852 - accuracy: 0.3377 - val_loss: 2.0338 - val_accuracy: 0.2288
# Epoch 3/10
# 113/113 [==============================] - 3s 29ms/step - loss: 1.5216 - accuracy: 0.4172 - val_loss: 2.1018 - val_accuracy: 0.2260
# Epoch 4/10
# 113/113 [==============================] - 3s 30ms/step - loss: 1.3679 - accuracy: 0.4937 - val_loss: 2.1953 - val_accuracy: 0.2264
# Epoch 5/10
# 113/113 [==============================] - 3s 30ms/step - loss: 1.2100 - accuracy: 0.5664 - val_loss: 2.2515 - val_accuracy: 0.2408
# Epoch 6/10
# 113/113 [==============================] - 4s 31ms/step - loss: 1.0355 - accuracy: 0.6452 - val_loss: 2.4406 - val_accuracy: 0.2256
# Epoch 7/10
# 113/113 [==============================] - 4s 31ms/step - loss: 0.8560 - accuracy: 0.7178 - val_loss: 2.7259 - val_accuracy: 0.2284
# Epoch 8/10
# 113/113 [==============================] - 4s 31ms/step - loss: 0.6768 - accuracy: 0.7892 - val_loss: 3.2632 - val_accuracy: 0.2148
# Epoch 9/10
# 113/113 [==============================] - 4s 31ms/step - loss: 0.5116 - accuracy: 0.8525 - val_loss: 3.6908 - val_accuracy: 0.2044
# Epoch 10/10
# 113/113 [==============================] - 4s 31ms/step - loss: 0.3571 - accuracy: 0.9129 - val_loss: 3.8309 - val_accuracy: 0.1988
# KR: 0 | GE for correct key (46): 49.0)
# KR: 1 | GE for correct key (46): 49.0)
# KR: 2 | GE for correct key (46): 49.0)
# KR: 3 | GE for correct key (46): 49.0)
# KR: 4 | GE for correct key (46): 49.0)
# KR: 5 | GE for correct key (46): 49.0)
# KR: 6 | GE for correct key (46): 49.0)
# KR: 7 | GE for correct key (46): 49.0)
# KR: 8 | GE for correct key (46): 49.0)
# KR: 9 | GE for correct key (46): 49.0)
# KR: 10 | GE for correct key (46): 49.0)
# KR: 11 | GE for correct key (46): 49.0)
# KR: 12 | GE for correct key (46): 49.0)
# KR: 13 | GE for correct key (46): 49.0)
# KR: 14 | GE for correct key (46): 49.0)
# KR: 15 | GE for correct key (46): 49.0)
# KR: 16 | GE for correct key (46): 49.0)
# KR: 17 | GE for correct key (46): 49.0)
# KR: 18 | GE for correct key (46): 49.0)
# KR: 19 | GE for correct key (46): 49.0)
# KR: 20 | GE for correct key (46): 49.0)
# KR: 21 | GE for correct key (46): 49.0)
# KR: 22 | GE for correct key (46): 49.0)
# KR: 23 | GE for correct key (46): 49.0)
# KR: 24 | GE for correct key (46): 49.0)
# KR: 25 | GE for correct key (46): 49.0)
# KR: 26 | GE for correct key (46): 49.0)
# KR: 27 | GE for correct key (46): 49.0)
# KR: 28 | GE for correct key (46): 49.0)
# KR: 29 | GE for correct key (46): 49.0)
# KR: 30 | GE for correct key (46): 49.0)
# KR: 31 | GE for correct key (46): 49.0)
# KR: 32 | GE for correct key (46): 49.0)
# KR: 33 | GE for correct key (46): 49.0)
# KR: 34 | GE for correct key (46): 49.0)
# KR: 35 | GE for correct key (46): 49.0)
# KR: 36 | GE for correct key (46): 49.0)
# KR: 37 | GE for correct key (46): 49.0)
# KR: 38 | GE for correct key (46): 49.0)
# KR: 39 | GE for correct key (46): 49.0)
# KR: 40 | GE for correct key (46): 49.0)
# KR: 41 | GE for correct key (46): 49.0)
# KR: 42 | GE for correct key (46): 49.0)
# KR: 43 | GE for correct key (46): 49.0)
# KR: 44 | GE for correct key (46): 49.0)
# KR: 45 | GE for correct key (46): 49.0)
# KR: 46 | GE for correct key (46): 49.0)
# KR: 47 | GE for correct key (46): 49.0)
# KR: 48 | GE for correct key (46): 49.0)
# KR: 49 | GE for correct key (46): 49.0)
# KR: 50 | GE for correct key (46): 49.0)
# KR: 51 | GE for correct key (46): 49.0)
# KR: 52 | GE for correct key (46): 49.0)
# KR: 53 | GE for correct key (46): 49.0)
# KR: 54 | GE for correct key (46): 49.0)
# KR: 55 | GE for correct key (46): 49.0)
# KR: 56 | GE for correct key (46): 49.0)
# KR: 57 | GE for correct key (46): 49.0)
# KR: 58 | GE for correct key (46): 49.0)
# KR: 59 | GE for correct key (46): 49.0)
# KR: 60 | GE for correct key (46): 49.0)
# KR: 61 | GE for correct key (46): 49.0)
# KR: 62 | GE for correct key (46): 49.0)
# KR: 63 | GE for correct key (46): 49.0)
# KR: 64 | GE for correct key (46): 49.0)
# KR: 65 | GE for correct key (46): 49.0)
# KR: 66 | GE for correct key (46): 49.0)
# KR: 67 | GE for correct key (46): 49.0)
# KR: 68 | GE for correct key (46): 49.0)
# KR: 69 | GE for correct key (46): 49.0)
# KR: 70 | GE for correct key (46): 49.0)
# KR: 71 | GE for correct key (46): 49.0)
# KR: 72 | GE for correct key (46): 49.0)
# KR: 73 | GE for correct key (46): 49.0)
# KR: 74 | GE for correct key (46): 49.0)
# KR: 75 | GE for correct key (46): 49.0)
# KR: 76 | GE for correct key (46): 49.0)
# KR: 77 | GE for correct key (46): 49.0)
# KR: 78 | GE for correct key (46): 49.0)
# KR: 79 | GE for correct key (46): 49.0)
# KR: 80 | GE for correct key (46): 49.0)
# KR: 81 | GE for correct key (46): 49.0)
# KR: 82 | GE for correct key (46): 49.0)
# KR: 83 | GE for correct key (46): 49.0)
# KR: 84 | GE for correct key (46): 49.0)
# KR: 85 | GE for correct key (46): 49.0)
# KR: 86 | GE for correct key (46): 49.0)
# KR: 87 | GE for correct key (46): 49.0)
# KR: 88 | GE for correct key (46): 49.0)
# KR: 89 | GE for correct key (46): 49.0)
# KR: 90 | GE for correct key (46): 49.0)
# KR: 91 | GE for correct key (46): 49.0)
# KR: 92 | GE for correct key (46): 49.0)
# KR: 93 | GE for correct key (46): 49.0)
# KR: 94 | GE for correct key (46): 49.0)
# KR: 95 | GE for correct key (46): 49.0)
# KR: 96 | GE for correct key (46): 49.0)
# KR: 97 | GE for correct key (46): 49.0)
# KR: 98 | GE for correct key (46): 49.0)
# KR: 99 | GE for correct key (46): 49.0)
# KR: 0 | GE for correct key (46): 54.0)
# KR: 1 | GE for correct key (46): 54.0)
# KR: 2 | GE for correct key (46): 54.0)
# KR: 3 | GE for correct key (46): 54.0)
# KR: 4 | GE for correct key (46): 54.0)
# KR: 5 | GE for correct key (46): 54.0)
# KR: 6 | GE for correct key (46): 54.0)
# KR: 7 | GE for correct key (46): 54.0)
# KR: 8 | GE for correct key (46): 54.0)
# KR: 9 | GE for correct key (46): 54.0)
# KR: 10 | GE for correct key (46): 54.0)
# KR: 11 | GE for correct key (46): 54.0)
# KR: 12 | GE for correct key (46): 54.0)
# KR: 13 | GE for correct key (46): 54.0)
# KR: 14 | GE for correct key (46): 54.0)
# KR: 15 | GE for correct key (46): 54.0)
# KR: 16 | GE for correct key (46): 54.0)
# KR: 17 | GE for correct key (46): 54.0)
# KR: 18 | GE for correct key (46): 54.0)
# KR: 19 | GE for correct key (46): 54.0)
# KR: 20 | GE for correct key (46): 54.0)
# KR: 21 | GE for correct key (46): 54.0)
# KR: 22 | GE for correct key (46): 54.0)
# KR: 23 | GE for correct key (46): 54.0)
# KR: 24 | GE for correct key (46): 54.0)
# KR: 25 | GE for correct key (46): 54.0)
# KR: 26 | GE for correct key (46): 54.0)
# KR: 27 | GE for correct key (46): 54.0)
# KR: 28 | GE for correct key (46): 54.0)
# KR: 29 | GE for correct key (46): 54.0)
# KR: 30 | GE for correct key (46): 54.0)
# KR: 31 | GE for correct key (46): 54.0)
# KR: 32 | GE for correct key (46): 54.0)
# KR: 33 | GE for correct key (46): 54.0)
# KR: 34 | GE for correct key (46): 54.0)
# KR: 35 | GE for correct key (46): 54.0)
# KR: 36 | GE for correct key (46): 54.0)
# KR: 37 | GE for correct key (46): 54.0)
# KR: 38 | GE for correct key (46): 54.0)
# KR: 39 | GE for correct key (46): 54.0)
# KR: 40 | GE for correct key (46): 54.0)
# KR: 41 | GE for correct key (46): 54.0)
# KR: 42 | GE for correct key (46): 54.0)
# KR: 43 | GE for correct key (46): 54.0)
# KR: 44 | GE for correct key (46): 54.0)
# KR: 45 | GE for correct key (46): 54.0)
# KR: 46 | GE for correct key (46): 54.0)
# KR: 47 | GE for correct key (46): 54.0)
# KR: 48 | GE for correct key (46): 54.0)
# KR: 49 | GE for correct key (46): 54.0)
# KR: 50 | GE for correct key (46): 54.0)
# KR: 51 | GE for correct key (46): 54.0)
# KR: 52 | GE for correct key (46): 54.0)
# KR: 53 | GE for correct key (46): 54.0)
# KR: 54 | GE for correct key (46): 54.0)
# KR: 55 | GE for correct key (46): 54.0)
# KR: 56 | GE for correct key (46): 54.0)
# KR: 57 | GE for correct key (46): 54.0)
# KR: 58 | GE for correct key (46): 54.0)
# KR: 59 | GE for correct key (46): 54.0)
# KR: 60 | GE for correct key (46): 54.0)
# KR: 61 | GE for correct key (46): 54.0)
# KR: 62 | GE for correct key (46): 54.0)
# KR: 63 | GE for correct key (46): 54.0)
# KR: 64 | GE for correct key (46): 54.0)
# KR: 65 | GE for correct key (46): 54.0)
# KR: 66 | GE for correct key (46): 54.0)
# KR: 67 | GE for correct key (46): 54.0)
# KR: 68 | GE for correct key (46): 54.0)
# KR: 69 | GE for correct key (46): 54.0)
# KR: 70 | GE for correct key (46): 54.0)
# KR: 71 | GE for correct key (46): 54.0)
# KR: 72 | GE for correct key (46): 54.0)
# KR: 73 | GE for correct key (46): 54.0)
# KR: 74 | GE for correct key (46): 54.0)
# KR: 75 | GE for correct key (46): 54.0)
# KR: 76 | GE for correct key (46): 54.0)
# KR: 77 | GE for correct key (46): 54.0)
# KR: 78 | GE for correct key (46): 54.0)
# KR: 79 | GE for correct key (46): 54.0)
# KR: 80 | GE for correct key (46): 54.0)
# KR: 81 | GE for correct key (46): 54.0)
# KR: 82 | GE for correct key (46): 54.0)
# KR: 83 | GE for correct key (46): 54.0)
# KR: 84 | GE for correct key (46): 54.0)
# KR: 85 | GE for correct key (46): 54.0)
# KR: 86 | GE for correct key (46): 54.0)
# KR: 87 | GE for correct key (46): 54.0)
# KR: 88 | GE for correct key (46): 54.0)
# KR: 89 | GE for correct key (46): 54.0)
# KR: 90 | GE for correct key (46): 54.0)
# KR: 91 | GE for correct key (46): 54.0)
# KR: 92 | GE for correct key (46): 54.0)
# KR: 93 | GE for correct key (46): 54.0)
# KR: 94 | GE for correct key (46): 54.0)
# KR: 95 | GE for correct key (46): 54.0)
# KR: 96 | GE for correct key (46): 54.0)
# KR: 97 | GE for correct key (46): 54.0)
# KR: 98 | GE for correct key (46): 54.0)
# KR: 99 | GE for correct key (46): 54.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  gaussian_noise (GaussianNoi  (None, 600)              0
#  se)
#
#  dense_4 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,416,609
# Trainable params: 2,412,209
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 113/113 [==============================] - 4s 31ms/step - loss: 2.1052 - accuracy: 0.1928 - val_loss: 2.0380 - val_accuracy: 0.1840
# Epoch 2/10
# 113/113 [==============================] - 3s 29ms/step - loss: 1.7019 - accuracy: 0.3293 - val_loss: 2.0839 - val_accuracy: 0.1752
# Epoch 3/10
# 113/113 [==============================] - 3s 29ms/step - loss: 1.5824 - accuracy: 0.3917 - val_loss: 1.8709 - val_accuracy: 0.2208
# Epoch 4/10
# 113/113 [==============================] - 3s 29ms/step - loss: 1.4781 - accuracy: 0.4514 - val_loss: 1.9447 - val_accuracy: 0.2116
# Epoch 5/10
# 113/113 [==============================] - 3s 29ms/step - loss: 1.3667 - accuracy: 0.5059 - val_loss: 1.9759 - val_accuracy: 0.2108
# Epoch 6/10
# 113/113 [==============================] - 3s 29ms/step - loss: 1.2317 - accuracy: 0.5704 - val_loss: 2.0956 - val_accuracy: 0.2044
# Epoch 7/10
# 113/113 [==============================] - 3s 29ms/step - loss: 1.0893 - accuracy: 0.6336 - val_loss: 2.2634 - val_accuracy: 0.1820
# Epoch 8/10
# 113/113 [==============================] - 3s 28ms/step - loss: 0.9364 - accuracy: 0.6935 - val_loss: 2.3369 - val_accuracy: 0.1976
# Epoch 9/10
# 113/113 [==============================] - 3s 28ms/step - loss: 0.7778 - accuracy: 0.7595 - val_loss: 2.5325 - val_accuracy: 0.2000
# Epoch 10/10
# 113/113 [==============================] - 3s 28ms/step - loss: 0.6286 - accuracy: 0.8130 - val_loss: 2.7884 - val_accuracy: 0.1948
# KR: 0 | GE for correct key (46): 5.0)
# KR: 1 | GE for correct key (46): 5.0)
# KR: 2 | GE for correct key (46): 5.0)
# KR: 3 | GE for correct key (46): 5.0)
# KR: 4 | GE for correct key (46): 5.0)
# KR: 5 | GE for correct key (46): 5.0)
# KR: 6 | GE for correct key (46): 5.0)
# KR: 7 | GE for correct key (46): 5.0)
# KR: 8 | GE for correct key (46): 5.0)
# KR: 9 | GE for correct key (46): 5.0)
# KR: 10 | GE for correct key (46): 5.0)
# KR: 11 | GE for correct key (46): 5.0)
# KR: 12 | GE for correct key (46): 5.0)
# KR: 13 | GE for correct key (46): 5.0)
# KR: 14 | GE for correct key (46): 5.0)
# KR: 15 | GE for correct key (46): 5.0)
# KR: 16 | GE for correct key (46): 5.0)
# KR: 17 | GE for correct key (46): 5.0)
# KR: 18 | GE for correct key (46): 5.0)
# KR: 19 | GE for correct key (46): 5.0)
# KR: 20 | GE for correct key (46): 5.0)
# KR: 21 | GE for correct key (46): 5.0)
# KR: 22 | GE for correct key (46): 5.0)
# KR: 23 | GE for correct key (46): 5.0)
# KR: 24 | GE for correct key (46): 5.0)
# KR: 25 | GE for correct key (46): 5.0)
# KR: 26 | GE for correct key (46): 5.0)
# KR: 27 | GE for correct key (46): 5.0)
# KR: 28 | GE for correct key (46): 5.0)
# KR: 29 | GE for correct key (46): 5.0)
# KR: 30 | GE for correct key (46): 5.0)
# KR: 31 | GE for correct key (46): 5.0)
# KR: 32 | GE for correct key (46): 5.0)
# KR: 33 | GE for correct key (46): 5.0)
# KR: 34 | GE for correct key (46): 5.0)
# KR: 35 | GE for correct key (46): 5.0)
# KR: 36 | GE for correct key (46): 5.0)
# KR: 37 | GE for correct key (46): 5.0)
# KR: 38 | GE for correct key (46): 5.0)
# KR: 39 | GE for correct key (46): 5.0)
# KR: 40 | GE for correct key (46): 5.0)
# KR: 41 | GE for correct key (46): 5.0)
# KR: 42 | GE for correct key (46): 5.0)
# KR: 43 | GE for correct key (46): 5.0)
# KR: 44 | GE for correct key (46): 5.0)
# KR: 45 | GE for correct key (46): 5.0)
# KR: 46 | GE for correct key (46): 5.0)
# KR: 47 | GE for correct key (46): 5.0)
# KR: 48 | GE for correct key (46): 5.0)
# KR: 49 | GE for correct key (46): 5.0)
# KR: 50 | GE for correct key (46): 5.0)
# KR: 51 | GE for correct key (46): 5.0)
# KR: 52 | GE for correct key (46): 5.0)
# KR: 53 | GE for correct key (46): 5.0)
# KR: 54 | GE for correct key (46): 5.0)
# KR: 55 | GE for correct key (46): 5.0)
# KR: 56 | GE for correct key (46): 5.0)
# KR: 57 | GE for correct key (46): 5.0)
# KR: 58 | GE for correct key (46): 5.0)
# KR: 59 | GE for correct key (46): 5.0)
# KR: 60 | GE for correct key (46): 5.0)
# KR: 61 | GE for correct key (46): 5.0)
# KR: 62 | GE for correct key (46): 5.0)
# KR: 63 | GE for correct key (46): 5.0)
# KR: 64 | GE for correct key (46): 5.0)
# KR: 65 | GE for correct key (46): 5.0)
# KR: 66 | GE for correct key (46): 5.0)
# KR: 67 | GE for correct key (46): 5.0)
# KR: 68 | GE for correct key (46): 5.0)
# KR: 69 | GE for correct key (46): 5.0)
# KR: 70 | GE for correct key (46): 5.0)
# KR: 71 | GE for correct key (46): 5.0)
# KR: 72 | GE for correct key (46): 5.0)
# KR: 73 | GE for correct key (46): 5.0)
# KR: 74 | GE for correct key (46): 5.0)
# KR: 75 | GE for correct key (46): 5.0)
# KR: 76 | GE for correct key (46): 5.0)
# KR: 77 | GE for correct key (46): 5.0)
# KR: 78 | GE for correct key (46): 5.0)
# KR: 79 | GE for correct key (46): 5.0)
# KR: 80 | GE for correct key (46): 5.0)
# KR: 81 | GE for correct key (46): 5.0)
# KR: 82 | GE for correct key (46): 5.0)
# KR: 83 | GE for correct key (46): 5.0)
# KR: 84 | GE for correct key (46): 5.0)
# KR: 85 | GE for correct key (46): 5.0)
# KR: 86 | GE for correct key (46): 5.0)
# KR: 87 | GE for correct key (46): 5.0)
# KR: 88 | GE for correct key (46): 5.0)
# KR: 89 | GE for correct key (46): 5.0)
# KR: 90 | GE for correct key (46): 5.0)
# KR: 91 | GE for correct key (46): 5.0)
# KR: 92 | GE for correct key (46): 5.0)
# KR: 93 | GE for correct key (46): 5.0)
# KR: 94 | GE for correct key (46): 5.0)
# KR: 95 | GE for correct key (46): 5.0)
# KR: 96 | GE for correct key (46): 5.0)
# KR: 97 | GE for correct key (46): 5.0)
# KR: 98 | GE for correct key (46): 5.0)
# KR: 99 | GE for correct key (46): 5.0)
# KR: 0 | GE for correct key (46): 248.0)
# KR: 1 | GE for correct key (46): 248.0)
# KR: 2 | GE for correct key (46): 248.0)
# KR: 3 | GE for correct key (46): 248.0)
# KR: 4 | GE for correct key (46): 248.0)
# KR: 5 | GE for correct key (46): 248.0)
# KR: 6 | GE for correct key (46): 248.0)
# KR: 7 | GE for correct key (46): 248.0)
# KR: 8 | GE for correct key (46): 248.0)
# KR: 9 | GE for correct key (46): 248.0)
# KR: 10 | GE for correct key (46): 248.0)
# KR: 11 | GE for correct key (46): 248.0)
# KR: 12 | GE for correct key (46): 248.0)
# KR: 13 | GE for correct key (46): 248.0)
# KR: 14 | GE for correct key (46): 248.0)
# KR: 15 | GE for correct key (46): 248.0)
# KR: 16 | GE for correct key (46): 248.0)
# KR: 17 | GE for correct key (46): 248.0)
# KR: 18 | GE for correct key (46): 248.0)
# KR: 19 | GE for correct key (46): 248.0)
# KR: 20 | GE for correct key (46): 248.0)
# KR: 21 | GE for correct key (46): 248.0)
# KR: 22 | GE for correct key (46): 248.0)
# KR: 23 | GE for correct key (46): 248.0)
# KR: 24 | GE for correct key (46): 248.0)
# KR: 25 | GE for correct key (46): 248.0)
# KR: 26 | GE for correct key (46): 248.0)
# KR: 27 | GE for correct key (46): 248.0)
# KR: 28 | GE for correct key (46): 248.0)
# KR: 29 | GE for correct key (46): 248.0)
# KR: 30 | GE for correct key (46): 248.0)
# KR: 31 | GE for correct key (46): 248.0)
# KR: 32 | GE for correct key (46): 248.0)
# KR: 33 | GE for correct key (46): 248.0)
# KR: 34 | GE for correct key (46): 248.0)
# KR: 35 | GE for correct key (46): 248.0)
# KR: 36 | GE for correct key (46): 248.0)
# KR: 37 | GE for correct key (46): 248.0)
# KR: 38 | GE for correct key (46): 248.0)
# KR: 39 | GE for correct key (46): 248.0)
# KR: 40 | GE for correct key (46): 248.0)
# KR: 41 | GE for correct key (46): 248.0)
# KR: 42 | GE for correct key (46): 248.0)
# KR: 43 | GE for correct key (46): 248.0)
# KR: 44 | GE for correct key (46): 248.0)
# KR: 45 | GE for correct key (46): 248.0)
# KR: 46 | GE for correct key (46): 248.0)
# KR: 47 | GE for correct key (46): 248.0)
# KR: 48 | GE for correct key (46): 248.0)
# KR: 49 | GE for correct key (46): 248.0)
# KR: 50 | GE for correct key (46): 248.0)
# KR: 51 | GE for correct key (46): 248.0)
# KR: 52 | GE for correct key (46): 248.0)
# KR: 53 | GE for correct key (46): 248.0)
# KR: 54 | GE for correct key (46): 248.0)
# KR: 55 | GE for correct key (46): 248.0)
# KR: 56 | GE for correct key (46): 248.0)
# KR: 57 | GE for correct key (46): 248.0)
# KR: 58 | GE for correct key (46): 248.0)
# KR: 59 | GE for correct key (46): 248.0)
# KR: 60 | GE for correct key (46): 248.0)
# KR: 61 | GE for correct key (46): 248.0)
# KR: 62 | GE for correct key (46): 248.0)
# KR: 63 | GE for correct key (46): 248.0)
# KR: 64 | GE for correct key (46): 248.0)
# KR: 65 | GE for correct key (46): 248.0)
# KR: 66 | GE for correct key (46): 248.0)
# KR: 67 | GE for correct key (46): 248.0)
# KR: 68 | GE for correct key (46): 248.0)
# KR: 69 | GE for correct key (46): 248.0)
# KR: 70 | GE for correct key (46): 248.0)
# KR: 71 | GE for correct key (46): 248.0)
# KR: 72 | GE for correct key (46): 248.0)
# KR: 73 | GE for correct key (46): 248.0)
# KR: 74 | GE for correct key (46): 248.0)
# ...
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 600)               360600
#
#  gaussian_noise (GaussianNoi  (None, 600)              0
#  se)
#
#  dense_6 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 3,137,809
# Trainable params: 3,133,409
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 113/113 [==============================] - 5s 40ms/step - loss: 2.7855 - accuracy: 0.2089 - val_loss: 2.2348 - val_accuracy: 0.2244
# Epoch 2/10
# 113/113 [==============================] - 4s 39ms/step - loss: 1.7612 - accuracy: 0.3423 - val_loss: 2.1865 - val_accuracy: 0.2256
# Epoch 3/10
# 113/113 [==============================] - 4s 38ms/step - loss: 1.4269 - accuracy: 0.4619 - val_loss: 2.3118 - val_accuracy: 0.2184
# Epoch 4/10
# 113/113 [==============================] - 4s 37ms/step - loss: 1.1595 - accuracy: 0.5705 - val_loss: 2.3898 - val_accuracy: 0.2140
# Epoch 5/10
# 113/113 [==============================] - 4s 35ms/step - loss: 0.8981 - accuracy: 0.6815 - val_loss: 2.5599 - val_accuracy: 0.2224
# Epoch 6/10
# 113/113 [==============================] - 4s 35ms/step - loss: 0.6571 - accuracy: 0.7810 - val_loss: 2.7900 - val_accuracy: 0.2220
# Epoch 7/10
# 113/113 [==============================] - 4s 33ms/step - loss: 0.4413 - accuracy: 0.8679 - val_loss: 3.1839 - val_accuracy: 0.2156
# Epoch 8/10
# 113/113 [==============================] - 4s 33ms/step - loss: 0.2802 - accuracy: 0.9278 - val_loss: 3.4263 - val_accuracy: 0.2128
# Epoch 9/10
# 113/113 [==============================] - 4s 34ms/step - loss: 0.1638 - accuracy: 0.9666 - val_loss: 3.7760 - val_accuracy: 0.2140
# Epoch 10/10
# 113/113 [==============================] - 4s 34ms/step - loss: 0.0914 - accuracy: 0.9866 - val_loss: 4.0180 - val_accuracy: 0.2244
# KR: 0 | GE for correct key (46): 91.0)
# KR: 1 | GE for correct key (46): 91.0)
# KR: 2 | GE for correct key (46): 91.0)
# KR: 3 | GE for correct key (46): 91.0)
# KR: 4 | GE for correct key (46): 91.0)
# KR: 5 | GE for correct key (46): 91.0)
# KR: 6 | GE for correct key (46): 91.0)
# KR: 7 | GE for correct key (46): 91.0)
# KR: 8 | GE for correct key (46): 91.0)
# KR: 9 | GE for correct key (46): 91.0)
# KR: 10 | GE for correct key (46): 91.0)
# KR: 11 | GE for correct key (46): 91.0)
# KR: 12 | GE for correct key (46): 91.0)
# KR: 13 | GE for correct key (46): 91.0)
# KR: 14 | GE for correct key (46): 91.0)
# KR: 15 | GE for correct key (46): 91.0)
# KR: 16 | GE for correct key (46): 91.0)
# KR: 17 | GE for correct key (46): 91.0)
# KR: 18 | GE for correct key (46): 91.0)
# KR: 19 | GE for correct key (46): 91.0)
# KR: 20 | GE for correct key (46): 91.0)
# KR: 21 | GE for correct key (46): 91.0)
# KR: 22 | GE for correct key (46): 91.0)
# KR: 23 | GE for correct key (46): 91.0)
# KR: 24 | GE for correct key (46): 91.0)
# KR: 25 | GE for correct key (46): 91.0)
# KR: 26 | GE for correct key (46): 91.0)
# KR: 27 | GE for correct key (46): 91.0)
# KR: 28 | GE for correct key (46): 91.0)
# KR: 29 | GE for correct key (46): 91.0)
# KR: 30 | GE for correct key (46): 91.0)
# KR: 31 | GE for correct key (46): 91.0)
# KR: 32 | GE for correct key (46): 91.0)
# KR: 33 | GE for correct key (46): 91.0)
# KR: 34 | GE for correct key (46): 91.0)
# KR: 35 | GE for correct key (46): 91.0)
# KR: 36 | GE for correct key (46): 91.0)
# KR: 37 | GE for correct key (46): 91.0)
# KR: 38 | GE for correct key (46): 91.0)
# KR: 39 | GE for correct key (46): 91.0)
# KR: 40 | GE for correct key (46): 91.0)
# KR: 41 | GE for correct key (46): 91.0)
# KR: 42 | GE for correct key (46): 91.0)
# KR: 43 | GE for correct key (46): 91.0)
# KR: 44 | GE for correct key (46): 91.0)
# KR: 45 | GE for correct key (46): 91.0)
# KR: 46 | GE for correct key (46): 91.0)
# KR: 47 | GE for correct key (46): 91.0)
# KR: 48 | GE for correct key (46): 91.0)
# KR: 49 | GE for correct key (46): 91.0)
# KR: 50 | GE for correct key (46): 91.0)
# KR: 51 | GE for correct key (46): 91.0)
# KR: 52 | GE for correct key (46): 91.0)
# KR: 53 | GE for correct key (46): 91.0)
# KR: 54 | GE for correct key (46): 91.0)
# KR: 55 | GE for correct key (46): 91.0)
# KR: 56 | GE for correct key (46): 91.0)
# KR: 57 | GE for correct key (46): 91.0)
# KR: 58 | GE for correct key (46): 91.0)
# KR: 59 | GE for correct key (46): 91.0)
# KR: 60 | GE for correct key (46): 91.0)
# KR: 61 | GE for correct key (46): 91.0)
# KR: 62 | GE for correct key (46): 91.0)
# KR: 63 | GE for correct key (46): 91.0)
# KR: 64 | GE for correct key (46): 91.0)
# KR: 65 | GE for correct key (46): 91.0)
# KR: 66 | GE for correct key (46): 91.0)
# KR: 67 | GE for correct key (46): 91.0)
# KR: 68 | GE for correct key (46): 91.0)
# KR: 69 | GE for correct key (46): 91.0)
# KR: 70 | GE for correct key (46): 91.0)
# KR: 71 | GE for correct key (46): 91.0)
# KR: 72 | GE for correct key (46): 91.0)
# KR: 73 | GE for correct key (46): 91.0)
# KR: 74 | GE for correct key (46): 91.0)
# KR: 75 | GE for correct key (46): 91.0)
# KR: 76 | GE for correct key (46): 91.0)
# KR: 77 | GE for correct key (46): 91.0)
# KR: 78 | GE for correct key (46): 91.0)
# KR: 79 | GE for correct key (46): 91.0)
# KR: 80 | GE for correct key (46): 91.0)
# KR: 81 | GE for correct key (46): 91.0)
# KR: 82 | GE for correct key (46): 91.0)
# KR: 83 | GE for correct key (46): 91.0)
# KR: 84 | GE for correct key (46): 91.0)
# KR: 85 | GE for correct key (46): 91.0)
# KR: 86 | GE for correct key (46): 91.0)
# KR: 87 | GE for correct key (46): 91.0)
# KR: 88 | GE for correct key (46): 91.0)
# KR: 89 | GE for correct key (46): 91.0)
# KR: 90 | GE for correct key (46): 91.0)
# KR: 91 | GE for correct key (46): 91.0)
# KR: 92 | GE for correct key (46): 91.0)
# KR: 93 | GE for correct key (46): 91.0)
# KR: 94 | GE for correct key (46): 91.0)
# KR: 95 | GE for correct key (46): 91.0)
# KR: 96 | GE for correct key (46): 91.0)
# KR: 97 | GE for correct key (46): 91.0)
# KR: 98 | GE for correct key (46): 91.0)
# KR: 99 | GE for correct key (46): 91.0)
# KR: 0 | GE for correct key (46): 13.0)
# KR: 1 | GE for correct key (46): 13.0)
# KR: 2 | GE for correct key (46): 13.0)
# KR: 3 | GE for correct key (46): 13.0)
# KR: 4 | GE for correct key (46): 13.0)
# KR: 5 | GE for correct key (46): 13.0)
# KR: 6 | GE for correct key (46): 13.0)
# KR: 7 | GE for correct key (46): 13.0)
# KR: 8 | GE for correct key (46): 13.0)
# KR: 9 | GE for correct key (46): 13.0)
# KR: 10 | GE for correct key (46): 13.0)
# KR: 11 | GE for correct key (46): 13.0)
# KR: 12 | GE for correct key (46): 13.0)
# KR: 13 | GE for correct key (46): 13.0)
# KR: 14 | GE for correct key (46): 13.0)
# KR: 15 | GE for correct key (46): 13.0)
# KR: 16 | GE for correct key (46): 13.0)
# KR: 17 | GE for correct key (46): 13.0)
# KR: 18 | GE for correct key (46): 13.0)
# KR: 19 | GE for correct key (46): 13.0)
# KR: 20 | GE for correct key (46): 13.0)
# KR: 21 | GE for correct key (46): 13.0)
# KR: 22 | GE for correct key (46): 13.0)
# KR: 23 | GE for correct key (46): 13.0)
# KR: 24 | GE for correct key (46): 13.0)
# KR: 25 | GE for correct key (46): 13.0)
# KR: 26 | GE for correct key (46): 13.0)
# KR: 27 | GE for correct key (46): 13.0)
# KR: 28 | GE for correct key (46): 13.0)
# KR: 29 | GE for correct key (46): 13.0)
# KR: 30 | GE for correct key (46): 13.0)
# KR: 31 | GE for correct key (46): 13.0)
# KR: 32 | GE for correct key (46): 13.0)
# KR: 33 | GE for correct key (46): 13.0)
# KR: 34 | GE for correct key (46): 13.0)
# KR: 35 | GE for correct key (46): 13.0)
# KR: 36 | GE for correct key (46): 13.0)
# KR: 37 | GE for correct key (46): 13.0)
# KR: 38 | GE for correct key (46): 13.0)
# KR: 39 | GE for correct key (46): 13.0)
# KR: 40 | GE for correct key (46): 13.0)
# KR: 41 | GE for correct key (46): 13.0)
# KR: 42 | GE for correct key (46): 13.0)
# KR: 43 | GE for correct key (46): 13.0)
# KR: 44 | GE for correct key (46): 13.0)
# KR: 45 | GE for correct key (46): 13.0)
# KR: 46 | GE for correct key (46): 13.0)
# KR: 47 | GE for correct key (46): 13.0)
# KR: 48 | GE for correct key (46): 13.0)
# KR: 49 | GE for correct key (46): 13.0)
# KR: 50 | GE for correct key (46): 13.0)
# KR: 51 | GE for correct key (46): 13.0)
# KR: 52 | GE for correct key (46): 13.0)
# KR: 53 | GE for correct key (46): 13.0)
# KR: 54 | GE for correct key (46): 13.0)
# KR: 55 | GE for correct key (46): 13.0)
# KR: 56 | GE for correct key (46): 13.0)
# KR: 57 | GE for correct key (46): 13.0)
# KR: 58 | GE for correct key (46): 13.0)
# KR: 59 | GE for correct key (46): 13.0)
# KR: 60 | GE for correct key (46): 13.0)
# KR: 61 | GE for correct key (46): 13.0)
# KR: 62 | GE for correct key (46): 13.0)
# KR: 63 | GE for correct key (46): 13.0)
# KR: 64 | GE for correct key (46): 13.0)
# KR: 65 | GE for correct key (46): 13.0)
# KR: 66 | GE for correct key (46): 13.0)
# KR: 67 | GE for correct key (46): 13.0)
# KR: 68 | GE for correct key (46): 13.0)
# KR: 69 | GE for correct key (46): 13.0)
# KR: 70 | GE for correct key (46): 13.0)
# KR: 71 | GE for correct key (46): 13.0)
# KR: 72 | GE for correct key (46): 13.0)
# KR: 73 | GE for correct key (46): 13.0)
# KR: 74 | GE for correct key (46): 13.0)
# KR: 75 | GE for correct key (46): 13.0)
# KR: 76 | GE for correct key (46): 13.0)
# KR: 77 | GE for correct key (46): 13.0)
# KR: 78 | GE for correct key (46): 13.0)
# KR: 79 | GE for correct key (46): 13.0)
# KR: 80 | GE for correct key (46): 13.0)
# KR: 81 | GE for correct key (46): 13.0)
# KR: 82 | GE for correct key (46): 13.0)
# KR: 83 | GE for correct key (46): 13.0)
# KR: 84 | GE for correct key (46): 13.0)
# KR: 85 | GE for correct key (46): 13.0)
# KR: 86 | GE for correct key (46): 13.0)
# KR: 87 | GE for correct key (46): 13.0)
# KR: 88 | GE for correct key (46): 13.0)
# KR: 89 | GE for correct key (46): 13.0)
# KR: 90 | GE for correct key (46): 13.0)
# KR: 91 | GE for correct key (46): 13.0)
# KR: 92 | GE for correct key (46): 13.0)
# KR: 93 | GE for correct key (46): 13.0)
# KR: 94 | GE for correct key (46): 13.0)
# KR: 95 | GE for correct key (46): 13.0)
# KR: 96 | GE for correct key (46): 13.0)
# KR: 97 | GE for correct key (46): 13.0)
# KR: 98 | GE for correct key (46): 13.0)
# KR: 99 | GE for correct key (46): 13.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-fa83d56d4cb6> in <module>()
#       7 ensemble_aes.set_epochs(10)
#       8 #ensemble_aes.run_ensemble(number_of_models=5, number_of_best_models=[1,2,3,4])
# ----> 9 ensemble_aes.run_ensemble(number_of_models=50, number_of_best_models=[1,5,10,20])
#
# <ipython-input-9-5b2edaf10298> in run_ensemble(self, number_of_models, number_of_best_models)
#     291
#     292         ge_ensemble, ge_ensemble_best_models, sr_ensemble, sr_ensemble_best_models = self.compute_ensembles(kr_nt,
# --> 293                                                                                                             target_params["good_key"])
#     294
#     295         self.ge_ensemble = ge_ensemble
#
# <ipython-input-9-5b2edaf10298> in compute_ensembles(self, kr_nt, correct_key)
#     161                 for model_index in range(self.number_of_models):
#     162                     key_p_ensemble += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)
# --> 163                 for model_index in range(self.number_of_best_models):
#     164                     key_p_ensemble_best_models += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)
#     165
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
plt.rc('figure', figsize=(15, 8))

# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('MLP_ASCAD_Ensembles_Tuning.png')
plt.savefig('MLP_ASCAD_Ensembles_Tuning.pdf')

# %%
ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ascad_fixed_key")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
ensemble_aes.run_ensemble(number_of_models=1, number_of_best_models=1)
# Out:
# loaded
# No handles with labels found to put in legend.
# Class=5, n=13554 (11.111%)
# Class=6, n=13554 (11.111%)
# Class=4, n=13554 (11.111%)
# Class=1, n=13554 (11.111%)
# Class=3, n=13554 (11.111%)
# Class=7, n=13554 (11.111%)
# Class=2, n=13554 (11.111%)
# Class=0, n=13554 (11.111%)
# Class=8, n=13554 (11.111%)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_7 (Batc  (None, 700)              2800
#  hNormalization)
#
#  dense_39 (Dense)            (None, 500)               350500
#
#  dense_40 (Dense)            (None, 500)               250500
#
#  dense_41 (Dense)            (None, 9)                 4509
#
# =================================================================
# Total params: 608,309
# Trainable params: 606,909
# Non-trainable params: 1,400
# _________________________________________________________________
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 125/125 [==============================] - 2s 15ms/step - loss: 1.9165 - accuracy: 0.2304 - val_loss: 1.8311 - val_accuracy: 0.2550
# Epoch 2/10
# 125/125 [==============================] - 1s 10ms/step - loss: 1.8026 - accuracy: 0.2582 - val_loss: 1.8336 - val_accuracy: 0.2410
# Epoch 3/10
# 125/125 [==============================] - 1s 10ms/step - loss: 1.7755 - accuracy: 0.2715 - val_loss: 1.8118 - val_accuracy: 0.2572
# Epoch 4/10
#  22/125 [====>.........................] - ETA: 1s - loss: 1.7575 - accuracy: 0.2875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-a69d99ce8306> in <module>()
#       5 ensemble_aes.set_mini_batch(400)
#       6 ensemble_aes.set_epochs(10)
# ----> 7 ensemble_aes.run_ensemble(number_of_models=1, number_of_best_models=1)
#
# <ipython-input-27-5b2edaf10298> in run_ensemble(self, number_of_models, number_of_best_models)
#     270                                                                                       X_attack, Y_attack,
#     271                                                                                       plt_validation, plt_attack,
# --> 272                                                                                       target_params, kr_step, kr_fraction)
#     273             self.ge_all_validation.append(ge_validation)
#     274             self.ge_all_attack.append(ge_attack)
#
# <ipython-input-27-5b2edaf10298> in run_mlp(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params, step, fraction)
#      90             shuffle=True,
#      91             validation_data=(X_validation, Y_validation),       #We train by running MLP and then we use SCA metrics to verify accuracy
# ---> 92             callbacks=[])
#      93                                                                                    #this shows on the window first
#      94         ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     534
#     535     for i, func_graph_output in enumerate(self._func_graph_outputs):
# --> 536       handle_data_util.copy_handle_data(func_graph_output, outputs[i])
#     537     if executing_eagerly:
#     538       return outputs
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/handle_data_util.py in copy_handle_data(source_t, target_t)
#      38     target_t: The tensor to copy HandleData to.
#      39   """
# ---> 40   if (target_t.dtype == dtypes.resource or
#      41       target_t.dtype == dtypes.variant):
#      42     if isinstance(source_t, ops.EagerTensor):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py in __eq__(self, other)
#     184         return False
#     185
# --> 186     return self._type_enum == other._type_enum  # pylint: disable=protected-access
#     187
#     188   def __ne__(self, other):
#
# KeyboardInterrupt:

# %%
ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
ensemble_aes.run_ensemble(number_of_models=50, number_of_best_models=10)

# plotting GE and SR
plt.subplot(1, 2, 1)
plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.show()
# Out:
# loaded
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0126e0351289> in <module>()
#       5 ensemble_aes.set_mini_batch(400)
#       6 ensemble_aes.set_epochs(10)
# ----> 7 ensemble_aes.run_ensemble(number_of_models=50, number_of_best_models=10)
#       8
#       9 # plotting GE and SR
#
# <ipython-input-13-c34a622f68f6> in run_ensemble(self, number_of_models, number_of_best_models)
#     223         X_profilinga, y_profilinga = oversample.fit_resample(X_profiling, Y_profiling)  #added
#     224         # summarize distribution
# --> 225         counter = Counter(y_profiling)      #added
#     226         for k,v in counter.items():   #added
#     227           per = v / len(y_profilinga) * 100   #added
#
# NameError: name 'y_profiling' is not defined

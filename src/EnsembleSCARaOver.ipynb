# %%
import sys
import os
from tensorflow.keras import backend as backend
from tensorflow.keras.utils import to_categorical
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import tensorflow as tf
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

#!cp /content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py/
#file_location = "/content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py"
#sys.path.append(os.path.abspath(file_location))
#sys.path.insert(0,'/content/drive/MyDrive/Colab\Notebooks/QEResearch/ches_ctf/')
#sys.path.append('/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf')
#import SCAMetrics
# Out:
# Mounted at /content/drive

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %%
import imblearn
print(imblearn.__version__)
# Out:
# 0.8.1

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1E9kCFN_Qf6720hbw996x6z0xUSLqQwjg'})

# %%
# !pip install import-ipynb
import import_ipynb

# !pip install -U -q PyDrive
#your_module.GetContentFile('sca_metrics.ipynb')
#from sca_metrics import *
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.3.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (57.4.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (2.15.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.4

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
#your_module = drive.CreateFile({'id':'11WgfAW1xTNRX_tl74AcFCnJNh6hhjtrQ'})
your_module = drive.CreateFile({'id':'1t5viOwM1THtGwwGzxVIO1hvrroYqvGdA'})
your_module.GetContentFile('sca_metrics.py') 
import sca_metrics
from sca_metrics import SCAMetrics
#your_module.GetContentFile({'id':'16R_OCUvUjNXD3hnk_XvW0H2CR-MtbpeI'})

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm'})
your_module.GetContentFile('loaddatasetimbalanced.py') #13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm
import loaddatasetimbalanced
from loaddatasetimbalanced import LoadDatasets

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'14CorI66D0y0P-4eXCStsl90Avpb-xtUM'})
your_module.GetContentFile('datasets.py') #14CorI66D0y0P-4eXCStsl90Avpb-xtUM
import datasets
from datasets import SCADatasets

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd'})
your_module.GetContentFile('neural_networks.py') #1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd
import neural_networks
from neural_networks import NeuralNetwork

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import random


class EnsembleAES:

    def __init__(self):
        self.number_of_models = 50
        self.number_of_best_models = [10, 10, 10, 10]
        self.ge_all_validation = []
        self.ge_all_attack = []
        self.sr_all_validation = []
        self.sr_all_attack = []
        self.k_ps_all = []
        self.ge_ensemble = None
        self.ge_ensemble_best_models = None
        self.ge_ensemble_best_models0 = None #added
        self.ge_ensemble_best_models1 = None #added
        self.ge_ensemble_best_models2 = None #added
        self.ge_ensemble_best_models3 = None #added
        self.ge_best_model_validation = None
        self.ge_best_model_attack = None
        self.sr_ensemble = None
        self.sr_ensemble_best_models = None
        self.sr_ensemble_best_models0 = None #added
        self.sr_ensemble_best_models1 = None #added
        self.sr_ensemble_best_models2 = None #added
        self.sr_ensemble_best_models3 = None #added
        self.sr_best_model_validation = None
        self.sr_best_model_attack = None
        self.target_dataset = None
        self.l_model = None
        self.target_byte = None
        self.classes = None
        self.epochs = None
        self.mini_batch = None

    def set_dataset(self, target): #function for setting up dataset - ASCAD | ches_ctf
        self.target_dataset = target

    def set_leakage_model(self, leakage_model): #function for setting up leakage model
        self.l_model = leakage_model
        if leakage_model == "HW":
            self.classes = 9
        else:
            self.classes = 256

    def set_target_byte(self, target_byte): #target byte to attack: most of the time, this is 3
        self.target_byte = target_byte

    def set_epochs(self, epochs): #we set no of epochs for our training model
        self.epochs = epochs

    def set_mini_batch(self, mini_batch): #not sure of mini_batch. I guess it means batch
        self.mini_batch = mini_batch

    def __add_if_one(self, value): #don't know when this will be useful
        return 1 if value == 1 else 0

    def get_best_models(self, n_models, result_models_validation, n_traces):
        result_number_of_traces_val = []                      #best models is ranked by guessing entropy traces (when it's equal 1)
        for model_index in range(n_models):
            if result_models_validation[model_index][n_traces - 1] == 1: #checking for the best model starting from the last (min) trace
                for index in range(n_traces - 1, -1, -1):           #decrementing and moving up the trace
                    if result_models_validation[model_index][index] != 1:
                        result_number_of_traces_val.append(
                            [result_models_validation[model_index][n_traces - 1], index + 1,
                             model_index])
                        break
            else:
                result_number_of_traces_val.append(
                    [result_models_validation[model_index][n_traces - 1], n_traces,
                     model_index])

        sorted_models = sorted(result_number_of_traces_val, key=lambda l: l[:]) #sort by 

        list_of_best_models = []
        for model_index in range(n_models):
            list_of_best_models.append(sorted_models[model_index][2])

        return list_of_best_models

    def run_mlp(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)

        model = NeuralNetwork().mlp_random(self.classes, params["number_of_samples"], activation, neurons, layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),
            callbacks=[])

        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation, step, fraction)
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def run_cnn(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        X_profiling = X_profiling.reshape((X_profiling.shape[0], X_profiling.shape[1], 1))
        X_validation = X_validation.reshape((X_validation.shape[0], X_validation.shape[1], 1))
        X_attack = X_attack.reshape((X_attack.shape[0], X_attack.shape[1], 1))

        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        dense_layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)
        conv_layers = random.randrange(1, 2, 1)
        filters = random.randrange(8, 32, 4)
        kernel_size = random.randrange(10, 20, 2)
        stride = random.randrange(5, 10, 5)

        model = NeuralNetwork().cnn_random(self.classes, params["number_of_samples"], activation, neurons, conv_layers, filters,
                                           kernel_size, stride, dense_layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),
            callbacks=[])
                                                                      #100 is for number of runs
        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation,
                                                                      step, fraction)
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def compute_ensembles(self, kr_nt, correct_key):
       #nm = number_of_models
      list_of_best_models = self.get_best_models(self.number_of_models, self.ge_all_validation, kr_nt) #i added

      self.ge_best_model_validation = self.ge_all_validation[list_of_best_models[0]]
      self.ge_best_model_attack = self.ge_all_attack[list_of_best_models[0]]
      self.sr_best_model_validation = self.sr_all_validation[list_of_best_models[0]]
      self.sr_best_model_attack = self.sr_all_attack[list_of_best_models[0]]

      for i in range(4): #added

          kr_ensemble = np.zeros(kr_nt)
          krs_ensemble = np.zeros((100, kr_nt))
          kr_ensemble_best_models = np.zeros(kr_nt)
          krs_ensemble_best_models = np.zeros((100, kr_nt))

          for run in range(100):

              key_p_ensemble = np.zeros(256)
              key_p_ensemble_best_models = np.zeros(256)

              for index in range(kr_nt):
                  for model_index in range(self.number_of_models):
                      key_p_ensemble += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)
                  for model_index in range(self.number_of_best_models[i]): #i added
                      key_p_ensemble_best_models += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)

                  key_p_ensemble_sorted = np.argsort(key_p_ensemble)[::-1]
                  key_p_ensemble_best_models_sorted = np.argsort(key_p_ensemble_best_models)[::-1]

                  kr_position = list(key_p_ensemble_sorted).index(correct_key) + 1
                  kr_ensemble[index] += kr_position
                  krs_ensemble[run][index] = kr_position

                  kr_position = list(key_p_ensemble_best_models_sorted).index(correct_key) + 1
                  kr_ensemble_best_models[index] += kr_position
                  krs_ensemble_best_models[run][index] = kr_position

              print("Run {} - GE {} models: {} | GE {} models: {} | ".format(run, self.number_of_models,
                                                                            int(kr_ensemble[kr_nt - 1] / (run + 1)),
                                                                            self.number_of_best_models[i], #i added
                                                                            int(kr_ensemble_best_models[kr_nt - 1] / (run + 1))))

          ge_ensemble = kr_ensemble / 100
          ge_ensemble_best_models = kr_ensemble_best_models / 100

          sr_ensemble = np.zeros(kr_nt)
          sr_ensemble_best_models = np.zeros(kr_nt)

          for index in range(kr_nt):
              for run in range(100):
                  sr_ensemble[index] += self.__add_if_one(krs_ensemble[run][index])
                  sr_ensemble_best_models[index] += self.__add_if_one(krs_ensemble_best_models[run][index])
          if (i==0): 
            ge_ensemble_best_models0 = ge_ensemble_best_models
            sr_ensemble_best_models0 = sr_ensemble_best_models
          if (i==1):
            ge_ensemble_best_models1 = ge_ensemble_best_models
            sr_ensemble_best_models1 = sr_ensemble_best_models
          if(i==2):
            ge_ensemble_best_models2 = ge_ensemble_best_models
            sr_ensemble_best_models2 = sr_ensemble_best_models
          if(i==3):
            ge_ensemble_best_models3 = ge_ensemble_best_models
            sr_ensemble_best_models3 = sr_ensemble_best_models
            ge_ensemble_best_models = ge_ensemble_best_models0
            sr_ensemble_best_models = sr_ensemble_best_models0
          
        #return ge_ensemble, ge_ensemble_best_models, sr_ensemble/100, sr_ensemble_best_models/100
          #next line added
      return ge_ensemble, ge_ensemble_best_models, ge_ensemble_best_models1, ge_ensemble_best_models2, ge_ensemble_best_models3, sr_ensemble/100, sr_ensemble_best_models/100, sr_ensemble_best_models1/100,sr_ensemble_best_models2/100,sr_ensemble_best_models3/100 

    def create_z_score_norm(self, dataset):
        z_score_mean = np.mean(dataset, axis=0)
        z_score_std = np.std(dataset, axis=0)
        return z_score_mean, z_score_std

    def apply_z_score_norm(self, dataset, z_score_mean, z_score_std):
        for index in range(len(dataset)):
            dataset[index] = (dataset[index] - z_score_mean) / z_score_std

    def run_ensemble(self, number_of_models, number_of_best_models):

        self.number_of_models = number_of_models
        self.number_of_best_models = number_of_best_models

        target_params = SCADatasets().get_trace_set(self.target_dataset)

        #root_folder = "D:/traces/"
        #root_folder = '/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf/'
        root_folder = '/content/gdrive/MyDrive/QEResearch/ches_ctf/'

        (X_profiling, Y_profiling), (X_validation, Y_validation), (X_attack, Y_attack), (
            _, plt_validation, plt_attack) = LoadDatasets().load_dataset(
            root_folder + target_params["file"], target_params["n_profiling"], target_params["n_attack"], self.target_byte, self.l_model)

        
         #measure imbalance of the data here
        ##oversample = SMOTE()          #added
        #sme = SMOTEENN(random_state=42) #added
        #sampling_strategy = "not majority"
        #oversample = RandomOverSampler(sampling_strategy=sampling_strategy)

        sampling_strategy = "not minority"
        undersample = RandomUnderSampler(sampling_strategy=sampling_strategy)
        #oversample = RandomOverSampler(sampling_strategy=0.5)

        X_profilinga, Y_profilinga = undersample.fit_resample(X_profiling, Y_profiling)  #added
        # summarize distribution
        counter = Counter(Y_profilinga)      #added switch betweenn Y_profiling & Y_profilinga
        for k,v in counter.items():   #added
          per = v / len(Y_profilinga) * 100   #added
          print('Class=%d, n=%d (%.3f%%)' % (k, v, per))  #added
        # plot the distribution
        plt.bar(counter.keys(), counter.values())    #added
        #plt.subplot(1, 2, 1)
        #plt.plot(ensemble_aes.get_ge_best_model_validation(), )
        plt.xlabel("Classes")
        plt.ylabel("Frequency")
        plt.legend()
        plt.show()   #added

        X_profiling, Y_profiling = X_profilinga, Y_profilinga
        # normalize with z-score
        z_score_mean, z_score_std = self.create_z_score_norm(X_profiling)
        self.apply_z_score_norm(X_profiling, z_score_mean, z_score_std) #a added
        self.apply_z_score_norm(X_validation, z_score_mean, z_score_std)
        self.apply_z_score_norm(X_attack, z_score_mean, z_score_std)

        # convert labels to categorical labels
        Y_profiling = to_categorical(Y_profiling, num_classes=self.classes) #a added
        Y_validation = to_categorical(Y_validation, num_classes=self.classes)
        Y_attack = to_categorical(Y_attack, num_classes=self.classes)

        X_profiling = X_profiling.astype('float32')
        X_validation = X_validation.astype('float32')
        X_attack = X_attack.astype('float32')

        kr_step = 10  # key rank processed for each kr_step traces
        kr_fraction = 1  # validation or attack sets are divided by kr_fraction before computing key rank

        self.ge_all_validation = []
        self.sr_all_validation = []
        self.ge_all_attack = []
        self.k_ps_all = []

        kr_nt = int(len(X_validation) / (kr_step * kr_fraction))

        # train random MLP
        for model_index in range(self.number_of_models):
            ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_mlp(X_profiling, Y_profiling,
                                                                                      X_validation, Y_validation,
                                                                                      X_attack, Y_attack,
                                                                                      plt_validation, plt_attack,
                                                                                      target_params, kr_step, kr_fraction)
            self.ge_all_validation.append(ge_validation)
            self.ge_all_attack.append(ge_attack)
            self.sr_all_validation.append(sr_validation)
            self.sr_all_attack.append(sr_attack)
            self.k_ps_all.append(kp_krs)

        # train random CNN
        #for model_index in range(self.number_of_models):
        #     ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_cnn(X_profiling, Y_profiling,
        #                                                                               X_validation, Y_validation,
        #                                                                               X_attack, Y_attack,
        #                                                                               plt_validation, plt_attack,
        #                                                                               target_params, kr_step, kr_fraction)
        #     self.ge_all_validation.append(ge_validation)
        #     self.ge_all_attack.append(ge_attack)
        #     self.sr_all_validation.append(sr_validation)
        #     self.sr_all_attack.append(sr_attack)
        #     self.k_ps_all.append(kp_krs)                  #kr_nt = int(len(X_validation) / (kr_step * kr_fraction))

        #ge_ensemble, ge_ensemble_best_models, sr_ensemble, sr_ensemble_best_models = self.compute_ensembles(kr_nt,
         #                                                                                                   target_params["good_key"])
        ge_ensemble, ge_ensemble_best_models, ge_ensemble_best_models1, ge_ensemble_best_models2, ge_ensemble_best_models3, sr_ensemble, sr_ensemble_best_models, sr_ensemble_best_models1, sr_ensemble_best_models2,sr_ensemble_best_models3 = self.compute_ensembles(kr_nt,
                                                                                                             target_params["good_key"])
             

        self.ge_ensemble = ge_ensemble
        self.ge_ensemble_best_models = ge_ensemble_best_models
        self.ge_ensemble_best_models1 = ge_ensemble_best_models1 #added
        self.ge_ensemble_best_models2 = ge_ensemble_best_models2 #added
        self.ge_ensemble_best_models3 = ge_ensemble_best_models3 #added

        self.sr_ensemble = sr_ensemble
        self.sr_ensemble_best_models = sr_ensemble_best_models
        self.sr_ensemble_best_models1 = sr_ensemble_best_models1 #added
        self.sr_ensemble_best_models2 = sr_ensemble_best_models2 #added
        self.sr_ensemble_best_models3 = sr_ensemble_best_models3 #added




    def get_ge_ensemble(self):
        return self.ge_ensemble

    def get_ge_ensemble_best_models(self):
        return self.ge_ensemble_best_models

    def get_ge_ensemble_best_models1(self): #added
        return self.ge_ensemble_best_models1

    def get_ge_ensemble_best_models2(self): #added
        return self.ge_ensemble_best_models2

    def get_ge_ensemble_best_models3(self): #added
        return self.ge_ensemble_best_models3

    def get_ge_best_model_validation(self):
        return self.ge_best_model_validation

    def get_ge_best_model_attack(self):
        return self.ge_best_model_attack

    def get_sr_ensemble(self):
        return self.sr_ensemble

    def get_sr_ensemble_best_models1(self): #added
        return self.sr_ensemble_best_models1

    def get_sr_ensemble_best_models2(self): #added
        return self.sr_ensemble_best_models2

    def get_sr_ensemble_best_models3(self): #added
        return self.sr_ensemble_best_models3


    def get_sr_ensemble_best_models(self):
        return self.sr_ensemble_best_models

    def get_sr_best_model_validation(self):
        return self.sr_best_model_validation

    def get_sr_best_model_attack(self):
        return self.sr_best_model_attack

# %%
ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
#ensemble_aes.set_dataset("ascad_fixed_key")  #changed from ches_ctf
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
#ensemble_aes.run_ensemble(number_of_models=5, number_of_best_models=[1,2,3,4])
ensemble_aes.run_ensemble(number_of_models=40, number_of_best_models=[1,5,10,20])
# Out:
# No handles with labels found to put in legend.
# Class=0, n=147 (11.111%)
# Class=1, n=147 (11.111%)
# Class=2, n=147 (11.111%)
# Class=3, n=147 (11.111%)
# Class=4, n=147 (11.111%)
# Class=5, n=147 (11.111%)
# Class=6, n=147 (11.111%)
# Class=7, n=147 (11.111%)
# Class=8, n=147 (11.111%)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 1,695,409
# Trainable params: 1,691,009
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Streaming output truncated to the last 5000 lines.
#
#  dense (Dense)               (None, 500)               1100500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 500)               250500
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  dense_6 (Dense)             (None, 500)               250500
#
#  dense_7 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 2,616,809
# Trainable params: 2,612,409
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 4/4 [==============================] - 1s 110ms/step - loss: 5.9954 - accuracy: 0.0952 - val_loss: 5.1380 - val_accuracy: 0.1160
# Epoch 2/10
# 4/4 [==============================] - 0s 52ms/step - loss: 1.2725 - accuracy: 0.6266 - val_loss: 4.4354 - val_accuracy: 0.1888
# Epoch 3/10
# 4/4 [==============================] - 0s 51ms/step - loss: 0.4060 - accuracy: 0.8632 - val_loss: 4.2332 - val_accuracy: 0.1576
# Epoch 4/10
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1458 - accuracy: 0.9690 - val_loss: 4.3382 - val_accuracy: 0.1512
# Epoch 5/10
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0747 - accuracy: 0.9932 - val_loss: 4.2011 - val_accuracy: 0.1468
# Epoch 6/10
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0376 - accuracy: 0.9992 - val_loss: 4.1019 - val_accuracy: 0.1544
# Epoch 7/10
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 4.1046 - val_accuracy: 0.1560
# Epoch 8/10
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 4.1316 - val_accuracy: 0.1608
# Epoch 9/10
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 4.1738 - val_accuracy: 0.1600
# Epoch 10/10
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 4.2179 - val_accuracy: 0.1620
# KR: 0 | GE for correct key (46): 223.0)
# KR: 1 | GE for correct key (46): 223.0)
# KR: 2 | GE for correct key (46): 223.0)
# KR: 3 | GE for correct key (46): 223.0)
# KR: 4 | GE for correct key (46): 223.0)
# KR: 5 | GE for correct key (46): 223.0)
# KR: 6 | GE for correct key (46): 223.0)
# KR: 7 | GE for correct key (46): 223.0)
# KR: 8 | GE for correct key (46): 223.0)
# KR: 9 | GE for correct key (46): 223.0)
# KR: 10 | GE for correct key (46): 223.0)
# KR: 11 | GE for correct key (46): 223.0)
# KR: 12 | GE for correct key (46): 223.0)
# KR: 13 | GE for correct key (46): 223.0)
# KR: 14 | GE for correct key (46): 223.0)
# KR: 15 | GE for correct key (46): 223.0)
# KR: 16 | GE for correct key (46): 223.0)
# KR: 17 | GE for correct key (46): 223.0)
# KR: 18 | GE for correct key (46): 223.0)
# KR: 19 | GE for correct key (46): 223.0)
# KR: 20 | GE for correct key (46): 223.0)
# KR: 21 | GE for correct key (46): 223.0)
# KR: 22 | GE for correct key (46): 223.0)
# KR: 23 | GE for correct key (46): 223.0)
# KR: 24 | GE for correct key (46): 223.0)
# KR: 25 | GE for correct key (46): 223.0)
# KR: 26 | GE for correct key (46): 223.0)
# KR: 27 | GE for correct key (46): 223.0)
# KR: 28 | GE for correct key (46): 223.0)
# KR: 29 | GE for correct key (46): 223.0)
# KR: 30 | GE for correct key (46): 223.0)
# KR: 31 | GE for correct key (46): 223.0)
# KR: 32 | GE for correct key (46): 223.0)
# KR: 33 | GE for correct key (46): 223.0)
# KR: 34 | GE for correct key (46): 223.0)
# KR: 35 | GE for correct key (46): 223.0)
# KR: 36 | GE for correct key (46): 223.0)
# KR: 37 | GE for correct key (46): 223.0)
# KR: 38 | GE for correct key (46): 223.0)
# KR: 39 | GE for correct key (46): 223.0)
# KR: 40 | GE for correct key (46): 223.0)
# KR: 41 | GE for correct key (46): 223.0)
# KR: 42 | GE for correct key (46): 223.0)
# KR: 43 | GE for correct key (46): 223.0)
# KR: 44 | GE for correct key (46): 223.0)
# KR: 45 | GE for correct key (46): 223.0)
# KR: 46 | GE for correct key (46): 223.0)
# KR: 47 | GE for correct key (46): 223.0)
# KR: 48 | GE for correct key (46): 223.0)
# KR: 49 | GE for correct key (46): 223.0)
# KR: 50 | GE for correct key (46): 223.0)
# KR: 51 | GE for correct key (46): 223.0)
# KR: 52 | GE for correct key (46): 223.0)
# KR: 53 | GE for correct key (46): 223.0)
# KR: 54 | GE for correct key (46): 223.0)
# KR: 55 | GE for correct key (46): 223.0)
# KR: 56 | GE for correct key (46): 223.0)
# KR: 57 | GE for correct key (46): 223.0)
# KR: 58 | GE for correct key (46): 223.0)
# KR: 59 | GE for correct key (46): 223.0)
# KR: 60 | GE for correct key (46): 223.0)
# KR: 61 | GE for correct key (46): 223.0)
# KR: 62 | GE for correct key (46): 223.0)
# KR: 63 | GE for correct key (46): 223.0)
# KR: 64 | GE for correct key (46): 223.0)
# KR: 65 | GE for correct key (46): 223.0)
# KR: 66 | GE for correct key (46): 223.0)
# KR: 67 | GE for correct key (46): 223.0)
# KR: 68 | GE for correct key (46): 223.0)
# KR: 69 | GE for correct key (46): 223.0)
# KR: 70 | GE for correct key (46): 223.0)
# KR: 71 | GE for correct key (46): 223.0)
# KR: 72 | GE for correct key (46): 223.0)
# KR: 73 | GE for correct key (46): 223.0)
# KR: 74 | GE for correct key (46): 223.0)
# KR: 75 | GE for correct key (46): 223.0)
# KR: 76 | GE for correct key (46): 223.0)
# KR: 77 | GE for correct key (46): 223.0)
# KR: 78 | GE for correct key (46): 223.0)
# KR: 79 | GE for correct key (46): 223.0)
# KR: 80 | GE for correct key (46): 223.0)
# KR: 81 | GE for correct key (46): 223.0)
# KR: 82 | GE for correct key (46): 223.0)
# KR: 83 | GE for correct key (46): 223.0)
# KR: 84 | GE for correct key (46): 223.0)
# KR: 85 | GE for correct key (46): 223.0)
# KR: 86 | GE for correct key (46): 223.0)
# KR: 87 | GE for correct key (46): 223.0)
# KR: 88 | GE for correct key (46): 223.0)
# KR: 89 | GE for correct key (46): 223.0)
# KR: 90 | GE for correct key (46): 223.0)
# KR: 91 | GE for correct key (46): 223.0)
# KR: 92 | GE for correct key (46): 223.0)
# KR: 93 | GE for correct key (46): 223.0)
# KR: 94 | GE for correct key (46): 223.0)
# KR: 95 | GE for correct key (46): 223.0)
# KR: 96 | GE for correct key (46): 223.0)
# KR: 97 | GE for correct key (46): 223.0)
# KR: 98 | GE for correct key (46): 223.0)
# KR: 99 | GE for correct key (46): 223.0)
# KR: 0 | GE for correct key (46): 53.0)
# KR: 1 | GE for correct key (46): 53.0)
# KR: 2 | GE for correct key (46): 53.0)
# KR: 3 | GE for correct key (46): 53.0)
# KR: 4 | GE for correct key (46): 53.0)
# KR: 5 | GE for correct key (46): 53.0)
# KR: 6 | GE for correct key (46): 53.0)
# KR: 7 | GE for correct key (46): 53.0)
# KR: 8 | GE for correct key (46): 53.0)
# KR: 9 | GE for correct key (46): 53.0)
# KR: 10 | GE for correct key (46): 53.0)
# KR: 11 | GE for correct key (46): 53.0)
# KR: 12 | GE for correct key (46): 53.0)
# KR: 13 | GE for correct key (46): 53.0)
# KR: 14 | GE for correct key (46): 53.0)
# KR: 15 | GE for correct key (46): 53.0)
# KR: 16 | GE for correct key (46): 53.0)
# KR: 17 | GE for correct key (46): 53.0)
# KR: 18 | GE for correct key (46): 53.0)
# KR: 19 | GE for correct key (46): 53.0)
# KR: 20 | GE for correct key (46): 53.0)
# KR: 21 | GE for correct key (46): 53.0)
# KR: 22 | GE for correct key (46): 53.0)
# KR: 23 | GE for correct key (46): 53.0)
# KR: 24 | GE for correct key (46): 53.0)
# KR: 25 | GE for correct key (46): 53.0)
# KR: 26 | GE for correct key (46): 53.0)
# KR: 27 | GE for correct key (46): 53.0)
# KR: 28 | GE for correct key (46): 53.0)
# KR: 29 | GE for correct key (46): 53.0)
# KR: 30 | GE for correct key (46): 53.0)
# KR: 31 | GE for correct key (46): 53.0)
# KR: 32 | GE for correct key (46): 53.0)
# KR: 33 | GE for correct key (46): 53.0)
# KR: 34 | GE for correct key (46): 53.0)
# KR: 35 | GE for correct key (46): 53.0)
# KR: 36 | GE for correct key (46): 53.0)
# KR: 37 | GE for correct key (46): 53.0)
# KR: 38 | GE for correct key (46): 53.0)
# KR: 39 | GE for correct key (46): 53.0)
# KR: 40 | GE for correct key (46): 53.0)
# KR: 41 | GE for correct key (46): 53.0)
# KR: 42 | GE for correct key (46): 53.0)
# KR: 43 | GE for correct key (46): 53.0)
# KR: 44 | GE for correct key (46): 53.0)
# KR: 45 | GE for correct key (46): 53.0)
# KR: 46 | GE for correct key (46): 53.0)
# KR: 47 | GE for correct key (46): 53.0)
# KR: 48 | GE for correct key (46): 53.0)
# KR: 49 | GE for correct key (46): 53.0)
# KR: 50 | GE for correct key (46): 53.0)
# KR: 51 | GE for correct key (46): 53.0)
# KR: 52 | GE for correct key (46): 53.0)
# KR: 53 | GE for correct key (46): 53.0)
# KR: 54 | GE for correct key (46): 53.0)
# KR: 55 | GE for correct key (46): 53.0)
# KR: 56 | GE for correct key (46): 53.0)
# KR: 57 | GE for correct key (46): 53.0)
# KR: 58 | GE for correct key (46): 53.0)
# KR: 59 | GE for correct key (46): 53.0)
# KR: 60 | GE for correct key (46): 53.0)
# KR: 61 | GE for correct key (46): 53.0)
# KR: 62 | GE for correct key (46): 53.0)
# KR: 63 | GE for correct key (46): 53.0)
# KR: 64 | GE for correct key (46): 53.0)
# KR: 65 | GE for correct key (46): 53.0)
# KR: 66 | GE for correct key (46): 53.0)
# KR: 67 | GE for correct key (46): 53.0)
# KR: 68 | GE for correct key (46): 53.0)
# KR: 69 | GE for correct key (46): 53.0)
# KR: 70 | GE for correct key (46): 53.0)
# KR: 71 | GE for correct key (46): 53.0)
# KR: 72 | GE for correct key (46): 53.0)
# KR: 73 | GE for correct key (46): 53.0)
# KR: 74 | GE for correct key (46): 53.0)
# KR: 75 | GE for correct key (46): 53.0)
# KR: 76 | GE for correct key (46): 53.0)
# KR: 77 | GE for correct key (46): 53.0)
# KR: 78 | GE for correct key (46): 53.0)
# KR: 79 | GE for correct key (46): 53.0)
# KR: 80 | GE for correct key (46): 53.0)
# KR: 81 | GE for correct key (46): 53.0)
# KR: 82 | GE for correct key (46): 53.0)
# KR: 83 | GE for correct key (46): 53.0)
# KR: 84 | GE for correct key (46): 53.0)
# KR: 85 | GE for correct key (46): 53.0)
# KR: 86 | GE for correct key (46): 53.0)
# KR: 87 | GE for correct key (46): 53.0)
# KR: 88 | GE for correct key (46): 53.0)
# KR: 89 | GE for correct key (46): 53.0)
# KR: 90 | GE for correct key (46): 53.0)
# KR: 91 | GE for correct key (46): 53.0)
# KR: 92 | GE for correct key (46): 53.0)
# KR: 93 | GE for correct key (46): 53.0)
# KR: 94 | GE for correct key (46): 53.0)
# KR: 95 | GE for correct key (46): 53.0)
# KR: 96 | GE for correct key (46): 53.0)
# KR: 97 | GE for correct key (46): 53.0)
# KR: 98 | GE for correct key (46): 53.0)
# KR: 99 | GE for correct key (46): 53.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,777,209
# Trainable params: 2,772,809
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 4/4 [==============================] - 1s 102ms/step - loss: 3.6934 - accuracy: 0.1187 - val_loss: 2.9901 - val_accuracy: 0.0416
# Epoch 2/10
# 4/4 [==============================] - 0s 46ms/step - loss: 2.2467 - accuracy: 0.3197 - val_loss: 2.3068 - val_accuracy: 0.1140
# Epoch 3/10
# 4/4 [==============================] - 0s 47ms/step - loss: 1.8018 - accuracy: 0.3545 - val_loss: 2.4400 - val_accuracy: 0.0572
# Epoch 4/10
# 4/4 [==============================] - 0s 46ms/step - loss: 1.5271 - accuracy: 0.6538 - val_loss: 2.4420 - val_accuracy: 0.1292
# Epoch 5/10
# 4/4 [==============================] - 0s 44ms/step - loss: 1.1320 - accuracy: 0.8171 - val_loss: 2.5336 - val_accuracy: 0.1516
# Epoch 6/10
# 4/4 [==============================] - 0s 45ms/step - loss: 0.6665 - accuracy: 0.9297 - val_loss: 3.4268 - val_accuracy: 0.1184
# Epoch 7/10
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3068 - accuracy: 0.9660 - val_loss: 3.5977 - val_accuracy: 0.1752
# Epoch 8/10
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1096 - accuracy: 0.9879 - val_loss: 5.3794 - val_accuracy: 0.0960
# Epoch 9/10
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0319 - accuracy: 0.9985 - val_loss: 5.9967 - val_accuracy: 0.0708
# Epoch 10/10
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 6.5959 - val_accuracy: 0.1180
# KR: 0 | GE for correct key (46): 227.0)
# KR: 1 | GE for correct key (46): 227.0)
# KR: 2 | GE for correct key (46): 227.0)
# KR: 3 | GE for correct key (46): 227.0)
# KR: 4 | GE for correct key (46): 227.0)
# KR: 5 | GE for correct key (46): 227.0)
# KR: 6 | GE for correct key (46): 227.0)
# KR: 7 | GE for correct key (46): 227.0)
# KR: 8 | GE for correct key (46): 227.0)
# KR: 9 | GE for correct key (46): 227.0)
# KR: 10 | GE for correct key (46): 227.0)
# KR: 11 | GE for correct key (46): 227.0)
# KR: 12 | GE for correct key (46): 227.0)
# KR: 13 | GE for correct key (46): 227.0)
# KR: 14 | GE for correct key (46): 227.0)
# KR: 15 | GE for correct key (46): 227.0)
# KR: 16 | GE for correct key (46): 227.0)
# KR: 17 | GE for correct key (46): 227.0)
# KR: 18 | GE for correct key (46): 227.0)
# KR: 19 | GE for correct key (46): 227.0)
# KR: 20 | GE for correct key (46): 227.0)
# KR: 21 | GE for correct key (46): 227.0)
# KR: 22 | GE for correct key (46): 227.0)
# KR: 23 | GE for correct key (46): 227.0)
# KR: 24 | GE for correct key (46): 227.0)
# KR: 25 | GE for correct key (46): 227.0)
# KR: 26 | GE for correct key (46): 227.0)
# KR: 27 | GE for correct key (46): 227.0)
# KR: 28 | GE for correct key (46): 227.0)
# KR: 29 | GE for correct key (46): 227.0)
# KR: 30 | GE for correct key (46): 227.0)
# KR: 31 | GE for correct key (46): 227.0)
# KR: 32 | GE for correct key (46): 227.0)
# KR: 33 | GE for correct key (46): 227.0)
# KR: 34 | GE for correct key (46): 227.0)
# KR: 35 | GE for correct key (46): 227.0)
# KR: 36 | GE for correct key (46): 227.0)
# KR: 37 | GE for correct key (46): 227.0)
# KR: 38 | GE for correct key (46): 227.0)
# KR: 39 | GE for correct key (46): 227.0)
# KR: 40 | GE for correct key (46): 227.0)
# KR: 41 | GE for correct key (46): 227.0)
# KR: 42 | GE for correct key (46): 227.0)
# KR: 43 | GE for correct key (46): 227.0)
# KR: 44 | GE for correct key (46): 227.0)
# KR: 45 | GE for correct key (46): 227.0)
# KR: 46 | GE for correct key (46): 227.0)
# KR: 47 | GE for correct key (46): 227.0)
# KR: 48 | GE for correct key (46): 227.0)
# KR: 49 | GE for correct key (46): 227.0)
# KR: 50 | GE for correct key (46): 227.0)
# KR: 51 | GE for correct key (46): 227.0)
# KR: 52 | GE for correct key (46): 227.0)
# KR: 53 | GE for correct key (46): 227.0)
# KR: 54 | GE for correct key (46): 227.0)
# KR: 55 | GE for correct key (46): 227.0)
# KR: 56 | GE for correct key (46): 227.0)
# KR: 57 | GE for correct key (46): 227.0)
# KR: 58 | GE for correct key (46): 227.0)
# KR: 59 | GE for correct key (46): 227.0)
# KR: 60 | GE for correct key (46): 227.0)
# KR: 61 | GE for correct key (46): 227.0)
# KR: 62 | GE for correct key (46): 227.0)
# KR: 63 | GE for correct key (46): 227.0)
# KR: 64 | GE for correct key (46): 227.0)
# KR: 65 | GE for correct key (46): 227.0)
# KR: 66 | GE for correct key (46): 227.0)
# KR: 67 | GE for correct key (46): 227.0)
# KR: 68 | GE for correct key (46): 227.0)
# KR: 69 | GE for correct key (46): 227.0)
# KR: 70 | GE for correct key (46): 227.0)
# KR: 71 | GE for correct key (46): 227.0)
# KR: 72 | GE for correct key (46): 227.0)
# KR: 73 | GE for correct key (46): 227.0)
# KR: 74 | GE for correct key (46): 227.0)
# KR: 75 | GE for correct key (46): 227.0)
# KR: 76 | GE for correct key (46): 227.0)
# KR: 77 | GE for correct key (46): 227.0)
# KR: 78 | GE for correct key (46): 227.0)
# KR: 79 | GE for correct key (46): 227.0)
# KR: 80 | GE for correct key (46): 227.0)
# KR: 81 | GE for correct key (46): 227.0)
# KR: 82 | GE for correct key (46): 227.0)
# KR: 83 | GE for correct key (46): 227.0)
# KR: 84 | GE for correct key (46): 227.0)
# KR: 85 | GE for correct key (46): 227.0)
# KR: 86 | GE for correct key (46): 227.0)
# KR: 87 | GE for correct key (46): 227.0)
# KR: 88 | GE for correct key (46): 227.0)
# KR: 89 | GE for correct key (46): 227.0)
# KR: 90 | GE for correct key (46): 227.0)
# KR: 91 | GE for correct key (46): 227.0)
# KR: 92 | GE for correct key (46): 227.0)
# KR: 93 | GE for correct key (46): 227.0)
# KR: 94 | GE for correct key (46): 227.0)
# KR: 95 | GE for correct key (46): 227.0)
# KR: 96 | GE for correct key (46): 227.0)
# KR: 97 | GE for correct key (46): 227.0)
# KR: 98 | GE for correct key (46): 227.0)
# KR: 99 | GE for correct key (46): 227.0)
# KR: 0 | GE for correct key (46): 31.0)
# KR: 1 | GE for correct key (46): 31.0)
# KR: 2 | GE for correct key (46): 31.0)
# KR: 3 | GE for correct key (46): 31.0)
# KR: 4 | GE for correct key (46): 31.0)
# KR: 5 | GE for correct key (46): 31.0)
# KR: 6 | GE for correct key (46): 31.0)
# KR: 7 | GE for correct key (46): 31.0)
# KR: 8 | GE for correct key (46): 31.0)
# KR: 9 | GE for correct key (46): 31.0)
# KR: 10 | GE for correct key (46): 31.0)
# KR: 11 | GE for correct key (46): 31.0)
# KR: 12 | GE for correct key (46): 31.0)
# KR: 13 | GE for correct key (46): 31.0)
# KR: 14 | GE for correct key (46): 31.0)
# KR: 15 | GE for correct key (46): 31.0)
# KR: 16 | GE for correct key (46): 31.0)
# KR: 17 | GE for correct key (46): 31.0)
# KR: 18 | GE for correct key (46): 31.0)
# KR: 19 | GE for correct key (46): 31.0)
# KR: 20 | GE for correct key (46): 31.0)
# KR: 21 | GE for correct key (46): 31.0)
# KR: 22 | GE for correct key (46): 31.0)
# KR: 23 | GE for correct key (46): 31.0)
# KR: 24 | GE for correct key (46): 31.0)
# KR: 25 | GE for correct key (46): 31.0)
# KR: 26 | GE for correct key (46): 31.0)
# KR: 27 | GE for correct key (46): 31.0)
# KR: 28 | GE for correct key (46): 31.0)
# KR: 29 | GE for correct key (46): 31.0)
# KR: 30 | GE for correct key (46): 31.0)
# KR: 31 | GE for correct key (46): 31.0)
# KR: 32 | GE for correct key (46): 31.0)
# KR: 33 | GE for correct key (46): 31.0)
# KR: 34 | GE for correct key (46): 31.0)
# KR: 35 | GE for correct key (46): 31.0)
# KR: 36 | GE for correct key (46): 31.0)
# KR: 37 | GE for correct key (46): 31.0)
# KR: 38 | GE for correct key (46): 31.0)
# KR: 39 | GE for correct key (46): 31.0)
# KR: 40 | GE for correct key (46): 31.0)
# KR: 41 | GE for correct key (46): 31.0)
# KR: 42 | GE for correct key (46): 31.0)
# KR: 43 | GE for correct key (46): 31.0)
# KR: 44 | GE for correct key (46): 31.0)
# KR: 45 | GE for correct key (46): 31.0)
# KR: 46 | GE for correct key (46): 31.0)
# KR: 47 | GE for correct key (46): 31.0)
# KR: 48 | GE for correct key (46): 31.0)
# KR: 49 | GE for correct key (46): 31.0)
# KR: 50 | GE for correct key (46): 31.0)
# KR: 51 | GE for correct key (46): 31.0)
# KR: 52 | GE for correct key (46): 31.0)
# KR: 53 | GE for correct key (46): 31.0)
# KR: 54 | GE for correct key (46): 31.0)
# KR: 55 | GE for correct key (46): 31.0)
# KR: 56 | GE for correct key (46): 31.0)
# KR: 57 | GE for correct key (46): 31.0)
# KR: 58 | GE for correct key (46): 31.0)
# KR: 59 | GE for correct key (46): 31.0)
# KR: 60 | GE for correct key (46): 31.0)
# KR: 61 | GE for correct key (46): 31.0)
# KR: 62 | GE for correct key (46): 31.0)
# KR: 63 | GE for correct key (46): 31.0)
# KR: 64 | GE for correct key (46): 31.0)
# KR: 65 | GE for correct key (46): 31.0)
# KR: 66 | GE for correct key (46): 31.0)
# KR: 67 | GE for correct key (46): 31.0)
# KR: 68 | GE for correct key (46): 31.0)
# KR: 69 | GE for correct key (46): 31.0)
# KR: 70 | GE for correct key (46): 31.0)
# KR: 71 | GE for correct key (46): 31.0)
# KR: 72 | GE for correct key (46): 31.0)
# KR: 73 | GE for correct key (46): 31.0)
# KR: 74 | GE for correct key (46): 31.0)
# KR: 75 | GE for correct key (46): 31.0)
# KR: 76 | GE for correct key (46): 31.0)
# KR: 77 | GE for correct key (46): 31.0)
# KR: 78 | GE for correct key (46): 31.0)
# KR: 79 | GE for correct key (46): 31.0)
# KR: 80 | GE for correct key (46): 31.0)
# KR: 81 | GE for correct key (46): 31.0)
# KR: 82 | GE for correct key (46): 31.0)
# KR: 83 | GE for correct key (46): 31.0)
# KR: 84 | GE for correct key (46): 31.0)
# KR: 85 | GE for correct key (46): 31.0)
# KR: 86 | GE for correct key (46): 31.0)
# KR: 87 | GE for correct key (46): 31.0)
# KR: 88 | GE for correct key (46): 31.0)
# KR: 89 | GE for correct key (46): 31.0)
# KR: 90 | GE for correct key (46): 31.0)
# KR: 91 | GE for correct key (46): 31.0)
# KR: 92 | GE for correct key (46): 31.0)
# KR: 93 | GE for correct key (46): 31.0)
# KR: 94 | GE for correct key (46): 31.0)
# KR: 95 | GE for correct key (46): 31.0)
# KR: 96 | GE for correct key (46): 31.0)
# KR: 97 | GE for correct key (46): 31.0)
# KR: 98 | GE for correct key (46): 31.0)
# KR: 99 | GE for correct key (46): 31.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 600)               360600
#
#  dense_6 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 3,137,809
# Trainable params: 3,133,409
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 4/4 [==============================] - 1s 112ms/step - loss: 2.4387 - accuracy: 0.1202 - val_loss: 2.4400 - val_accuracy: 0.1000
# Epoch 2/10
# 4/4 [==============================] - 0s 54ms/step - loss: 1.8601 - accuracy: 0.3621 - val_loss: 2.4477 - val_accuracy: 0.0992
# Epoch 3/10
# 4/4 [==============================] - 0s 56ms/step - loss: 1.5466 - accuracy: 0.5722 - val_loss: 2.4937 - val_accuracy: 0.1000
# Epoch 4/10
# 4/4 [==============================] - 0s 55ms/step - loss: 1.3059 - accuracy: 0.7128 - val_loss: 2.5130 - val_accuracy: 0.1092
# Epoch 5/10
# 4/4 [==============================] - 0s 52ms/step - loss: 1.0981 - accuracy: 0.8156 - val_loss: 2.5212 - val_accuracy: 0.1264
# Epoch 6/10
# 4/4 [==============================] - 0s 54ms/step - loss: 0.9180 - accuracy: 0.8866 - val_loss: 2.5315 - val_accuracy: 0.1328
# Epoch 7/10
# 4/4 [==============================] - 0s 55ms/step - loss: 0.7588 - accuracy: 0.9388 - val_loss: 2.5537 - val_accuracy: 0.1348
# Epoch 8/10
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6183 - accuracy: 0.9705 - val_loss: 2.6079 - val_accuracy: 0.1380
# Epoch 9/10
# 4/4 [==============================] - 0s 54ms/step - loss: 0.4961 - accuracy: 0.9856 - val_loss: 2.6662 - val_accuracy: 0.1448
# Epoch 10/10
# 4/4 [==============================] - 0s 56ms/step - loss: 0.3908 - accuracy: 0.9947 - val_loss: 2.7210 - val_accuracy: 0.1512
# KR: 0 | GE for correct key (46): 212.0)
# KR: 1 | GE for correct key (46): 212.0)
# KR: 2 | GE for correct key (46): 212.0)
# KR: 3 | GE for correct key (46): 212.0)
# KR: 4 | GE for correct key (46): 212.0)
# KR: 5 | GE for correct key (46): 212.0)
# KR: 6 | GE for correct key (46): 212.0)
# KR: 7 | GE for correct key (46): 212.0)
# KR: 8 | GE for correct key (46): 212.0)
# KR: 9 | GE for correct key (46): 212.0)
# KR: 10 | GE for correct key (46): 212.0)
# KR: 11 | GE for correct key (46): 212.0)
# KR: 12 | GE for correct key (46): 212.0)
# KR: 13 | GE for correct key (46): 212.0)
# KR: 14 | GE for correct key (46): 212.0)
# KR: 15 | GE for correct key (46): 212.0)
# KR: 16 | GE for correct key (46): 212.0)
# KR: 17 | GE for correct key (46): 212.0)
# KR: 18 | GE for correct key (46): 212.0)
# KR: 19 | GE for correct key (46): 212.0)
# KR: 20 | GE for correct key (46): 212.0)
# KR: 21 | GE for correct key (46): 212.0)
# KR: 22 | GE for correct key (46): 212.0)
# KR: 23 | GE for correct key (46): 212.0)
# KR: 24 | GE for correct key (46): 212.0)
# KR: 25 | GE for correct key (46): 212.0)
# KR: 26 | GE for correct key (46): 212.0)
# KR: 27 | GE for correct key (46): 212.0)
# KR: 28 | GE for correct key (46): 212.0)
# KR: 29 | GE for correct key (46): 212.0)
# KR: 30 | GE for correct key (46): 212.0)
# KR: 31 | GE for correct key (46): 212.0)
# KR: 32 | GE for correct key (46): 212.0)
# KR: 33 | GE for correct key (46): 212.0)
# KR: 34 | GE for correct key (46): 212.0)
# KR: 35 | GE for correct key (46): 212.0)
# KR: 36 | GE for correct key (46): 212.0)
# KR: 37 | GE for correct key (46): 212.0)
# KR: 38 | GE for correct key (46): 212.0)
# KR: 39 | GE for correct key (46): 212.0)
# KR: 40 | GE for correct key (46): 212.0)
# KR: 41 | GE for correct key (46): 212.0)
# KR: 42 | GE for correct key (46): 212.0)
# KR: 43 | GE for correct key (46): 212.0)
# KR: 44 | GE for correct key (46): 212.0)
# KR: 45 | GE for correct key (46): 212.0)
# KR: 46 | GE for correct key (46): 212.0)
# KR: 47 | GE for correct key (46): 212.0)
# KR: 48 | GE for correct key (46): 212.0)
# KR: 49 | GE for correct key (46): 212.0)
# KR: 50 | GE for correct key (46): 212.0)
# KR: 51 | GE for correct key (46): 212.0)
# KR: 52 | GE for correct key (46): 212.0)
# KR: 53 | GE for correct key (46): 212.0)
# KR: 54 | GE for correct key (46): 212.0)
# KR: 55 | GE for correct key (46): 212.0)
# KR: 56 | GE for correct key (46): 212.0)
# KR: 57 | GE for correct key (46): 212.0)
# KR: 58 | GE for correct key (46): 212.0)
# KR: 59 | GE for correct key (46): 212.0)
# KR: 60 | GE for correct key (46): 212.0)
# KR: 61 | GE for correct key (46): 212.0)
# KR: 62 | GE for correct key (46): 212.0)
# KR: 63 | GE for correct key (46): 212.0)
# KR: 64 | GE for correct key (46): 212.0)
# KR: 65 | GE for correct key (46): 212.0)
# KR: 66 | GE for correct key (46): 212.0)
# KR: 67 | GE for correct key (46): 212.0)
# KR: 68 | GE for correct key (46): 212.0)
# KR: 69 | GE for correct key (46): 212.0)
# KR: 70 | GE for correct key (46): 212.0)
# KR: 71 | GE for correct key (46): 212.0)
# KR: 72 | GE for correct key (46): 212.0)
# KR: 73 | GE for correct key (46): 212.0)
# KR: 74 | GE for correct key (46): 212.0)
# KR: 75 | GE for correct key (46): 212.0)
# KR: 76 | GE for correct key (46): 212.0)
# KR: 77 | GE for correct key (46): 212.0)
# KR: 78 | GE for correct key (46): 212.0)
# KR: 79 | GE for correct key (46): 212.0)
# KR: 80 | GE for correct key (46): 212.0)
# KR: 81 | GE for correct key (46): 212.0)
# KR: 82 | GE for correct key (46): 212.0)
# KR: 83 | GE for correct key (46): 212.0)
# KR: 84 | GE for correct key (46): 212.0)
# KR: 85 | GE for correct key (46): 212.0)
# KR: 86 | GE for correct key (46): 212.0)
# KR: 87 | GE for correct key (46): 212.0)
# KR: 88 | GE for correct key (46): 212.0)
# KR: 89 | GE for correct key (46): 212.0)
# KR: 90 | GE for correct key (46): 212.0)
# KR: 91 | GE for correct key (46): 212.0)
# KR: 92 | GE for correct key (46): 212.0)
# KR: 93 | GE for correct key (46): 212.0)
# KR: 94 | GE for correct key (46): 212.0)
# KR: 95 | GE for correct key (46): 212.0)
# KR: 96 | GE for correct key (46): 212.0)
# KR: 97 | GE for correct key (46): 212.0)
# KR: 98 | GE for correct key (46): 212.0)
# KR: 99 | GE for correct key (46): 212.0)
# KR: 0 | GE for correct key (46): 24.0)
# KR: 1 | GE for correct key (46): 24.0)
# KR: 2 | GE for correct key (46): 24.0)
# KR: 3 | GE for correct key (46): 24.0)
# KR: 4 | GE for correct key (46): 24.0)
# KR: 5 | GE for correct key (46): 24.0)
# KR: 6 | GE for correct key (46): 24.0)
# KR: 7 | GE for correct key (46): 24.0)
# KR: 8 | GE for correct key (46): 24.0)
# KR: 9 | GE for correct key (46): 24.0)
# KR: 10 | GE for correct key (46): 24.0)
# KR: 11 | GE for correct key (46): 24.0)
# KR: 12 | GE for correct key (46): 24.0)
# KR: 13 | GE for correct key (46): 24.0)
# KR: 14 | GE for correct key (46): 24.0)
# KR: 15 | GE for correct key (46): 24.0)
# KR: 16 | GE for correct key (46): 24.0)
# KR: 17 | GE for correct key (46): 24.0)
# KR: 18 | GE for correct key (46): 24.0)
# KR: 19 | GE for correct key (46): 24.0)
# KR: 20 | GE for correct key (46): 24.0)
# KR: 21 | GE for correct key (46): 24.0)
# KR: 22 | GE for correct key (46): 24.0)
# KR: 23 | GE for correct key (46): 24.0)
# KR: 24 | GE for correct key (46): 24.0)
# KR: 25 | GE for correct key (46): 24.0)
# KR: 26 | GE for correct key (46): 24.0)
# KR: 27 | GE for correct key (46): 24.0)
# KR: 28 | GE for correct key (46): 24.0)
# KR: 29 | GE for correct key (46): 24.0)
# KR: 30 | GE for correct key (46): 24.0)
# KR: 31 | GE for correct key (46): 24.0)
# KR: 32 | GE for correct key (46): 24.0)
# KR: 33 | GE for correct key (46): 24.0)
# KR: 34 | GE for correct key (46): 24.0)
# KR: 35 | GE for correct key (46): 24.0)
# KR: 36 | GE for correct key (46): 24.0)
# KR: 37 | GE for correct key (46): 24.0)
# KR: 38 | GE for correct key (46): 24.0)
# KR: 39 | GE for correct key (46): 24.0)
# KR: 40 | GE for correct key (46): 24.0)
# KR: 41 | GE for correct key (46): 24.0)
# KR: 42 | GE for correct key (46): 24.0)
# KR: 43 | GE for correct key (46): 24.0)
# KR: 44 | GE for correct key (46): 24.0)
# KR: 45 | GE for correct key (46): 24.0)
# KR: 46 | GE for correct key (46): 24.0)
# KR: 47 | GE for correct key (46): 24.0)
# KR: 48 | GE for correct key (46): 24.0)
# KR: 49 | GE for correct key (46): 24.0)
# KR: 50 | GE for correct key (46): 24.0)
# KR: 51 | GE for correct key (46): 24.0)
# KR: 52 | GE for correct key (46): 24.0)
# KR: 53 | GE for correct key (46): 24.0)
# KR: 54 | GE for correct key (46): 24.0)
# KR: 55 | GE for correct key (46): 24.0)
# KR: 56 | GE for correct key (46): 24.0)
# KR: 57 | GE for correct key (46): 24.0)
# KR: 58 | GE for correct key (46): 24.0)
# KR: 59 | GE for correct key (46): 24.0)
# KR: 60 | GE for correct key (46): 24.0)
# KR: 61 | GE for correct key (46): 24.0)
# KR: 62 | GE for correct key (46): 24.0)
# KR: 63 | GE for correct key (46): 24.0)
# KR: 64 | GE for correct key (46): 24.0)
# KR: 65 | GE for correct key (46): 24.0)
# KR: 66 | GE for correct key (46): 24.0)
# KR: 67 | GE for correct key (46): 24.0)
# KR: 68 | GE for correct key (46): 24.0)
# KR: 69 | GE for correct key (46): 24.0)
# KR: 70 | GE for correct key (46): 24.0)
# KR: 71 | GE for correct key (46): 24.0)
# KR: 72 | GE for correct key (46): 24.0)
# KR: 73 | GE for correct key (46): 24.0)
# KR: 74 | GE for correct key (46): 24.0)
# KR: 75 | GE for correct key (46): 24.0)
# KR: 76 | GE for correct key (46): 24.0)
# KR: 77 | GE for correct key (46): 24.0)
# KR: 78 | GE for correct key (46): 24.0)
# KR: 79 | GE for correct key (46): 24.0)
# KR: 80 | GE for correct key (46): 24.0)
# KR: 81 | GE for correct key (46): 24.0)
# KR: 82 | GE for correct key (46): 24.0)
# KR: 83 | GE for correct key (46): 24.0)
# KR: 84 | GE for correct key (46): 24.0)
# KR: 85 | GE for correct key (46): 24.0)
# KR: 86 | GE for correct key (46): 24.0)
# KR: 87 | GE for correct key (46): 24.0)
# KR: 88 | GE for correct key (46): 24.0)
# KR: 89 | GE for correct key (46): 24.0)
# KR: 90 | GE for correct key (46): 24.0)
# KR: 91 | GE for correct key (46): 24.0)
# KR: 92 | GE for correct key (46): 24.0)
# KR: 93 | GE for correct key (46): 24.0)
# KR: 94 | GE for correct key (46): 24.0)
# KR: 95 | GE for correct key (46): 24.0)
# KR: 96 | GE for correct key (46): 24.0)
# KR: 97 | GE for correct key (46): 24.0)
# KR: 98 | GE for correct key (46): 24.0)
# KR: 99 | GE for correct key (46): 24.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 700)               1540700
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 2,046,509
# Trainable params: 2,042,109
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 4/4 [==============================] - 1s 82ms/step - loss: 3.3917 - accuracy: 0.1013 - val_loss: 4.5160 - val_accuracy: 0.0760
# Epoch 2/10
# 4/4 [==============================] - 0s 34ms/step - loss: 1.7260 - accuracy: 0.4626 - val_loss: 3.6998 - val_accuracy: 0.1152
# Epoch 3/10
# 4/4 [==============================] - 0s 34ms/step - loss: 0.9831 - accuracy: 0.6652 - val_loss: 3.5795 - val_accuracy: 0.1336
# Epoch 4/10
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6019 - accuracy: 0.8209 - val_loss: 3.8773 - val_accuracy: 0.1276
# Epoch 5/10
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3428 - accuracy: 0.9418 - val_loss: 3.9761 - val_accuracy: 0.1264
# Epoch 6/10
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2068 - accuracy: 0.9796 - val_loss: 3.9633 - val_accuracy: 0.1464
# Epoch 7/10
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1321 - accuracy: 0.9947 - val_loss: 4.0184 - val_accuracy: 0.1808
# Epoch 8/10
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 4.0878 - val_accuracy: 0.1744
# Epoch 9/10
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 4.1658 - val_accuracy: 0.1544
# Epoch 10/10
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 4.3011 - val_accuracy: 0.1376
# KR: 0 | GE for correct key (46): 197.0)
# KR: 1 | GE for correct key (46): 197.0)
# KR: 2 | GE for correct key (46): 197.0)
# KR: 3 | GE for correct key (46): 197.0)
# KR: 4 | GE for correct key (46): 197.0)
# KR: 5 | GE for correct key (46): 197.0)
# KR: 6 | GE for correct key (46): 197.0)
# KR: 7 | GE for correct key (46): 197.0)
# KR: 8 | GE for correct key (46): 197.0)
# KR: 9 | GE for correct key (46): 197.0)
# KR: 10 | GE for correct key (46): 197.0)
# KR: 11 | GE for correct key (46): 197.0)
# KR: 12 | GE for correct key (46): 197.0)
# KR: 13 | GE for correct key (46): 197.0)
# KR: 14 | GE for correct key (46): 197.0)
# KR: 15 | GE for correct key (46): 197.0)
# KR: 16 | GE for correct key (46): 197.0)
# KR: 17 | GE for correct key (46): 197.0)
# KR: 18 | GE for correct key (46): 197.0)
# KR: 19 | GE for correct key (46): 197.0)
# KR: 20 | GE for correct key (46): 197.0)
# KR: 21 | GE for correct key (46): 197.0)
# KR: 22 | GE for correct key (46): 197.0)
# KR: 23 | GE for correct key (46): 197.0)
# KR: 24 | GE for correct key (46): 197.0)
# KR: 25 | GE for correct key (46): 197.0)
# KR: 26 | GE for correct key (46): 197.0)
# KR: 27 | GE for correct key (46): 197.0)
# KR: 28 | GE for correct key (46): 197.0)
# KR: 29 | GE for correct key (46): 197.0)
# KR: 30 | GE for correct key (46): 197.0)
# KR: 31 | GE for correct key (46): 197.0)
# KR: 32 | GE for correct key (46): 197.0)
# KR: 33 | GE for correct key (46): 197.0)
# KR: 34 | GE for correct key (46): 197.0)
# KR: 35 | GE for correct key (46): 197.0)
# KR: 36 | GE for correct key (46): 197.0)
# KR: 37 | GE for correct key (46): 197.0)
# KR: 38 | GE for correct key (46): 197.0)
# KR: 39 | GE for correct key (46): 197.0)
# KR: 40 | GE for correct key (46): 197.0)
# KR: 41 | GE for correct key (46): 197.0)
# KR: 42 | GE for correct key (46): 197.0)
# KR: 43 | GE for correct key (46): 197.0)
# KR: 44 | GE for correct key (46): 197.0)
# KR: 45 | GE for correct key (46): 197.0)
# KR: 46 | GE for correct key (46): 197.0)
# KR: 47 | GE for correct key (46): 197.0)
# KR: 48 | GE for correct key (46): 197.0)
# KR: 49 | GE for correct key (46): 197.0)
# KR: 50 | GE for correct key (46): 197.0)
# KR: 51 | GE for correct key (46): 197.0)
# KR: 52 | GE for correct key (46): 197.0)
# KR: 53 | GE for correct key (46): 197.0)
# KR: 54 | GE for correct key (46): 197.0)
# KR: 55 | GE for correct key (46): 197.0)
# KR: 56 | GE for correct key (46): 197.0)
# KR: 57 | GE for correct key (46): 197.0)
# KR: 58 | GE for correct key (46): 197.0)
# KR: 59 | GE for correct key (46): 197.0)
# KR: 60 | GE for correct key (46): 197.0)
# KR: 61 | GE for correct key (46): 197.0)
# KR: 62 | GE for correct key (46): 197.0)
# KR: 63 | GE for correct key (46): 197.0)
# KR: 64 | GE for correct key (46): 197.0)
# KR: 65 | GE for correct key (46): 197.0)
# KR: 66 | GE for correct key (46): 197.0)
# KR: 67 | GE for correct key (46): 197.0)
# KR: 68 | GE for correct key (46): 197.0)
# KR: 69 | GE for correct key (46): 197.0)
# KR: 70 | GE for correct key (46): 197.0)
# KR: 71 | GE for correct key (46): 197.0)
# KR: 72 | GE for correct key (46): 197.0)
# KR: 73 | GE for correct key (46): 197.0)
# KR: 74 | GE for correct key (46): 197.0)
# KR: 75 | GE for correct key (46): 197.0)
# KR: 76 | GE for correct key (46): 197.0)
# KR: 77 | GE for correct key (46): 197.0)
# KR: 78 | GE for correct key (46): 197.0)
# KR: 79 | GE for correct key (46): 197.0)
# KR: 80 | GE for correct key (46): 197.0)
# KR: 81 | GE for correct key (46): 197.0)
# KR: 82 | GE for correct key (46): 197.0)
# KR: 83 | GE for correct key (46): 197.0)
# KR: 84 | GE for correct key (46): 197.0)
# KR: 85 | GE for correct key (46): 197.0)
# KR: 86 | GE for correct key (46): 197.0)
# KR: 87 | GE for correct key (46): 197.0)
# KR: 88 | GE for correct key (46): 197.0)
# KR: 89 | GE for correct key (46): 197.0)
# KR: 90 | GE for correct key (46): 197.0)
# KR: 91 | GE for correct key (46): 197.0)
# KR: 92 | GE for correct key (46): 197.0)
# KR: 93 | GE for correct key (46): 197.0)
# KR: 94 | GE for correct key (46): 197.0)
# KR: 95 | GE for correct key (46): 197.0)
# KR: 96 | GE for correct key (46): 197.0)
# KR: 97 | GE for correct key (46): 197.0)
# KR: 98 | GE for correct key (46): 197.0)
# KR: 99 | GE for correct key (46): 197.0)
# KR: 0 | GE for correct key (46): 11.0)
# KR: 1 | GE for correct key (46): 11.0)
# KR: 2 | GE for correct key (46): 11.0)
# KR: 3 | GE for correct key (46): 11.0)
# KR: 4 | GE for correct key (46): 11.0)
# KR: 5 | GE for correct key (46): 11.0)
# KR: 6 | GE for correct key (46): 11.0)
# KR: 7 | GE for correct key (46): 11.0)
# KR: 8 | GE for correct key (46): 11.0)
# KR: 9 | GE for correct key (46): 11.0)
# KR: 10 | GE for correct key (46): 11.0)
# KR: 11 | GE for correct key (46): 11.0)
# KR: 12 | GE for correct key (46): 11.0)
# KR: 13 | GE for correct key (46): 11.0)
# KR: 14 | GE for correct key (46): 11.0)
# KR: 15 | GE for correct key (46): 11.0)
# KR: 16 | GE for correct key (46): 11.0)
# KR: 17 | GE for correct key (46): 11.0)
# KR: 18 | GE for correct key (46): 11.0)
# KR: 19 | GE for correct key (46): 11.0)
# KR: 20 | GE for correct key (46): 11.0)
# KR: 21 | GE for correct key (46): 11.0)
# KR: 22 | GE for correct key (46): 11.0)
# KR: 23 | GE for correct key (46): 11.0)
# KR: 24 | GE for correct key (46): 11.0)
# KR: 25 | GE for correct key (46): 11.0)
# KR: 26 | GE for correct key (46): 11.0)
# KR: 27 | GE for correct key (46): 11.0)
# KR: 28 | GE for correct key (46): 11.0)
# KR: 29 | GE for correct key (46): 11.0)
# KR: 30 | GE for correct key (46): 11.0)
# KR: 31 | GE for correct key (46): 11.0)
# KR: 32 | GE for correct key (46): 11.0)
# KR: 33 | GE for correct key (46): 11.0)
# KR: 34 | GE for correct key (46): 11.0)
# KR: 35 | GE for correct key (46): 11.0)
# KR: 36 | GE for correct key (46): 11.0)
# KR: 37 | GE for correct key (46): 11.0)
# KR: 38 | GE for correct key (46): 11.0)
# KR: 39 | GE for correct key (46): 11.0)
# KR: 40 | GE for correct key (46): 11.0)
# KR: 41 | GE for correct key (46): 11.0)
# KR: 42 | GE for correct key (46): 11.0)
# KR: 43 | GE for correct key (46): 11.0)
# KR: 44 | GE for correct key (46): 11.0)
# KR: 45 | GE for correct key (46): 11.0)
# KR: 46 | GE for correct key (46): 11.0)
# KR: 47 | GE for correct key (46): 11.0)
# KR: 48 | GE for correct key (46): 11.0)
# KR: 49 | GE for correct key (46): 11.0)
# KR: 50 | GE for correct key (46): 11.0)
# KR: 51 | GE for correct key (46): 11.0)
# KR: 52 | GE for correct key (46): 11.0)
# KR: 53 | GE for correct key (46): 11.0)
# KR: 54 | GE for correct key (46): 11.0)
# KR: 55 | GE for correct key (46): 11.0)
# KR: 56 | GE for correct key (46): 11.0)
# KR: 57 | GE for correct key (46): 11.0)
# KR: 58 | GE for correct key (46): 11.0)
# KR: 59 | GE for correct key (46): 11.0)
# KR: 60 | GE for correct key (46): 11.0)
# KR: 61 | GE for correct key (46): 11.0)
# KR: 62 | GE for correct key (46): 11.0)
# KR: 63 | GE for correct key (46): 11.0)
# KR: 64 | GE for correct key (46): 11.0)
# KR: 65 | GE for correct key (46): 11.0)
# KR: 66 | GE for correct key (46): 11.0)
# KR: 67 | GE for correct key (46): 11.0)
# KR: 68 | GE for correct key (46): 11.0)
# KR: 69 | GE for correct key (46): 11.0)
# KR: 70 | GE for correct key (46): 11.0)
# KR: 71 | GE for correct key (46): 11.0)
# KR: 72 | GE for correct key (46): 11.0)
# KR: 73 | GE for correct key (46): 11.0)
# KR: 74 | GE for correct key (46): 11.0)
# KR: 75 | GE for correct key (46): 11.0)
# KR: 76 | GE for correct key (46): 11.0)
# KR: 77 | GE for correct key (46): 11.0)
# KR: 78 | GE for correct key (46): 11.0)
# KR: 79 | GE for correct key (46): 11.0)
# KR: 80 | GE for correct key (46): 11.0)
# KR: 81 | GE for correct key (46): 11.0)
# KR: 82 | GE for correct key (46): 11.0)
# KR: 83 | GE for correct key (46): 11.0)
# KR: 84 | GE for correct key (46): 11.0)
# KR: 85 | GE for correct key (46): 11.0)
# KR: 86 | GE for correct key (46): 11.0)
# KR: 87 | GE for correct key (46): 11.0)
# KR: 88 | GE for correct key (46): 11.0)
# KR: 89 | GE for correct key (46): 11.0)
# KR: 90 | GE for correct key (46): 11.0)
# KR: 91 | GE for correct key (46): 11.0)
# KR: 92 | GE for correct key (46): 11.0)
# KR: 93 | GE for correct key (46): 11.0)
# KR: 94 | GE for correct key (46): 11.0)
# KR: 95 | GE for correct key (46): 11.0)
# KR: 96 | GE for correct key (46): 11.0)
# KR: 97 | GE for correct key (46): 11.0)
# KR: 98 | GE for correct key (46): 11.0)
# KR: 99 | GE for correct key (46): 11.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 700)               1540700
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 700)               490700
#
#  dense_3 (Dense)             (None, 700)               490700
#
#  dense_4 (Dense)             (None, 700)               490700
#
#  dense_5 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 3,518,609
# Trainable params: 3,514,209
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 4/4 [==============================] - 1s 108ms/step - loss: 3.0632 - accuracy: 0.0937 - val_loss: 3.0132 - val_accuracy: 0.1940
# Epoch 2/10
# 4/4 [==============================] - 0s 50ms/step - loss: 2.0377 - accuracy: 0.3938 - val_loss: 2.5371 - val_accuracy: 0.1036
# Epoch 3/10
# 4/4 [==============================] - 0s 49ms/step - loss: 1.5116 - accuracy: 0.6251 - val_loss: 2.2594 - val_accuracy: 0.1260
# Epoch 4/10
# 4/4 [==============================] - 0s 50ms/step - loss: 1.1830 - accuracy: 0.8186 - val_loss: 2.3059 - val_accuracy: 0.1432
# Epoch 5/10
# 4/4 [==============================] - 0s 51ms/step - loss: 0.8364 - accuracy: 0.9342 - val_loss: 2.5643 - val_accuracy: 0.1148
# Epoch 6/10
# 4/4 [==============================] - 0s 50ms/step - loss: 0.5383 - accuracy: 0.9705 - val_loss: 2.4730 - val_accuracy: 0.1508
# Epoch 7/10
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2905 - accuracy: 0.9872 - val_loss: 2.9831 - val_accuracy: 0.1220
# Epoch 8/10
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1422 - accuracy: 1.0000 - val_loss: 3.1006 - val_accuracy: 0.1436
# Epoch 9/10
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0675 - accuracy: 1.0000 - val_loss: 3.3947 - val_accuracy: 0.1448
# Epoch 10/10
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 3.7355 - val_accuracy: 0.1240
# KR: 0 | GE for correct key (46): 197.0)
# KR: 1 | GE for correct key (46): 197.0)
# KR: 2 | GE for correct key (46): 197.0)
# KR: 3 | GE for correct key (46): 197.0)
# KR: 4 | GE for correct key (46): 197.0)
# KR: 5 | GE for correct key (46): 197.0)
# KR: 6 | GE for correct key (46): 197.0)
# KR: 7 | GE for correct key (46): 197.0)
# KR: 8 | GE for correct key (46): 197.0)
# KR: 9 | GE for correct key (46): 197.0)
# ...
# Run 73 - GE 40 models: 197 | GE 1 models: 85 |
# Run 74 - GE 40 models: 198 | GE 1 models: 87 |
# Run 75 - GE 40 models: 198 | GE 1 models: 88 |
# Run 76 - GE 40 models: 198 | GE 1 models: 88 |
# Run 77 - GE 40 models: 199 | GE 1 models: 89 |
# Run 78 - GE 40 models: 199 | GE 1 models: 89 |
# Run 79 - GE 40 models: 198 | GE 1 models: 88 |
# Run 80 - GE 40 models: 198 | GE 1 models: 90 |
# Run 81 - GE 40 models: 198 | GE 1 models: 91 |
# Run 82 - GE 40 models: 198 | GE 1 models: 92 |
# Run 83 - GE 40 models: 198 | GE 1 models: 93 |
# Run 84 - GE 40 models: 198 | GE 1 models: 93 |
# Run 85 - GE 40 models: 197 | GE 1 models: 93 |
# Run 86 - GE 40 models: 198 | GE 1 models: 92 |
# Run 87 - GE 40 models: 197 | GE 1 models: 91 |
# Run 88 - GE 40 models: 197 | GE 1 models: 91 |
# Run 89 - GE 40 models: 197 | GE 1 models: 92 |
# Run 90 - GE 40 models: 197 | GE 1 models: 91 |
# Run 91 - GE 40 models: 198 | GE 1 models: 90 |
# Run 92 - GE 40 models: 197 | GE 1 models: 89 |
# Run 93 - GE 40 models: 197 | GE 1 models: 89 |
# Run 94 - GE 40 models: 197 | GE 1 models: 88 |
# Run 95 - GE 40 models: 198 | GE 1 models: 88 |
# Run 96 - GE 40 models: 197 | GE 1 models: 87 |
# Run 97 - GE 40 models: 197 | GE 1 models: 87 |
# Run 98 - GE 40 models: 197 | GE 1 models: 88 |
# Run 99 - GE 40 models: 196 | GE 1 models: 88 |
# Run 0 - GE 40 models: 211 | GE 5 models: 64 |
# Run 1 - GE 40 models: 185 | GE 5 models: 50 |
# Run 2 - GE 40 models: 203 | GE 5 models: 59 |
# Run 3 - GE 40 models: 197 | GE 5 models: 55 |
# Run 4 - GE 40 models: 201 | GE 5 models: 49 |
# Run 5 - GE 40 models: 201 | GE 5 models: 43 |
# Run 6 - GE 40 models: 201 | GE 5 models: 55 |
# Run 7 - GE 40 models: 203 | GE 5 models: 53 |
# Run 8 - GE 40 models: 202 | GE 5 models: 52 |
# Run 9 - GE 40 models: 201 | GE 5 models: 49 |
# Run 10 - GE 40 models: 190 | GE 5 models: 46 |
# Run 11 - GE 40 models: 185 | GE 5 models: 43 |
# Run 12 - GE 40 models: 187 | GE 5 models: 44 |
# Run 13 - GE 40 models: 188 | GE 5 models: 43 |
# Run 14 - GE 40 models: 191 | GE 5 models: 51 |
# Run 15 - GE 40 models: 191 | GE 5 models: 50 |
# Run 16 - GE 40 models: 189 | GE 5 models: 51 |
# Run 17 - GE 40 models: 191 | GE 5 models: 57 |
# Run 18 - GE 40 models: 193 | GE 5 models: 63 |
# Run 19 - GE 40 models: 192 | GE 5 models: 65 |
# Run 20 - GE 40 models: 195 | GE 5 models: 64 |
# Run 21 - GE 40 models: 196 | GE 5 models: 66 |
# Run 22 - GE 40 models: 197 | GE 5 models: 66 |
# Run 23 - GE 40 models: 198 | GE 5 models: 67 |
# Run 24 - GE 40 models: 200 | GE 5 models: 71 |
# Run 25 - GE 40 models: 199 | GE 5 models: 73 |
# Run 26 - GE 40 models: 199 | GE 5 models: 71 |
# Run 27 - GE 40 models: 199 | GE 5 models: 72 |
# Run 28 - GE 40 models: 200 | GE 5 models: 72 |
# Run 29 - GE 40 models: 201 | GE 5 models: 74 |
# Run 30 - GE 40 models: 201 | GE 5 models: 73 |
# Run 31 - GE 40 models: 202 | GE 5 models: 77 |
# Run 32 - GE 40 models: 202 | GE 5 models: 78 |
# Run 33 - GE 40 models: 201 | GE 5 models: 77 |
# Run 34 - GE 40 models: 202 | GE 5 models: 76 |
# Run 35 - GE 40 models: 202 | GE 5 models: 75 |
# Run 36 - GE 40 models: 199 | GE 5 models: 73 |
# Run 37 - GE 40 models: 200 | GE 5 models: 75 |
# Run 38 - GE 40 models: 199 | GE 5 models: 74 |
# Run 39 - GE 40 models: 196 | GE 5 models: 72 |
# Run 40 - GE 40 models: 196 | GE 5 models: 71 |
# Run 41 - GE 40 models: 195 | GE 5 models: 70 |
# Run 42 - GE 40 models: 196 | GE 5 models: 69 |
# Run 43 - GE 40 models: 195 | GE 5 models: 72 |
# Run 44 - GE 40 models: 192 | GE 5 models: 72 |
# Run 45 - GE 40 models: 193 | GE 5 models: 72 |
# Run 46 - GE 40 models: 194 | GE 5 models: 73 |
# Run 47 - GE 40 models: 195 | GE 5 models: 73 |
# Run 48 - GE 40 models: 195 | GE 5 models: 73 |
# Run 49 - GE 40 models: 193 | GE 5 models: 72 |
# Run 50 - GE 40 models: 193 | GE 5 models: 71 |
# Run 51 - GE 40 models: 193 | GE 5 models: 71 |
# Run 52 - GE 40 models: 193 | GE 5 models: 70 |
# Run 53 - GE 40 models: 193 | GE 5 models: 69 |
# Run 54 - GE 40 models: 193 | GE 5 models: 69 |
# Run 55 - GE 40 models: 194 | GE 5 models: 72 |
# Run 56 - GE 40 models: 194 | GE 5 models: 71 |
# Run 57 - GE 40 models: 194 | GE 5 models: 70 |
# Run 58 - GE 40 models: 193 | GE 5 models: 71 |
# Run 59 - GE 40 models: 194 | GE 5 models: 71 |
# Run 60 - GE 40 models: 194 | GE 5 models: 71 |
# Run 61 - GE 40 models: 194 | GE 5 models: 70 |
# Run 62 - GE 40 models: 194 | GE 5 models: 70 |
# Run 63 - GE 40 models: 195 | GE 5 models: 72 |
# Run 64 - GE 40 models: 196 | GE 5 models: 72 |
# Run 65 - GE 40 models: 196 | GE 5 models: 71 |
# Run 66 - GE 40 models: 196 | GE 5 models: 72 |
# Run 67 - GE 40 models: 197 | GE 5 models: 73 |
# Run 68 - GE 40 models: 197 | GE 5 models: 72 |
# Run 69 - GE 40 models: 197 | GE 5 models: 74 |
# Run 70 - GE 40 models: 197 | GE 5 models: 74 |
# Run 71 - GE 40 models: 197 | GE 5 models: 73 |
# Run 72 - GE 40 models: 197 | GE 5 models: 75 |
# Run 73 - GE 40 models: 197 | GE 5 models: 75 |
# Run 74 - GE 40 models: 198 | GE 5 models: 75 |
# Run 75 - GE 40 models: 198 | GE 5 models: 76 |
# Run 76 - GE 40 models: 198 | GE 5 models: 77 |
# Run 77 - GE 40 models: 199 | GE 5 models: 79 |
# Run 78 - GE 40 models: 199 | GE 5 models: 80 |
# Run 79 - GE 40 models: 198 | GE 5 models: 79 |
# Run 80 - GE 40 models: 198 | GE 5 models: 80 |
# Run 81 - GE 40 models: 198 | GE 5 models: 82 |
# Run 82 - GE 40 models: 198 | GE 5 models: 82 |
# Run 83 - GE 40 models: 198 | GE 5 models: 81 |
# Run 84 - GE 40 models: 198 | GE 5 models: 81 |
# Run 85 - GE 40 models: 197 | GE 5 models: 81 |
# Run 86 - GE 40 models: 198 | GE 5 models: 81 |
# Run 87 - GE 40 models: 197 | GE 5 models: 80 |
# Run 88 - GE 40 models: 197 | GE 5 models: 80 |
# Run 89 - GE 40 models: 197 | GE 5 models: 80 |
# Run 90 - GE 40 models: 197 | GE 5 models: 79 |
# Run 91 - GE 40 models: 198 | GE 5 models: 79 |
# Run 92 - GE 40 models: 197 | GE 5 models: 78 |
# Run 93 - GE 40 models: 197 | GE 5 models: 77 |
# Run 94 - GE 40 models: 197 | GE 5 models: 76 |
# Run 95 - GE 40 models: 198 | GE 5 models: 76 |
# Run 96 - GE 40 models: 197 | GE 5 models: 75 |
# Run 97 - GE 40 models: 197 | GE 5 models: 75 |
# Run 98 - GE 40 models: 197 | GE 5 models: 75 |
# Run 99 - GE 40 models: 196 | GE 5 models: 74 |
# Run 0 - GE 40 models: 211 | GE 10 models: 153 |
# Run 1 - GE 40 models: 185 | GE 10 models: 83 |
# Run 2 - GE 40 models: 203 | GE 10 models: 96 |
# Run 3 - GE 40 models: 197 | GE 10 models: 86 |
# Run 4 - GE 40 models: 201 | GE 10 models: 86 |
# Run 5 - GE 40 models: 201 | GE 10 models: 75 |
# Run 6 - GE 40 models: 201 | GE 10 models: 94 |
# Run 7 - GE 40 models: 203 | GE 10 models: 99 |
# Run 8 - GE 40 models: 202 | GE 10 models: 107 |
# Run 9 - GE 40 models: 201 | GE 10 models: 99 |
# Run 10 - GE 40 models: 190 | GE 10 models: 91 |
# Run 11 - GE 40 models: 185 | GE 10 models: 88 |
# Run 12 - GE 40 models: 187 | GE 10 models: 85 |
# Run 13 - GE 40 models: 188 | GE 10 models: 84 |
# Run 14 - GE 40 models: 191 | GE 10 models: 87 |
# Run 15 - GE 40 models: 191 | GE 10 models: 82 |
# Run 16 - GE 40 models: 189 | GE 10 models: 82 |
# Run 17 - GE 40 models: 191 | GE 10 models: 88 |
# Run 18 - GE 40 models: 193 | GE 10 models: 92 |
# Run 19 - GE 40 models: 192 | GE 10 models: 93 |
# Run 20 - GE 40 models: 195 | GE 10 models: 93 |
# Run 21 - GE 40 models: 196 | GE 10 models: 99 |
# Run 22 - GE 40 models: 197 | GE 10 models: 100 |
# Run 23 - GE 40 models: 198 | GE 10 models: 99 |
# Run 24 - GE 40 models: 200 | GE 10 models: 101 |
# Run 25 - GE 40 models: 199 | GE 10 models: 101 |
# Run 26 - GE 40 models: 199 | GE 10 models: 100 |
# Run 27 - GE 40 models: 199 | GE 10 models: 101 |
# Run 28 - GE 40 models: 200 | GE 10 models: 98 |
# Run 29 - GE 40 models: 201 | GE 10 models: 100 |
# Run 30 - GE 40 models: 201 | GE 10 models: 100 |
# Run 31 - GE 40 models: 202 | GE 10 models: 104 |
# Run 32 - GE 40 models: 202 | GE 10 models: 104 |
# Run 33 - GE 40 models: 201 | GE 10 models: 102 |
# Run 34 - GE 40 models: 202 | GE 10 models: 100 |
# Run 35 - GE 40 models: 202 | GE 10 models: 99 |
# Run 36 - GE 40 models: 199 | GE 10 models: 97 |
# Run 37 - GE 40 models: 200 | GE 10 models: 98 |
# Run 38 - GE 40 models: 199 | GE 10 models: 99 |
# Run 39 - GE 40 models: 196 | GE 10 models: 96 |
# Run 40 - GE 40 models: 196 | GE 10 models: 95 |
# Run 41 - GE 40 models: 195 | GE 10 models: 94 |
# Run 42 - GE 40 models: 196 | GE 10 models: 92 |
# Run 43 - GE 40 models: 195 | GE 10 models: 93 |
# Run 44 - GE 40 models: 192 | GE 10 models: 94 |
# Run 45 - GE 40 models: 193 | GE 10 models: 93 |
# Run 46 - GE 40 models: 194 | GE 10 models: 91 |
# Run 47 - GE 40 models: 195 | GE 10 models: 91 |
# Run 48 - GE 40 models: 195 | GE 10 models: 91 |
# Run 49 - GE 40 models: 193 | GE 10 models: 90 |
# Run 50 - GE 40 models: 193 | GE 10 models: 90 |
# Run 51 - GE 40 models: 193 | GE 10 models: 91 |
# Run 52 - GE 40 models: 193 | GE 10 models: 89 |
# Run 53 - GE 40 models: 193 | GE 10 models: 88 |
# Run 54 - GE 40 models: 193 | GE 10 models: 88 |
# Run 55 - GE 40 models: 194 | GE 10 models: 90 |
# Run 56 - GE 40 models: 194 | GE 10 models: 89 |
# Run 57 - GE 40 models: 194 | GE 10 models: 88 |
# Run 58 - GE 40 models: 193 | GE 10 models: 88 |
# Run 59 - GE 40 models: 194 | GE 10 models: 90 |
# Run 60 - GE 40 models: 194 | GE 10 models: 90 |
# Run 61 - GE 40 models: 194 | GE 10 models: 89 |
# Run 62 - GE 40 models: 194 | GE 10 models: 91 |
# Run 63 - GE 40 models: 195 | GE 10 models: 93 |
# Run 64 - GE 40 models: 196 | GE 10 models: 92 |
# Run 65 - GE 40 models: 196 | GE 10 models: 92 |
# Run 66 - GE 40 models: 196 | GE 10 models: 94 |
# Run 67 - GE 40 models: 197 | GE 10 models: 95 |
# Run 68 - GE 40 models: 197 | GE 10 models: 94 |
# Run 69 - GE 40 models: 197 | GE 10 models: 95 |
# Run 70 - GE 40 models: 197 | GE 10 models: 95 |
# Run 71 - GE 40 models: 197 | GE 10 models: 95 |
# Run 72 - GE 40 models: 197 | GE 10 models: 96 |
# Run 73 - GE 40 models: 197 | GE 10 models: 95 |
# Run 74 - GE 40 models: 198 | GE 10 models: 95 |
# Run 75 - GE 40 models: 198 | GE 10 models: 96 |
# Run 76 - GE 40 models: 198 | GE 10 models: 98 |
# Run 77 - GE 40 models: 199 | GE 10 models: 99 |
# Run 78 - GE 40 models: 199 | GE 10 models: 99 |
# Run 79 - GE 40 models: 198 | GE 10 models: 98 |
# Run 80 - GE 40 models: 198 | GE 10 models: 99 |
# Run 81 - GE 40 models: 198 | GE 10 models: 100 |
# Run 82 - GE 40 models: 198 | GE 10 models: 100 |
# Run 83 - GE 40 models: 198 | GE 10 models: 99 |
# Run 84 - GE 40 models: 198 | GE 10 models: 100 |
# Run 85 - GE 40 models: 197 | GE 10 models: 99 |
# Run 86 - GE 40 models: 198 | GE 10 models: 100 |
# Run 87 - GE 40 models: 197 | GE 10 models: 99 |
# Run 88 - GE 40 models: 197 | GE 10 models: 98 |
# Run 89 - GE 40 models: 197 | GE 10 models: 98 |
# Run 90 - GE 40 models: 197 | GE 10 models: 97 |
# Run 91 - GE 40 models: 198 | GE 10 models: 96 |
# Run 92 - GE 40 models: 197 | GE 10 models: 95 |
# Run 93 - GE 40 models: 197 | GE 10 models: 94 |
# Run 94 - GE 40 models: 197 | GE 10 models: 94 |
# Run 95 - GE 40 models: 198 | GE 10 models: 93 |
# Run 96 - GE 40 models: 197 | GE 10 models: 92 |
# Run 97 - GE 40 models: 197 | GE 10 models: 92 |
# Run 98 - GE 40 models: 197 | GE 10 models: 93 |
# Run 99 - GE 40 models: 196 | GE 10 models: 92 |
# Run 0 - GE 40 models: 211 | GE 20 models: 210 |
# Run 1 - GE 40 models: 185 | GE 20 models: 140 |
# Run 2 - GE 40 models: 203 | GE 20 models: 150 |
# Run 3 - GE 40 models: 197 | GE 20 models: 137 |
# Run 4 - GE 40 models: 201 | GE 20 models: 131 |
# Run 5 - GE 40 models: 201 | GE 20 models: 114 |
# Run 6 - GE 40 models: 201 | GE 20 models: 124 |
# Run 7 - GE 40 models: 203 | GE 20 models: 130 |
# Run 8 - GE 40 models: 202 | GE 20 models: 136 |
# Run 9 - GE 40 models: 201 | GE 20 models: 125 |
# Run 10 - GE 40 models: 190 | GE 20 models: 117 |
# Run 11 - GE 40 models: 185 | GE 20 models: 112 |
# Run 12 - GE 40 models: 187 | GE 20 models: 112 |
# Run 13 - GE 40 models: 188 | GE 20 models: 115 |
# Run 14 - GE 40 models: 191 | GE 20 models: 121 |
# Run 15 - GE 40 models: 191 | GE 20 models: 117 |
# Run 16 - GE 40 models: 189 | GE 20 models: 119 |
# Run 17 - GE 40 models: 191 | GE 20 models: 121 |
# Run 18 - GE 40 models: 193 | GE 20 models: 124 |
# Run 19 - GE 40 models: 192 | GE 20 models: 123 |
# Run 20 - GE 40 models: 195 | GE 20 models: 124 |
# Run 21 - GE 40 models: 196 | GE 20 models: 128 |
# Run 22 - GE 40 models: 197 | GE 20 models: 130 |
# Run 23 - GE 40 models: 198 | GE 20 models: 129 |
# Run 24 - GE 40 models: 200 | GE 20 models: 132 |
# Run 25 - GE 40 models: 199 | GE 20 models: 129 |
# Run 26 - GE 40 models: 199 | GE 20 models: 127 |
# Run 27 - GE 40 models: 199 | GE 20 models: 128 |
# Run 28 - GE 40 models: 200 | GE 20 models: 126 |
# Run 29 - GE 40 models: 201 | GE 20 models: 127 |
# Run 30 - GE 40 models: 201 | GE 20 models: 127 |
# Run 31 - GE 40 models: 202 | GE 20 models: 131 |
# Run 32 - GE 40 models: 202 | GE 20 models: 132 |
# Run 33 - GE 40 models: 201 | GE 20 models: 131 |
# Run 34 - GE 40 models: 202 | GE 20 models: 130 |
# Run 35 - GE 40 models: 202 | GE 20 models: 130 |
# Run 36 - GE 40 models: 199 | GE 20 models: 128 |
# Run 37 - GE 40 models: 200 | GE 20 models: 129 |
# Run 38 - GE 40 models: 199 | GE 20 models: 129 |
# Run 39 - GE 40 models: 196 | GE 20 models: 127 |
# Run 40 - GE 40 models: 196 | GE 20 models: 128 |
# Run 41 - GE 40 models: 195 | GE 20 models: 126 |
# Run 42 - GE 40 models: 196 | GE 20 models: 128 |
# Run 43 - GE 40 models: 195 | GE 20 models: 126 |
# Run 44 - GE 40 models: 192 | GE 20 models: 127 |
# Run 45 - GE 40 models: 193 | GE 20 models: 126 |
# Run 46 - GE 40 models: 194 | GE 20 models: 125 |
# Run 47 - GE 40 models: 195 | GE 20 models: 127 |
# Run 48 - GE 40 models: 195 | GE 20 models: 126 |
# Run 49 - GE 40 models: 193 | GE 20 models: 124 |
# Run 50 - GE 40 models: 193 | GE 20 models: 125 |
# Run 51 - GE 40 models: 193 | GE 20 models: 125 |
# Run 52 - GE 40 models: 193 | GE 20 models: 123 |
# Run 53 - GE 40 models: 193 | GE 20 models: 122 |
# Run 54 - GE 40 models: 193 | GE 20 models: 122 |
# Run 55 - GE 40 models: 194 | GE 20 models: 123 |
# Run 56 - GE 40 models: 194 | GE 20 models: 121 |
# Run 57 - GE 40 models: 194 | GE 20 models: 121 |
# Run 58 - GE 40 models: 193 | GE 20 models: 121 |
# Run 59 - GE 40 models: 194 | GE 20 models: 122 |
# Run 60 - GE 40 models: 194 | GE 20 models: 120 |
# Run 61 - GE 40 models: 194 | GE 20 models: 120 |
# Run 62 - GE 40 models: 194 | GE 20 models: 121 |
# Run 63 - GE 40 models: 195 | GE 20 models: 122 |
# Run 64 - GE 40 models: 196 | GE 20 models: 121 |
# Run 65 - GE 40 models: 196 | GE 20 models: 120 |
# Run 66 - GE 40 models: 196 | GE 20 models: 121 |
# Run 67 - GE 40 models: 197 | GE 20 models: 123 |
# Run 68 - GE 40 models: 197 | GE 20 models: 122 |
# Run 69 - GE 40 models: 197 | GE 20 models: 122 |
# Run 70 - GE 40 models: 197 | GE 20 models: 123 |
# Run 71 - GE 40 models: 197 | GE 20 models: 123 |
# Run 72 - GE 40 models: 197 | GE 20 models: 123 |
# Run 73 - GE 40 models: 197 | GE 20 models: 123 |
# Run 74 - GE 40 models: 198 | GE 20 models: 124 |
# Run 75 - GE 40 models: 198 | GE 20 models: 125 |
# Run 76 - GE 40 models: 198 | GE 20 models: 125 |
# Run 77 - GE 40 models: 199 | GE 20 models: 126 |
# Run 78 - GE 40 models: 199 | GE 20 models: 126 |
# Run 79 - GE 40 models: 198 | GE 20 models: 125 |
# Run 80 - GE 40 models: 198 | GE 20 models: 125 |
# Run 81 - GE 40 models: 198 | GE 20 models: 126 |
# Run 82 - GE 40 models: 198 | GE 20 models: 126 |
# Run 83 - GE 40 models: 198 | GE 20 models: 126 |
# Run 84 - GE 40 models: 198 | GE 20 models: 126 |
# Run 85 - GE 40 models: 197 | GE 20 models: 126 |
# Run 86 - GE 40 models: 198 | GE 20 models: 127 |
# Run 87 - GE 40 models: 197 | GE 20 models: 126 |
# Run 88 - GE 40 models: 197 | GE 20 models: 126 |
# Run 89 - GE 40 models: 197 | GE 20 models: 126 |
# Run 90 - GE 40 models: 197 | GE 20 models: 126 |
# Run 91 - GE 40 models: 198 | GE 20 models: 125 |
# Run 92 - GE 40 models: 197 | GE 20 models: 125 |
# Run 93 - GE 40 models: 197 | GE 20 models: 124 |
# Run 94 - GE 40 models: 197 | GE 20 models: 124 |
# Run 95 - GE 40 models: 198 | GE 20 models: 125 |
# Run 96 - GE 40 models: 197 | GE 20 models: 124 |
# Run 97 - GE 40 models: 197 | GE 20 models: 124 |
# Run 98 - GE 40 models: 197 | GE 20 models: 123 |
# Run 99 - GE 40 models: 196 | GE 20 models: 122 |

# %%
plt.rc('figure', figsize=(15, 8))

# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('MLP_CHES_Random_Undersample_Apr29.png')
plt.savefig('MLP_CHES_Random_Undersample_Apr29.pdf')

# %%
plt.rc('figure', figsize=(15, 8))
ensemble_aes = EnsembleAES()
#ensemble_aes.set_dataset("ascad_fixed_key")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_dataset("ches_ctf")
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0) # 0 for CHES. 2 for ASCAD
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
#ensemble_aes.run_ensemble(number_of_models=30, number_of_best_models=[1,1,1,1])
# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
#plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
#plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
#plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
#plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
#plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
#plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('CNN_CHES_Ensembles_SMOTE_SingleModel.png')
plt.savefig('CNN_CHES_Ensembles_SMOTE_SingleModel.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-16036964b460> in <module>()
#      12 #plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#      13 #plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
# ---> 14 plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
#      15 plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
#      16 #plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     320         # element array of None which causes problems downstream.
#     321         if any(v is None for v in tup):
# --> 322             raise ValueError("x, y, and format string must not be None")
#     323
#     324         kw = {}
#
# ValueError: x, y, and format string must not be None

# %%
ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
#ensemble_aes.run_ensemble(number_of_models=50, number_of_best_models=10)

# plotting GE and SR
plt.subplot(1, 2, 1)
plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.show()

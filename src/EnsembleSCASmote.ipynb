# %%
import sys
import os
from tensorflow.keras import backend as backend
from tensorflow.keras.utils import to_categorical
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import tensorflow as tf
from imblearn.over_sampling import SMOTE
from collections import Counter

#!cp /content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py/
#file_location = "/content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py"
#sys.path.append(os.path.abspath(file_location))
#sys.path.insert(0,'/content/drive/MyDrive/Colab\Notebooks/QEResearch/ches_ctf/')
#sys.path.append('/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf')
#import SCAMetrics
# Out:
# Mounted at /content/drive

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1E9kCFN_Qf6720hbw996x6z0xUSLqQwjg'})

# %%
# !pip install import-ipynb
import import_ipynb

# !pip install -U -q PyDrive
#your_module.GetContentFile('sca_metrics.ipynb')
#from sca_metrics import *
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.4)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.3.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.5.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.8.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.9.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (2.15.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.11.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.7.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
#your_module = drive.CreateFile({'id':'11WgfAW1xTNRX_tl74AcFCnJNh6hhjtrQ'})
your_module = drive.CreateFile({'id':'1t5viOwM1THtGwwGzxVIO1hvrroYqvGdA'})
your_module.GetContentFile('sca_metrics.py') 
import sca_metrics
from sca_metrics import SCAMetrics
#your_module.GetContentFile({'id':'16R_OCUvUjNXD3hnk_XvW0H2CR-MtbpeI'})

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm'})
your_module.GetContentFile('loaddatasetimbalanced.py') #13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm
import loaddatasetimbalanced
from loaddatasetimbalanced import LoadDatasets

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'14CorI66D0y0P-4eXCStsl90Avpb-xtUM'})
your_module.GetContentFile('datasets.py') #14CorI66D0y0P-4eXCStsl90Avpb-xtUM
import datasets
from datasets import SCADatasets

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd'})
your_module.GetContentFile('neural_networks.py') #1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd
import neural_networks
from neural_networks import NeuralNetwork

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import random


class EnsembleAES:

    def __init__(self):
        self.number_of_models = 50
        self.number_of_best_models = [10, 10, 10, 10]
        self.ge_all_validation = []
        self.ge_all_attack = []
        self.sr_all_validation = []
        self.sr_all_attack = []
        self.k_ps_all = []
        self.ge_ensemble = None
        self.ge_ensemble_best_models = None
        self.ge_ensemble_best_models0 = None #added
        self.ge_ensemble_best_models1 = None #added
        self.ge_ensemble_best_models2 = None #added
        self.ge_ensemble_best_models3 = None #added
        self.ge_best_model_validation = None
        self.ge_best_model_attack = None
        self.sr_ensemble = None
        self.sr_ensemble_best_models = None
        self.sr_ensemble_best_models0 = None #added
        self.sr_ensemble_best_models1 = None #added
        self.sr_ensemble_best_models2 = None #added
        self.sr_ensemble_best_models3 = None #added
        self.sr_best_model_validation = None
        self.sr_best_model_attack = None
        self.target_dataset = None
        self.l_model = None
        self.target_byte = None
        self.classes = None
        self.epochs = None
        self.mini_batch = None

    def set_dataset(self, target): #function for setting up dataset - ASCAD | ches_ctf
        self.target_dataset = target

    def set_leakage_model(self, leakage_model): #function for setting up leakage model
        self.l_model = leakage_model
        if leakage_model == "HW":
            self.classes = 9
        else:
            self.classes = 256

    def set_target_byte(self, target_byte): #target byte to attack: most of the time, this is 3
        self.target_byte = target_byte

    def set_epochs(self, epochs): #we set no of epochs for our training model
        self.epochs = epochs

    def set_mini_batch(self, mini_batch): #not sure of mini_batch. I guess it means batch
        self.mini_batch = mini_batch

    def __add_if_one(self, value): #don't know when this will be useful
        return 1 if value == 1 else 0

    def get_best_models(self, n_models, result_models_validation, n_traces):
        result_number_of_traces_val = []                      #best models is ranked by guessing entropy traces (when it's equal 1)
        for model_index in range(n_models):
            if result_models_validation[model_index][n_traces - 1] == 1: #checking for the best model starting from the last (min) trace
                for index in range(n_traces - 1, -1, -1):           #decrementing and moving up the trace
                    if result_models_validation[model_index][index] != 1:
                        result_number_of_traces_val.append(
                            [result_models_validation[model_index][n_traces - 1], index + 1,
                             model_index])
                        break
            else:
                result_number_of_traces_val.append(
                    [result_models_validation[model_index][n_traces - 1], n_traces,
                     model_index])

        sorted_models = sorted(result_number_of_traces_val, key=lambda l: l[:]) #sort by 

        list_of_best_models = []
        for model_index in range(n_models):
            list_of_best_models.append(sorted_models[model_index][2])

        return list_of_best_models

    def run_mlp(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)

        model = NeuralNetwork().mlp_random(self.classes, params["number_of_samples"], activation, neurons, layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),
            callbacks=[])

        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation, step, fraction)
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def run_cnn(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        X_profiling = X_profiling.reshape((X_profiling.shape[0], X_profiling.shape[1], 1))
        X_validation = X_validation.reshape((X_validation.shape[0], X_validation.shape[1], 1))
        X_attack = X_attack.reshape((X_attack.shape[0], X_attack.shape[1], 1))

        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        dense_layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)
        conv_layers = random.randrange(1, 2, 1)
        filters = random.randrange(8, 32, 4)
        kernel_size = random.randrange(10, 20, 2)
        stride = random.randrange(5, 10, 5)

        model = NeuralNetwork().cnn_random(self.classes, params["number_of_samples"], activation, neurons, conv_layers, filters,
                                           kernel_size, stride, dense_layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),
            callbacks=[])
                                                                      #100 is for number of runs
        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation,
                                                                      step, fraction)
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def compute_ensembles(self, kr_nt, correct_key):
       #nm = number_of_models
      list_of_best_models = self.get_best_models(self.number_of_models, self.ge_all_validation, kr_nt) #i added

      self.ge_best_model_validation = self.ge_all_validation[list_of_best_models[0]]
      self.ge_best_model_attack = self.ge_all_attack[list_of_best_models[0]]
      self.sr_best_model_validation = self.sr_all_validation[list_of_best_models[0]]
      self.sr_best_model_attack = self.sr_all_attack[list_of_best_models[0]]

      for i in range(4): #added

          kr_ensemble = np.zeros(kr_nt)
          krs_ensemble = np.zeros((100, kr_nt))
          kr_ensemble_best_models = np.zeros(kr_nt)
          krs_ensemble_best_models = np.zeros((100, kr_nt))

          for run in range(100):

              key_p_ensemble = np.zeros(256)
              key_p_ensemble_best_models = np.zeros(256)

              for index in range(kr_nt):
                  for model_index in range(self.number_of_models):
                      key_p_ensemble += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)
                  for model_index in range(self.number_of_best_models[i]): #i added
                      key_p_ensemble_best_models += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)

                  key_p_ensemble_sorted = np.argsort(key_p_ensemble)[::-1]
                  key_p_ensemble_best_models_sorted = np.argsort(key_p_ensemble_best_models)[::-1]

                  kr_position = list(key_p_ensemble_sorted).index(correct_key) + 1
                  kr_ensemble[index] += kr_position
                  krs_ensemble[run][index] = kr_position

                  kr_position = list(key_p_ensemble_best_models_sorted).index(correct_key) + 1
                  kr_ensemble_best_models[index] += kr_position
                  krs_ensemble_best_models[run][index] = kr_position

              print("Run {} - GE {} models: {} | GE {} models: {} | ".format(run, self.number_of_models,
                                                                            int(kr_ensemble[kr_nt - 1] / (run + 1)),
                                                                            self.number_of_best_models[i], #i added
                                                                            int(kr_ensemble_best_models[kr_nt - 1] / (run + 1))))

          ge_ensemble = kr_ensemble / 100
          ge_ensemble_best_models = kr_ensemble_best_models / 100

          sr_ensemble = np.zeros(kr_nt)
          sr_ensemble_best_models = np.zeros(kr_nt)

          for index in range(kr_nt):
              for run in range(100):
                  sr_ensemble[index] += self.__add_if_one(krs_ensemble[run][index])
                  sr_ensemble_best_models[index] += self.__add_if_one(krs_ensemble_best_models[run][index])
          if (i==0): 
            ge_ensemble_best_models0 = ge_ensemble_best_models
            sr_ensemble_best_models0 = sr_ensemble_best_models
          if (i==1):
            ge_ensemble_best_models1 = ge_ensemble_best_models
            sr_ensemble_best_models1 = sr_ensemble_best_models
          if(i==2):
            ge_ensemble_best_models2 = ge_ensemble_best_models
            sr_ensemble_best_models2 = sr_ensemble_best_models
          if(i==3):
            ge_ensemble_best_models3 = ge_ensemble_best_models
            sr_ensemble_best_models3 = sr_ensemble_best_models
            ge_ensemble_best_models = ge_ensemble_best_models0
            sr_ensemble_best_models = sr_ensemble_best_models0
          
        #return ge_ensemble, ge_ensemble_best_models, sr_ensemble/100, sr_ensemble_best_models/100
          #next line added
      return ge_ensemble, ge_ensemble_best_models, ge_ensemble_best_models1, ge_ensemble_best_models2, ge_ensemble_best_models3, sr_ensemble/100, sr_ensemble_best_models/100, sr_ensemble_best_models1/100,sr_ensemble_best_models2/100,sr_ensemble_best_models3/100 

    def create_z_score_norm(self, dataset):
        z_score_mean = np.mean(dataset, axis=0)
        z_score_std = np.std(dataset, axis=0)
        return z_score_mean, z_score_std

    def apply_z_score_norm(self, dataset, z_score_mean, z_score_std):
        for index in range(len(dataset)):
            dataset[index] = (dataset[index] - z_score_mean) / z_score_std

    def run_ensemble(self, number_of_models, number_of_best_models):

        self.number_of_models = number_of_models
        self.number_of_best_models = number_of_best_models

        target_params = SCADatasets().get_trace_set(self.target_dataset)

        #root_folder = "D:/traces/"
        #root_folder = '/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf/'
        root_folder = '/content/gdrive/MyDrive/QEResearch/ches_ctf/'

        (X_profiling, Y_profiling), (X_validation, Y_validation), (X_attack, Y_attack), (
            _, plt_validation, plt_attack) = LoadDatasets().load_dataset(
            root_folder + target_params["file"], target_params["n_profiling"], target_params["n_attack"], self.target_byte, self.l_model)

        
         #measure imbalance of the data here
        oversample = SMOTE()          #added
        X_profilinga, Y_profilinga = oversample.fit_resample(X_profiling, Y_profiling)  #added
        # summarize distribution
        counter = Counter(Y_profilinga)      #added switch betweenn Y_profiling & Y_profilinga
        for k,v in counter.items():   #added
          per = v / len(Y_profilinga) * 100   #added
          print('Class=%d, n=%d (%.3f%%)' % (k, v, per))  #added
        # plot the distribution
        plt.bar(counter.keys(), counter.values())    #added
        #plt.subplot(1, 2, 1)
        #plt.plot(ensemble_aes.get_ge_best_model_validation(), )
        plt.xlabel("Classes")
        plt.ylabel("Frequency")
        plt.legend()
        plt.show()   #added

        X_profiling, Y_profiling = X_profilinga, Y_profilinga
        # normalize with z-score
        z_score_mean, z_score_std = self.create_z_score_norm(X_profiling)
        self.apply_z_score_norm(X_profiling, z_score_mean, z_score_std) #a added
        self.apply_z_score_norm(X_validation, z_score_mean, z_score_std)
        self.apply_z_score_norm(X_attack, z_score_mean, z_score_std)

        # convert labels to categorical labels
        Y_profiling = to_categorical(Y_profiling, num_classes=self.classes) #a added
        Y_validation = to_categorical(Y_validation, num_classes=self.classes)
        Y_attack = to_categorical(Y_attack, num_classes=self.classes)

        X_profiling = X_profiling.astype('float32')
        X_validation = X_validation.astype('float32')
        X_attack = X_attack.astype('float32')

        kr_step = 10  # key rank processed for each kr_step traces
        kr_fraction = 1  # validation or attack sets are divided by kr_fraction before computing key rank

        self.ge_all_validation = []
        self.sr_all_validation = []
        self.ge_all_attack = []
        self.k_ps_all = []

        kr_nt = int(len(X_validation) / (kr_step * kr_fraction))

        # train random MLP
        for model_index in range(self.number_of_models):
            ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_mlp(X_profiling, Y_profiling,
                                                                                      X_validation, Y_validation,
                                                                                      X_attack, Y_attack,
                                                                                      plt_validation, plt_attack,
                                                                                      target_params, kr_step, kr_fraction)
            self.ge_all_validation.append(ge_validation)
            self.ge_all_attack.append(ge_attack)
            self.sr_all_validation.append(sr_validation)
            self.sr_all_attack.append(sr_attack)
            self.k_ps_all.append(kp_krs)

        # train random CNN
        #for model_index in range(self.number_of_models):
        #     ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_cnn(X_profiling, Y_profiling,
        #                                                                               X_validation, Y_validation,
        #                                                                               X_attack, Y_attack,
        #                                                                               plt_validation, plt_attack,
        #                                                                               target_params, kr_step, kr_fraction)
        #     self.ge_all_validation.append(ge_validation)
        #     self.ge_all_attack.append(ge_attack)
        #     self.sr_all_validation.append(sr_validation)
        #     self.sr_all_attack.append(sr_attack)
        #     self.k_ps_all.append(kp_krs)                  #kr_nt = int(len(X_validation) / (kr_step * kr_fraction))

        #ge_ensemble, ge_ensemble_best_models, sr_ensemble, sr_ensemble_best_models = self.compute_ensembles(kr_nt,
         #                                                                                                   target_params["good_key"])
        ge_ensemble, ge_ensemble_best_models, ge_ensemble_best_models1, ge_ensemble_best_models2, ge_ensemble_best_models3, sr_ensemble, sr_ensemble_best_models, sr_ensemble_best_models1, sr_ensemble_best_models2,sr_ensemble_best_models3 = self.compute_ensembles(kr_nt,
                                                                                                             target_params["good_key"])
             

        self.ge_ensemble = ge_ensemble
        self.ge_ensemble_best_models = ge_ensemble_best_models
        self.ge_ensemble_best_models1 = ge_ensemble_best_models1 #added
        self.ge_ensemble_best_models2 = ge_ensemble_best_models2 #added
        self.ge_ensemble_best_models3 = ge_ensemble_best_models3 #added

        self.sr_ensemble = sr_ensemble
        self.sr_ensemble_best_models = sr_ensemble_best_models
        self.sr_ensemble_best_models1 = sr_ensemble_best_models1 #added
        self.sr_ensemble_best_models2 = sr_ensemble_best_models2 #added
        self.sr_ensemble_best_models3 = sr_ensemble_best_models3 #added




    def get_ge_ensemble(self):
        return self.ge_ensemble

    def get_ge_ensemble_best_models(self):
        return self.ge_ensemble_best_models

    def get_ge_ensemble_best_models1(self): #added
        return self.ge_ensemble_best_models1

    def get_ge_ensemble_best_models2(self): #added
        return self.ge_ensemble_best_models2

    def get_ge_ensemble_best_models3(self): #added
        return self.ge_ensemble_best_models3

    def get_ge_best_model_validation(self):
        return self.ge_best_model_validation

    def get_ge_best_model_attack(self):
        return self.ge_best_model_attack

    def get_sr_ensemble(self):
        return self.sr_ensemble

    def get_sr_ensemble_best_models1(self): #added
        return self.sr_ensemble_best_models1

    def get_sr_ensemble_best_models2(self): #added
        return self.sr_ensemble_best_models2

    def get_sr_ensemble_best_models3(self): #added
        return self.sr_ensemble_best_models3


    def get_sr_ensemble_best_models(self):
        return self.sr_ensemble_best_models

    def get_sr_best_model_validation(self):
        return self.sr_best_model_validation

    def get_sr_best_model_attack(self):
        return self.sr_best_model_attack

# %%
ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
#ensemble_aes.set_dataset("ascad_fixed_key")  #changed from ches_ctf
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
#ensemble_aes.run_ensemble(number_of_models=5, number_of_best_models=[1,2,3,4])
ensemble_aes.run_ensemble(number_of_models=40, number_of_best_models=[1,5,10,20])
# Out:
# No handles with labels found to put in legend.
# Class=5, n=12294 (11.111%)
# Class=4, n=12294 (11.111%)
# Class=6, n=12294 (11.111%)
# Class=3, n=12294 (11.111%)
# Class=7, n=12294 (11.111%)
# Class=1, n=12294 (11.111%)
# Class=2, n=12294 (11.111%)
# Class=0, n=12294 (11.111%)
# Class=8, n=12294 (11.111%)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 700)               1540700
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 2,046,509
# Trainable params: 2,042,109
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Streaming output truncated to the last 5000 lines.
# KR: 96 | GE for correct key (46): 40.0)
# KR: 97 | GE for correct key (46): 40.0)
# KR: 98 | GE for correct key (46): 40.0)
# KR: 99 | GE for correct key (46): 40.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 700)               1540700
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 700)               490700
#
#  dense_3 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 2,537,209
# Trainable params: 2,532,809
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 5s 16ms/step - loss: 1.3235 - accuracy: 0.5282 - val_loss: 2.5550 - val_accuracy: 0.2548
# Epoch 2/10
# 277/277 [==============================] - 4s 16ms/step - loss: 0.7649 - accuracy: 0.7131 - val_loss: 2.7344 - val_accuracy: 0.2380
# Epoch 3/10
# 277/277 [==============================] - 4s 16ms/step - loss: 0.5553 - accuracy: 0.7935 - val_loss: 3.2068 - val_accuracy: 0.2436
# Epoch 4/10
# 277/277 [==============================] - 4s 16ms/step - loss: 0.4067 - accuracy: 0.8517 - val_loss: 3.6379 - val_accuracy: 0.2356
# Epoch 5/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.2895 - accuracy: 0.8972 - val_loss: 4.1503 - val_accuracy: 0.2096
# Epoch 6/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.2051 - accuracy: 0.9298 - val_loss: 5.0474 - val_accuracy: 0.2432
# Epoch 7/10
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1421 - accuracy: 0.9530 - val_loss: 5.0224 - val_accuracy: 0.2292
# Epoch 8/10
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1094 - accuracy: 0.9637 - val_loss: 5.5355 - val_accuracy: 0.2328
# Epoch 9/10
# 277/277 [==============================] - 4s 16ms/step - loss: 0.0971 - accuracy: 0.9671 - val_loss: 5.5528 - val_accuracy: 0.2172
# Epoch 10/10
# 277/277 [==============================] - 4s 16ms/step - loss: 0.1225 - accuracy: 0.9575 - val_loss: 6.1654 - val_accuracy: 0.2480
# KR: 0 | GE for correct key (46): 6.0)
# KR: 1 | GE for correct key (46): 6.0)
# KR: 2 | GE for correct key (46): 6.0)
# KR: 3 | GE for correct key (46): 6.0)
# KR: 4 | GE for correct key (46): 6.0)
# KR: 5 | GE for correct key (46): 6.0)
# KR: 6 | GE for correct key (46): 6.0)
# KR: 7 | GE for correct key (46): 6.0)
# KR: 8 | GE for correct key (46): 6.0)
# KR: 9 | GE for correct key (46): 6.0)
# KR: 10 | GE for correct key (46): 6.0)
# KR: 11 | GE for correct key (46): 6.0)
# KR: 12 | GE for correct key (46): 6.0)
# KR: 13 | GE for correct key (46): 6.0)
# KR: 14 | GE for correct key (46): 6.0)
# KR: 15 | GE for correct key (46): 6.0)
# KR: 16 | GE for correct key (46): 6.0)
# KR: 17 | GE for correct key (46): 6.0)
# KR: 18 | GE for correct key (46): 6.0)
# KR: 19 | GE for correct key (46): 6.0)
# KR: 20 | GE for correct key (46): 6.0)
# KR: 21 | GE for correct key (46): 6.0)
# KR: 22 | GE for correct key (46): 6.0)
# KR: 23 | GE for correct key (46): 6.0)
# KR: 24 | GE for correct key (46): 6.0)
# KR: 25 | GE for correct key (46): 6.0)
# KR: 26 | GE for correct key (46): 6.0)
# KR: 27 | GE for correct key (46): 6.0)
# KR: 28 | GE for correct key (46): 6.0)
# KR: 29 | GE for correct key (46): 6.0)
# KR: 30 | GE for correct key (46): 6.0)
# KR: 31 | GE for correct key (46): 6.0)
# KR: 32 | GE for correct key (46): 6.0)
# KR: 33 | GE for correct key (46): 6.0)
# KR: 34 | GE for correct key (46): 6.0)
# KR: 35 | GE for correct key (46): 6.0)
# KR: 36 | GE for correct key (46): 6.0)
# KR: 37 | GE for correct key (46): 6.0)
# KR: 38 | GE for correct key (46): 6.0)
# KR: 39 | GE for correct key (46): 6.0)
# KR: 40 | GE for correct key (46): 6.0)
# KR: 41 | GE for correct key (46): 6.0)
# KR: 42 | GE for correct key (46): 6.0)
# KR: 43 | GE for correct key (46): 6.0)
# KR: 44 | GE for correct key (46): 6.0)
# KR: 45 | GE for correct key (46): 6.0)
# KR: 46 | GE for correct key (46): 6.0)
# KR: 47 | GE for correct key (46): 6.0)
# KR: 48 | GE for correct key (46): 6.0)
# KR: 49 | GE for correct key (46): 6.0)
# KR: 50 | GE for correct key (46): 6.0)
# KR: 51 | GE for correct key (46): 6.0)
# KR: 52 | GE for correct key (46): 6.0)
# KR: 53 | GE for correct key (46): 6.0)
# KR: 54 | GE for correct key (46): 6.0)
# KR: 55 | GE for correct key (46): 6.0)
# KR: 56 | GE for correct key (46): 6.0)
# KR: 57 | GE for correct key (46): 6.0)
# KR: 58 | GE for correct key (46): 6.0)
# KR: 59 | GE for correct key (46): 6.0)
# KR: 60 | GE for correct key (46): 6.0)
# KR: 61 | GE for correct key (46): 6.0)
# KR: 62 | GE for correct key (46): 6.0)
# KR: 63 | GE for correct key (46): 6.0)
# KR: 64 | GE for correct key (46): 6.0)
# KR: 65 | GE for correct key (46): 6.0)
# KR: 66 | GE for correct key (46): 6.0)
# KR: 67 | GE for correct key (46): 6.0)
# KR: 68 | GE for correct key (46): 6.0)
# KR: 69 | GE for correct key (46): 6.0)
# KR: 70 | GE for correct key (46): 6.0)
# KR: 71 | GE for correct key (46): 6.0)
# KR: 72 | GE for correct key (46): 6.0)
# KR: 73 | GE for correct key (46): 6.0)
# KR: 74 | GE for correct key (46): 6.0)
# KR: 75 | GE for correct key (46): 6.0)
# KR: 76 | GE for correct key (46): 6.0)
# KR: 77 | GE for correct key (46): 6.0)
# KR: 78 | GE for correct key (46): 6.0)
# KR: 79 | GE for correct key (46): 6.0)
# KR: 80 | GE for correct key (46): 6.0)
# KR: 81 | GE for correct key (46): 6.0)
# KR: 82 | GE for correct key (46): 6.0)
# KR: 83 | GE for correct key (46): 6.0)
# KR: 84 | GE for correct key (46): 6.0)
# KR: 85 | GE for correct key (46): 6.0)
# KR: 86 | GE for correct key (46): 6.0)
# KR: 87 | GE for correct key (46): 6.0)
# KR: 88 | GE for correct key (46): 6.0)
# KR: 89 | GE for correct key (46): 6.0)
# KR: 90 | GE for correct key (46): 6.0)
# KR: 91 | GE for correct key (46): 6.0)
# KR: 92 | GE for correct key (46): 6.0)
# KR: 93 | GE for correct key (46): 6.0)
# KR: 94 | GE for correct key (46): 6.0)
# KR: 95 | GE for correct key (46): 6.0)
# KR: 96 | GE for correct key (46): 6.0)
# KR: 97 | GE for correct key (46): 6.0)
# KR: 98 | GE for correct key (46): 6.0)
# KR: 99 | GE for correct key (46): 6.0)
# KR: 0 | GE for correct key (46): 14.0)
# KR: 1 | GE for correct key (46): 14.0)
# KR: 2 | GE for correct key (46): 14.0)
# KR: 3 | GE for correct key (46): 14.0)
# KR: 4 | GE for correct key (46): 14.0)
# KR: 5 | GE for correct key (46): 14.0)
# KR: 6 | GE for correct key (46): 14.0)
# KR: 7 | GE for correct key (46): 14.0)
# KR: 8 | GE for correct key (46): 14.0)
# KR: 9 | GE for correct key (46): 14.0)
# KR: 10 | GE for correct key (46): 14.0)
# KR: 11 | GE for correct key (46): 14.0)
# KR: 12 | GE for correct key (46): 14.0)
# KR: 13 | GE for correct key (46): 14.0)
# KR: 14 | GE for correct key (46): 14.0)
# KR: 15 | GE for correct key (46): 14.0)
# KR: 16 | GE for correct key (46): 14.0)
# KR: 17 | GE for correct key (46): 14.0)
# KR: 18 | GE for correct key (46): 14.0)
# KR: 19 | GE for correct key (46): 14.0)
# KR: 20 | GE for correct key (46): 14.0)
# KR: 21 | GE for correct key (46): 14.0)
# KR: 22 | GE for correct key (46): 14.0)
# KR: 23 | GE for correct key (46): 14.0)
# KR: 24 | GE for correct key (46): 14.0)
# KR: 25 | GE for correct key (46): 14.0)
# KR: 26 | GE for correct key (46): 14.0)
# KR: 27 | GE for correct key (46): 14.0)
# KR: 28 | GE for correct key (46): 14.0)
# KR: 29 | GE for correct key (46): 14.0)
# KR: 30 | GE for correct key (46): 14.0)
# KR: 31 | GE for correct key (46): 14.0)
# KR: 32 | GE for correct key (46): 14.0)
# KR: 33 | GE for correct key (46): 14.0)
# KR: 34 | GE for correct key (46): 14.0)
# KR: 35 | GE for correct key (46): 14.0)
# KR: 36 | GE for correct key (46): 14.0)
# KR: 37 | GE for correct key (46): 14.0)
# KR: 38 | GE for correct key (46): 14.0)
# KR: 39 | GE for correct key (46): 14.0)
# KR: 40 | GE for correct key (46): 14.0)
# KR: 41 | GE for correct key (46): 14.0)
# KR: 42 | GE for correct key (46): 14.0)
# KR: 43 | GE for correct key (46): 14.0)
# KR: 44 | GE for correct key (46): 14.0)
# KR: 45 | GE for correct key (46): 14.0)
# KR: 46 | GE for correct key (46): 14.0)
# KR: 47 | GE for correct key (46): 14.0)
# KR: 48 | GE for correct key (46): 14.0)
# KR: 49 | GE for correct key (46): 14.0)
# KR: 50 | GE for correct key (46): 14.0)
# KR: 51 | GE for correct key (46): 14.0)
# KR: 52 | GE for correct key (46): 14.0)
# KR: 53 | GE for correct key (46): 14.0)
# KR: 54 | GE for correct key (46): 14.0)
# KR: 55 | GE for correct key (46): 14.0)
# KR: 56 | GE for correct key (46): 14.0)
# KR: 57 | GE for correct key (46): 14.0)
# KR: 58 | GE for correct key (46): 14.0)
# KR: 59 | GE for correct key (46): 14.0)
# KR: 60 | GE for correct key (46): 14.0)
# KR: 61 | GE for correct key (46): 14.0)
# KR: 62 | GE for correct key (46): 14.0)
# KR: 63 | GE for correct key (46): 14.0)
# KR: 64 | GE for correct key (46): 14.0)
# KR: 65 | GE for correct key (46): 14.0)
# KR: 66 | GE for correct key (46): 14.0)
# KR: 67 | GE for correct key (46): 14.0)
# KR: 68 | GE for correct key (46): 14.0)
# KR: 69 | GE for correct key (46): 14.0)
# KR: 70 | GE for correct key (46): 14.0)
# KR: 71 | GE for correct key (46): 14.0)
# KR: 72 | GE for correct key (46): 14.0)
# KR: 73 | GE for correct key (46): 14.0)
# KR: 74 | GE for correct key (46): 14.0)
# KR: 75 | GE for correct key (46): 14.0)
# KR: 76 | GE for correct key (46): 14.0)
# KR: 77 | GE for correct key (46): 14.0)
# KR: 78 | GE for correct key (46): 14.0)
# KR: 79 | GE for correct key (46): 14.0)
# KR: 80 | GE for correct key (46): 14.0)
# KR: 81 | GE for correct key (46): 14.0)
# KR: 82 | GE for correct key (46): 14.0)
# KR: 83 | GE for correct key (46): 14.0)
# KR: 84 | GE for correct key (46): 14.0)
# KR: 85 | GE for correct key (46): 14.0)
# KR: 86 | GE for correct key (46): 14.0)
# KR: 87 | GE for correct key (46): 14.0)
# KR: 88 | GE for correct key (46): 14.0)
# KR: 89 | GE for correct key (46): 14.0)
# KR: 90 | GE for correct key (46): 14.0)
# KR: 91 | GE for correct key (46): 14.0)
# KR: 92 | GE for correct key (46): 14.0)
# KR: 93 | GE for correct key (46): 14.0)
# KR: 94 | GE for correct key (46): 14.0)
# KR: 95 | GE for correct key (46): 14.0)
# KR: 96 | GE for correct key (46): 14.0)
# KR: 97 | GE for correct key (46): 14.0)
# KR: 98 | GE for correct key (46): 14.0)
# KR: 99 | GE for correct key (46): 14.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 500)               1100500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 500)               250500
#
#  dense_5 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 2,115,809
# Trainable params: 2,111,409
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 5s 18ms/step - loss: 1.4095 - accuracy: 0.4706 - val_loss: 2.0815 - val_accuracy: 0.1320
# Epoch 2/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.9001 - accuracy: 0.6478 - val_loss: 2.1020 - val_accuracy: 0.1984
# Epoch 3/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.7060 - accuracy: 0.7260 - val_loss: 2.3056 - val_accuracy: 0.1876
# Epoch 4/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.5719 - accuracy: 0.7800 - val_loss: 2.5429 - val_accuracy: 0.1760
# Epoch 5/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.4647 - accuracy: 0.8237 - val_loss: 2.8911 - val_accuracy: 0.2000
# Epoch 6/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.3810 - accuracy: 0.8581 - val_loss: 3.0658 - val_accuracy: 0.1836
# Epoch 7/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.3171 - accuracy: 0.8840 - val_loss: 3.3345 - val_accuracy: 0.1888
# Epoch 8/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.2525 - accuracy: 0.9094 - val_loss: 3.6360 - val_accuracy: 0.2068
# Epoch 9/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.2058 - accuracy: 0.9283 - val_loss: 3.8118 - val_accuracy: 0.2096
# Epoch 10/10
# 277/277 [==============================] - 5s 17ms/step - loss: 0.1708 - accuracy: 0.9418 - val_loss: 4.1451 - val_accuracy: 0.2084
# KR: 0 | GE for correct key (46): 100.0)
# KR: 1 | GE for correct key (46): 100.0)
# KR: 2 | GE for correct key (46): 100.0)
# KR: 3 | GE for correct key (46): 100.0)
# KR: 4 | GE for correct key (46): 100.0)
# KR: 5 | GE for correct key (46): 100.0)
# KR: 6 | GE for correct key (46): 100.0)
# KR: 7 | GE for correct key (46): 100.0)
# KR: 8 | GE for correct key (46): 100.0)
# KR: 9 | GE for correct key (46): 100.0)
# KR: 10 | GE for correct key (46): 100.0)
# KR: 11 | GE for correct key (46): 100.0)
# KR: 12 | GE for correct key (46): 100.0)
# KR: 13 | GE for correct key (46): 100.0)
# KR: 14 | GE for correct key (46): 100.0)
# KR: 15 | GE for correct key (46): 100.0)
# KR: 16 | GE for correct key (46): 100.0)
# KR: 17 | GE for correct key (46): 100.0)
# KR: 18 | GE for correct key (46): 100.0)
# KR: 19 | GE for correct key (46): 100.0)
# KR: 20 | GE for correct key (46): 100.0)
# KR: 21 | GE for correct key (46): 100.0)
# KR: 22 | GE for correct key (46): 100.0)
# KR: 23 | GE for correct key (46): 100.0)
# KR: 24 | GE for correct key (46): 100.0)
# KR: 25 | GE for correct key (46): 100.0)
# KR: 26 | GE for correct key (46): 100.0)
# KR: 27 | GE for correct key (46): 100.0)
# KR: 28 | GE for correct key (46): 100.0)
# KR: 29 | GE for correct key (46): 100.0)
# KR: 30 | GE for correct key (46): 100.0)
# KR: 31 | GE for correct key (46): 100.0)
# KR: 32 | GE for correct key (46): 100.0)
# KR: 33 | GE for correct key (46): 100.0)
# KR: 34 | GE for correct key (46): 100.0)
# KR: 35 | GE for correct key (46): 100.0)
# KR: 36 | GE for correct key (46): 100.0)
# KR: 37 | GE for correct key (46): 100.0)
# KR: 38 | GE for correct key (46): 100.0)
# KR: 39 | GE for correct key (46): 100.0)
# KR: 40 | GE for correct key (46): 100.0)
# KR: 41 | GE for correct key (46): 100.0)
# KR: 42 | GE for correct key (46): 100.0)
# KR: 43 | GE for correct key (46): 100.0)
# KR: 44 | GE for correct key (46): 100.0)
# KR: 45 | GE for correct key (46): 100.0)
# KR: 46 | GE for correct key (46): 100.0)
# KR: 47 | GE for correct key (46): 100.0)
# KR: 48 | GE for correct key (46): 100.0)
# KR: 49 | GE for correct key (46): 100.0)
# KR: 50 | GE for correct key (46): 100.0)
# KR: 51 | GE for correct key (46): 100.0)
# KR: 52 | GE for correct key (46): 100.0)
# KR: 53 | GE for correct key (46): 100.0)
# KR: 54 | GE for correct key (46): 100.0)
# KR: 55 | GE for correct key (46): 100.0)
# KR: 56 | GE for correct key (46): 100.0)
# KR: 57 | GE for correct key (46): 100.0)
# KR: 58 | GE for correct key (46): 100.0)
# KR: 59 | GE for correct key (46): 100.0)
# KR: 60 | GE for correct key (46): 100.0)
# KR: 61 | GE for correct key (46): 100.0)
# KR: 62 | GE for correct key (46): 100.0)
# KR: 63 | GE for correct key (46): 100.0)
# KR: 64 | GE for correct key (46): 100.0)
# KR: 65 | GE for correct key (46): 100.0)
# KR: 66 | GE for correct key (46): 100.0)
# KR: 67 | GE for correct key (46): 100.0)
# KR: 68 | GE for correct key (46): 100.0)
# KR: 69 | GE for correct key (46): 100.0)
# KR: 70 | GE for correct key (46): 100.0)
# KR: 71 | GE for correct key (46): 100.0)
# KR: 72 | GE for correct key (46): 100.0)
# KR: 73 | GE for correct key (46): 100.0)
# KR: 74 | GE for correct key (46): 100.0)
# KR: 75 | GE for correct key (46): 100.0)
# KR: 76 | GE for correct key (46): 100.0)
# KR: 77 | GE for correct key (46): 100.0)
# KR: 78 | GE for correct key (46): 100.0)
# KR: 79 | GE for correct key (46): 100.0)
# KR: 80 | GE for correct key (46): 100.0)
# KR: 81 | GE for correct key (46): 100.0)
# KR: 82 | GE for correct key (46): 100.0)
# KR: 83 | GE for correct key (46): 100.0)
# KR: 84 | GE for correct key (46): 100.0)
# KR: 85 | GE for correct key (46): 100.0)
# KR: 86 | GE for correct key (46): 100.0)
# KR: 87 | GE for correct key (46): 100.0)
# KR: 88 | GE for correct key (46): 100.0)
# KR: 89 | GE for correct key (46): 100.0)
# KR: 90 | GE for correct key (46): 100.0)
# KR: 91 | GE for correct key (46): 100.0)
# KR: 92 | GE for correct key (46): 100.0)
# KR: 93 | GE for correct key (46): 100.0)
# KR: 94 | GE for correct key (46): 100.0)
# KR: 95 | GE for correct key (46): 100.0)
# KR: 96 | GE for correct key (46): 100.0)
# KR: 97 | GE for correct key (46): 100.0)
# KR: 98 | GE for correct key (46): 100.0)
# KR: 99 | GE for correct key (46): 100.0)
# KR: 0 | GE for correct key (46): 155.0)
# KR: 1 | GE for correct key (46): 155.0)
# KR: 2 | GE for correct key (46): 155.0)
# KR: 3 | GE for correct key (46): 155.0)
# KR: 4 | GE for correct key (46): 155.0)
# KR: 5 | GE for correct key (46): 155.0)
# KR: 6 | GE for correct key (46): 155.0)
# KR: 7 | GE for correct key (46): 155.0)
# KR: 8 | GE for correct key (46): 155.0)
# KR: 9 | GE for correct key (46): 155.0)
# KR: 10 | GE for correct key (46): 155.0)
# KR: 11 | GE for correct key (46): 155.0)
# KR: 12 | GE for correct key (46): 155.0)
# KR: 13 | GE for correct key (46): 155.0)
# KR: 14 | GE for correct key (46): 155.0)
# KR: 15 | GE for correct key (46): 155.0)
# KR: 16 | GE for correct key (46): 155.0)
# KR: 17 | GE for correct key (46): 155.0)
# KR: 18 | GE for correct key (46): 155.0)
# KR: 19 | GE for correct key (46): 155.0)
# KR: 20 | GE for correct key (46): 155.0)
# KR: 21 | GE for correct key (46): 155.0)
# KR: 22 | GE for correct key (46): 155.0)
# KR: 23 | GE for correct key (46): 155.0)
# KR: 24 | GE for correct key (46): 155.0)
# KR: 25 | GE for correct key (46): 155.0)
# KR: 26 | GE for correct key (46): 155.0)
# KR: 27 | GE for correct key (46): 155.0)
# KR: 28 | GE for correct key (46): 155.0)
# KR: 29 | GE for correct key (46): 155.0)
# KR: 30 | GE for correct key (46): 155.0)
# KR: 31 | GE for correct key (46): 155.0)
# KR: 32 | GE for correct key (46): 155.0)
# KR: 33 | GE for correct key (46): 155.0)
# KR: 34 | GE for correct key (46): 155.0)
# KR: 35 | GE for correct key (46): 155.0)
# KR: 36 | GE for correct key (46): 155.0)
# KR: 37 | GE for correct key (46): 155.0)
# KR: 38 | GE for correct key (46): 155.0)
# KR: 39 | GE for correct key (46): 155.0)
# KR: 40 | GE for correct key (46): 155.0)
# KR: 41 | GE for correct key (46): 155.0)
# KR: 42 | GE for correct key (46): 155.0)
# KR: 43 | GE for correct key (46): 155.0)
# KR: 44 | GE for correct key (46): 155.0)
# KR: 45 | GE for correct key (46): 155.0)
# KR: 46 | GE for correct key (46): 155.0)
# KR: 47 | GE for correct key (46): 155.0)
# KR: 48 | GE for correct key (46): 155.0)
# KR: 49 | GE for correct key (46): 155.0)
# KR: 50 | GE for correct key (46): 155.0)
# KR: 51 | GE for correct key (46): 155.0)
# KR: 52 | GE for correct key (46): 155.0)
# KR: 53 | GE for correct key (46): 155.0)
# KR: 54 | GE for correct key (46): 155.0)
# KR: 55 | GE for correct key (46): 155.0)
# KR: 56 | GE for correct key (46): 155.0)
# KR: 57 | GE for correct key (46): 155.0)
# KR: 58 | GE for correct key (46): 155.0)
# KR: 59 | GE for correct key (46): 155.0)
# KR: 60 | GE for correct key (46): 155.0)
# KR: 61 | GE for correct key (46): 155.0)
# KR: 62 | GE for correct key (46): 155.0)
# KR: 63 | GE for correct key (46): 155.0)
# KR: 64 | GE for correct key (46): 155.0)
# KR: 65 | GE for correct key (46): 155.0)
# KR: 66 | GE for correct key (46): 155.0)
# KR: 67 | GE for correct key (46): 155.0)
# KR: 68 | GE for correct key (46): 155.0)
# KR: 69 | GE for correct key (46): 155.0)
# KR: 70 | GE for correct key (46): 155.0)
# KR: 71 | GE for correct key (46): 155.0)
# KR: 72 | GE for correct key (46): 155.0)
# KR: 73 | GE for correct key (46): 155.0)
# KR: 74 | GE for correct key (46): 155.0)
# KR: 75 | GE for correct key (46): 155.0)
# KR: 76 | GE for correct key (46): 155.0)
# KR: 77 | GE for correct key (46): 155.0)
# KR: 78 | GE for correct key (46): 155.0)
# KR: 79 | GE for correct key (46): 155.0)
# KR: 80 | GE for correct key (46): 155.0)
# KR: 81 | GE for correct key (46): 155.0)
# KR: 82 | GE for correct key (46): 155.0)
# KR: 83 | GE for correct key (46): 155.0)
# KR: 84 | GE for correct key (46): 155.0)
# KR: 85 | GE for correct key (46): 155.0)
# KR: 86 | GE for correct key (46): 155.0)
# KR: 87 | GE for correct key (46): 155.0)
# KR: 88 | GE for correct key (46): 155.0)
# KR: 89 | GE for correct key (46): 155.0)
# KR: 90 | GE for correct key (46): 155.0)
# KR: 91 | GE for correct key (46): 155.0)
# KR: 92 | GE for correct key (46): 155.0)
# KR: 93 | GE for correct key (46): 155.0)
# KR: 94 | GE for correct key (46): 155.0)
# KR: 95 | GE for correct key (46): 155.0)
# KR: 96 | GE for correct key (46): 155.0)
# KR: 97 | GE for correct key (46): 155.0)
# KR: 98 | GE for correct key (46): 155.0)
# KR: 99 | GE for correct key (46): 155.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,777,209
# Trainable params: 2,772,809
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 6s 20ms/step - loss: 1.4531 - accuracy: 0.4657 - val_loss: 1.9421 - val_accuracy: 0.1952
# Epoch 2/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.9064 - accuracy: 0.6558 - val_loss: 2.1037 - val_accuracy: 0.1972
# Epoch 3/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.6872 - accuracy: 0.7396 - val_loss: 2.2802 - val_accuracy: 0.2116
# Epoch 4/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.5400 - accuracy: 0.7981 - val_loss: 2.5081 - val_accuracy: 0.2112
# Epoch 5/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.4254 - accuracy: 0.8436 - val_loss: 2.9193 - val_accuracy: 0.2428
# Epoch 6/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.3324 - accuracy: 0.8810 - val_loss: 3.2580 - val_accuracy: 0.2132
# Epoch 7/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.2603 - accuracy: 0.9105 - val_loss: 3.5398 - val_accuracy: 0.2320
# Epoch 8/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.2000 - accuracy: 0.9334 - val_loss: 3.7189 - val_accuracy: 0.2136
# Epoch 9/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.1557 - accuracy: 0.9496 - val_loss: 3.8927 - val_accuracy: 0.2288
# Epoch 10/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.1196 - accuracy: 0.9636 - val_loss: 4.2511 - val_accuracy: 0.2252
# KR: 0 | GE for correct key (46): 37.0)
# KR: 1 | GE for correct key (46): 37.0)
# KR: 2 | GE for correct key (46): 37.0)
# KR: 3 | GE for correct key (46): 37.0)
# KR: 4 | GE for correct key (46): 37.0)
# KR: 5 | GE for correct key (46): 37.0)
# KR: 6 | GE for correct key (46): 37.0)
# KR: 7 | GE for correct key (46): 37.0)
# KR: 8 | GE for correct key (46): 37.0)
# KR: 9 | GE for correct key (46): 37.0)
# KR: 10 | GE for correct key (46): 37.0)
# KR: 11 | GE for correct key (46): 37.0)
# KR: 12 | GE for correct key (46): 37.0)
# KR: 13 | GE for correct key (46): 37.0)
# KR: 14 | GE for correct key (46): 37.0)
# KR: 15 | GE for correct key (46): 37.0)
# KR: 16 | GE for correct key (46): 37.0)
# KR: 17 | GE for correct key (46): 37.0)
# KR: 18 | GE for correct key (46): 37.0)
# KR: 19 | GE for correct key (46): 37.0)
# KR: 20 | GE for correct key (46): 37.0)
# KR: 21 | GE for correct key (46): 37.0)
# KR: 22 | GE for correct key (46): 37.0)
# KR: 23 | GE for correct key (46): 37.0)
# KR: 24 | GE for correct key (46): 37.0)
# KR: 25 | GE for correct key (46): 37.0)
# KR: 26 | GE for correct key (46): 37.0)
# KR: 27 | GE for correct key (46): 37.0)
# KR: 28 | GE for correct key (46): 37.0)
# KR: 29 | GE for correct key (46): 37.0)
# KR: 30 | GE for correct key (46): 37.0)
# KR: 31 | GE for correct key (46): 37.0)
# KR: 32 | GE for correct key (46): 37.0)
# KR: 33 | GE for correct key (46): 37.0)
# KR: 34 | GE for correct key (46): 37.0)
# KR: 35 | GE for correct key (46): 37.0)
# KR: 36 | GE for correct key (46): 37.0)
# KR: 37 | GE for correct key (46): 37.0)
# KR: 38 | GE for correct key (46): 37.0)
# KR: 39 | GE for correct key (46): 37.0)
# KR: 40 | GE for correct key (46): 37.0)
# KR: 41 | GE for correct key (46): 37.0)
# KR: 42 | GE for correct key (46): 37.0)
# KR: 43 | GE for correct key (46): 37.0)
# KR: 44 | GE for correct key (46): 37.0)
# KR: 45 | GE for correct key (46): 37.0)
# KR: 46 | GE for correct key (46): 37.0)
# KR: 47 | GE for correct key (46): 37.0)
# KR: 48 | GE for correct key (46): 37.0)
# KR: 49 | GE for correct key (46): 37.0)
# KR: 50 | GE for correct key (46): 37.0)
# KR: 51 | GE for correct key (46): 37.0)
# KR: 52 | GE for correct key (46): 37.0)
# KR: 53 | GE for correct key (46): 37.0)
# KR: 54 | GE for correct key (46): 37.0)
# KR: 55 | GE for correct key (46): 37.0)
# KR: 56 | GE for correct key (46): 37.0)
# KR: 57 | GE for correct key (46): 37.0)
# KR: 58 | GE for correct key (46): 37.0)
# KR: 59 | GE for correct key (46): 37.0)
# KR: 60 | GE for correct key (46): 37.0)
# KR: 61 | GE for correct key (46): 37.0)
# KR: 62 | GE for correct key (46): 37.0)
# KR: 63 | GE for correct key (46): 37.0)
# KR: 64 | GE for correct key (46): 37.0)
# KR: 65 | GE for correct key (46): 37.0)
# KR: 66 | GE for correct key (46): 37.0)
# KR: 67 | GE for correct key (46): 37.0)
# KR: 68 | GE for correct key (46): 37.0)
# KR: 69 | GE for correct key (46): 37.0)
# KR: 70 | GE for correct key (46): 37.0)
# KR: 71 | GE for correct key (46): 37.0)
# KR: 72 | GE for correct key (46): 37.0)
# KR: 73 | GE for correct key (46): 37.0)
# KR: 74 | GE for correct key (46): 37.0)
# KR: 75 | GE for correct key (46): 37.0)
# KR: 76 | GE for correct key (46): 37.0)
# KR: 77 | GE for correct key (46): 37.0)
# KR: 78 | GE for correct key (46): 37.0)
# KR: 79 | GE for correct key (46): 37.0)
# KR: 80 | GE for correct key (46): 37.0)
# KR: 81 | GE for correct key (46): 37.0)
# KR: 82 | GE for correct key (46): 37.0)
# KR: 83 | GE for correct key (46): 37.0)
# KR: 84 | GE for correct key (46): 37.0)
# KR: 85 | GE for correct key (46): 37.0)
# KR: 86 | GE for correct key (46): 37.0)
# KR: 87 | GE for correct key (46): 37.0)
# KR: 88 | GE for correct key (46): 37.0)
# KR: 89 | GE for correct key (46): 37.0)
# KR: 90 | GE for correct key (46): 37.0)
# KR: 91 | GE for correct key (46): 37.0)
# KR: 92 | GE for correct key (46): 37.0)
# KR: 93 | GE for correct key (46): 37.0)
# KR: 94 | GE for correct key (46): 37.0)
# KR: 95 | GE for correct key (46): 37.0)
# KR: 96 | GE for correct key (46): 37.0)
# KR: 97 | GE for correct key (46): 37.0)
# KR: 98 | GE for correct key (46): 37.0)
# KR: 99 | GE for correct key (46): 37.0)
# KR: 0 | GE for correct key (46): 100.0)
# KR: 1 | GE for correct key (46): 100.0)
# KR: 2 | GE for correct key (46): 100.0)
# KR: 3 | GE for correct key (46): 100.0)
# KR: 4 | GE for correct key (46): 100.0)
# KR: 5 | GE for correct key (46): 100.0)
# KR: 6 | GE for correct key (46): 100.0)
# KR: 7 | GE for correct key (46): 100.0)
# KR: 8 | GE for correct key (46): 100.0)
# KR: 9 | GE for correct key (46): 100.0)
# KR: 10 | GE for correct key (46): 100.0)
# KR: 11 | GE for correct key (46): 100.0)
# KR: 12 | GE for correct key (46): 100.0)
# KR: 13 | GE for correct key (46): 100.0)
# KR: 14 | GE for correct key (46): 100.0)
# KR: 15 | GE for correct key (46): 100.0)
# KR: 16 | GE for correct key (46): 100.0)
# KR: 17 | GE for correct key (46): 100.0)
# KR: 18 | GE for correct key (46): 100.0)
# KR: 19 | GE for correct key (46): 100.0)
# KR: 20 | GE for correct key (46): 100.0)
# KR: 21 | GE for correct key (46): 100.0)
# KR: 22 | GE for correct key (46): 100.0)
# KR: 23 | GE for correct key (46): 100.0)
# KR: 24 | GE for correct key (46): 100.0)
# KR: 25 | GE for correct key (46): 100.0)
# KR: 26 | GE for correct key (46): 100.0)
# KR: 27 | GE for correct key (46): 100.0)
# KR: 28 | GE for correct key (46): 100.0)
# KR: 29 | GE for correct key (46): 100.0)
# KR: 30 | GE for correct key (46): 100.0)
# KR: 31 | GE for correct key (46): 100.0)
# KR: 32 | GE for correct key (46): 100.0)
# KR: 33 | GE for correct key (46): 100.0)
# KR: 34 | GE for correct key (46): 100.0)
# KR: 35 | GE for correct key (46): 100.0)
# KR: 36 | GE for correct key (46): 100.0)
# KR: 37 | GE for correct key (46): 100.0)
# KR: 38 | GE for correct key (46): 100.0)
# KR: 39 | GE for correct key (46): 100.0)
# KR: 40 | GE for correct key (46): 100.0)
# KR: 41 | GE for correct key (46): 100.0)
# KR: 42 | GE for correct key (46): 100.0)
# KR: 43 | GE for correct key (46): 100.0)
# KR: 44 | GE for correct key (46): 100.0)
# KR: 45 | GE for correct key (46): 100.0)
# KR: 46 | GE for correct key (46): 100.0)
# KR: 47 | GE for correct key (46): 100.0)
# KR: 48 | GE for correct key (46): 100.0)
# KR: 49 | GE for correct key (46): 100.0)
# KR: 50 | GE for correct key (46): 100.0)
# KR: 51 | GE for correct key (46): 100.0)
# KR: 52 | GE for correct key (46): 100.0)
# KR: 53 | GE for correct key (46): 100.0)
# KR: 54 | GE for correct key (46): 100.0)
# KR: 55 | GE for correct key (46): 100.0)
# KR: 56 | GE for correct key (46): 100.0)
# KR: 57 | GE for correct key (46): 100.0)
# KR: 58 | GE for correct key (46): 100.0)
# KR: 59 | GE for correct key (46): 100.0)
# KR: 60 | GE for correct key (46): 100.0)
# KR: 61 | GE for correct key (46): 100.0)
# KR: 62 | GE for correct key (46): 100.0)
# KR: 63 | GE for correct key (46): 100.0)
# KR: 64 | GE for correct key (46): 100.0)
# KR: 65 | GE for correct key (46): 100.0)
# KR: 66 | GE for correct key (46): 100.0)
# KR: 67 | GE for correct key (46): 100.0)
# KR: 68 | GE for correct key (46): 100.0)
# KR: 69 | GE for correct key (46): 100.0)
# KR: 70 | GE for correct key (46): 100.0)
# KR: 71 | GE for correct key (46): 100.0)
# KR: 72 | GE for correct key (46): 100.0)
# KR: 73 | GE for correct key (46): 100.0)
# KR: 74 | GE for correct key (46): 100.0)
# KR: 75 | GE for correct key (46): 100.0)
# KR: 76 | GE for correct key (46): 100.0)
# KR: 77 | GE for correct key (46): 100.0)
# KR: 78 | GE for correct key (46): 100.0)
# KR: 79 | GE for correct key (46): 100.0)
# KR: 80 | GE for correct key (46): 100.0)
# KR: 81 | GE for correct key (46): 100.0)
# KR: 82 | GE for correct key (46): 100.0)
# KR: 83 | GE for correct key (46): 100.0)
# KR: 84 | GE for correct key (46): 100.0)
# KR: 85 | GE for correct key (46): 100.0)
# KR: 86 | GE for correct key (46): 100.0)
# KR: 87 | GE for correct key (46): 100.0)
# KR: 88 | GE for correct key (46): 100.0)
# KR: 89 | GE for correct key (46): 100.0)
# KR: 90 | GE for correct key (46): 100.0)
# KR: 91 | GE for correct key (46): 100.0)
# KR: 92 | GE for correct key (46): 100.0)
# KR: 93 | GE for correct key (46): 100.0)
# KR: 94 | GE for correct key (46): 100.0)
# KR: 95 | GE for correct key (46): 100.0)
# KR: 96 | GE for correct key (46): 100.0)
# KR: 97 | GE for correct key (46): 100.0)
# KR: 98 | GE for correct key (46): 100.0)
# KR: 99 | GE for correct key (46): 100.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,777,209
# Trainable params: 2,772,809
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 6s 20ms/step - loss: 1.5496 - accuracy: 0.5193 - val_loss: 2.6671 - val_accuracy: 0.2292
# Epoch 2/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.7914 - accuracy: 0.7082 - val_loss: 2.8815 - val_accuracy: 0.2204
# Epoch 3/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.5682 - accuracy: 0.7908 - val_loss: 2.8829 - val_accuracy: 0.2288
# Epoch 4/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.4255 - accuracy: 0.8450 - val_loss: 3.6445 - val_accuracy: 0.2276
# Epoch 5/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.3130 - accuracy: 0.8889 - val_loss: 3.6724 - val_accuracy: 0.2284
# Epoch 6/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.2458 - accuracy: 0.9134 - val_loss: 4.0411 - val_accuracy: 0.2308
# Epoch 7/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.1908 - accuracy: 0.9342 - val_loss: 4.6057 - val_accuracy: 0.2276
# Epoch 8/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.1556 - accuracy: 0.9464 - val_loss: 4.8300 - val_accuracy: 0.2248
# Epoch 9/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.1571 - accuracy: 0.9449 - val_loss: 5.2205 - val_accuracy: 0.2324
# Epoch 10/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.1603 - accuracy: 0.9428 - val_loss: 4.9380 - val_accuracy: 0.2352
# KR: 0 | GE for correct key (46): 1.0)
# KR: 1 | GE for correct key (46): 1.0)
# KR: 2 | GE for correct key (46): 1.0)
# KR: 3 | GE for correct key (46): 1.0)
# KR: 4 | GE for correct key (46): 1.0)
# KR: 5 | GE for correct key (46): 1.0)
# KR: 6 | GE for correct key (46): 1.0)
# KR: 7 | GE for correct key (46): 1.0)
# KR: 8 | GE for correct key (46): 1.0)
# KR: 9 | GE for correct key (46): 1.0)
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# KR: 0 | GE for correct key (46): 17.0)
# KR: 1 | GE for correct key (46): 17.0)
# KR: 2 | GE for correct key (46): 17.0)
# KR: 3 | GE for correct key (46): 17.0)
# KR: 4 | GE for correct key (46): 17.0)
# KR: 5 | GE for correct key (46): 17.0)
# KR: 6 | GE for correct key (46): 17.0)
# KR: 7 | GE for correct key (46): 17.0)
# KR: 8 | GE for correct key (46): 17.0)
# KR: 9 | GE for correct key (46): 17.0)
# KR: 10 | GE for correct key (46): 17.0)
# KR: 11 | GE for correct key (46): 17.0)
# KR: 12 | GE for correct key (46): 17.0)
# KR: 13 | GE for correct key (46): 17.0)
# KR: 14 | GE for correct key (46): 17.0)
# KR: 15 | GE for correct key (46): 17.0)
# KR: 16 | GE for correct key (46): 17.0)
# KR: 17 | GE for correct key (46): 17.0)
# KR: 18 | GE for correct key (46): 17.0)
# KR: 19 | GE for correct key (46): 17.0)
# KR: 20 | GE for correct key (46): 17.0)
# KR: 21 | GE for correct key (46): 17.0)
# KR: 22 | GE for correct key (46): 17.0)
# KR: 23 | GE for correct key (46): 17.0)
# KR: 24 | GE for correct key (46): 17.0)
# KR: 25 | GE for correct key (46): 17.0)
# KR: 26 | GE for correct key (46): 17.0)
# KR: 27 | GE for correct key (46): 17.0)
# KR: 28 | GE for correct key (46): 17.0)
# KR: 29 | GE for correct key (46): 17.0)
# KR: 30 | GE for correct key (46): 17.0)
# KR: 31 | GE for correct key (46): 17.0)
# KR: 32 | GE for correct key (46): 17.0)
# KR: 33 | GE for correct key (46): 17.0)
# KR: 34 | GE for correct key (46): 17.0)
# KR: 35 | GE for correct key (46): 17.0)
# KR: 36 | GE for correct key (46): 17.0)
# KR: 37 | GE for correct key (46): 17.0)
# KR: 38 | GE for correct key (46): 17.0)
# KR: 39 | GE for correct key (46): 17.0)
# KR: 40 | GE for correct key (46): 17.0)
# KR: 41 | GE for correct key (46): 17.0)
# KR: 42 | GE for correct key (46): 17.0)
# KR: 43 | GE for correct key (46): 17.0)
# KR: 44 | GE for correct key (46): 17.0)
# KR: 45 | GE for correct key (46): 17.0)
# KR: 46 | GE for correct key (46): 17.0)
# KR: 47 | GE for correct key (46): 17.0)
# KR: 48 | GE for correct key (46): 17.0)
# KR: 49 | GE for correct key (46): 17.0)
# KR: 50 | GE for correct key (46): 17.0)
# KR: 51 | GE for correct key (46): 17.0)
# KR: 52 | GE for correct key (46): 17.0)
# KR: 53 | GE for correct key (46): 17.0)
# KR: 54 | GE for correct key (46): 17.0)
# KR: 55 | GE for correct key (46): 17.0)
# KR: 56 | GE for correct key (46): 17.0)
# KR: 57 | GE for correct key (46): 17.0)
# KR: 58 | GE for correct key (46): 17.0)
# KR: 59 | GE for correct key (46): 17.0)
# KR: 60 | GE for correct key (46): 17.0)
# KR: 61 | GE for correct key (46): 17.0)
# KR: 62 | GE for correct key (46): 17.0)
# KR: 63 | GE for correct key (46): 17.0)
# KR: 64 | GE for correct key (46): 17.0)
# KR: 65 | GE for correct key (46): 17.0)
# KR: 66 | GE for correct key (46): 17.0)
# KR: 67 | GE for correct key (46): 17.0)
# KR: 68 | GE for correct key (46): 17.0)
# KR: 69 | GE for correct key (46): 17.0)
# KR: 70 | GE for correct key (46): 17.0)
# KR: 71 | GE for correct key (46): 17.0)
# KR: 72 | GE for correct key (46): 17.0)
# KR: 73 | GE for correct key (46): 17.0)
# KR: 74 | GE for correct key (46): 17.0)
# KR: 75 | GE for correct key (46): 17.0)
# KR: 76 | GE for correct key (46): 17.0)
# KR: 77 | GE for correct key (46): 17.0)
# KR: 78 | GE for correct key (46): 17.0)
# KR: 79 | GE for correct key (46): 17.0)
# KR: 80 | GE for correct key (46): 17.0)
# KR: 81 | GE for correct key (46): 17.0)
# KR: 82 | GE for correct key (46): 17.0)
# KR: 83 | GE for correct key (46): 17.0)
# KR: 84 | GE for correct key (46): 17.0)
# KR: 85 | GE for correct key (46): 17.0)
# KR: 86 | GE for correct key (46): 17.0)
# KR: 87 | GE for correct key (46): 17.0)
# KR: 88 | GE for correct key (46): 17.0)
# KR: 89 | GE for correct key (46): 17.0)
# KR: 90 | GE for correct key (46): 17.0)
# KR: 91 | GE for correct key (46): 17.0)
# KR: 92 | GE for correct key (46): 17.0)
# KR: 93 | GE for correct key (46): 17.0)
# KR: 94 | GE for correct key (46): 17.0)
# KR: 95 | GE for correct key (46): 17.0)
# KR: 96 | GE for correct key (46): 17.0)
# KR: 97 | GE for correct key (46): 17.0)
# KR: 98 | GE for correct key (46): 17.0)
# KR: 99 | GE for correct key (46): 17.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,056,009
# Trainable params: 2,051,609
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 5s 15ms/step - loss: 1.3592 - accuracy: 0.4920 - val_loss: 2.5432 - val_accuracy: 0.0956
# Epoch 2/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.8839 - accuracy: 0.6551 - val_loss: 2.3727 - val_accuracy: 0.1492
# Epoch 3/10
# 277/277 [==============================] - 4s 14ms/step - loss: 0.7073 - accuracy: 0.7242 - val_loss: 2.3052 - val_accuracy: 0.2152
# Epoch 4/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.5819 - accuracy: 0.7765 - val_loss: 2.4266 - val_accuracy: 0.2128
# Epoch 5/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.4867 - accuracy: 0.8144 - val_loss: 2.7263 - val_accuracy: 0.2288
# Epoch 6/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.4075 - accuracy: 0.8483 - val_loss: 3.0798 - val_accuracy: 0.2208
# Epoch 7/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.3385 - accuracy: 0.8755 - val_loss: 3.0922 - val_accuracy: 0.2268
# Epoch 8/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.2873 - accuracy: 0.8973 - val_loss: 3.3737 - val_accuracy: 0.2168
# Epoch 9/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.2481 - accuracy: 0.9130 - val_loss: 3.6030 - val_accuracy: 0.2352
# Epoch 10/10
# 277/277 [==============================] - 4s 15ms/step - loss: 0.2043 - accuracy: 0.9300 - val_loss: 3.6478 - val_accuracy: 0.2172
# KR: 0 | GE for correct key (46): 30.0)
# KR: 1 | GE for correct key (46): 30.0)
# KR: 2 | GE for correct key (46): 30.0)
# KR: 3 | GE for correct key (46): 30.0)
# KR: 4 | GE for correct key (46): 30.0)
# KR: 5 | GE for correct key (46): 30.0)
# KR: 6 | GE for correct key (46): 30.0)
# KR: 7 | GE for correct key (46): 30.0)
# KR: 8 | GE for correct key (46): 30.0)
# KR: 9 | GE for correct key (46): 30.0)
# KR: 10 | GE for correct key (46): 30.0)
# KR: 11 | GE for correct key (46): 30.0)
# KR: 12 | GE for correct key (46): 30.0)
# ...
# Run 59 - GE 40 models: 14 | GE 1 models: 46 |
# Run 60 - GE 40 models: 14 | GE 1 models: 45 |
# Run 61 - GE 40 models: 14 | GE 1 models: 46 |
# Run 62 - GE 40 models: 14 | GE 1 models: 45 |
# Run 63 - GE 40 models: 14 | GE 1 models: 45 |
# Run 64 - GE 40 models: 14 | GE 1 models: 44 |
# Run 65 - GE 40 models: 14 | GE 1 models: 44 |
# Run 66 - GE 40 models: 14 | GE 1 models: 43 |
# Run 67 - GE 40 models: 13 | GE 1 models: 43 |
# Run 68 - GE 40 models: 13 | GE 1 models: 42 |
# Run 69 - GE 40 models: 14 | GE 1 models: 42 |
# Run 70 - GE 40 models: 14 | GE 1 models: 43 |
# Run 71 - GE 40 models: 14 | GE 1 models: 42 |
# Run 72 - GE 40 models: 14 | GE 1 models: 42 |
# Run 73 - GE 40 models: 14 | GE 1 models: 42 |
# Run 74 - GE 40 models: 14 | GE 1 models: 42 |
# Run 75 - GE 40 models: 14 | GE 1 models: 42 |
# Run 76 - GE 40 models: 14 | GE 1 models: 41 |
# Run 77 - GE 40 models: 14 | GE 1 models: 41 |
# Run 78 - GE 40 models: 14 | GE 1 models: 40 |
# Run 79 - GE 40 models: 14 | GE 1 models: 40 |
# Run 80 - GE 40 models: 14 | GE 1 models: 41 |
# Run 81 - GE 40 models: 13 | GE 1 models: 40 |
# Run 82 - GE 40 models: 13 | GE 1 models: 41 |
# Run 83 - GE 40 models: 13 | GE 1 models: 42 |
# Run 84 - GE 40 models: 13 | GE 1 models: 43 |
# Run 85 - GE 40 models: 13 | GE 1 models: 42 |
# Run 86 - GE 40 models: 13 | GE 1 models: 42 |
# Run 87 - GE 40 models: 13 | GE 1 models: 42 |
# Run 88 - GE 40 models: 13 | GE 1 models: 41 |
# Run 89 - GE 40 models: 13 | GE 1 models: 41 |
# Run 90 - GE 40 models: 13 | GE 1 models: 41 |
# Run 91 - GE 40 models: 13 | GE 1 models: 41 |
# Run 92 - GE 40 models: 13 | GE 1 models: 41 |
# Run 93 - GE 40 models: 13 | GE 1 models: 41 |
# Run 94 - GE 40 models: 13 | GE 1 models: 41 |
# Run 95 - GE 40 models: 13 | GE 1 models: 41 |
# Run 96 - GE 40 models: 12 | GE 1 models: 41 |
# Run 97 - GE 40 models: 13 | GE 1 models: 40 |
# Run 98 - GE 40 models: 13 | GE 1 models: 40 |
# Run 99 - GE 40 models: 13 | GE 1 models: 40 |
# Run 0 - GE 40 models: 13 | GE 5 models: 2 |
# Run 1 - GE 40 models: 10 | GE 5 models: 63 |
# Run 2 - GE 40 models: 8 | GE 5 models: 44 |
# Run 3 - GE 40 models: 10 | GE 5 models: 40 |
# Run 4 - GE 40 models: 10 | GE 5 models: 33 |
# Run 5 - GE 40 models: 10 | GE 5 models: 30 |
# Run 6 - GE 40 models: 9 | GE 5 models: 29 |
# Run 7 - GE 40 models: 9 | GE 5 models: 29 |
# Run 8 - GE 40 models: 8 | GE 5 models: 30 |
# Run 9 - GE 40 models: 10 | GE 5 models: 29 |
# Run 10 - GE 40 models: 9 | GE 5 models: 27 |
# Run 11 - GE 40 models: 9 | GE 5 models: 25 |
# Run 12 - GE 40 models: 9 | GE 5 models: 23 |
# Run 13 - GE 40 models: 9 | GE 5 models: 22 |
# Run 14 - GE 40 models: 9 | GE 5 models: 21 |
# Run 15 - GE 40 models: 8 | GE 5 models: 19 |
# Run 16 - GE 40 models: 9 | GE 5 models: 19 |
# Run 17 - GE 40 models: 9 | GE 5 models: 18 |
# Run 18 - GE 40 models: 9 | GE 5 models: 18 |
# Run 19 - GE 40 models: 9 | GE 5 models: 19 |
# Run 20 - GE 40 models: 10 | GE 5 models: 18 |
# Run 21 - GE 40 models: 10 | GE 5 models: 17 |
# Run 22 - GE 40 models: 10 | GE 5 models: 17 |
# Run 23 - GE 40 models: 10 | GE 5 models: 16 |
# Run 24 - GE 40 models: 10 | GE 5 models: 17 |
# Run 25 - GE 40 models: 10 | GE 5 models: 16 |
# Run 26 - GE 40 models: 10 | GE 5 models: 16 |
# Run 27 - GE 40 models: 10 | GE 5 models: 16 |
# Run 28 - GE 40 models: 11 | GE 5 models: 15 |
# Run 29 - GE 40 models: 13 | GE 5 models: 15 |
# Run 30 - GE 40 models: 13 | GE 5 models: 15 |
# Run 31 - GE 40 models: 13 | GE 5 models: 15 |
# Run 32 - GE 40 models: 13 | GE 5 models: 14 |
# Run 33 - GE 40 models: 13 | GE 5 models: 15 |
# Run 34 - GE 40 models: 13 | GE 5 models: 15 |
# Run 35 - GE 40 models: 13 | GE 5 models: 15 |
# Run 36 - GE 40 models: 12 | GE 5 models: 15 |
# Run 37 - GE 40 models: 12 | GE 5 models: 14 |
# Run 38 - GE 40 models: 12 | GE 5 models: 16 |
# Run 39 - GE 40 models: 12 | GE 5 models: 16 |
# Run 40 - GE 40 models: 12 | GE 5 models: 15 |
# Run 41 - GE 40 models: 13 | GE 5 models: 18 |
# Run 42 - GE 40 models: 13 | GE 5 models: 19 |
# Run 43 - GE 40 models: 13 | GE 5 models: 18 |
# Run 44 - GE 40 models: 13 | GE 5 models: 18 |
# Run 45 - GE 40 models: 13 | GE 5 models: 19 |
# Run 46 - GE 40 models: 13 | GE 5 models: 19 |
# Run 47 - GE 40 models: 13 | GE 5 models: 18 |
# Run 48 - GE 40 models: 13 | GE 5 models: 18 |
# Run 49 - GE 40 models: 13 | GE 5 models: 18 |
# Run 50 - GE 40 models: 13 | GE 5 models: 18 |
# Run 51 - GE 40 models: 13 | GE 5 models: 18 |
# Run 52 - GE 40 models: 13 | GE 5 models: 18 |
# Run 53 - GE 40 models: 13 | GE 5 models: 20 |
# Run 54 - GE 40 models: 13 | GE 5 models: 21 |
# Run 55 - GE 40 models: 14 | GE 5 models: 22 |
# Run 56 - GE 40 models: 13 | GE 5 models: 22 |
# Run 57 - GE 40 models: 13 | GE 5 models: 23 |
# Run 58 - GE 40 models: 14 | GE 5 models: 22 |
# Run 59 - GE 40 models: 14 | GE 5 models: 23 |
# Run 60 - GE 40 models: 14 | GE 5 models: 23 |
# Run 61 - GE 40 models: 14 | GE 5 models: 23 |
# Run 62 - GE 40 models: 14 | GE 5 models: 22 |
# Run 63 - GE 40 models: 14 | GE 5 models: 22 |
# Run 64 - GE 40 models: 14 | GE 5 models: 22 |
# Run 65 - GE 40 models: 14 | GE 5 models: 22 |
# Run 66 - GE 40 models: 14 | GE 5 models: 22 |
# Run 67 - GE 40 models: 13 | GE 5 models: 21 |
# Run 68 - GE 40 models: 13 | GE 5 models: 21 |
# Run 69 - GE 40 models: 14 | GE 5 models: 21 |
# Run 70 - GE 40 models: 14 | GE 5 models: 21 |
# Run 71 - GE 40 models: 14 | GE 5 models: 21 |
# Run 72 - GE 40 models: 14 | GE 5 models: 20 |
# Run 73 - GE 40 models: 14 | GE 5 models: 20 |
# Run 74 - GE 40 models: 14 | GE 5 models: 20 |
# Run 75 - GE 40 models: 14 | GE 5 models: 20 |
# Run 76 - GE 40 models: 14 | GE 5 models: 20 |
# Run 77 - GE 40 models: 14 | GE 5 models: 20 |
# Run 78 - GE 40 models: 14 | GE 5 models: 20 |
# Run 79 - GE 40 models: 14 | GE 5 models: 19 |
# Run 80 - GE 40 models: 14 | GE 5 models: 19 |
# Run 81 - GE 40 models: 13 | GE 5 models: 20 |
# Run 82 - GE 40 models: 13 | GE 5 models: 20 |
# Run 83 - GE 40 models: 13 | GE 5 models: 19 |
# Run 84 - GE 40 models: 13 | GE 5 models: 19 |
# Run 85 - GE 40 models: 13 | GE 5 models: 19 |
# Run 86 - GE 40 models: 13 | GE 5 models: 19 |
# Run 87 - GE 40 models: 13 | GE 5 models: 19 |
# Run 88 - GE 40 models: 13 | GE 5 models: 19 |
# Run 89 - GE 40 models: 13 | GE 5 models: 19 |
# Run 90 - GE 40 models: 13 | GE 5 models: 19 |
# Run 91 - GE 40 models: 13 | GE 5 models: 19 |
# Run 92 - GE 40 models: 13 | GE 5 models: 19 |
# Run 93 - GE 40 models: 13 | GE 5 models: 19 |
# Run 94 - GE 40 models: 13 | GE 5 models: 18 |
# Run 95 - GE 40 models: 13 | GE 5 models: 18 |
# Run 96 - GE 40 models: 12 | GE 5 models: 18 |
# Run 97 - GE 40 models: 13 | GE 5 models: 18 |
# Run 98 - GE 40 models: 13 | GE 5 models: 18 |
# Run 99 - GE 40 models: 13 | GE 5 models: 18 |
# Run 0 - GE 40 models: 13 | GE 10 models: 3 |
# Run 1 - GE 40 models: 10 | GE 10 models: 11 |
# Run 2 - GE 40 models: 8 | GE 10 models: 9 |
# Run 3 - GE 40 models: 10 | GE 10 models: 11 |
# Run 4 - GE 40 models: 10 | GE 10 models: 9 |
# Run 5 - GE 40 models: 10 | GE 10 models: 8 |
# Run 6 - GE 40 models: 9 | GE 10 models: 10 |
# Run 7 - GE 40 models: 9 | GE 10 models: 12 |
# Run 8 - GE 40 models: 8 | GE 10 models: 12 |
# Run 9 - GE 40 models: 10 | GE 10 models: 11 |
# Run 10 - GE 40 models: 9 | GE 10 models: 10 |
# Run 11 - GE 40 models: 9 | GE 10 models: 10 |
# Run 12 - GE 40 models: 9 | GE 10 models: 9 |
# Run 13 - GE 40 models: 9 | GE 10 models: 8 |
# Run 14 - GE 40 models: 9 | GE 10 models: 8 |
# Run 15 - GE 40 models: 8 | GE 10 models: 7 |
# Run 16 - GE 40 models: 9 | GE 10 models: 9 |
# Run 17 - GE 40 models: 9 | GE 10 models: 9 |
# Run 18 - GE 40 models: 9 | GE 10 models: 10 |
# Run 19 - GE 40 models: 9 | GE 10 models: 10 |
# Run 20 - GE 40 models: 10 | GE 10 models: 9 |
# Run 21 - GE 40 models: 10 | GE 10 models: 9 |
# Run 22 - GE 40 models: 10 | GE 10 models: 9 |
# Run 23 - GE 40 models: 10 | GE 10 models: 9 |
# Run 24 - GE 40 models: 10 | GE 10 models: 10 |
# Run 25 - GE 40 models: 10 | GE 10 models: 10 |
# Run 26 - GE 40 models: 10 | GE 10 models: 9 |
# Run 27 - GE 40 models: 10 | GE 10 models: 9 |
# Run 28 - GE 40 models: 11 | GE 10 models: 9 |
# Run 29 - GE 40 models: 13 | GE 10 models: 10 |
# Run 30 - GE 40 models: 13 | GE 10 models: 9 |
# Run 31 - GE 40 models: 13 | GE 10 models: 9 |
# Run 32 - GE 40 models: 13 | GE 10 models: 9 |
# Run 33 - GE 40 models: 13 | GE 10 models: 9 |
# Run 34 - GE 40 models: 13 | GE 10 models: 9 |
# Run 35 - GE 40 models: 13 | GE 10 models: 9 |
# Run 36 - GE 40 models: 12 | GE 10 models: 9 |
# Run 37 - GE 40 models: 12 | GE 10 models: 8 |
# Run 38 - GE 40 models: 12 | GE 10 models: 8 |
# Run 39 - GE 40 models: 12 | GE 10 models: 8 |
# Run 40 - GE 40 models: 12 | GE 10 models: 8 |
# Run 41 - GE 40 models: 13 | GE 10 models: 8 |
# Run 42 - GE 40 models: 13 | GE 10 models: 8 |
# Run 43 - GE 40 models: 13 | GE 10 models: 8 |
# Run 44 - GE 40 models: 13 | GE 10 models: 8 |
# Run 45 - GE 40 models: 13 | GE 10 models: 8 |
# Run 46 - GE 40 models: 13 | GE 10 models: 8 |
# Run 47 - GE 40 models: 13 | GE 10 models: 8 |
# Run 48 - GE 40 models: 13 | GE 10 models: 8 |
# Run 49 - GE 40 models: 13 | GE 10 models: 8 |
# Run 50 - GE 40 models: 13 | GE 10 models: 8 |
# Run 51 - GE 40 models: 13 | GE 10 models: 8 |
# Run 52 - GE 40 models: 13 | GE 10 models: 8 |
# Run 53 - GE 40 models: 13 | GE 10 models: 9 |
# Run 54 - GE 40 models: 13 | GE 10 models: 9 |
# Run 55 - GE 40 models: 14 | GE 10 models: 9 |
# Run 56 - GE 40 models: 13 | GE 10 models: 9 |
# Run 57 - GE 40 models: 13 | GE 10 models: 9 |
# Run 58 - GE 40 models: 14 | GE 10 models: 9 |
# Run 59 - GE 40 models: 14 | GE 10 models: 10 |
# Run 60 - GE 40 models: 14 | GE 10 models: 10 |
# Run 61 - GE 40 models: 14 | GE 10 models: 10 |
# Run 62 - GE 40 models: 14 | GE 10 models: 10 |
# Run 63 - GE 40 models: 14 | GE 10 models: 9 |
# Run 64 - GE 40 models: 14 | GE 10 models: 9 |
# Run 65 - GE 40 models: 14 | GE 10 models: 9 |
# Run 66 - GE 40 models: 14 | GE 10 models: 9 |
# Run 67 - GE 40 models: 13 | GE 10 models: 9 |
# Run 68 - GE 40 models: 13 | GE 10 models: 9 |
# Run 69 - GE 40 models: 14 | GE 10 models: 9 |
# Run 70 - GE 40 models: 14 | GE 10 models: 9 |
# Run 71 - GE 40 models: 14 | GE 10 models: 9 |
# Run 72 - GE 40 models: 14 | GE 10 models: 9 |
# Run 73 - GE 40 models: 14 | GE 10 models: 9 |
# Run 74 - GE 40 models: 14 | GE 10 models: 9 |
# Run 75 - GE 40 models: 14 | GE 10 models: 9 |
# Run 76 - GE 40 models: 14 | GE 10 models: 9 |
# Run 77 - GE 40 models: 14 | GE 10 models: 9 |
# Run 78 - GE 40 models: 14 | GE 10 models: 9 |
# Run 79 - GE 40 models: 14 | GE 10 models: 9 |
# Run 80 - GE 40 models: 14 | GE 10 models: 8 |
# Run 81 - GE 40 models: 13 | GE 10 models: 8 |
# Run 82 - GE 40 models: 13 | GE 10 models: 8 |
# Run 83 - GE 40 models: 13 | GE 10 models: 8 |
# Run 84 - GE 40 models: 13 | GE 10 models: 8 |
# Run 85 - GE 40 models: 13 | GE 10 models: 8 |
# Run 86 - GE 40 models: 13 | GE 10 models: 8 |
# Run 87 - GE 40 models: 13 | GE 10 models: 8 |
# Run 88 - GE 40 models: 13 | GE 10 models: 8 |
# Run 89 - GE 40 models: 13 | GE 10 models: 8 |
# Run 90 - GE 40 models: 13 | GE 10 models: 8 |
# Run 91 - GE 40 models: 13 | GE 10 models: 8 |
# Run 92 - GE 40 models: 13 | GE 10 models: 8 |
# Run 93 - GE 40 models: 13 | GE 10 models: 8 |
# Run 94 - GE 40 models: 13 | GE 10 models: 8 |
# Run 95 - GE 40 models: 13 | GE 10 models: 8 |
# Run 96 - GE 40 models: 12 | GE 10 models: 8 |
# Run 97 - GE 40 models: 13 | GE 10 models: 8 |
# Run 98 - GE 40 models: 13 | GE 10 models: 8 |
# Run 99 - GE 40 models: 13 | GE 10 models: 8 |
# Run 0 - GE 40 models: 13 | GE 20 models: 2 |
# Run 1 - GE 40 models: 10 | GE 20 models: 13 |
# Run 2 - GE 40 models: 8 | GE 20 models: 12 |
# Run 3 - GE 40 models: 10 | GE 20 models: 12 |
# Run 4 - GE 40 models: 10 | GE 20 models: 11 |
# Run 5 - GE 40 models: 10 | GE 20 models: 10 |
# Run 6 - GE 40 models: 9 | GE 20 models: 9 |
# Run 7 - GE 40 models: 9 | GE 20 models: 8 |
# Run 8 - GE 40 models: 8 | GE 20 models: 9 |
# Run 9 - GE 40 models: 10 | GE 20 models: 9 |
# Run 10 - GE 40 models: 9 | GE 20 models: 8 |
# Run 11 - GE 40 models: 9 | GE 20 models: 7 |
# Run 12 - GE 40 models: 9 | GE 20 models: 7 |
# Run 13 - GE 40 models: 9 | GE 20 models: 7 |
# Run 14 - GE 40 models: 9 | GE 20 models: 6 |
# Run 15 - GE 40 models: 8 | GE 20 models: 6 |
# Run 16 - GE 40 models: 9 | GE 20 models: 6 |
# Run 17 - GE 40 models: 9 | GE 20 models: 6 |
# Run 18 - GE 40 models: 9 | GE 20 models: 7 |
# Run 19 - GE 40 models: 9 | GE 20 models: 7 |
# Run 20 - GE 40 models: 10 | GE 20 models: 7 |
# Run 21 - GE 40 models: 10 | GE 20 models: 7 |
# Run 22 - GE 40 models: 10 | GE 20 models: 7 |
# Run 23 - GE 40 models: 10 | GE 20 models: 7 |
# Run 24 - GE 40 models: 10 | GE 20 models: 7 |
# Run 25 - GE 40 models: 10 | GE 20 models: 7 |
# Run 26 - GE 40 models: 10 | GE 20 models: 6 |
# Run 27 - GE 40 models: 10 | GE 20 models: 6 |
# Run 28 - GE 40 models: 11 | GE 20 models: 7 |
# Run 29 - GE 40 models: 13 | GE 20 models: 7 |
# Run 30 - GE 40 models: 13 | GE 20 models: 7 |
# Run 31 - GE 40 models: 13 | GE 20 models: 7 |
# Run 32 - GE 40 models: 13 | GE 20 models: 7 |
# Run 33 - GE 40 models: 13 | GE 20 models: 7 |
# Run 34 - GE 40 models: 13 | GE 20 models: 6 |
# Run 35 - GE 40 models: 13 | GE 20 models: 6 |
# Run 36 - GE 40 models: 12 | GE 20 models: 6 |
# Run 37 - GE 40 models: 12 | GE 20 models: 6 |
# Run 38 - GE 40 models: 12 | GE 20 models: 6 |
# Run 39 - GE 40 models: 12 | GE 20 models: 6 |
# Run 40 - GE 40 models: 12 | GE 20 models: 6 |
# Run 41 - GE 40 models: 13 | GE 20 models: 7 |
# Run 42 - GE 40 models: 13 | GE 20 models: 6 |
# Run 43 - GE 40 models: 13 | GE 20 models: 6 |
# Run 44 - GE 40 models: 13 | GE 20 models: 7 |
# Run 45 - GE 40 models: 13 | GE 20 models: 6 |
# Run 46 - GE 40 models: 13 | GE 20 models: 7 |
# Run 47 - GE 40 models: 13 | GE 20 models: 7 |
# Run 48 - GE 40 models: 13 | GE 20 models: 7 |
# Run 49 - GE 40 models: 13 | GE 20 models: 7 |
# Run 50 - GE 40 models: 13 | GE 20 models: 7 |
# Run 51 - GE 40 models: 13 | GE 20 models: 7 |
# Run 52 - GE 40 models: 13 | GE 20 models: 7 |
# Run 53 - GE 40 models: 13 | GE 20 models: 7 |
# Run 54 - GE 40 models: 13 | GE 20 models: 7 |
# Run 55 - GE 40 models: 14 | GE 20 models: 7 |
# Run 56 - GE 40 models: 13 | GE 20 models: 7 |
# Run 57 - GE 40 models: 13 | GE 20 models: 7 |
# Run 58 - GE 40 models: 14 | GE 20 models: 7 |
# Run 59 - GE 40 models: 14 | GE 20 models: 8 |
# Run 60 - GE 40 models: 14 | GE 20 models: 8 |
# Run 61 - GE 40 models: 14 | GE 20 models: 8 |
# Run 62 - GE 40 models: 14 | GE 20 models: 8 |
# Run 63 - GE 40 models: 14 | GE 20 models: 7 |
# Run 64 - GE 40 models: 14 | GE 20 models: 7 |
# Run 65 - GE 40 models: 14 | GE 20 models: 7 |
# Run 66 - GE 40 models: 14 | GE 20 models: 7 |
# Run 67 - GE 40 models: 13 | GE 20 models: 7 |
# Run 68 - GE 40 models: 13 | GE 20 models: 7 |
# Run 69 - GE 40 models: 14 | GE 20 models: 8 |
# Run 70 - GE 40 models: 14 | GE 20 models: 8 |
# Run 71 - GE 40 models: 14 | GE 20 models: 8 |
# Run 72 - GE 40 models: 14 | GE 20 models: 8 |
# Run 73 - GE 40 models: 14 | GE 20 models: 8 |
# Run 74 - GE 40 models: 14 | GE 20 models: 8 |
# Run 75 - GE 40 models: 14 | GE 20 models: 8 |
# Run 76 - GE 40 models: 14 | GE 20 models: 8 |
# Run 77 - GE 40 models: 14 | GE 20 models: 8 |
# Run 78 - GE 40 models: 14 | GE 20 models: 8 |
# Run 79 - GE 40 models: 14 | GE 20 models: 7 |
# Run 80 - GE 40 models: 14 | GE 20 models: 7 |
# Run 81 - GE 40 models: 13 | GE 20 models: 7 |
# Run 82 - GE 40 models: 13 | GE 20 models: 7 |
# Run 83 - GE 40 models: 13 | GE 20 models: 7 |
# Run 84 - GE 40 models: 13 | GE 20 models: 7 |
# Run 85 - GE 40 models: 13 | GE 20 models: 7 |
# Run 86 - GE 40 models: 13 | GE 20 models: 7 |
# Run 87 - GE 40 models: 13 | GE 20 models: 7 |
# Run 88 - GE 40 models: 13 | GE 20 models: 7 |
# Run 89 - GE 40 models: 13 | GE 20 models: 7 |
# Run 90 - GE 40 models: 13 | GE 20 models: 7 |
# Run 91 - GE 40 models: 13 | GE 20 models: 7 |
# Run 92 - GE 40 models: 13 | GE 20 models: 7 |
# Run 93 - GE 40 models: 13 | GE 20 models: 7 |
# Run 94 - GE 40 models: 13 | GE 20 models: 7 |
# Run 95 - GE 40 models: 13 | GE 20 models: 7 |
# Run 96 - GE 40 models: 12 | GE 20 models: 7 |
# Run 97 - GE 40 models: 13 | GE 20 models: 7 |
# Run 98 - GE 40 models: 13 | GE 20 models: 7 |
# Run 99 - GE 40 models: 13 | GE 20 models: 7 |

# %%
plt.rc('figure', figsize=(15, 8))

# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('MLP_ASCAD_Ensembles_Tuning.png')
plt.savefig('MLP_ASCAD_Ensembles_Tuning.pdf')

# %%
plt.rc('figure', figsize=(15, 8))
ensemble_aes = EnsembleAES()
#ensemble_aes.set_dataset("ascad_fixed_key")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_dataset("ches_ctf")
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0) # 0 for CHES. 2 for ASCAD
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
ensemble_aes.run_ensemble(number_of_models=30, number_of_best_models=[1,1,1,1])
# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
#plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
#plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
#plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
#plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
#plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
#plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('CNN_CHES_Ensembles_SMOTE_SingleModel.png')
plt.savefig('CNN_CHES_Ensembles_SMOTE_SingleModel.pdf')
# Out:
# No handles with labels found to put in legend.
# Class=5, n=12294 (11.111%)
# Class=4, n=12294 (11.111%)
# Class=6, n=12294 (11.111%)
# Class=3, n=12294 (11.111%)
# Class=7, n=12294 (11.111%)
# Class=1, n=12294 (11.111%)
# Class=2, n=12294 (11.111%)
# Class=0, n=12294 (11.111%)
# Class=8, n=12294 (11.111%)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 500)               1100500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 500)               250500
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  dense_6 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 2,366,309
# Trainable params: 2,361,909
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Streaming output truncated to the last 5000 lines.
# KR: 4 | GE for correct key (46): 3.0)
# KR: 5 | GE for correct key (46): 3.0)
# KR: 6 | GE for correct key (46): 3.0)
# KR: 7 | GE for correct key (46): 3.0)
# KR: 8 | GE for correct key (46): 3.0)
# KR: 9 | GE for correct key (46): 3.0)
# KR: 10 | GE for correct key (46): 3.0)
# KR: 11 | GE for correct key (46): 3.0)
# KR: 12 | GE for correct key (46): 3.0)
# KR: 13 | GE for correct key (46): 3.0)
# KR: 14 | GE for correct key (46): 3.0)
# KR: 15 | GE for correct key (46): 3.0)
# KR: 16 | GE for correct key (46): 3.0)
# KR: 17 | GE for correct key (46): 3.0)
# KR: 18 | GE for correct key (46): 3.0)
# KR: 19 | GE for correct key (46): 3.0)
# KR: 20 | GE for correct key (46): 3.0)
# KR: 21 | GE for correct key (46): 3.0)
# KR: 22 | GE for correct key (46): 3.0)
# KR: 23 | GE for correct key (46): 3.0)
# KR: 24 | GE for correct key (46): 3.0)
# KR: 25 | GE for correct key (46): 3.0)
# KR: 26 | GE for correct key (46): 3.0)
# KR: 27 | GE for correct key (46): 3.0)
# KR: 28 | GE for correct key (46): 3.0)
# KR: 29 | GE for correct key (46): 3.0)
# KR: 30 | GE for correct key (46): 3.0)
# KR: 31 | GE for correct key (46): 3.0)
# KR: 32 | GE for correct key (46): 3.0)
# KR: 33 | GE for correct key (46): 3.0)
# KR: 34 | GE for correct key (46): 3.0)
# KR: 35 | GE for correct key (46): 3.0)
# KR: 36 | GE for correct key (46): 3.0)
# KR: 37 | GE for correct key (46): 3.0)
# KR: 38 | GE for correct key (46): 3.0)
# KR: 39 | GE for correct key (46): 3.0)
# KR: 40 | GE for correct key (46): 3.0)
# KR: 41 | GE for correct key (46): 3.0)
# KR: 42 | GE for correct key (46): 3.0)
# KR: 43 | GE for correct key (46): 3.0)
# KR: 44 | GE for correct key (46): 3.0)
# KR: 45 | GE for correct key (46): 3.0)
# KR: 46 | GE for correct key (46): 3.0)
# KR: 47 | GE for correct key (46): 3.0)
# KR: 48 | GE for correct key (46): 3.0)
# KR: 49 | GE for correct key (46): 3.0)
# KR: 50 | GE for correct key (46): 3.0)
# KR: 51 | GE for correct key (46): 3.0)
# KR: 52 | GE for correct key (46): 3.0)
# KR: 53 | GE for correct key (46): 3.0)
# KR: 54 | GE for correct key (46): 3.0)
# KR: 55 | GE for correct key (46): 3.0)
# KR: 56 | GE for correct key (46): 3.0)
# KR: 57 | GE for correct key (46): 3.0)
# KR: 58 | GE for correct key (46): 3.0)
# KR: 59 | GE for correct key (46): 3.0)
# KR: 60 | GE for correct key (46): 3.0)
# KR: 61 | GE for correct key (46): 3.0)
# KR: 62 | GE for correct key (46): 3.0)
# KR: 63 | GE for correct key (46): 3.0)
# KR: 64 | GE for correct key (46): 3.0)
# KR: 65 | GE for correct key (46): 3.0)
# KR: 66 | GE for correct key (46): 3.0)
# KR: 67 | GE for correct key (46): 3.0)
# KR: 68 | GE for correct key (46): 3.0)
# KR: 69 | GE for correct key (46): 3.0)
# KR: 70 | GE for correct key (46): 3.0)
# KR: 71 | GE for correct key (46): 3.0)
# KR: 72 | GE for correct key (46): 3.0)
# KR: 73 | GE for correct key (46): 3.0)
# KR: 74 | GE for correct key (46): 3.0)
# KR: 75 | GE for correct key (46): 3.0)
# KR: 76 | GE for correct key (46): 3.0)
# KR: 77 | GE for correct key (46): 3.0)
# KR: 78 | GE for correct key (46): 3.0)
# KR: 79 | GE for correct key (46): 3.0)
# KR: 80 | GE for correct key (46): 3.0)
# KR: 81 | GE for correct key (46): 3.0)
# KR: 82 | GE for correct key (46): 3.0)
# KR: 83 | GE for correct key (46): 3.0)
# KR: 84 | GE for correct key (46): 3.0)
# KR: 85 | GE for correct key (46): 3.0)
# KR: 86 | GE for correct key (46): 3.0)
# KR: 87 | GE for correct key (46): 3.0)
# KR: 88 | GE for correct key (46): 3.0)
# KR: 89 | GE for correct key (46): 3.0)
# KR: 90 | GE for correct key (46): 3.0)
# KR: 91 | GE for correct key (46): 3.0)
# KR: 92 | GE for correct key (46): 3.0)
# KR: 93 | GE for correct key (46): 3.0)
# KR: 94 | GE for correct key (46): 3.0)
# KR: 95 | GE for correct key (46): 3.0)
# KR: 96 | GE for correct key (46): 3.0)
# KR: 97 | GE for correct key (46): 3.0)
# KR: 98 | GE for correct key (46): 3.0)
# KR: 99 | GE for correct key (46): 3.0)
# KR: 0 | GE for correct key (46): 1.0)
# KR: 1 | GE for correct key (46): 1.0)
# KR: 2 | GE for correct key (46): 1.0)
# KR: 3 | GE for correct key (46): 1.0)
# KR: 4 | GE for correct key (46): 1.0)
# KR: 5 | GE for correct key (46): 1.0)
# KR: 6 | GE for correct key (46): 1.0)
# KR: 7 | GE for correct key (46): 1.0)
# KR: 8 | GE for correct key (46): 1.0)
# KR: 9 | GE for correct key (46): 1.0)
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 700)               1540700
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 700)               490700
#
#  dense_3 (Dense)             (None, 700)               490700
#
#  dense_4 (Dense)             (None, 700)               490700
#
#  dense_5 (Dense)             (None, 700)               490700
#
#  dense_6 (Dense)             (None, 700)               490700
#
#  dense_7 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 4,500,009
# Trainable params: 4,495,609
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 8s 28ms/step - loss: 1.6140 - accuracy: 0.5102 - val_loss: 2.1781 - val_accuracy: 0.2424
# Epoch 2/10
# 277/277 [==============================] - 7s 26ms/step - loss: 0.8439 - accuracy: 0.6801 - val_loss: 2.3362 - val_accuracy: 0.2276
# Epoch 3/10
# 277/277 [==============================] - 7s 27ms/step - loss: 0.6530 - accuracy: 0.7510 - val_loss: 2.4555 - val_accuracy: 0.2424
# Epoch 4/10
# 277/277 [==============================] - 7s 27ms/step - loss: 0.5395 - accuracy: 0.7946 - val_loss: 2.5551 - val_accuracy: 0.2140
# Epoch 5/10
# 277/277 [==============================] - 7s 27ms/step - loss: 0.4531 - accuracy: 0.8299 - val_loss: 2.5981 - val_accuracy: 0.2224
# Epoch 6/10
# 277/277 [==============================] - 7s 27ms/step - loss: 0.4054 - accuracy: 0.8499 - val_loss: 2.8939 - val_accuracy: 0.2232
# Epoch 7/10
# 277/277 [==============================] - 7s 27ms/step - loss: 0.3472 - accuracy: 0.8707 - val_loss: 3.0476 - val_accuracy: 0.2312
# Epoch 8/10
# 277/277 [==============================] - 7s 27ms/step - loss: 0.3138 - accuracy: 0.8842 - val_loss: 3.4461 - val_accuracy: 0.2480
# Epoch 9/10
# 277/277 [==============================] - 7s 27ms/step - loss: 0.2734 - accuracy: 0.9020 - val_loss: 3.2788 - val_accuracy: 0.2244
# Epoch 10/10
# 277/277 [==============================] - 8s 27ms/step - loss: 0.2641 - accuracy: 0.9058 - val_loss: 3.4333 - val_accuracy: 0.2208
# KR: 0 | GE for correct key (46): 4.0)
# KR: 1 | GE for correct key (46): 4.0)
# KR: 2 | GE for correct key (46): 4.0)
# KR: 3 | GE for correct key (46): 4.0)
# KR: 4 | GE for correct key (46): 4.0)
# KR: 5 | GE for correct key (46): 4.0)
# KR: 6 | GE for correct key (46): 4.0)
# KR: 7 | GE for correct key (46): 4.0)
# KR: 8 | GE for correct key (46): 4.0)
# KR: 9 | GE for correct key (46): 4.0)
# KR: 10 | GE for correct key (46): 4.0)
# KR: 11 | GE for correct key (46): 4.0)
# KR: 12 | GE for correct key (46): 4.0)
# KR: 13 | GE for correct key (46): 4.0)
# KR: 14 | GE for correct key (46): 4.0)
# KR: 15 | GE for correct key (46): 4.0)
# KR: 16 | GE for correct key (46): 4.0)
# KR: 17 | GE for correct key (46): 4.0)
# KR: 18 | GE for correct key (46): 4.0)
# KR: 19 | GE for correct key (46): 4.0)
# KR: 20 | GE for correct key (46): 4.0)
# KR: 21 | GE for correct key (46): 4.0)
# KR: 22 | GE for correct key (46): 4.0)
# KR: 23 | GE for correct key (46): 4.0)
# KR: 24 | GE for correct key (46): 4.0)
# KR: 25 | GE for correct key (46): 4.0)
# KR: 26 | GE for correct key (46): 4.0)
# KR: 27 | GE for correct key (46): 4.0)
# KR: 28 | GE for correct key (46): 4.0)
# KR: 29 | GE for correct key (46): 4.0)
# KR: 30 | GE for correct key (46): 4.0)
# KR: 31 | GE for correct key (46): 4.0)
# KR: 32 | GE for correct key (46): 4.0)
# KR: 33 | GE for correct key (46): 4.0)
# KR: 34 | GE for correct key (46): 4.0)
# KR: 35 | GE for correct key (46): 4.0)
# KR: 36 | GE for correct key (46): 4.0)
# KR: 37 | GE for correct key (46): 4.0)
# KR: 38 | GE for correct key (46): 4.0)
# KR: 39 | GE for correct key (46): 4.0)
# KR: 40 | GE for correct key (46): 4.0)
# KR: 41 | GE for correct key (46): 4.0)
# KR: 42 | GE for correct key (46): 4.0)
# KR: 43 | GE for correct key (46): 4.0)
# KR: 44 | GE for correct key (46): 4.0)
# KR: 45 | GE for correct key (46): 4.0)
# KR: 46 | GE for correct key (46): 4.0)
# KR: 47 | GE for correct key (46): 4.0)
# KR: 48 | GE for correct key (46): 4.0)
# KR: 49 | GE for correct key (46): 4.0)
# KR: 50 | GE for correct key (46): 4.0)
# KR: 51 | GE for correct key (46): 4.0)
# KR: 52 | GE for correct key (46): 4.0)
# KR: 53 | GE for correct key (46): 4.0)
# KR: 54 | GE for correct key (46): 4.0)
# KR: 55 | GE for correct key (46): 4.0)
# KR: 56 | GE for correct key (46): 4.0)
# KR: 57 | GE for correct key (46): 4.0)
# KR: 58 | GE for correct key (46): 4.0)
# KR: 59 | GE for correct key (46): 4.0)
# KR: 60 | GE for correct key (46): 4.0)
# KR: 61 | GE for correct key (46): 4.0)
# KR: 62 | GE for correct key (46): 4.0)
# KR: 63 | GE for correct key (46): 4.0)
# KR: 64 | GE for correct key (46): 4.0)
# KR: 65 | GE for correct key (46): 4.0)
# KR: 66 | GE for correct key (46): 4.0)
# KR: 67 | GE for correct key (46): 4.0)
# KR: 68 | GE for correct key (46): 4.0)
# KR: 69 | GE for correct key (46): 4.0)
# KR: 70 | GE for correct key (46): 4.0)
# KR: 71 | GE for correct key (46): 4.0)
# KR: 72 | GE for correct key (46): 4.0)
# KR: 73 | GE for correct key (46): 4.0)
# KR: 74 | GE for correct key (46): 4.0)
# KR: 75 | GE for correct key (46): 4.0)
# KR: 76 | GE for correct key (46): 4.0)
# KR: 77 | GE for correct key (46): 4.0)
# KR: 78 | GE for correct key (46): 4.0)
# KR: 79 | GE for correct key (46): 4.0)
# KR: 80 | GE for correct key (46): 4.0)
# KR: 81 | GE for correct key (46): 4.0)
# KR: 82 | GE for correct key (46): 4.0)
# KR: 83 | GE for correct key (46): 4.0)
# KR: 84 | GE for correct key (46): 4.0)
# KR: 85 | GE for correct key (46): 4.0)
# KR: 86 | GE for correct key (46): 4.0)
# KR: 87 | GE for correct key (46): 4.0)
# KR: 88 | GE for correct key (46): 4.0)
# KR: 89 | GE for correct key (46): 4.0)
# KR: 90 | GE for correct key (46): 4.0)
# KR: 91 | GE for correct key (46): 4.0)
# KR: 92 | GE for correct key (46): 4.0)
# KR: 93 | GE for correct key (46): 4.0)
# KR: 94 | GE for correct key (46): 4.0)
# KR: 95 | GE for correct key (46): 4.0)
# KR: 96 | GE for correct key (46): 4.0)
# KR: 97 | GE for correct key (46): 4.0)
# KR: 98 | GE for correct key (46): 4.0)
# KR: 99 | GE for correct key (46): 4.0)
# KR: 0 | GE for correct key (46): 8.0)
# KR: 1 | GE for correct key (46): 8.0)
# KR: 2 | GE for correct key (46): 8.0)
# KR: 3 | GE for correct key (46): 8.0)
# KR: 4 | GE for correct key (46): 8.0)
# KR: 5 | GE for correct key (46): 8.0)
# KR: 6 | GE for correct key (46): 8.0)
# KR: 7 | GE for correct key (46): 8.0)
# KR: 8 | GE for correct key (46): 8.0)
# KR: 9 | GE for correct key (46): 8.0)
# KR: 10 | GE for correct key (46): 8.0)
# KR: 11 | GE for correct key (46): 8.0)
# KR: 12 | GE for correct key (46): 8.0)
# KR: 13 | GE for correct key (46): 8.0)
# KR: 14 | GE for correct key (46): 8.0)
# KR: 15 | GE for correct key (46): 8.0)
# KR: 16 | GE for correct key (46): 8.0)
# KR: 17 | GE for correct key (46): 8.0)
# KR: 18 | GE for correct key (46): 8.0)
# KR: 19 | GE for correct key (46): 8.0)
# KR: 20 | GE for correct key (46): 8.0)
# KR: 21 | GE for correct key (46): 8.0)
# KR: 22 | GE for correct key (46): 8.0)
# KR: 23 | GE for correct key (46): 8.0)
# KR: 24 | GE for correct key (46): 8.0)
# KR: 25 | GE for correct key (46): 8.0)
# KR: 26 | GE for correct key (46): 8.0)
# KR: 27 | GE for correct key (46): 8.0)
# KR: 28 | GE for correct key (46): 8.0)
# KR: 29 | GE for correct key (46): 8.0)
# KR: 30 | GE for correct key (46): 8.0)
# KR: 31 | GE for correct key (46): 8.0)
# KR: 32 | GE for correct key (46): 8.0)
# KR: 33 | GE for correct key (46): 8.0)
# KR: 34 | GE for correct key (46): 8.0)
# KR: 35 | GE for correct key (46): 8.0)
# KR: 36 | GE for correct key (46): 8.0)
# KR: 37 | GE for correct key (46): 8.0)
# KR: 38 | GE for correct key (46): 8.0)
# KR: 39 | GE for correct key (46): 8.0)
# KR: 40 | GE for correct key (46): 8.0)
# KR: 41 | GE for correct key (46): 8.0)
# KR: 42 | GE for correct key (46): 8.0)
# KR: 43 | GE for correct key (46): 8.0)
# KR: 44 | GE for correct key (46): 8.0)
# KR: 45 | GE for correct key (46): 8.0)
# KR: 46 | GE for correct key (46): 8.0)
# KR: 47 | GE for correct key (46): 8.0)
# KR: 48 | GE for correct key (46): 8.0)
# KR: 49 | GE for correct key (46): 8.0)
# KR: 50 | GE for correct key (46): 8.0)
# KR: 51 | GE for correct key (46): 8.0)
# KR: 52 | GE for correct key (46): 8.0)
# KR: 53 | GE for correct key (46): 8.0)
# KR: 54 | GE for correct key (46): 8.0)
# KR: 55 | GE for correct key (46): 8.0)
# KR: 56 | GE for correct key (46): 8.0)
# KR: 57 | GE for correct key (46): 8.0)
# KR: 58 | GE for correct key (46): 8.0)
# KR: 59 | GE for correct key (46): 8.0)
# KR: 60 | GE for correct key (46): 8.0)
# KR: 61 | GE for correct key (46): 8.0)
# KR: 62 | GE for correct key (46): 8.0)
# KR: 63 | GE for correct key (46): 8.0)
# KR: 64 | GE for correct key (46): 8.0)
# KR: 65 | GE for correct key (46): 8.0)
# KR: 66 | GE for correct key (46): 8.0)
# KR: 67 | GE for correct key (46): 8.0)
# KR: 68 | GE for correct key (46): 8.0)
# KR: 69 | GE for correct key (46): 8.0)
# KR: 70 | GE for correct key (46): 8.0)
# KR: 71 | GE for correct key (46): 8.0)
# KR: 72 | GE for correct key (46): 8.0)
# KR: 73 | GE for correct key (46): 8.0)
# KR: 74 | GE for correct key (46): 8.0)
# KR: 75 | GE for correct key (46): 8.0)
# KR: 76 | GE for correct key (46): 8.0)
# KR: 77 | GE for correct key (46): 8.0)
# KR: 78 | GE for correct key (46): 8.0)
# KR: 79 | GE for correct key (46): 8.0)
# KR: 80 | GE for correct key (46): 8.0)
# KR: 81 | GE for correct key (46): 8.0)
# KR: 82 | GE for correct key (46): 8.0)
# KR: 83 | GE for correct key (46): 8.0)
# KR: 84 | GE for correct key (46): 8.0)
# KR: 85 | GE for correct key (46): 8.0)
# KR: 86 | GE for correct key (46): 8.0)
# KR: 87 | GE for correct key (46): 8.0)
# KR: 88 | GE for correct key (46): 8.0)
# KR: 89 | GE for correct key (46): 8.0)
# KR: 90 | GE for correct key (46): 8.0)
# KR: 91 | GE for correct key (46): 8.0)
# KR: 92 | GE for correct key (46): 8.0)
# KR: 93 | GE for correct key (46): 8.0)
# KR: 94 | GE for correct key (46): 8.0)
# KR: 95 | GE for correct key (46): 8.0)
# KR: 96 | GE for correct key (46): 8.0)
# KR: 97 | GE for correct key (46): 8.0)
# KR: 98 | GE for correct key (46): 8.0)
# KR: 99 | GE for correct key (46): 8.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 500)               1100500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 500)               250500
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  dense_6 (Dense)             (None, 500)               250500
#
#  dense_7 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 2,616,809
# Trainable params: 2,612,409
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 6s 20ms/step - loss: 1.3789 - accuracy: 0.4600 - val_loss: 2.2774 - val_accuracy: 0.1456
# Epoch 2/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.9449 - accuracy: 0.6145 - val_loss: 2.7306 - val_accuracy: 0.1636
# Epoch 3/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.7938 - accuracy: 0.6765 - val_loss: 2.3244 - val_accuracy: 0.2136
# Epoch 4/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.6840 - accuracy: 0.7209 - val_loss: 2.4352 - val_accuracy: 0.2140
# Epoch 5/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.5986 - accuracy: 0.7531 - val_loss: 2.7868 - val_accuracy: 0.2248
# Epoch 6/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.5221 - accuracy: 0.7842 - val_loss: 2.9292 - val_accuracy: 0.2108
# Epoch 7/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.4635 - accuracy: 0.8103 - val_loss: 3.2976 - val_accuracy: 0.2516
# Epoch 8/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.4139 - accuracy: 0.8343 - val_loss: 3.5845 - val_accuracy: 0.2176
# Epoch 9/10
# 277/277 [==============================] - 5s 20ms/step - loss: 0.3578 - accuracy: 0.8581 - val_loss: 4.0709 - val_accuracy: 0.2304
# Epoch 10/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.3237 - accuracy: 0.8745 - val_loss: 4.0070 - val_accuracy: 0.2148
# KR: 0 | GE for correct key (46): 13.0)
# KR: 1 | GE for correct key (46): 13.0)
# KR: 2 | GE for correct key (46): 13.0)
# KR: 3 | GE for correct key (46): 13.0)
# KR: 4 | GE for correct key (46): 13.0)
# KR: 5 | GE for correct key (46): 13.0)
# KR: 6 | GE for correct key (46): 13.0)
# KR: 7 | GE for correct key (46): 13.0)
# KR: 8 | GE for correct key (46): 13.0)
# KR: 9 | GE for correct key (46): 13.0)
# KR: 10 | GE for correct key (46): 13.0)
# KR: 11 | GE for correct key (46): 13.0)
# KR: 12 | GE for correct key (46): 13.0)
# KR: 13 | GE for correct key (46): 13.0)
# KR: 14 | GE for correct key (46): 13.0)
# KR: 15 | GE for correct key (46): 13.0)
# KR: 16 | GE for correct key (46): 13.0)
# KR: 17 | GE for correct key (46): 13.0)
# KR: 18 | GE for correct key (46): 13.0)
# KR: 19 | GE for correct key (46): 13.0)
# KR: 20 | GE for correct key (46): 13.0)
# KR: 21 | GE for correct key (46): 13.0)
# KR: 22 | GE for correct key (46): 13.0)
# KR: 23 | GE for correct key (46): 13.0)
# KR: 24 | GE for correct key (46): 13.0)
# KR: 25 | GE for correct key (46): 13.0)
# KR: 26 | GE for correct key (46): 13.0)
# KR: 27 | GE for correct key (46): 13.0)
# KR: 28 | GE for correct key (46): 13.0)
# KR: 29 | GE for correct key (46): 13.0)
# KR: 30 | GE for correct key (46): 13.0)
# KR: 31 | GE for correct key (46): 13.0)
# KR: 32 | GE for correct key (46): 13.0)
# KR: 33 | GE for correct key (46): 13.0)
# KR: 34 | GE for correct key (46): 13.0)
# KR: 35 | GE for correct key (46): 13.0)
# KR: 36 | GE for correct key (46): 13.0)
# KR: 37 | GE for correct key (46): 13.0)
# KR: 38 | GE for correct key (46): 13.0)
# KR: 39 | GE for correct key (46): 13.0)
# KR: 40 | GE for correct key (46): 13.0)
# KR: 41 | GE for correct key (46): 13.0)
# KR: 42 | GE for correct key (46): 13.0)
# KR: 43 | GE for correct key (46): 13.0)
# KR: 44 | GE for correct key (46): 13.0)
# KR: 45 | GE for correct key (46): 13.0)
# KR: 46 | GE for correct key (46): 13.0)
# KR: 47 | GE for correct key (46): 13.0)
# KR: 48 | GE for correct key (46): 13.0)
# KR: 49 | GE for correct key (46): 13.0)
# KR: 50 | GE for correct key (46): 13.0)
# KR: 51 | GE for correct key (46): 13.0)
# KR: 52 | GE for correct key (46): 13.0)
# KR: 53 | GE for correct key (46): 13.0)
# KR: 54 | GE for correct key (46): 13.0)
# KR: 55 | GE for correct key (46): 13.0)
# KR: 56 | GE for correct key (46): 13.0)
# KR: 57 | GE for correct key (46): 13.0)
# KR: 58 | GE for correct key (46): 13.0)
# KR: 59 | GE for correct key (46): 13.0)
# KR: 60 | GE for correct key (46): 13.0)
# KR: 61 | GE for correct key (46): 13.0)
# KR: 62 | GE for correct key (46): 13.0)
# KR: 63 | GE for correct key (46): 13.0)
# KR: 64 | GE for correct key (46): 13.0)
# KR: 65 | GE for correct key (46): 13.0)
# KR: 66 | GE for correct key (46): 13.0)
# KR: 67 | GE for correct key (46): 13.0)
# KR: 68 | GE for correct key (46): 13.0)
# KR: 69 | GE for correct key (46): 13.0)
# KR: 70 | GE for correct key (46): 13.0)
# KR: 71 | GE for correct key (46): 13.0)
# KR: 72 | GE for correct key (46): 13.0)
# KR: 73 | GE for correct key (46): 13.0)
# KR: 74 | GE for correct key (46): 13.0)
# KR: 75 | GE for correct key (46): 13.0)
# KR: 76 | GE for correct key (46): 13.0)
# KR: 77 | GE for correct key (46): 13.0)
# KR: 78 | GE for correct key (46): 13.0)
# KR: 79 | GE for correct key (46): 13.0)
# KR: 80 | GE for correct key (46): 13.0)
# KR: 81 | GE for correct key (46): 13.0)
# KR: 82 | GE for correct key (46): 13.0)
# KR: 83 | GE for correct key (46): 13.0)
# KR: 84 | GE for correct key (46): 13.0)
# KR: 85 | GE for correct key (46): 13.0)
# KR: 86 | GE for correct key (46): 13.0)
# KR: 87 | GE for correct key (46): 13.0)
# KR: 88 | GE for correct key (46): 13.0)
# KR: 89 | GE for correct key (46): 13.0)
# KR: 90 | GE for correct key (46): 13.0)
# KR: 91 | GE for correct key (46): 13.0)
# KR: 92 | GE for correct key (46): 13.0)
# KR: 93 | GE for correct key (46): 13.0)
# KR: 94 | GE for correct key (46): 13.0)
# KR: 95 | GE for correct key (46): 13.0)
# KR: 96 | GE for correct key (46): 13.0)
# KR: 97 | GE for correct key (46): 13.0)
# KR: 98 | GE for correct key (46): 13.0)
# KR: 99 | GE for correct key (46): 13.0)
# KR: 0 | GE for correct key (46): 1.0)
# KR: 1 | GE for correct key (46): 1.0)
# KR: 2 | GE for correct key (46): 1.0)
# KR: 3 | GE for correct key (46): 1.0)
# KR: 4 | GE for correct key (46): 1.0)
# KR: 5 | GE for correct key (46): 1.0)
# KR: 6 | GE for correct key (46): 1.0)
# KR: 7 | GE for correct key (46): 1.0)
# KR: 8 | GE for correct key (46): 1.0)
# KR: 9 | GE for correct key (46): 1.0)
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 600)               1320600
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,777,209
# Trainable params: 2,772,809
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 6s 19ms/step - loss: 1.3567 - accuracy: 0.4806 - val_loss: 2.0177 - val_accuracy: 0.1732
# Epoch 2/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.9309 - accuracy: 0.6278 - val_loss: 2.1613 - val_accuracy: 0.2036
# Epoch 3/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.7694 - accuracy: 0.6941 - val_loss: 2.2637 - val_accuracy: 0.1808
# Epoch 4/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.6643 - accuracy: 0.7358 - val_loss: 2.4957 - val_accuracy: 0.2124
# Epoch 5/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.5838 - accuracy: 0.7673 - val_loss: 2.5631 - val_accuracy: 0.1980
# Epoch 6/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.5209 - accuracy: 0.7950 - val_loss: 2.7645 - val_accuracy: 0.1996
# Epoch 7/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.4591 - accuracy: 0.8209 - val_loss: 2.7944 - val_accuracy: 0.2004
# Epoch 8/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.4165 - accuracy: 0.8390 - val_loss: 3.1875 - val_accuracy: 0.1928
# Epoch 9/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.3874 - accuracy: 0.8528 - val_loss: 3.3730 - val_accuracy: 0.2100
# Epoch 10/10
# 277/277 [==============================] - 5s 19ms/step - loss: 0.3464 - accuracy: 0.8700 - val_loss: 3.2175 - val_accuracy: 0.2288
# KR: 0 | GE for correct key (46): 1.0)
# KR: 1 | GE for correct key (46): 1.0)
# KR: 2 | GE for correct key (46): 1.0)
# KR: 3 | GE for correct key (46): 1.0)
# KR: 4 | GE for correct key (46): 1.0)
# KR: 5 | GE for correct key (46): 1.0)
# KR: 6 | GE for correct key (46): 1.0)
# KR: 7 | GE for correct key (46): 1.0)
# KR: 8 | GE for correct key (46): 1.0)
# KR: 9 | GE for correct key (46): 1.0)
# KR: 10 | GE for correct key (46): 1.0)
# KR: 11 | GE for correct key (46): 1.0)
# KR: 12 | GE for correct key (46): 1.0)
# KR: 13 | GE for correct key (46): 1.0)
# KR: 14 | GE for correct key (46): 1.0)
# KR: 15 | GE for correct key (46): 1.0)
# KR: 16 | GE for correct key (46): 1.0)
# KR: 17 | GE for correct key (46): 1.0)
# KR: 18 | GE for correct key (46): 1.0)
# KR: 19 | GE for correct key (46): 1.0)
# KR: 20 | GE for correct key (46): 1.0)
# KR: 21 | GE for correct key (46): 1.0)
# KR: 22 | GE for correct key (46): 1.0)
# KR: 23 | GE for correct key (46): 1.0)
# KR: 24 | GE for correct key (46): 1.0)
# KR: 25 | GE for correct key (46): 1.0)
# KR: 26 | GE for correct key (46): 1.0)
# KR: 27 | GE for correct key (46): 1.0)
# KR: 28 | GE for correct key (46): 1.0)
# KR: 29 | GE for correct key (46): 1.0)
# KR: 30 | GE for correct key (46): 1.0)
# KR: 31 | GE for correct key (46): 1.0)
# KR: 32 | GE for correct key (46): 1.0)
# KR: 33 | GE for correct key (46): 1.0)
# KR: 34 | GE for correct key (46): 1.0)
# KR: 35 | GE for correct key (46): 1.0)
# KR: 36 | GE for correct key (46): 1.0)
# KR: 37 | GE for correct key (46): 1.0)
# KR: 38 | GE for correct key (46): 1.0)
# KR: 39 | GE for correct key (46): 1.0)
# KR: 40 | GE for correct key (46): 1.0)
# KR: 41 | GE for correct key (46): 1.0)
# KR: 42 | GE for correct key (46): 1.0)
# KR: 43 | GE for correct key (46): 1.0)
# KR: 44 | GE for correct key (46): 1.0)
# KR: 45 | GE for correct key (46): 1.0)
# KR: 46 | GE for correct key (46): 1.0)
# KR: 47 | GE for correct key (46): 1.0)
# KR: 48 | GE for correct key (46): 1.0)
# KR: 49 | GE for correct key (46): 1.0)
# KR: 50 | GE for correct key (46): 1.0)
# KR: 51 | GE for correct key (46): 1.0)
# KR: 52 | GE for correct key (46): 1.0)
# KR: 53 | GE for correct key (46): 1.0)
# KR: 54 | GE for correct key (46): 1.0)
# KR: 55 | GE for correct key (46): 1.0)
# KR: 56 | GE for correct key (46): 1.0)
# KR: 57 | GE for correct key (46): 1.0)
# KR: 58 | GE for correct key (46): 1.0)
# KR: 59 | GE for correct key (46): 1.0)
# KR: 60 | GE for correct key (46): 1.0)
# KR: 61 | GE for correct key (46): 1.0)
# KR: 62 | GE for correct key (46): 1.0)
# KR: 63 | GE for correct key (46): 1.0)
# KR: 64 | GE for correct key (46): 1.0)
# KR: 65 | GE for correct key (46): 1.0)
# KR: 66 | GE for correct key (46): 1.0)
# KR: 67 | GE for correct key (46): 1.0)
# KR: 68 | GE for correct key (46): 1.0)
# KR: 69 | GE for correct key (46): 1.0)
# KR: 70 | GE for correct key (46): 1.0)
# KR: 71 | GE for correct key (46): 1.0)
# KR: 72 | GE for correct key (46): 1.0)
# KR: 73 | GE for correct key (46): 1.0)
# KR: 74 | GE for correct key (46): 1.0)
# KR: 75 | GE for correct key (46): 1.0)
# KR: 76 | GE for correct key (46): 1.0)
# KR: 77 | GE for correct key (46): 1.0)
# KR: 78 | GE for correct key (46): 1.0)
# KR: 79 | GE for correct key (46): 1.0)
# KR: 80 | GE for correct key (46): 1.0)
# KR: 81 | GE for correct key (46): 1.0)
# KR: 82 | GE for correct key (46): 1.0)
# KR: 83 | GE for correct key (46): 1.0)
# KR: 84 | GE for correct key (46): 1.0)
# KR: 85 | GE for correct key (46): 1.0)
# KR: 86 | GE for correct key (46): 1.0)
# KR: 87 | GE for correct key (46): 1.0)
# KR: 88 | GE for correct key (46): 1.0)
# KR: 89 | GE for correct key (46): 1.0)
# KR: 90 | GE for correct key (46): 1.0)
# KR: 91 | GE for correct key (46): 1.0)
# KR: 92 | GE for correct key (46): 1.0)
# KR: 93 | GE for correct key (46): 1.0)
# KR: 94 | GE for correct key (46): 1.0)
# KR: 95 | GE for correct key (46): 1.0)
# KR: 96 | GE for correct key (46): 1.0)
# KR: 97 | GE for correct key (46): 1.0)
# KR: 98 | GE for correct key (46): 1.0)
# KR: 99 | GE for correct key (46): 1.0)
# KR: 0 | GE for correct key (46): 8.0)
# KR: 1 | GE for correct key (46): 8.0)
# KR: 2 | GE for correct key (46): 8.0)
# KR: 3 | GE for correct key (46): 8.0)
# KR: 4 | GE for correct key (46): 8.0)
# KR: 5 | GE for correct key (46): 8.0)
# KR: 6 | GE for correct key (46): 8.0)
# KR: 7 | GE for correct key (46): 8.0)
# KR: 8 | GE for correct key (46): 8.0)
# KR: 9 | GE for correct key (46): 8.0)
# KR: 10 | GE for correct key (46): 8.0)
# KR: 11 | GE for correct key (46): 8.0)
# KR: 12 | GE for correct key (46): 8.0)
# KR: 13 | GE for correct key (46): 8.0)
# KR: 14 | GE for correct key (46): 8.0)
# KR: 15 | GE for correct key (46): 8.0)
# KR: 16 | GE for correct key (46): 8.0)
# KR: 17 | GE for correct key (46): 8.0)
# KR: 18 | GE for correct key (46): 8.0)
# KR: 19 | GE for correct key (46): 8.0)
# KR: 20 | GE for correct key (46): 8.0)
# KR: 21 | GE for correct key (46): 8.0)
# KR: 22 | GE for correct key (46): 8.0)
# KR: 23 | GE for correct key (46): 8.0)
# KR: 24 | GE for correct key (46): 8.0)
# KR: 25 | GE for correct key (46): 8.0)
# KR: 26 | GE for correct key (46): 8.0)
# KR: 27 | GE for correct key (46): 8.0)
# KR: 28 | GE for correct key (46): 8.0)
# KR: 29 | GE for correct key (46): 8.0)
# KR: 30 | GE for correct key (46): 8.0)
# KR: 31 | GE for correct key (46): 8.0)
# KR: 32 | GE for correct key (46): 8.0)
# KR: 33 | GE for correct key (46): 8.0)
# KR: 34 | GE for correct key (46): 8.0)
# KR: 35 | GE for correct key (46): 8.0)
# KR: 36 | GE for correct key (46): 8.0)
# KR: 37 | GE for correct key (46): 8.0)
# KR: 38 | GE for correct key (46): 8.0)
# KR: 39 | GE for correct key (46): 8.0)
# KR: 40 | GE for correct key (46): 8.0)
# KR: 41 | GE for correct key (46): 8.0)
# KR: 42 | GE for correct key (46): 8.0)
# KR: 43 | GE for correct key (46): 8.0)
# KR: 44 | GE for correct key (46): 8.0)
# KR: 45 | GE for correct key (46): 8.0)
# KR: 46 | GE for correct key (46): 8.0)
# KR: 47 | GE for correct key (46): 8.0)
# KR: 48 | GE for correct key (46): 8.0)
# KR: 49 | GE for correct key (46): 8.0)
# KR: 50 | GE for correct key (46): 8.0)
# KR: 51 | GE for correct key (46): 8.0)
# KR: 52 | GE for correct key (46): 8.0)
# KR: 53 | GE for correct key (46): 8.0)
# KR: 54 | GE for correct key (46): 8.0)
# KR: 55 | GE for correct key (46): 8.0)
# KR: 56 | GE for correct key (46): 8.0)
# KR: 57 | GE for correct key (46): 8.0)
# KR: 58 | GE for correct key (46): 8.0)
# KR: 59 | GE for correct key (46): 8.0)
# KR: 60 | GE for correct key (46): 8.0)
# KR: 61 | GE for correct key (46): 8.0)
# KR: 62 | GE for correct key (46): 8.0)
# KR: 63 | GE for correct key (46): 8.0)
# KR: 64 | GE for correct key (46): 8.0)
# KR: 65 | GE for correct key (46): 8.0)
# KR: 66 | GE for correct key (46): 8.0)
# KR: 67 | GE for correct key (46): 8.0)
# KR: 68 | GE for correct key (46): 8.0)
# KR: 69 | GE for correct key (46): 8.0)
# KR: 70 | GE for correct key (46): 8.0)
# KR: 71 | GE for correct key (46): 8.0)
# KR: 72 | GE for correct key (46): 8.0)
# KR: 73 | GE for correct key (46): 8.0)
# KR: 74 | GE for correct key (46): 8.0)
# KR: 75 | GE for correct key (46): 8.0)
# KR: 76 | GE for correct key (46): 8.0)
# KR: 77 | GE for correct key (46): 8.0)
# KR: 78 | GE for correct key (46): 8.0)
# KR: 79 | GE for correct key (46): 8.0)
# KR: 80 | GE for correct key (46): 8.0)
# KR: 81 | GE for correct key (46): 8.0)
# KR: 82 | GE for correct key (46): 8.0)
# KR: 83 | GE for correct key (46): 8.0)
# KR: 84 | GE for correct key (46): 8.0)
# KR: 85 | GE for correct key (46): 8.0)
# KR: 86 | GE for correct key (46): 8.0)
# KR: 87 | GE for correct key (46): 8.0)
# KR: 88 | GE for correct key (46): 8.0)
# KR: 89 | GE for correct key (46): 8.0)
# KR: 90 | GE for correct key (46): 8.0)
# KR: 91 | GE for correct key (46): 8.0)
# KR: 92 | GE for correct key (46): 8.0)
# KR: 93 | GE for correct key (46): 8.0)
# KR: 94 | GE for correct key (46): 8.0)
# KR: 95 | GE for correct key (46): 8.0)
# KR: 96 | GE for correct key (46): 8.0)
# KR: 97 | GE for correct key (46): 8.0)
# KR: 98 | GE for correct key (46): 8.0)
# KR: 99 | GE for correct key (46): 8.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 2200)             8800
#  ormalization)
#
#  dense (Dense)               (None, 500)               1100500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 500)               250500
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  dense_6 (Dense)             (None, 500)               250500
#
#  dense_7 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 2,616,809
# Trainable params: 2,612,409
# Non-trainable params: 4,400
# _________________________________________________________________
# Epoch 1/10
# 277/277 [==============================] - 6s 21ms/step - loss: 1.4019 - accuracy: 0.4579 - val_loss: 2.0186 - val_accuracy: 0.1712
# Epoch 2/10
# 277/277 [==============================] - 6s 20ms/step - loss: 1.0104 - accuracy: 0.5941 - val_loss: 2.0852 - val_accuracy: 0.1800
# Epoch 3/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.8626 - accuracy: 0.6529 - val_loss: 2.2765 - val_accuracy: 0.1480
# Epoch 4/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.7721 - accuracy: 0.6883 - val_loss: 2.3129 - val_accuracy: 0.1696
# Epoch 5/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.6953 - accuracy: 0.7195 - val_loss: 2.4241 - val_accuracy: 0.1844
# Epoch 6/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.6384 - accuracy: 0.7424 - val_loss: 2.4523 - val_accuracy: 0.1996
# Epoch 7/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.5891 - accuracy: 0.7629 - val_loss: 2.6894 - val_accuracy: 0.1936
# Epoch 8/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.5546 - accuracy: 0.7779 - val_loss: 2.6350 - val_accuracy: 0.1968
# Epoch 9/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.5243 - accuracy: 0.7901 - val_loss: 2.7274 - val_accuracy: 0.1976
# Epoch 10/10
# 277/277 [==============================] - 6s 20ms/step - loss: 0.4978 - accuracy: 0.8027 - val_loss: 2.8853 - val_accuracy: 0.2016
# KR: 0 | GE for correct key (46): 2.0)
# KR: 1 | GE for correct key (46): 2.0)
# KR: 2 | GE for correct key (46): 2.0)
# KR: 3 | GE for correct key (46): 2.0)
# KR: 4 | GE for correct key (46): 2.0)
# KR: 5 | GE for correct key (46): 2.0)
# KR: 6 | GE for correct key (46): 2.0)
# KR: 7 | GE for correct key (46): 2.0)
# KR: 8 | GE for correct key (46): 2.0)
# KR: 9 | GE for correct key (46): 2.0)
# KR: 10 | GE for correct key (46): 2.0)
# KR: 11 | GE for correct key (46): 2.0)
# KR: 12 | GE for correct key (46): 2.0)
# KR: 13 | GE for correct key (46): 2.0)
# KR: 14 | GE for correct key (46): 2.0)
# KR: 15 | GE for correct key (46): 2.0)
# KR: 16 | GE for correct key (46): 2.0)
# KR: 17 | GE for correct key (46): 2.0)
# KR: 18 | GE for correct key (46): 2.0)
# KR: 19 | GE for correct key (46): 2.0)
# KR: 20 | GE for correct key (46): 2.0)
# KR: 21 | GE for correct key (46): 2.0)
# KR: 22 | GE for correct key (46): 2.0)
# KR: 23 | GE for correct key (46): 2.0)
# KR: 24 | GE for correct key (46): 2.0)
# KR: 25 | GE for correct key (46): 2.0)
# KR: 26 | GE for correct key (46): 2.0)
# KR: 27 | GE for correct key (46): 2.0)
# KR: 28 | GE for correct key (46): 2.0)
# KR: 29 | GE for correct key (46): 2.0)
# KR: 30 | GE for correct key (46): 2.0)
# KR: 31 | GE for correct key (46): 2.0)
# KR: 32 | GE for correct key (46): 2.0)
# KR: 33 | GE for correct key (46): 2.0)
# KR: 34 | GE for correct key (46): 2.0)
# KR: 35 | GE for correct key (46): 2.0)
# KR: 36 | GE for correct key (46): 2.0)
# KR: 37 | GE for correct key (46): 2.0)
# KR: 38 | GE for correct key (46): 2.0)
# KR: 39 | GE for correct key (46): 2.0)
# KR: 40 | GE for correct key (46): 2.0)
# KR: 41 | GE for correct key (46): 2.0)
# KR: 42 | GE for correct key (46): 2.0)
# KR: 43 | GE for correct key (46): 2.0)
# KR: 44 | GE for correct key (46): 2.0)
# KR: 45 | GE for correct key (46): 2.0)
# KR: 46 | GE for correct key (46): 2.0)
# KR: 47 | GE for correct key (46): 2.0)
# KR: 48 | GE for correct key (46): 2.0)
# KR: 49 | GE for correct key (46): 2.0)
# KR: 50 | GE for correct key (46): 2.0)
# KR: 51 | GE for correct key (46): 2.0)
# KR: 52 | GE for correct key (46): 2.0)
# KR: 53 | GE for correct key (46): 2.0)
# KR: 54 | GE for correct key (46): 2.0)
# KR: 55 | GE for correct key (46): 2.0)
# KR: 56 | GE for correct key (46): 2.0)
# KR: 57 | GE for correct key (46): 2.0)
# KR: 58 | GE for correct key (46): 2.0)
# KR: 59 | GE for correct key (46): 2.0)
# KR: 60 | GE for correct key (46): 2.0)
# KR: 61 | GE for correct key (46): 2.0)
# KR: 62 | GE for correct key (46): 2.0)
# KR: 63 | GE for correct key (46): 2.0)
# KR: 64 | GE for correct key (46): 2.0)
# KR: 65 | GE for correct key (46): 2.0)
# KR: 66 | GE for correct key (46): 2.0)
# ...
# Run 60 - GE 30 models: 15 | GE 1 models: 72 |
# Run 61 - GE 30 models: 15 | GE 1 models: 71 |
# Run 62 - GE 30 models: 15 | GE 1 models: 71 |
# Run 63 - GE 30 models: 15 | GE 1 models: 70 |
# Run 64 - GE 30 models: 15 | GE 1 models: 69 |
# Run 65 - GE 30 models: 15 | GE 1 models: 68 |
# Run 66 - GE 30 models: 15 | GE 1 models: 67 |
# Run 67 - GE 30 models: 15 | GE 1 models: 66 |
# Run 68 - GE 30 models: 15 | GE 1 models: 66 |
# Run 69 - GE 30 models: 15 | GE 1 models: 66 |
# Run 70 - GE 30 models: 15 | GE 1 models: 67 |
# Run 71 - GE 30 models: 15 | GE 1 models: 66 |
# Run 72 - GE 30 models: 15 | GE 1 models: 66 |
# Run 73 - GE 30 models: 15 | GE 1 models: 65 |
# Run 74 - GE 30 models: 15 | GE 1 models: 64 |
# Run 75 - GE 30 models: 15 | GE 1 models: 64 |
# Run 76 - GE 30 models: 15 | GE 1 models: 64 |
# Run 77 - GE 30 models: 14 | GE 1 models: 64 |
# Run 78 - GE 30 models: 14 | GE 1 models: 65 |
# Run 79 - GE 30 models: 14 | GE 1 models: 66 |
# Run 80 - GE 30 models: 14 | GE 1 models: 65 |
# Run 81 - GE 30 models: 14 | GE 1 models: 65 |
# Run 82 - GE 30 models: 15 | GE 1 models: 65 |
# Run 83 - GE 30 models: 15 | GE 1 models: 65 |
# Run 84 - GE 30 models: 15 | GE 1 models: 65 |
# Run 85 - GE 30 models: 14 | GE 1 models: 64 |
# Run 86 - GE 30 models: 15 | GE 1 models: 64 |
# Run 87 - GE 30 models: 15 | GE 1 models: 65 |
# Run 88 - GE 30 models: 15 | GE 1 models: 65 |
# Run 89 - GE 30 models: 15 | GE 1 models: 65 |
# Run 90 - GE 30 models: 15 | GE 1 models: 65 |
# Run 91 - GE 30 models: 15 | GE 1 models: 66 |
# Run 92 - GE 30 models: 15 | GE 1 models: 67 |
# Run 93 - GE 30 models: 15 | GE 1 models: 67 |
# Run 94 - GE 30 models: 15 | GE 1 models: 66 |
# Run 95 - GE 30 models: 15 | GE 1 models: 65 |
# Run 96 - GE 30 models: 15 | GE 1 models: 65 |
# Run 97 - GE 30 models: 15 | GE 1 models: 65 |
# Run 98 - GE 30 models: 15 | GE 1 models: 64 |
# Run 99 - GE 30 models: 15 | GE 1 models: 64 |
# Run 0 - GE 30 models: 4 | GE 1 models: 2 |
# Run 1 - GE 30 models: 17 | GE 1 models: 5 |
# Run 2 - GE 30 models: 13 | GE 1 models: 74 |
# Run 3 - GE 30 models: 11 | GE 1 models: 83 |
# Run 4 - GE 30 models: 14 | GE 1 models: 110 |
# Run 5 - GE 30 models: 13 | GE 1 models: 96 |
# Run 6 - GE 30 models: 16 | GE 1 models: 109 |
# Run 7 - GE 30 models: 15 | GE 1 models: 115 |
# Run 8 - GE 30 models: 13 | GE 1 models: 106 |
# Run 9 - GE 30 models: 13 | GE 1 models: 98 |
# Run 10 - GE 30 models: 15 | GE 1 models: 100 |
# Run 11 - GE 30 models: 15 | GE 1 models: 101 |
# Run 12 - GE 30 models: 15 | GE 1 models: 94 |
# Run 13 - GE 30 models: 15 | GE 1 models: 98 |
# Run 14 - GE 30 models: 17 | GE 1 models: 106 |
# Run 15 - GE 30 models: 16 | GE 1 models: 102 |
# Run 16 - GE 30 models: 15 | GE 1 models: 96 |
# Run 17 - GE 30 models: 15 | GE 1 models: 101 |
# Run 18 - GE 30 models: 14 | GE 1 models: 98 |
# Run 19 - GE 30 models: 15 | GE 1 models: 93 |
# Run 20 - GE 30 models: 15 | GE 1 models: 95 |
# Run 21 - GE 30 models: 17 | GE 1 models: 97 |
# Run 22 - GE 30 models: 17 | GE 1 models: 94 |
# Run 23 - GE 30 models: 17 | GE 1 models: 92 |
# Run 24 - GE 30 models: 19 | GE 1 models: 90 |
# Run 25 - GE 30 models: 18 | GE 1 models: 90 |
# Run 26 - GE 30 models: 18 | GE 1 models: 88 |
# Run 27 - GE 30 models: 18 | GE 1 models: 89 |
# Run 28 - GE 30 models: 18 | GE 1 models: 86 |
# Run 29 - GE 30 models: 18 | GE 1 models: 84 |
# Run 30 - GE 30 models: 17 | GE 1 models: 83 |
# Run 31 - GE 30 models: 17 | GE 1 models: 84 |
# Run 32 - GE 30 models: 17 | GE 1 models: 82 |
# Run 33 - GE 30 models: 17 | GE 1 models: 83 |
# Run 34 - GE 30 models: 18 | GE 1 models: 81 |
# Run 35 - GE 30 models: 17 | GE 1 models: 83 |
# Run 36 - GE 30 models: 18 | GE 1 models: 82 |
# Run 37 - GE 30 models: 18 | GE 1 models: 82 |
# Run 38 - GE 30 models: 17 | GE 1 models: 80 |
# Run 39 - GE 30 models: 18 | GE 1 models: 79 |
# Run 40 - GE 30 models: 18 | GE 1 models: 80 |
# Run 41 - GE 30 models: 18 | GE 1 models: 81 |
# Run 42 - GE 30 models: 18 | GE 1 models: 79 |
# Run 43 - GE 30 models: 18 | GE 1 models: 78 |
# Run 44 - GE 30 models: 18 | GE 1 models: 76 |
# Run 45 - GE 30 models: 18 | GE 1 models: 77 |
# Run 46 - GE 30 models: 18 | GE 1 models: 77 |
# Run 47 - GE 30 models: 17 | GE 1 models: 76 |
# Run 48 - GE 30 models: 17 | GE 1 models: 76 |
# Run 49 - GE 30 models: 17 | GE 1 models: 75 |
# Run 50 - GE 30 models: 16 | GE 1 models: 76 |
# Run 51 - GE 30 models: 16 | GE 1 models: 75 |
# Run 52 - GE 30 models: 16 | GE 1 models: 74 |
# Run 53 - GE 30 models: 16 | GE 1 models: 75 |
# Run 54 - GE 30 models: 16 | GE 1 models: 75 |
# Run 55 - GE 30 models: 16 | GE 1 models: 74 |
# Run 56 - GE 30 models: 15 | GE 1 models: 74 |
# Run 57 - GE 30 models: 16 | GE 1 models: 74 |
# Run 58 - GE 30 models: 15 | GE 1 models: 73 |
# Run 59 - GE 30 models: 15 | GE 1 models: 72 |
# Run 60 - GE 30 models: 15 | GE 1 models: 72 |
# Run 61 - GE 30 models: 15 | GE 1 models: 71 |
# Run 62 - GE 30 models: 15 | GE 1 models: 71 |
# Run 63 - GE 30 models: 15 | GE 1 models: 70 |
# Run 64 - GE 30 models: 15 | GE 1 models: 69 |
# Run 65 - GE 30 models: 15 | GE 1 models: 68 |
# Run 66 - GE 30 models: 15 | GE 1 models: 67 |
# Run 67 - GE 30 models: 15 | GE 1 models: 66 |
# Run 68 - GE 30 models: 15 | GE 1 models: 66 |
# Run 69 - GE 30 models: 15 | GE 1 models: 66 |
# Run 70 - GE 30 models: 15 | GE 1 models: 67 |
# Run 71 - GE 30 models: 15 | GE 1 models: 66 |
# Run 72 - GE 30 models: 15 | GE 1 models: 66 |
# Run 73 - GE 30 models: 15 | GE 1 models: 65 |
# Run 74 - GE 30 models: 15 | GE 1 models: 64 |
# Run 75 - GE 30 models: 15 | GE 1 models: 64 |
# Run 76 - GE 30 models: 15 | GE 1 models: 64 |
# Run 77 - GE 30 models: 14 | GE 1 models: 64 |
# Run 78 - GE 30 models: 14 | GE 1 models: 65 |
# Run 79 - GE 30 models: 14 | GE 1 models: 66 |
# Run 80 - GE 30 models: 14 | GE 1 models: 65 |
# Run 81 - GE 30 models: 14 | GE 1 models: 65 |
# Run 82 - GE 30 models: 15 | GE 1 models: 65 |
# Run 83 - GE 30 models: 15 | GE 1 models: 65 |
# Run 84 - GE 30 models: 15 | GE 1 models: 65 |
# Run 85 - GE 30 models: 14 | GE 1 models: 64 |
# Run 86 - GE 30 models: 15 | GE 1 models: 64 |
# Run 87 - GE 30 models: 15 | GE 1 models: 65 |
# Run 88 - GE 30 models: 15 | GE 1 models: 65 |
# Run 89 - GE 30 models: 15 | GE 1 models: 65 |
# Run 90 - GE 30 models: 15 | GE 1 models: 65 |
# Run 91 - GE 30 models: 15 | GE 1 models: 66 |
# Run 92 - GE 30 models: 15 | GE 1 models: 67 |
# Run 93 - GE 30 models: 15 | GE 1 models: 67 |
# Run 94 - GE 30 models: 15 | GE 1 models: 66 |
# Run 95 - GE 30 models: 15 | GE 1 models: 65 |
# Run 96 - GE 30 models: 15 | GE 1 models: 65 |
# Run 97 - GE 30 models: 15 | GE 1 models: 65 |
# Run 98 - GE 30 models: 15 | GE 1 models: 64 |
# Run 99 - GE 30 models: 15 | GE 1 models: 64 |
# Run 0 - GE 30 models: 4 | GE 1 models: 2 |
# Run 1 - GE 30 models: 17 | GE 1 models: 5 |
# Run 2 - GE 30 models: 13 | GE 1 models: 74 |
# Run 3 - GE 30 models: 11 | GE 1 models: 83 |
# Run 4 - GE 30 models: 14 | GE 1 models: 110 |
# Run 5 - GE 30 models: 13 | GE 1 models: 96 |
# Run 6 - GE 30 models: 16 | GE 1 models: 109 |
# Run 7 - GE 30 models: 15 | GE 1 models: 115 |
# Run 8 - GE 30 models: 13 | GE 1 models: 106 |
# Run 9 - GE 30 models: 13 | GE 1 models: 98 |
# Run 10 - GE 30 models: 15 | GE 1 models: 100 |
# Run 11 - GE 30 models: 15 | GE 1 models: 101 |
# Run 12 - GE 30 models: 15 | GE 1 models: 94 |
# Run 13 - GE 30 models: 15 | GE 1 models: 98 |
# Run 14 - GE 30 models: 17 | GE 1 models: 106 |
# Run 15 - GE 30 models: 16 | GE 1 models: 102 |
# Run 16 - GE 30 models: 15 | GE 1 models: 96 |
# Run 17 - GE 30 models: 15 | GE 1 models: 101 |
# Run 18 - GE 30 models: 14 | GE 1 models: 98 |
# Run 19 - GE 30 models: 15 | GE 1 models: 93 |
# Run 20 - GE 30 models: 15 | GE 1 models: 95 |
# Run 21 - GE 30 models: 17 | GE 1 models: 97 |
# Run 22 - GE 30 models: 17 | GE 1 models: 94 |
# Run 23 - GE 30 models: 17 | GE 1 models: 92 |
# Run 24 - GE 30 models: 19 | GE 1 models: 90 |
# Run 25 - GE 30 models: 18 | GE 1 models: 90 |
# Run 26 - GE 30 models: 18 | GE 1 models: 88 |
# Run 27 - GE 30 models: 18 | GE 1 models: 89 |
# Run 28 - GE 30 models: 18 | GE 1 models: 86 |
# Run 29 - GE 30 models: 18 | GE 1 models: 84 |
# Run 30 - GE 30 models: 17 | GE 1 models: 83 |
# Run 31 - GE 30 models: 17 | GE 1 models: 84 |
# Run 32 - GE 30 models: 17 | GE 1 models: 82 |
# Run 33 - GE 30 models: 17 | GE 1 models: 83 |
# Run 34 - GE 30 models: 18 | GE 1 models: 81 |
# Run 35 - GE 30 models: 17 | GE 1 models: 83 |
# Run 36 - GE 30 models: 18 | GE 1 models: 82 |
# Run 37 - GE 30 models: 18 | GE 1 models: 82 |
# Run 38 - GE 30 models: 17 | GE 1 models: 80 |
# Run 39 - GE 30 models: 18 | GE 1 models: 79 |
# Run 40 - GE 30 models: 18 | GE 1 models: 80 |
# Run 41 - GE 30 models: 18 | GE 1 models: 81 |
# Run 42 - GE 30 models: 18 | GE 1 models: 79 |
# Run 43 - GE 30 models: 18 | GE 1 models: 78 |
# Run 44 - GE 30 models: 18 | GE 1 models: 76 |
# Run 45 - GE 30 models: 18 | GE 1 models: 77 |
# Run 46 - GE 30 models: 18 | GE 1 models: 77 |
# Run 47 - GE 30 models: 17 | GE 1 models: 76 |
# Run 48 - GE 30 models: 17 | GE 1 models: 76 |
# Run 49 - GE 30 models: 17 | GE 1 models: 75 |
# Run 50 - GE 30 models: 16 | GE 1 models: 76 |
# Run 51 - GE 30 models: 16 | GE 1 models: 75 |
# Run 52 - GE 30 models: 16 | GE 1 models: 74 |
# Run 53 - GE 30 models: 16 | GE 1 models: 75 |
# Run 54 - GE 30 models: 16 | GE 1 models: 75 |
# Run 55 - GE 30 models: 16 | GE 1 models: 74 |
# Run 56 - GE 30 models: 15 | GE 1 models: 74 |
# Run 57 - GE 30 models: 16 | GE 1 models: 74 |
# Run 58 - GE 30 models: 15 | GE 1 models: 73 |
# Run 59 - GE 30 models: 15 | GE 1 models: 72 |
# Run 60 - GE 30 models: 15 | GE 1 models: 72 |
# Run 61 - GE 30 models: 15 | GE 1 models: 71 |
# Run 62 - GE 30 models: 15 | GE 1 models: 71 |
# Run 63 - GE 30 models: 15 | GE 1 models: 70 |
# Run 64 - GE 30 models: 15 | GE 1 models: 69 |
# Run 65 - GE 30 models: 15 | GE 1 models: 68 |
# Run 66 - GE 30 models: 15 | GE 1 models: 67 |
# Run 67 - GE 30 models: 15 | GE 1 models: 66 |
# Run 68 - GE 30 models: 15 | GE 1 models: 66 |
# Run 69 - GE 30 models: 15 | GE 1 models: 66 |
# Run 70 - GE 30 models: 15 | GE 1 models: 67 |
# Run 71 - GE 30 models: 15 | GE 1 models: 66 |
# Run 72 - GE 30 models: 15 | GE 1 models: 66 |
# Run 73 - GE 30 models: 15 | GE 1 models: 65 |
# Run 74 - GE 30 models: 15 | GE 1 models: 64 |
# Run 75 - GE 30 models: 15 | GE 1 models: 64 |
# Run 76 - GE 30 models: 15 | GE 1 models: 64 |
# Run 77 - GE 30 models: 14 | GE 1 models: 64 |
# Run 78 - GE 30 models: 14 | GE 1 models: 65 |
# Run 79 - GE 30 models: 14 | GE 1 models: 66 |
# Run 80 - GE 30 models: 14 | GE 1 models: 65 |
# Run 81 - GE 30 models: 14 | GE 1 models: 65 |
# Run 82 - GE 30 models: 15 | GE 1 models: 65 |
# Run 83 - GE 30 models: 15 | GE 1 models: 65 |
# Run 84 - GE 30 models: 15 | GE 1 models: 65 |
# Run 85 - GE 30 models: 14 | GE 1 models: 64 |
# Run 86 - GE 30 models: 15 | GE 1 models: 64 |
# Run 87 - GE 30 models: 15 | GE 1 models: 65 |
# Run 88 - GE 30 models: 15 | GE 1 models: 65 |
# Run 89 - GE 30 models: 15 | GE 1 models: 65 |
# Run 90 - GE 30 models: 15 | GE 1 models: 65 |
# Run 91 - GE 30 models: 15 | GE 1 models: 66 |
# Run 92 - GE 30 models: 15 | GE 1 models: 67 |
# Run 93 - GE 30 models: 15 | GE 1 models: 67 |
# Run 94 - GE 30 models: 15 | GE 1 models: 66 |
# Run 95 - GE 30 models: 15 | GE 1 models: 65 |
# Run 96 - GE 30 models: 15 | GE 1 models: 65 |
# Run 97 - GE 30 models: 15 | GE 1 models: 65 |
# Run 98 - GE 30 models: 15 | GE 1 models: 64 |
# Run 99 - GE 30 models: 15 | GE 1 models: 64 |
# Run 0 - GE 30 models: 4 | GE 1 models: 2 |
# Run 1 - GE 30 models: 17 | GE 1 models: 5 |
# Run 2 - GE 30 models: 13 | GE 1 models: 74 |
# Run 3 - GE 30 models: 11 | GE 1 models: 83 |
# Run 4 - GE 30 models: 14 | GE 1 models: 110 |
# Run 5 - GE 30 models: 13 | GE 1 models: 96 |
# Run 6 - GE 30 models: 16 | GE 1 models: 109 |
# Run 7 - GE 30 models: 15 | GE 1 models: 115 |
# Run 8 - GE 30 models: 13 | GE 1 models: 106 |
# Run 9 - GE 30 models: 13 | GE 1 models: 98 |
# Run 10 - GE 30 models: 15 | GE 1 models: 100 |
# Run 11 - GE 30 models: 15 | GE 1 models: 101 |
# Run 12 - GE 30 models: 15 | GE 1 models: 94 |
# Run 13 - GE 30 models: 15 | GE 1 models: 98 |
# Run 14 - GE 30 models: 17 | GE 1 models: 106 |
# Run 15 - GE 30 models: 16 | GE 1 models: 102 |
# Run 16 - GE 30 models: 15 | GE 1 models: 96 |
# Run 17 - GE 30 models: 15 | GE 1 models: 101 |
# Run 18 - GE 30 models: 14 | GE 1 models: 98 |
# Run 19 - GE 30 models: 15 | GE 1 models: 93 |
# Run 20 - GE 30 models: 15 | GE 1 models: 95 |
# Run 21 - GE 30 models: 17 | GE 1 models: 97 |
# Run 22 - GE 30 models: 17 | GE 1 models: 94 |
# Run 23 - GE 30 models: 17 | GE 1 models: 92 |
# Run 24 - GE 30 models: 19 | GE 1 models: 90 |
# Run 25 - GE 30 models: 18 | GE 1 models: 90 |
# Run 26 - GE 30 models: 18 | GE 1 models: 88 |
# Run 27 - GE 30 models: 18 | GE 1 models: 89 |
# Run 28 - GE 30 models: 18 | GE 1 models: 86 |
# Run 29 - GE 30 models: 18 | GE 1 models: 84 |
# Run 30 - GE 30 models: 17 | GE 1 models: 83 |
# Run 31 - GE 30 models: 17 | GE 1 models: 84 |
# Run 32 - GE 30 models: 17 | GE 1 models: 82 |
# Run 33 - GE 30 models: 17 | GE 1 models: 83 |
# Run 34 - GE 30 models: 18 | GE 1 models: 81 |
# Run 35 - GE 30 models: 17 | GE 1 models: 83 |
# Run 36 - GE 30 models: 18 | GE 1 models: 82 |
# Run 37 - GE 30 models: 18 | GE 1 models: 82 |
# Run 38 - GE 30 models: 17 | GE 1 models: 80 |
# Run 39 - GE 30 models: 18 | GE 1 models: 79 |
# Run 40 - GE 30 models: 18 | GE 1 models: 80 |
# Run 41 - GE 30 models: 18 | GE 1 models: 81 |
# Run 42 - GE 30 models: 18 | GE 1 models: 79 |
# Run 43 - GE 30 models: 18 | GE 1 models: 78 |
# Run 44 - GE 30 models: 18 | GE 1 models: 76 |
# Run 45 - GE 30 models: 18 | GE 1 models: 77 |
# Run 46 - GE 30 models: 18 | GE 1 models: 77 |
# Run 47 - GE 30 models: 17 | GE 1 models: 76 |
# Run 48 - GE 30 models: 17 | GE 1 models: 76 |
# Run 49 - GE 30 models: 17 | GE 1 models: 75 |
# Run 50 - GE 30 models: 16 | GE 1 models: 76 |
# Run 51 - GE 30 models: 16 | GE 1 models: 75 |
# Run 52 - GE 30 models: 16 | GE 1 models: 74 |
# Run 53 - GE 30 models: 16 | GE 1 models: 75 |
# Run 54 - GE 30 models: 16 | GE 1 models: 75 |
# Run 55 - GE 30 models: 16 | GE 1 models: 74 |
# Run 56 - GE 30 models: 15 | GE 1 models: 74 |
# Run 57 - GE 30 models: 16 | GE 1 models: 74 |
# Run 58 - GE 30 models: 15 | GE 1 models: 73 |
# Run 59 - GE 30 models: 15 | GE 1 models: 72 |
# Run 60 - GE 30 models: 15 | GE 1 models: 72 |
# Run 61 - GE 30 models: 15 | GE 1 models: 71 |
# Run 62 - GE 30 models: 15 | GE 1 models: 71 |
# Run 63 - GE 30 models: 15 | GE 1 models: 70 |
# Run 64 - GE 30 models: 15 | GE 1 models: 69 |
# Run 65 - GE 30 models: 15 | GE 1 models: 68 |
# Run 66 - GE 30 models: 15 | GE 1 models: 67 |
# Run 67 - GE 30 models: 15 | GE 1 models: 66 |
# Run 68 - GE 30 models: 15 | GE 1 models: 66 |
# Run 69 - GE 30 models: 15 | GE 1 models: 66 |
# Run 70 - GE 30 models: 15 | GE 1 models: 67 |
# Run 71 - GE 30 models: 15 | GE 1 models: 66 |
# Run 72 - GE 30 models: 15 | GE 1 models: 66 |
# Run 73 - GE 30 models: 15 | GE 1 models: 65 |
# Run 74 - GE 30 models: 15 | GE 1 models: 64 |
# Run 75 - GE 30 models: 15 | GE 1 models: 64 |
# Run 76 - GE 30 models: 15 | GE 1 models: 64 |
# Run 77 - GE 30 models: 14 | GE 1 models: 64 |
# Run 78 - GE 30 models: 14 | GE 1 models: 65 |
# Run 79 - GE 30 models: 14 | GE 1 models: 66 |
# Run 80 - GE 30 models: 14 | GE 1 models: 65 |
# Run 81 - GE 30 models: 14 | GE 1 models: 65 |
# Run 82 - GE 30 models: 15 | GE 1 models: 65 |
# Run 83 - GE 30 models: 15 | GE 1 models: 65 |
# Run 84 - GE 30 models: 15 | GE 1 models: 65 |
# Run 85 - GE 30 models: 14 | GE 1 models: 64 |
# Run 86 - GE 30 models: 15 | GE 1 models: 64 |
# Run 87 - GE 30 models: 15 | GE 1 models: 65 |
# Run 88 - GE 30 models: 15 | GE 1 models: 65 |
# Run 89 - GE 30 models: 15 | GE 1 models: 65 |
# Run 90 - GE 30 models: 15 | GE 1 models: 65 |
# Run 91 - GE 30 models: 15 | GE 1 models: 66 |
# Run 92 - GE 30 models: 15 | GE 1 models: 67 |
# Run 93 - GE 30 models: 15 | GE 1 models: 67 |
# Run 94 - GE 30 models: 15 | GE 1 models: 66 |
# Run 95 - GE 30 models: 15 | GE 1 models: 65 |
# Run 96 - GE 30 models: 15 | GE 1 models: 65 |
# Run 97 - GE 30 models: 15 | GE 1 models: 65 |
# Run 98 - GE 30 models: 15 | GE 1 models: 64 |
# Run 99 - GE 30 models: 15 | GE 1 models: 64 |

# %%
ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
ensemble_aes.run_ensemble(number_of_models=50, number_of_best_models=10)

# plotting GE and SR
plt.subplot(1, 2, 1)
plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.show()

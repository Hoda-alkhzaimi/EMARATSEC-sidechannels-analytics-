# %%
import sys
import os
from tensorflow.keras import backend as backend
from tensorflow.keras.utils import to_categorical
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import tensorflow as tf

#!cp /content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py/
#file_location = "/content/drive/MyDrive/Colab\ Notebooks/QEResearch/ches_ctf/sca_metrics.py"
#sys.path.append(os.path.abspath(file_location))
#sys.path.insert(0,'/content/drive/MyDrive/Colab\Notebooks/QEResearch/ches_ctf/')
#sys.path.append('/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf')
#import SCAMetrics
# Out:
# Mounted at /content/drive

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1E9kCFN_Qf6720hbw996x6z0xUSLqQwjg'})

# %%
# !pip install import-ipynb
import import_ipynb

# !pip install -U -q PyDrive
#your_module.GetContentFile('sca_metrics.ipynb')
#from sca_metrics import *
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
#your_module = drive.CreateFile({'id':'11WgfAW1xTNRX_tl74AcFCnJNh6hhjtrQ'})
your_module = drive.CreateFile({'id':'1t5viOwM1THtGwwGzxVIO1hvrroYqvGdA'})
your_module.GetContentFile('sca_metrics.py') 
import sca_metrics
from sca_metrics import SCAMetrics
#your_module.GetContentFile({'id':'16R_OCUvUjNXD3hnk_XvW0H2CR-MtbpeI'})

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm'})
your_module.GetContentFile('loaddataset.py') #13XQlHNSBzOV7jPlTvAxmC2U3G3MtQvVm
import loaddataset
from loaddataset import LoadDatasets

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'14CorI66D0y0P-4eXCStsl90Avpb-xtUM'})
your_module.GetContentFile('datasets.py') #14CorI66D0y0P-4eXCStsl90Avpb-xtUM
import datasets
from datasets import SCADatasets

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Authenticate Google Drive Access
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Linking Colab Notebook to the Module
your_module = drive.CreateFile({'id':'1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd'})
your_module.GetContentFile('neural_networks.py') #1-FN6v9o_gRLvKjr0Bof9rWuYCnSI7HPd
import neural_networks
from neural_networks import NeuralNetwork

# %%
import numpy as np
import random


class EnsembleAES:

    def __init__(self):
        self.number_of_models = 30
        self.number_of_best_models = [10, 10, 10, 10]
        self.ge_all_validation = []
        self.ge_all_attack = []
        self.sr_all_validation = []
        self.sr_all_attack = []
        self.k_ps_all = []
        self.ge_ensemble = None
        self.ge_ensemble_best_models = None
        self.ge_ensemble_best_models0 = None #added
        self.ge_ensemble_best_models1 = None #added
        self.ge_ensemble_best_models2 = None #added
        self.ge_ensemble_best_models3 = None #added
        self.ge_best_model_validation = None
        self.ge_best_model_attack = None
        self.sr_ensemble = None
        self.sr_ensemble_best_models = None
        self.sr_ensemble_best_models0 = None #added
        self.sr_ensemble_best_models1 = None #added
        self.sr_ensemble_best_models2 = None #added
        self.sr_ensemble_best_models3 = None #added
        self.sr_best_model_validation = None
        self.sr_best_model_attack = None
        self.target_dataset = None
        self.l_model = None
        self.target_byte = None
        self.classes = None
        self.epochs = None
        self.mini_batch = None

    def set_dataset(self, target): #function for setting up dataset - ASCAD | ches_ctf
        self.target_dataset = target

    def set_leakage_model(self, leakage_model): #function for setting up leakage model
        self.l_model = leakage_model
        if leakage_model == "HW":
            self.classes = 9
        else:
            self.classes = 256

    def set_target_byte(self, target_byte): #target byte to attack: most of the time, this is 3
        self.target_byte = target_byte

    def set_epochs(self, epochs): #we set no of epochs for our training model
        self.epochs = epochs

    def set_mini_batch(self, mini_batch): #not sure of mini_batch. I guess it means batch
        self.mini_batch = mini_batch

    def __add_if_one(self, value): #don't know when this will be useful
        return 1 if value == 1 else 0

    def get_best_models(self, n_models, result_models_validation, n_traces):
        result_number_of_traces_val = []                      #best models is ranked by guessing entropy traces (when it's equal 1)
        for model_index in range(n_models):
            if result_models_validation[model_index][n_traces - 1] == 1: #checking for the best model starting from the last (min) trace
                for index in range(n_traces - 1, -1, -1):           #decrementing and moving up the trace
                    if result_models_validation[model_index][index] != 1:
                        result_number_of_traces_val.append(
                            [result_models_validation[model_index][n_traces - 1], index + 1,
                             model_index])
                        break
            else:
                result_number_of_traces_val.append(
                    [result_models_validation[model_index][n_traces - 1], n_traces,
                     model_index])

        sorted_models = sorted(result_number_of_traces_val, key=lambda l: l[:]) #sort by 

        list_of_best_models = []
        for model_index in range(n_models):
            list_of_best_models.append(sorted_models[model_index][2])

        return list_of_best_models

    def run_mlp(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)

        model = NeuralNetwork().mlp_random(self.classes, params["number_of_samples"], activation, neurons, layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),
            callbacks=[])

        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation, step, fraction)
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def run_cnn(self, X_profiling, Y_profiling, X_validation, Y_validation, X_attack, Y_attack, plt_validation, plt_attack, params,
                step, fraction):
        X_profiling = X_profiling.reshape((X_profiling.shape[0], X_profiling.shape[1], 1))
        X_validation = X_validation.reshape((X_validation.shape[0], X_validation.shape[1], 1))
        X_attack = X_attack.reshape((X_attack.shape[0], X_attack.shape[1], 1))

        mini_batch = random.randrange(500, 1000, 100)
        learning_rate = random.uniform(0.0001, 0.001)
        activation = ['relu', 'tanh', 'elu', 'selu'][random.randint(0, 3)]
        dense_layers = random.randrange(2, 8, 1)
        neurons = random.randrange(500, 800, 100)
        conv_layers = random.randrange(1, 2, 1)
        filters = random.randrange(8, 32, 4)
        kernel_size = random.randrange(10, 20, 2)
        stride = random.randrange(5, 10, 5)

        model = NeuralNetwork().cnn_random(self.classes, params["number_of_samples"], activation, neurons, conv_layers, filters,
                                           kernel_size, stride, dense_layers, learning_rate)
        model.fit(
            x=X_profiling,
            y=Y_profiling,
            batch_size=self.mini_batch,
            verbose=1,
            epochs=self.epochs,
            shuffle=True,
            validation_data=(X_validation, Y_validation),
            callbacks=[])
                                                                      #100 is for number of runs
        ge_validation, sr_validation, kp_krs = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte,
                                                                      X_validation, plt_validation,
                                                                      step, fraction)
        ge_attack, sr_attack, _ = SCAMetrics().ge_and_sr(100, model, params, self.l_model, self.target_byte, X_attack, plt_attack, step,
                                                         fraction)

        backend.clear_session()

        return ge_validation, ge_attack, sr_validation, sr_attack, kp_krs

    def compute_ensembles(self, kr_nt, correct_key):
       #nm = number_of_models
      list_of_best_models = self.get_best_models(self.number_of_models, self.ge_all_validation, kr_nt) #i added

      self.ge_best_model_validation = self.ge_all_validation[list_of_best_models[0]]
      self.ge_best_model_attack = self.ge_all_attack[list_of_best_models[0]]
      self.sr_best_model_validation = self.sr_all_validation[list_of_best_models[0]]
      self.sr_best_model_attack = self.sr_all_attack[list_of_best_models[0]]

      for i in range(4): #added

          kr_ensemble = np.zeros(kr_nt)
          krs_ensemble = np.zeros((100, kr_nt))
          kr_ensemble_best_models = np.zeros(kr_nt)
          krs_ensemble_best_models = np.zeros((100, kr_nt))

          for run in range(100):

              key_p_ensemble = np.zeros(256)
              key_p_ensemble_best_models = np.zeros(256)

              for index in range(kr_nt):
                  for model_index in range(self.number_of_models):
                      key_p_ensemble += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)
                  for model_index in range(self.number_of_best_models[i]): #i added
                      key_p_ensemble_best_models += np.log(self.k_ps_all[list_of_best_models[model_index]][run][index] + 1e-36)

                  key_p_ensemble_sorted = np.argsort(key_p_ensemble)[::-1]
                  key_p_ensemble_best_models_sorted = np.argsort(key_p_ensemble_best_models)[::-1]

                  kr_position = list(key_p_ensemble_sorted).index(correct_key) + 1
                  kr_ensemble[index] += kr_position
                  krs_ensemble[run][index] = kr_position

                  kr_position = list(key_p_ensemble_best_models_sorted).index(correct_key) + 1
                  kr_ensemble_best_models[index] += kr_position
                  krs_ensemble_best_models[run][index] = kr_position

              print("Run {} - GE {} models: {} | GE {} models: {} | ".format(run, self.number_of_models,
                                                                            int(kr_ensemble[kr_nt - 1] / (run + 1)),
                                                                            self.number_of_best_models[i], #i added
                                                                            int(kr_ensemble_best_models[kr_nt - 1] / (run + 1))))

          ge_ensemble = kr_ensemble / 100
          ge_ensemble_best_models = kr_ensemble_best_models / 100

          sr_ensemble = np.zeros(kr_nt)
          sr_ensemble_best_models = np.zeros(kr_nt)

          for index in range(kr_nt):
              for run in range(100):
                  sr_ensemble[index] += self.__add_if_one(krs_ensemble[run][index])
                  sr_ensemble_best_models[index] += self.__add_if_one(krs_ensemble_best_models[run][index])
          if (i==0): 
            ge_ensemble_best_models0 = ge_ensemble_best_models
            sr_ensemble_best_models0 = sr_ensemble_best_models
          if (i==1):
            ge_ensemble_best_models1 = ge_ensemble_best_models
            sr_ensemble_best_models1 = sr_ensemble_best_models
          if(i==2):
            ge_ensemble_best_models2 = ge_ensemble_best_models
            sr_ensemble_best_models2 = sr_ensemble_best_models
          if(i==3):
            ge_ensemble_best_models3 = ge_ensemble_best_models
            sr_ensemble_best_models3 = sr_ensemble_best_models
            ge_ensemble_best_models = ge_ensemble_best_models0
            sr_ensemble_best_models = sr_ensemble_best_models0
          
        #return ge_ensemble, ge_ensemble_best_models, sr_ensemble/100, sr_ensemble_best_models/100
          #next line added
      return ge_ensemble, ge_ensemble_best_models, ge_ensemble_best_models1, ge_ensemble_best_models2, ge_ensemble_best_models3, sr_ensemble/100, sr_ensemble_best_models/100, sr_ensemble_best_models1/100,sr_ensemble_best_models2/100,sr_ensemble_best_models3/100 

    def create_z_score_norm(self, dataset):
        z_score_mean = np.mean(dataset, axis=0)
        z_score_std = np.std(dataset, axis=0)
        return z_score_mean, z_score_std

    def apply_z_score_norm(self, dataset, z_score_mean, z_score_std):
        for index in range(len(dataset)):
            dataset[index] = (dataset[index] - z_score_mean) / z_score_std

    def run_ensemble(self, number_of_models, number_of_best_models):

        self.number_of_models = number_of_models
        self.number_of_best_models = number_of_best_models

        target_params = SCADatasets().get_trace_set(self.target_dataset)

        #root_folder = "D:/traces/"
        #root_folder = '/content/drive/MyDrive/Colab Notebooks/QEResearch/ches_ctf/'
        root_folder = '/content/gdrive/MyDrive/QEResearch/ches_ctf/'

        (X_profiling, Y_profiling), (X_validation, Y_validation), (X_attack, Y_attack), (
            _, plt_validation, plt_attack) = LoadDatasets().load_dataset(
            root_folder + target_params["file"], target_params["n_profiling"], target_params["n_attack"], self.target_byte, self.l_model)

        # normalize with z-score
        z_score_mean, z_score_std = self.create_z_score_norm(X_profiling)
        self.apply_z_score_norm(X_profiling, z_score_mean, z_score_std)
        self.apply_z_score_norm(X_validation, z_score_mean, z_score_std)
        self.apply_z_score_norm(X_attack, z_score_mean, z_score_std)

        # convert labels to categorical labels
        Y_profiling = to_categorical(Y_profiling, num_classes=self.classes)
        Y_validation = to_categorical(Y_validation, num_classes=self.classes)
        Y_attack = to_categorical(Y_attack, num_classes=self.classes)

        X_profiling = X_profiling.astype('float32')
        X_validation = X_validation.astype('float32')
        X_attack = X_attack.astype('float32')
        print(X_profiling.shape[0], X_attack.shape[0])
        kr_step = 10  # key rank processed for each kr_step traces
        kr_fraction = 1  # validation or attack sets are divided by kr_fraction before computing key rank

        self.ge_all_validation = []
        self.sr_all_validation = []
        self.ge_all_attack = []
        self.k_ps_all = []

        kr_nt = int(len(X_validation) / (kr_step * kr_fraction))

        # train random MLP
        #for model_index in range(self.number_of_models):
         #   ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_mlp(X_profiling, Y_profiling,
         #                                                                             X_validation, Y_validation,
         #                                                                             X_attack, Y_attack,
         #                                                                             plt_validation, plt_attack,
         #                                                                             target_params, kr_step, kr_fraction)
          #  self.ge_all_validation.append(ge_validation)
          #  self.ge_all_attack.append(ge_attack)
          #  self.sr_all_validation.append(sr_validation)
          #  self.sr_all_attack.append(sr_attack)
          #  self.k_ps_all.append(kp_krs)

        # train random CNN
        for model_index in range(self.number_of_models):
             ge_validation, ge_attack, sr_validation, sr_attack, kp_krs = self.run_cnn(X_profiling, Y_profiling,
                                                                                       X_validation, Y_validation,
                                                                                       X_attack, Y_attack,
                                                                                       plt_validation, plt_attack,
                                                                                       target_params, kr_step, kr_fraction)
             self.ge_all_validation.append(ge_validation)
             self.ge_all_attack.append(ge_attack)
             self.sr_all_validation.append(sr_validation)
             self.sr_all_attack.append(sr_attack)
             self.k_ps_all.append(kp_krs)                  #kr_nt = int(len(X_validation) / (kr_step * kr_fraction))

        #ge_ensemble, ge_ensemble_best_models, sr_ensemble, sr_ensemble_best_models = self.compute_ensembles(kr_nt,
         #                                                                                                   target_params["good_key"])
        ge_ensemble, ge_ensemble_best_models, ge_ensemble_best_models1, ge_ensemble_best_models2, ge_ensemble_best_models3, sr_ensemble, sr_ensemble_best_models, sr_ensemble_best_models1, sr_ensemble_best_models2,sr_ensemble_best_models3 = self.compute_ensembles(kr_nt,
                                                                                                             target_params["good_key"])
             

        self.ge_ensemble = ge_ensemble
        self.ge_ensemble_best_models = ge_ensemble_best_models
        self.ge_ensemble_best_models1 = ge_ensemble_best_models1 #added
        self.ge_ensemble_best_models2 = ge_ensemble_best_models2 #added
        self.ge_ensemble_best_models3 = ge_ensemble_best_models3 #added

        self.sr_ensemble = sr_ensemble
        self.sr_ensemble_best_models = sr_ensemble_best_models
        self.sr_ensemble_best_models1 = sr_ensemble_best_models1 #added
        self.sr_ensemble_best_models2 = sr_ensemble_best_models2 #added
        self.sr_ensemble_best_models3 = sr_ensemble_best_models3 #added




    def get_ge_ensemble(self):
        return self.ge_ensemble

    def get_ge_ensemble_best_models(self):
        return self.ge_ensemble_best_models

    def get_ge_ensemble_best_models1(self): #added
        return self.ge_ensemble_best_models1

    def get_ge_ensemble_best_models2(self): #added
        return self.ge_ensemble_best_models2

    def get_ge_ensemble_best_models3(self): #added
        return self.ge_ensemble_best_models3

    def get_ge_best_model_validation(self):
        return self.ge_best_model_validation

    def get_ge_best_model_attack(self):
        return self.ge_best_model_attack

    def get_sr_ensemble(self):
        return self.sr_ensemble

    def get_sr_ensemble_best_models1(self): #added
        return self.sr_ensemble_best_models1

    def get_sr_ensemble_best_models2(self): #added
        return self.sr_ensemble_best_models2

    def get_sr_ensemble_best_models3(self): #added
        return self.sr_ensemble_best_models3


    def get_sr_ensemble_best_models(self):
        return self.sr_ensemble_best_models

    def get_sr_best_model_validation(self):
        return self.sr_best_model_validation

    def get_sr_best_model_attack(self):
        return self.sr_best_model_attack

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 37.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
plt.rc('figure', figsize=(15, 8))

ensemble_aes = EnsembleAES()
#ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_dataset("ascad_fixed_key")  #changed from ches_ctf
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(2)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(50)
ensemble_aes.run_ensemble(number_of_models=33, number_of_best_models=[1,5,10,20])
#ensemble_aes.run_ensemble(number_of_models=10, number_of_best_models=[1,1,1,1])
# Out:
# 50000 5000
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 137, 16)           272
#
#  flatten (Flatten)           (None, 2192)              0
#
#  dense (Dense)               (None, 600)               1315800
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 600)               360600
#
#  dense_6 (Dense)             (None, 600)               360600
#
#  dense_7 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 3,485,081
# Trainable params: 3,485,081
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Streaming output truncated to the last 5000 lines.
# 125/125 [==============================] - 2s 16ms/step - loss: 1.2023 - accuracy: 0.5236 - val_loss: 2.5449 - val_accuracy: 0.2140
# Epoch 40/50
# 125/125 [==============================] - 2s 16ms/step - loss: 1.1465 - accuracy: 0.5470 - val_loss: 2.7515 - val_accuracy: 0.2012
# Epoch 41/50
# 125/125 [==============================] - 2s 16ms/step - loss: 1.0981 - accuracy: 0.5676 - val_loss: 2.7800 - val_accuracy: 0.2082
# Epoch 42/50
# 125/125 [==============================] - 2s 16ms/step - loss: 1.0486 - accuracy: 0.5917 - val_loss: 2.9557 - val_accuracy: 0.2072
# Epoch 43/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.9925 - accuracy: 0.6140 - val_loss: 2.9619 - val_accuracy: 0.2190
# Epoch 44/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.9294 - accuracy: 0.6393 - val_loss: 3.2840 - val_accuracy: 0.2064
# Epoch 45/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.8727 - accuracy: 0.6628 - val_loss: 3.3478 - val_accuracy: 0.1992
# Epoch 46/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.8181 - accuracy: 0.6856 - val_loss: 3.5970 - val_accuracy: 0.1996
# Epoch 47/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.7537 - accuracy: 0.7151 - val_loss: 3.8443 - val_accuracy: 0.1994
# Epoch 48/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.6890 - accuracy: 0.7390 - val_loss: 4.0294 - val_accuracy: 0.2024
# Epoch 49/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.6258 - accuracy: 0.7674 - val_loss: 4.3628 - val_accuracy: 0.1970
# Epoch 50/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.5673 - accuracy: 0.7896 - val_loss: 4.7115 - val_accuracy: 0.2072
# KR: 0 | GE for correct key (224): 13.0)
# KR: 1 | GE for correct key (224): 13.0)
# KR: 2 | GE for correct key (224): 13.0)
# KR: 3 | GE for correct key (224): 13.0)
# KR: 4 | GE for correct key (224): 13.0)
# KR: 5 | GE for correct key (224): 13.0)
# KR: 6 | GE for correct key (224): 13.0)
# KR: 7 | GE for correct key (224): 13.0)
# KR: 8 | GE for correct key (224): 13.0)
# KR: 9 | GE for correct key (224): 13.0)
# KR: 10 | GE for correct key (224): 13.0)
# KR: 11 | GE for correct key (224): 13.0)
# KR: 12 | GE for correct key (224): 13.0)
# KR: 13 | GE for correct key (224): 13.0)
# KR: 14 | GE for correct key (224): 13.0)
# KR: 15 | GE for correct key (224): 13.0)
# KR: 16 | GE for correct key (224): 13.0)
# KR: 17 | GE for correct key (224): 13.0)
# KR: 18 | GE for correct key (224): 13.0)
# KR: 19 | GE for correct key (224): 13.0)
# KR: 20 | GE for correct key (224): 13.0)
# KR: 21 | GE for correct key (224): 13.0)
# KR: 22 | GE for correct key (224): 13.0)
# KR: 23 | GE for correct key (224): 13.0)
# KR: 24 | GE for correct key (224): 13.0)
# KR: 25 | GE for correct key (224): 13.0)
# KR: 26 | GE for correct key (224): 13.0)
# KR: 27 | GE for correct key (224): 13.0)
# KR: 28 | GE for correct key (224): 13.0)
# KR: 29 | GE for correct key (224): 13.0)
# KR: 30 | GE for correct key (224): 13.0)
# KR: 31 | GE for correct key (224): 13.0)
# KR: 32 | GE for correct key (224): 13.0)
# KR: 33 | GE for correct key (224): 13.0)
# KR: 34 | GE for correct key (224): 13.0)
# KR: 35 | GE for correct key (224): 13.0)
# KR: 36 | GE for correct key (224): 13.0)
# KR: 37 | GE for correct key (224): 13.0)
# KR: 38 | GE for correct key (224): 13.0)
# KR: 39 | GE for correct key (224): 13.0)
# KR: 40 | GE for correct key (224): 13.0)
# KR: 41 | GE for correct key (224): 13.0)
# KR: 42 | GE for correct key (224): 13.0)
# KR: 43 | GE for correct key (224): 13.0)
# KR: 44 | GE for correct key (224): 13.0)
# KR: 45 | GE for correct key (224): 13.0)
# KR: 46 | GE for correct key (224): 13.0)
# KR: 47 | GE for correct key (224): 13.0)
# KR: 48 | GE for correct key (224): 13.0)
# KR: 49 | GE for correct key (224): 13.0)
# KR: 50 | GE for correct key (224): 13.0)
# KR: 51 | GE for correct key (224): 13.0)
# KR: 52 | GE for correct key (224): 13.0)
# KR: 53 | GE for correct key (224): 13.0)
# KR: 54 | GE for correct key (224): 13.0)
# KR: 55 | GE for correct key (224): 13.0)
# KR: 56 | GE for correct key (224): 13.0)
# KR: 57 | GE for correct key (224): 13.0)
# KR: 58 | GE for correct key (224): 13.0)
# KR: 59 | GE for correct key (224): 13.0)
# KR: 60 | GE for correct key (224): 13.0)
# KR: 61 | GE for correct key (224): 13.0)
# KR: 62 | GE for correct key (224): 13.0)
# KR: 63 | GE for correct key (224): 13.0)
# KR: 64 | GE for correct key (224): 13.0)
# KR: 65 | GE for correct key (224): 13.0)
# KR: 66 | GE for correct key (224): 13.0)
# KR: 67 | GE for correct key (224): 13.0)
# KR: 68 | GE for correct key (224): 13.0)
# KR: 69 | GE for correct key (224): 13.0)
# KR: 70 | GE for correct key (224): 13.0)
# KR: 71 | GE for correct key (224): 13.0)
# KR: 72 | GE for correct key (224): 13.0)
# KR: 73 | GE for correct key (224): 13.0)
# KR: 74 | GE for correct key (224): 13.0)
# KR: 75 | GE for correct key (224): 13.0)
# KR: 76 | GE for correct key (224): 13.0)
# KR: 77 | GE for correct key (224): 13.0)
# KR: 78 | GE for correct key (224): 13.0)
# KR: 79 | GE for correct key (224): 13.0)
# KR: 80 | GE for correct key (224): 13.0)
# KR: 81 | GE for correct key (224): 13.0)
# KR: 82 | GE for correct key (224): 13.0)
# KR: 83 | GE for correct key (224): 13.0)
# KR: 84 | GE for correct key (224): 13.0)
# KR: 85 | GE for correct key (224): 13.0)
# KR: 86 | GE for correct key (224): 13.0)
# KR: 87 | GE for correct key (224): 13.0)
# KR: 88 | GE for correct key (224): 13.0)
# KR: 89 | GE for correct key (224): 13.0)
# KR: 90 | GE for correct key (224): 13.0)
# KR: 91 | GE for correct key (224): 13.0)
# KR: 92 | GE for correct key (224): 13.0)
# KR: 93 | GE for correct key (224): 13.0)
# KR: 94 | GE for correct key (224): 13.0)
# KR: 95 | GE for correct key (224): 13.0)
# KR: 96 | GE for correct key (224): 13.0)
# KR: 97 | GE for correct key (224): 13.0)
# KR: 98 | GE for correct key (224): 13.0)
# KR: 99 | GE for correct key (224): 13.0)
# KR: 0 | GE for correct key (224): 1.0)
# KR: 1 | GE for correct key (224): 1.0)
# KR: 2 | GE for correct key (224): 1.0)
# KR: 3 | GE for correct key (224): 1.0)
# KR: 4 | GE for correct key (224): 1.0)
# KR: 5 | GE for correct key (224): 1.0)
# KR: 6 | GE for correct key (224): 1.0)
# KR: 7 | GE for correct key (224): 1.0)
# KR: 8 | GE for correct key (224): 1.0)
# KR: 9 | GE for correct key (224): 1.0)
# KR: 10 | GE for correct key (224): 1.0)
# KR: 11 | GE for correct key (224): 1.0)
# KR: 12 | GE for correct key (224): 1.0)
# KR: 13 | GE for correct key (224): 1.0)
# KR: 14 | GE for correct key (224): 1.0)
# KR: 15 | GE for correct key (224): 1.0)
# KR: 16 | GE for correct key (224): 1.0)
# KR: 17 | GE for correct key (224): 1.0)
# KR: 18 | GE for correct key (224): 1.0)
# KR: 19 | GE for correct key (224): 1.0)
# KR: 20 | GE for correct key (224): 1.0)
# KR: 21 | GE for correct key (224): 1.0)
# KR: 22 | GE for correct key (224): 1.0)
# KR: 23 | GE for correct key (224): 1.0)
# KR: 24 | GE for correct key (224): 1.0)
# KR: 25 | GE for correct key (224): 1.0)
# KR: 26 | GE for correct key (224): 1.0)
# KR: 27 | GE for correct key (224): 1.0)
# KR: 28 | GE for correct key (224): 1.0)
# KR: 29 | GE for correct key (224): 1.0)
# KR: 30 | GE for correct key (224): 1.0)
# KR: 31 | GE for correct key (224): 1.0)
# KR: 32 | GE for correct key (224): 1.0)
# KR: 33 | GE for correct key (224): 1.0)
# KR: 34 | GE for correct key (224): 1.0)
# KR: 35 | GE for correct key (224): 1.0)
# KR: 36 | GE for correct key (224): 1.0)
# KR: 37 | GE for correct key (224): 1.0)
# KR: 38 | GE for correct key (224): 1.0)
# KR: 39 | GE for correct key (224): 1.0)
# KR: 40 | GE for correct key (224): 1.0)
# KR: 41 | GE for correct key (224): 1.0)
# KR: 42 | GE for correct key (224): 1.0)
# KR: 43 | GE for correct key (224): 1.0)
# KR: 44 | GE for correct key (224): 1.0)
# KR: 45 | GE for correct key (224): 1.0)
# KR: 46 | GE for correct key (224): 1.0)
# KR: 47 | GE for correct key (224): 1.0)
# KR: 48 | GE for correct key (224): 1.0)
# KR: 49 | GE for correct key (224): 1.0)
# KR: 50 | GE for correct key (224): 1.0)
# KR: 51 | GE for correct key (224): 1.0)
# KR: 52 | GE for correct key (224): 1.0)
# KR: 53 | GE for correct key (224): 1.0)
# KR: 54 | GE for correct key (224): 1.0)
# KR: 55 | GE for correct key (224): 1.0)
# KR: 56 | GE for correct key (224): 1.0)
# KR: 57 | GE for correct key (224): 1.0)
# KR: 58 | GE for correct key (224): 1.0)
# KR: 59 | GE for correct key (224): 1.0)
# KR: 60 | GE for correct key (224): 1.0)
# KR: 61 | GE for correct key (224): 1.0)
# KR: 62 | GE for correct key (224): 1.0)
# KR: 63 | GE for correct key (224): 1.0)
# KR: 64 | GE for correct key (224): 1.0)
# KR: 65 | GE for correct key (224): 1.0)
# KR: 66 | GE for correct key (224): 1.0)
# KR: 67 | GE for correct key (224): 1.0)
# KR: 68 | GE for correct key (224): 1.0)
# KR: 69 | GE for correct key (224): 1.0)
# KR: 70 | GE for correct key (224): 1.0)
# KR: 71 | GE for correct key (224): 1.0)
# KR: 72 | GE for correct key (224): 1.0)
# KR: 73 | GE for correct key (224): 1.0)
# KR: 74 | GE for correct key (224): 1.0)
# KR: 75 | GE for correct key (224): 1.0)
# KR: 76 | GE for correct key (224): 1.0)
# KR: 77 | GE for correct key (224): 1.0)
# KR: 78 | GE for correct key (224): 1.0)
# KR: 79 | GE for correct key (224): 1.0)
# KR: 80 | GE for correct key (224): 1.0)
# KR: 81 | GE for correct key (224): 1.0)
# KR: 82 | GE for correct key (224): 1.0)
# KR: 83 | GE for correct key (224): 1.0)
# KR: 84 | GE for correct key (224): 1.0)
# KR: 85 | GE for correct key (224): 1.0)
# KR: 86 | GE for correct key (224): 1.0)
# KR: 87 | GE for correct key (224): 1.0)
# KR: 88 | GE for correct key (224): 1.0)
# KR: 89 | GE for correct key (224): 1.0)
# KR: 90 | GE for correct key (224): 1.0)
# KR: 91 | GE for correct key (224): 1.0)
# KR: 92 | GE for correct key (224): 1.0)
# KR: 93 | GE for correct key (224): 1.0)
# KR: 94 | GE for correct key (224): 1.0)
# KR: 95 | GE for correct key (224): 1.0)
# KR: 96 | GE for correct key (224): 1.0)
# KR: 97 | GE for correct key (224): 1.0)
# KR: 98 | GE for correct key (224): 1.0)
# KR: 99 | GE for correct key (224): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 138, 8)            120
#
#  flatten (Flatten)           (None, 1104)              0
#
#  dense (Dense)               (None, 700)               773500
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 700)               490700
#
#  dense_3 (Dense)             (None, 700)               490700
#
#  dense_4 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 2,252,029
# Trainable params: 2,252,029
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 125/125 [==============================] - 3s 19ms/step - loss: 1.7930 - accuracy: 0.2584 - val_loss: 1.7953 - val_accuracy: 0.2416
# Epoch 2/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7687 - accuracy: 0.2670 - val_loss: 1.7952 - val_accuracy: 0.2696
# Epoch 3/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7631 - accuracy: 0.2678 - val_loss: 1.7948 - val_accuracy: 0.2694
# Epoch 4/50
# 125/125 [==============================] - 2s 17ms/step - loss: 1.7591 - accuracy: 0.2712 - val_loss: 1.7927 - val_accuracy: 0.2616
# Epoch 5/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7541 - accuracy: 0.2747 - val_loss: 1.8068 - val_accuracy: 0.2528
# Epoch 6/50
# 125/125 [==============================] - 2s 17ms/step - loss: 1.7491 - accuracy: 0.2772 - val_loss: 1.7991 - val_accuracy: 0.2704
# Epoch 7/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7466 - accuracy: 0.2772 - val_loss: 1.8030 - val_accuracy: 0.2576
# Epoch 8/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7401 - accuracy: 0.2789 - val_loss: 1.8048 - val_accuracy: 0.2494
# Epoch 9/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7376 - accuracy: 0.2813 - val_loss: 1.8084 - val_accuracy: 0.2586
# Epoch 10/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7317 - accuracy: 0.2846 - val_loss: 1.8133 - val_accuracy: 0.2570
# Epoch 11/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7303 - accuracy: 0.2822 - val_loss: 1.8249 - val_accuracy: 0.2408
# Epoch 12/50
# 125/125 [==============================] - 2s 19ms/step - loss: 1.7246 - accuracy: 0.2895 - val_loss: 1.8259 - val_accuracy: 0.2592
# Epoch 13/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7227 - accuracy: 0.2867 - val_loss: 1.8256 - val_accuracy: 0.2512
# Epoch 14/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7189 - accuracy: 0.2908 - val_loss: 1.8237 - val_accuracy: 0.2508
# Epoch 15/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7176 - accuracy: 0.2892 - val_loss: 1.8231 - val_accuracy: 0.2428
# Epoch 16/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7153 - accuracy: 0.2905 - val_loss: 1.8226 - val_accuracy: 0.2476
# Epoch 17/50
# 125/125 [==============================] - 2s 19ms/step - loss: 1.7124 - accuracy: 0.2911 - val_loss: 1.8290 - val_accuracy: 0.2526
# Epoch 18/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7101 - accuracy: 0.2947 - val_loss: 1.8374 - val_accuracy: 0.2456
# Epoch 19/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7089 - accuracy: 0.2953 - val_loss: 1.8331 - val_accuracy: 0.2426
# Epoch 20/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7072 - accuracy: 0.2936 - val_loss: 1.8402 - val_accuracy: 0.2400
# Epoch 21/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7059 - accuracy: 0.2964 - val_loss: 1.8396 - val_accuracy: 0.2438
# Epoch 22/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.7032 - accuracy: 0.2959 - val_loss: 1.8435 - val_accuracy: 0.2484
# Epoch 23/50
# 125/125 [==============================] - 2s 19ms/step - loss: 1.7012 - accuracy: 0.2945 - val_loss: 1.8364 - val_accuracy: 0.2394
# Epoch 24/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6990 - accuracy: 0.2979 - val_loss: 1.8558 - val_accuracy: 0.2432
# Epoch 25/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6963 - accuracy: 0.2990 - val_loss: 1.8580 - val_accuracy: 0.2460
# Epoch 26/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6950 - accuracy: 0.2973 - val_loss: 1.8559 - val_accuracy: 0.2452
# Epoch 27/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6924 - accuracy: 0.2998 - val_loss: 1.8597 - val_accuracy: 0.2418
# Epoch 28/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6913 - accuracy: 0.2997 - val_loss: 1.8539 - val_accuracy: 0.2434
# Epoch 29/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6883 - accuracy: 0.3005 - val_loss: 1.8549 - val_accuracy: 0.2542
# Epoch 30/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6848 - accuracy: 0.2999 - val_loss: 1.8661 - val_accuracy: 0.2424
# Epoch 31/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6823 - accuracy: 0.3017 - val_loss: 1.8685 - val_accuracy: 0.2372
# Epoch 32/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6766 - accuracy: 0.3035 - val_loss: 1.8721 - val_accuracy: 0.2410
# Epoch 33/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6729 - accuracy: 0.3046 - val_loss: 1.8741 - val_accuracy: 0.2404
# Epoch 34/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6708 - accuracy: 0.3054 - val_loss: 1.8804 - val_accuracy: 0.2408
# Epoch 35/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6624 - accuracy: 0.3060 - val_loss: 1.8913 - val_accuracy: 0.2380
# Epoch 36/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6580 - accuracy: 0.3077 - val_loss: 1.8900 - val_accuracy: 0.2348
# Epoch 37/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6511 - accuracy: 0.3144 - val_loss: 1.9003 - val_accuracy: 0.2356
# Epoch 38/50
# 125/125 [==============================] - 2s 19ms/step - loss: 1.6418 - accuracy: 0.3193 - val_loss: 1.9201 - val_accuracy: 0.2392
# Epoch 39/50
# 125/125 [==============================] - 2s 20ms/step - loss: 1.6361 - accuracy: 0.3203 - val_loss: 1.9297 - val_accuracy: 0.2268
# Epoch 40/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6238 - accuracy: 0.3237 - val_loss: 1.9286 - val_accuracy: 0.2258
# Epoch 41/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6126 - accuracy: 0.3301 - val_loss: 1.9556 - val_accuracy: 0.2264
# Epoch 42/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.6048 - accuracy: 0.3335 - val_loss: 1.9611 - val_accuracy: 0.2236
# Epoch 43/50
# 125/125 [==============================] - 2s 19ms/step - loss: 1.5900 - accuracy: 0.3416 - val_loss: 1.9775 - val_accuracy: 0.2184
# Epoch 44/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.5759 - accuracy: 0.3451 - val_loss: 1.9977 - val_accuracy: 0.2340
# Epoch 45/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.5635 - accuracy: 0.3527 - val_loss: 2.0158 - val_accuracy: 0.2244
# Epoch 46/50
# 125/125 [==============================] - 2s 17ms/step - loss: 1.5483 - accuracy: 0.3595 - val_loss: 2.0351 - val_accuracy: 0.2236
# Epoch 47/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.5328 - accuracy: 0.3689 - val_loss: 2.0603 - val_accuracy: 0.2176
# Epoch 48/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.5136 - accuracy: 0.3746 - val_loss: 2.0804 - val_accuracy: 0.2214
# Epoch 49/50
# 125/125 [==============================] - 2s 18ms/step - loss: 1.4929 - accuracy: 0.3875 - val_loss: 2.1172 - val_accuracy: 0.2120
# Epoch 50/50
# 125/125 [==============================] - 2s 17ms/step - loss: 1.4772 - accuracy: 0.3902 - val_loss: 2.1300 - val_accuracy: 0.2044
# KR: 0 | GE for correct key (224): 192.0)
# KR: 1 | GE for correct key (224): 192.0)
# KR: 2 | GE for correct key (224): 192.0)
# KR: 3 | GE for correct key (224): 192.0)
# KR: 4 | GE for correct key (224): 192.0)
# KR: 5 | GE for correct key (224): 192.0)
# KR: 6 | GE for correct key (224): 192.0)
# KR: 7 | GE for correct key (224): 192.0)
# KR: 8 | GE for correct key (224): 192.0)
# KR: 9 | GE for correct key (224): 192.0)
# KR: 10 | GE for correct key (224): 192.0)
# KR: 11 | GE for correct key (224): 192.0)
# KR: 12 | GE for correct key (224): 192.0)
# KR: 13 | GE for correct key (224): 192.0)
# KR: 14 | GE for correct key (224): 192.0)
# KR: 15 | GE for correct key (224): 192.0)
# KR: 16 | GE for correct key (224): 192.0)
# KR: 17 | GE for correct key (224): 192.0)
# KR: 18 | GE for correct key (224): 192.0)
# KR: 19 | GE for correct key (224): 192.0)
# KR: 20 | GE for correct key (224): 192.0)
# KR: 21 | GE for correct key (224): 192.0)
# KR: 22 | GE for correct key (224): 192.0)
# KR: 23 | GE for correct key (224): 192.0)
# KR: 24 | GE for correct key (224): 192.0)
# KR: 25 | GE for correct key (224): 192.0)
# KR: 26 | GE for correct key (224): 192.0)
# KR: 27 | GE for correct key (224): 192.0)
# KR: 28 | GE for correct key (224): 192.0)
# KR: 29 | GE for correct key (224): 192.0)
# KR: 30 | GE for correct key (224): 192.0)
# KR: 31 | GE for correct key (224): 192.0)
# KR: 32 | GE for correct key (224): 192.0)
# KR: 33 | GE for correct key (224): 192.0)
# KR: 34 | GE for correct key (224): 192.0)
# KR: 35 | GE for correct key (224): 192.0)
# KR: 36 | GE for correct key (224): 192.0)
# KR: 37 | GE for correct key (224): 192.0)
# KR: 38 | GE for correct key (224): 192.0)
# KR: 39 | GE for correct key (224): 192.0)
# KR: 40 | GE for correct key (224): 192.0)
# KR: 41 | GE for correct key (224): 192.0)
# KR: 42 | GE for correct key (224): 192.0)
# KR: 43 | GE for correct key (224): 192.0)
# KR: 44 | GE for correct key (224): 192.0)
# KR: 45 | GE for correct key (224): 192.0)
# KR: 46 | GE for correct key (224): 192.0)
# KR: 47 | GE for correct key (224): 192.0)
# KR: 48 | GE for correct key (224): 192.0)
# KR: 49 | GE for correct key (224): 192.0)
# KR: 50 | GE for correct key (224): 192.0)
# KR: 51 | GE for correct key (224): 192.0)
# KR: 52 | GE for correct key (224): 192.0)
# KR: 53 | GE for correct key (224): 192.0)
# KR: 54 | GE for correct key (224): 192.0)
# KR: 55 | GE for correct key (224): 192.0)
# KR: 56 | GE for correct key (224): 192.0)
# KR: 57 | GE for correct key (224): 192.0)
# KR: 58 | GE for correct key (224): 192.0)
# KR: 59 | GE for correct key (224): 192.0)
# KR: 60 | GE for correct key (224): 192.0)
# KR: 61 | GE for correct key (224): 192.0)
# KR: 62 | GE for correct key (224): 192.0)
# KR: 63 | GE for correct key (224): 192.0)
# KR: 64 | GE for correct key (224): 192.0)
# KR: 65 | GE for correct key (224): 192.0)
# KR: 66 | GE for correct key (224): 192.0)
# KR: 67 | GE for correct key (224): 192.0)
# KR: 68 | GE for correct key (224): 192.0)
# KR: 69 | GE for correct key (224): 192.0)
# KR: 70 | GE for correct key (224): 192.0)
# KR: 71 | GE for correct key (224): 192.0)
# KR: 72 | GE for correct key (224): 192.0)
# KR: 73 | GE for correct key (224): 192.0)
# KR: 74 | GE for correct key (224): 192.0)
# KR: 75 | GE for correct key (224): 192.0)
# KR: 76 | GE for correct key (224): 192.0)
# KR: 77 | GE for correct key (224): 192.0)
# KR: 78 | GE for correct key (224): 192.0)
# KR: 79 | GE for correct key (224): 192.0)
# KR: 80 | GE for correct key (224): 192.0)
# KR: 81 | GE for correct key (224): 192.0)
# KR: 82 | GE for correct key (224): 192.0)
# KR: 83 | GE for correct key (224): 192.0)
# KR: 84 | GE for correct key (224): 192.0)
# KR: 85 | GE for correct key (224): 192.0)
# KR: 86 | GE for correct key (224): 192.0)
# KR: 87 | GE for correct key (224): 192.0)
# KR: 88 | GE for correct key (224): 192.0)
# KR: 89 | GE for correct key (224): 192.0)
# KR: 90 | GE for correct key (224): 192.0)
# KR: 91 | GE for correct key (224): 192.0)
# KR: 92 | GE for correct key (224): 192.0)
# KR: 93 | GE for correct key (224): 192.0)
# KR: 94 | GE for correct key (224): 192.0)
# KR: 95 | GE for correct key (224): 192.0)
# KR: 96 | GE for correct key (224): 192.0)
# KR: 97 | GE for correct key (224): 192.0)
# KR: 98 | GE for correct key (224): 192.0)
# KR: 99 | GE for correct key (224): 192.0)
# KR: 0 | GE for correct key (224): 171.0)
# KR: 1 | GE for correct key (224): 171.0)
# KR: 2 | GE for correct key (224): 171.0)
# KR: 3 | GE for correct key (224): 171.0)
# KR: 4 | GE for correct key (224): 171.0)
# KR: 5 | GE for correct key (224): 171.0)
# KR: 6 | GE for correct key (224): 171.0)
# KR: 7 | GE for correct key (224): 171.0)
# KR: 8 | GE for correct key (224): 171.0)
# KR: 9 | GE for correct key (224): 171.0)
# KR: 10 | GE for correct key (224): 171.0)
# KR: 11 | GE for correct key (224): 171.0)
# KR: 12 | GE for correct key (224): 171.0)
# KR: 13 | GE for correct key (224): 171.0)
# KR: 14 | GE for correct key (224): 171.0)
# KR: 15 | GE for correct key (224): 171.0)
# KR: 16 | GE for correct key (224): 171.0)
# KR: 17 | GE for correct key (224): 171.0)
# KR: 18 | GE for correct key (224): 171.0)
# KR: 19 | GE for correct key (224): 171.0)
# KR: 20 | GE for correct key (224): 171.0)
# KR: 21 | GE for correct key (224): 171.0)
# KR: 22 | GE for correct key (224): 171.0)
# KR: 23 | GE for correct key (224): 171.0)
# KR: 24 | GE for correct key (224): 171.0)
# KR: 25 | GE for correct key (224): 171.0)
# KR: 26 | GE for correct key (224): 171.0)
# KR: 27 | GE for correct key (224): 171.0)
# KR: 28 | GE for correct key (224): 171.0)
# KR: 29 | GE for correct key (224): 171.0)
# KR: 30 | GE for correct key (224): 171.0)
# KR: 31 | GE for correct key (224): 171.0)
# KR: 32 | GE for correct key (224): 171.0)
# KR: 33 | GE for correct key (224): 171.0)
# KR: 34 | GE for correct key (224): 171.0)
# KR: 35 | GE for correct key (224): 171.0)
# KR: 36 | GE for correct key (224): 171.0)
# KR: 37 | GE for correct key (224): 171.0)
# KR: 38 | GE for correct key (224): 171.0)
# KR: 39 | GE for correct key (224): 171.0)
# KR: 40 | GE for correct key (224): 171.0)
# KR: 41 | GE for correct key (224): 171.0)
# KR: 42 | GE for correct key (224): 171.0)
# KR: 43 | GE for correct key (224): 171.0)
# KR: 44 | GE for correct key (224): 171.0)
# KR: 45 | GE for correct key (224): 171.0)
# KR: 46 | GE for correct key (224): 171.0)
# KR: 47 | GE for correct key (224): 171.0)
# KR: 48 | GE for correct key (224): 171.0)
# KR: 49 | GE for correct key (224): 171.0)
# KR: 50 | GE for correct key (224): 171.0)
# KR: 51 | GE for correct key (224): 171.0)
# KR: 52 | GE for correct key (224): 171.0)
# KR: 53 | GE for correct key (224): 171.0)
# KR: 54 | GE for correct key (224): 171.0)
# KR: 55 | GE for correct key (224): 171.0)
# KR: 56 | GE for correct key (224): 171.0)
# KR: 57 | GE for correct key (224): 171.0)
# KR: 58 | GE for correct key (224): 171.0)
# KR: 59 | GE for correct key (224): 171.0)
# KR: 60 | GE for correct key (224): 171.0)
# KR: 61 | GE for correct key (224): 171.0)
# KR: 62 | GE for correct key (224): 171.0)
# KR: 63 | GE for correct key (224): 171.0)
# KR: 64 | GE for correct key (224): 171.0)
# KR: 65 | GE for correct key (224): 171.0)
# KR: 66 | GE for correct key (224): 171.0)
# KR: 67 | GE for correct key (224): 171.0)
# KR: 68 | GE for correct key (224): 171.0)
# KR: 69 | GE for correct key (224): 171.0)
# KR: 70 | GE for correct key (224): 171.0)
# KR: 71 | GE for correct key (224): 171.0)
# KR: 72 | GE for correct key (224): 171.0)
# KR: 73 | GE for correct key (224): 171.0)
# KR: 74 | GE for correct key (224): 171.0)
# KR: 75 | GE for correct key (224): 171.0)
# KR: 76 | GE for correct key (224): 171.0)
# KR: 77 | GE for correct key (224): 171.0)
# KR: 78 | GE for correct key (224): 171.0)
# KR: 79 | GE for correct key (224): 171.0)
# KR: 80 | GE for correct key (224): 171.0)
# KR: 81 | GE for correct key (224): 171.0)
# KR: 82 | GE for correct key (224): 171.0)
# KR: 83 | GE for correct key (224): 171.0)
# KR: 84 | GE for correct key (224): 171.0)
# KR: 85 | GE for correct key (224): 171.0)
# KR: 86 | GE for correct key (224): 171.0)
# KR: 87 | GE for correct key (224): 171.0)
# KR: 88 | GE for correct key (224): 171.0)
# KR: 89 | GE for correct key (224): 171.0)
# KR: 90 | GE for correct key (224): 171.0)
# KR: 91 | GE for correct key (224): 171.0)
# KR: 92 | GE for correct key (224): 171.0)
# KR: 93 | GE for correct key (224): 171.0)
# KR: 94 | GE for correct key (224): 171.0)
# KR: 95 | GE for correct key (224): 171.0)
# KR: 96 | GE for correct key (224): 171.0)
# KR: 97 | GE for correct key (224): 171.0)
# KR: 98 | GE for correct key (224): 171.0)
# KR: 99 | GE for correct key (224): 171.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 137, 24)           408
#
#  flatten (Flatten)           (None, 3288)              0
#
#  dense (Dense)               (None, 500)               1644500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 500)               250500
#
#  dense_3 (Dense)             (None, 500)               250500
#
#  dense_4 (Dense)             (None, 500)               250500
#
#  dense_5 (Dense)             (None, 500)               250500
#
#  dense_6 (Dense)             (None, 9)                 4509
#
# =================================================================
# Total params: 2,901,917
# Trainable params: 2,901,917
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 125/125 [==============================] - 4s 23ms/step - loss: 1.7833 - accuracy: 0.2682 - val_loss: 1.7917 - val_accuracy: 0.2696
# Epoch 2/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7643 - accuracy: 0.2691 - val_loss: 1.7846 - val_accuracy: 0.2696
# Epoch 3/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7617 - accuracy: 0.2749 - val_loss: 1.7885 - val_accuracy: 0.2696
# Epoch 4/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7611 - accuracy: 0.2749 - val_loss: 1.7832 - val_accuracy: 0.2696
# Epoch 5/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7600 - accuracy: 0.2749 - val_loss: 1.7850 - val_accuracy: 0.2696
# Epoch 6/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7590 - accuracy: 0.2749 - val_loss: 1.7843 - val_accuracy: 0.2696
# Epoch 7/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7577 - accuracy: 0.2745 - val_loss: 1.7945 - val_accuracy: 0.2696
# Epoch 8/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7544 - accuracy: 0.2749 - val_loss: 1.7986 - val_accuracy: 0.2696
# Epoch 9/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7459 - accuracy: 0.2740 - val_loss: 1.8116 - val_accuracy: 0.2680
# Epoch 10/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7300 - accuracy: 0.2756 - val_loss: 1.8030 - val_accuracy: 0.2516
# Epoch 11/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.6964 - accuracy: 0.2814 - val_loss: 1.8195 - val_accuracy: 0.2758
# Epoch 12/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.6542 - accuracy: 0.2896 - val_loss: 1.9008 - val_accuracy: 0.2570
# Epoch 13/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.6067 - accuracy: 0.3071 - val_loss: 1.9020 - val_accuracy: 0.2560
# Epoch 14/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5387 - accuracy: 0.3317 - val_loss: 2.0221 - val_accuracy: 0.2372
# Epoch 15/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.4450 - accuracy: 0.3701 - val_loss: 2.1491 - val_accuracy: 0.2434
# Epoch 16/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.3405 - accuracy: 0.4181 - val_loss: 2.5081 - val_accuracy: 0.2442
# Epoch 17/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.2297 - accuracy: 0.4637 - val_loss: 2.7249 - val_accuracy: 0.2210
# Epoch 18/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.1219 - accuracy: 0.5135 - val_loss: 3.1487 - val_accuracy: 0.2276
# Epoch 19/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.0178 - accuracy: 0.5622 - val_loss: 3.3949 - val_accuracy: 0.2214
# Epoch 20/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.9384 - accuracy: 0.5995 - val_loss: 3.8309 - val_accuracy: 0.2308
# Epoch 21/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.8453 - accuracy: 0.6431 - val_loss: 4.1694 - val_accuracy: 0.2242
# Epoch 22/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.7650 - accuracy: 0.6766 - val_loss: 4.7591 - val_accuracy: 0.2272
# Epoch 23/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.6923 - accuracy: 0.7100 - val_loss: 5.4550 - val_accuracy: 0.2192
# Epoch 24/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.6401 - accuracy: 0.7337 - val_loss: 5.2426 - val_accuracy: 0.2204
# Epoch 25/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.5839 - accuracy: 0.7594 - val_loss: 6.0472 - val_accuracy: 0.2178
# Epoch 26/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.5404 - accuracy: 0.7800 - val_loss: 6.2964 - val_accuracy: 0.2260
# Epoch 27/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.5046 - accuracy: 0.7946 - val_loss: 6.6796 - val_accuracy: 0.2268
# Epoch 28/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.4660 - accuracy: 0.8106 - val_loss: 6.7639 - val_accuracy: 0.2138
# Epoch 29/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.4330 - accuracy: 0.8228 - val_loss: 7.2645 - val_accuracy: 0.2114
# Epoch 30/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.3979 - accuracy: 0.8397 - val_loss: 7.4651 - val_accuracy: 0.2186
# Epoch 31/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.3692 - accuracy: 0.8509 - val_loss: 7.9709 - val_accuracy: 0.2274
# Epoch 32/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.3454 - accuracy: 0.8636 - val_loss: 8.2087 - val_accuracy: 0.2162
# Epoch 33/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.3209 - accuracy: 0.8727 - val_loss: 8.0223 - val_accuracy: 0.2094
# Epoch 34/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2971 - accuracy: 0.8817 - val_loss: 8.0569 - val_accuracy: 0.2144
# Epoch 35/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2805 - accuracy: 0.8910 - val_loss: 7.8889 - val_accuracy: 0.2200
# Epoch 36/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2622 - accuracy: 0.8981 - val_loss: 8.5893 - val_accuracy: 0.2078
# Epoch 37/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.2463 - accuracy: 0.9037 - val_loss: 8.2290 - val_accuracy: 0.2186
# Epoch 38/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2289 - accuracy: 0.9130 - val_loss: 8.4038 - val_accuracy: 0.2250
# Epoch 39/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.2150 - accuracy: 0.9173 - val_loss: 8.5158 - val_accuracy: 0.2210
# Epoch 40/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.2068 - accuracy: 0.9213 - val_loss: 8.3176 - val_accuracy: 0.2154
# Epoch 41/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1912 - accuracy: 0.9268 - val_loss: 8.7423 - val_accuracy: 0.2270
# Epoch 42/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1815 - accuracy: 0.9324 - val_loss: 8.9426 - val_accuracy: 0.2214
# Epoch 43/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1609 - accuracy: 0.9408 - val_loss: 8.8033 - val_accuracy: 0.2184
# Epoch 44/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1591 - accuracy: 0.9425 - val_loss: 8.5546 - val_accuracy: 0.2254
# Epoch 45/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1454 - accuracy: 0.9461 - val_loss: 9.3980 - val_accuracy: 0.2258
# Epoch 46/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1428 - accuracy: 0.9490 - val_loss: 9.0142 - val_accuracy: 0.2186
# Epoch 47/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1383 - accuracy: 0.9506 - val_loss: 9.1818 - val_accuracy: 0.2092
# Epoch 48/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1315 - accuracy: 0.9526 - val_loss: 8.8240 - val_accuracy: 0.2104
# Epoch 49/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1278 - accuracy: 0.9545 - val_loss: 8.9966 - val_accuracy: 0.2204
# Epoch 50/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1153 - accuracy: 0.9588 - val_loss: 8.5863 - val_accuracy: 0.2164
# KR: 0 | GE for correct key (224): 1.0)
# KR: 1 | GE for correct key (224): 1.0)
# KR: 2 | GE for correct key (224): 1.0)
# KR: 3 | GE for correct key (224): 1.0)
# KR: 4 | GE for correct key (224): 1.0)
# KR: 5 | GE for correct key (224): 1.0)
# KR: 6 | GE for correct key (224): 1.0)
# KR: 7 | GE for correct key (224): 1.0)
# KR: 8 | GE for correct key (224): 1.0)
# KR: 9 | GE for correct key (224): 1.0)
# KR: 10 | GE for correct key (224): 1.0)
# KR: 11 | GE for correct key (224): 1.0)
# KR: 12 | GE for correct key (224): 1.0)
# KR: 13 | GE for correct key (224): 1.0)
# KR: 14 | GE for correct key (224): 1.0)
# KR: 15 | GE for correct key (224): 1.0)
# KR: 16 | GE for correct key (224): 1.0)
# KR: 17 | GE for correct key (224): 1.0)
# KR: 18 | GE for correct key (224): 1.0)
# KR: 19 | GE for correct key (224): 1.0)
# KR: 20 | GE for correct key (224): 1.0)
# KR: 21 | GE for correct key (224): 1.0)
# KR: 22 | GE for correct key (224): 1.0)
# KR: 23 | GE for correct key (224): 1.0)
# KR: 24 | GE for correct key (224): 1.0)
# KR: 25 | GE for correct key (224): 1.0)
# KR: 26 | GE for correct key (224): 1.0)
# KR: 27 | GE for correct key (224): 1.0)
# KR: 28 | GE for correct key (224): 1.0)
# KR: 29 | GE for correct key (224): 1.0)
# KR: 30 | GE for correct key (224): 1.0)
# KR: 31 | GE for correct key (224): 1.0)
# KR: 32 | GE for correct key (224): 1.0)
# KR: 33 | GE for correct key (224): 1.0)
# KR: 34 | GE for correct key (224): 1.0)
# KR: 35 | GE for correct key (224): 1.0)
# KR: 36 | GE for correct key (224): 1.0)
# KR: 37 | GE for correct key (224): 1.0)
# KR: 38 | GE for correct key (224): 1.0)
# KR: 39 | GE for correct key (224): 1.0)
# KR: 40 | GE for correct key (224): 1.0)
# KR: 41 | GE for correct key (224): 1.0)
# KR: 42 | GE for correct key (224): 1.0)
# KR: 43 | GE for correct key (224): 1.0)
# KR: 44 | GE for correct key (224): 1.0)
# KR: 45 | GE for correct key (224): 1.0)
# KR: 46 | GE for correct key (224): 1.0)
# KR: 47 | GE for correct key (224): 1.0)
# KR: 48 | GE for correct key (224): 1.0)
# KR: 49 | GE for correct key (224): 1.0)
# KR: 50 | GE for correct key (224): 1.0)
# KR: 51 | GE for correct key (224): 1.0)
# KR: 52 | GE for correct key (224): 1.0)
# KR: 53 | GE for correct key (224): 1.0)
# KR: 54 | GE for correct key (224): 1.0)
# KR: 55 | GE for correct key (224): 1.0)
# KR: 56 | GE for correct key (224): 1.0)
# KR: 57 | GE for correct key (224): 1.0)
# KR: 58 | GE for correct key (224): 1.0)
# KR: 59 | GE for correct key (224): 1.0)
# KR: 60 | GE for correct key (224): 1.0)
# KR: 61 | GE for correct key (224): 1.0)
# KR: 62 | GE for correct key (224): 1.0)
# KR: 63 | GE for correct key (224): 1.0)
# KR: 64 | GE for correct key (224): 1.0)
# KR: 65 | GE for correct key (224): 1.0)
# KR: 66 | GE for correct key (224): 1.0)
# KR: 67 | GE for correct key (224): 1.0)
# KR: 68 | GE for correct key (224): 1.0)
# KR: 69 | GE for correct key (224): 1.0)
# KR: 70 | GE for correct key (224): 1.0)
# KR: 71 | GE for correct key (224): 1.0)
# KR: 72 | GE for correct key (224): 1.0)
# KR: 73 | GE for correct key (224): 1.0)
# KR: 74 | GE for correct key (224): 1.0)
# KR: 75 | GE for correct key (224): 1.0)
# KR: 76 | GE for correct key (224): 1.0)
# KR: 77 | GE for correct key (224): 1.0)
# KR: 78 | GE for correct key (224): 1.0)
# KR: 79 | GE for correct key (224): 1.0)
# KR: 80 | GE for correct key (224): 1.0)
# KR: 81 | GE for correct key (224): 1.0)
# KR: 82 | GE for correct key (224): 1.0)
# KR: 83 | GE for correct key (224): 1.0)
# KR: 84 | GE for correct key (224): 1.0)
# KR: 85 | GE for correct key (224): 1.0)
# KR: 86 | GE for correct key (224): 1.0)
# KR: 87 | GE for correct key (224): 1.0)
# KR: 88 | GE for correct key (224): 1.0)
# KR: 89 | GE for correct key (224): 1.0)
# KR: 90 | GE for correct key (224): 1.0)
# KR: 91 | GE for correct key (224): 1.0)
# KR: 92 | GE for correct key (224): 1.0)
# KR: 93 | GE for correct key (224): 1.0)
# KR: 94 | GE for correct key (224): 1.0)
# KR: 95 | GE for correct key (224): 1.0)
# KR: 96 | GE for correct key (224): 1.0)
# KR: 97 | GE for correct key (224): 1.0)
# KR: 98 | GE for correct key (224): 1.0)
# KR: 99 | GE for correct key (224): 1.0)
# KR: 0 | GE for correct key (224): 1.0)
# KR: 1 | GE for correct key (224): 1.0)
# KR: 2 | GE for correct key (224): 1.0)
# KR: 3 | GE for correct key (224): 1.0)
# KR: 4 | GE for correct key (224): 1.0)
# KR: 5 | GE for correct key (224): 1.0)
# KR: 6 | GE for correct key (224): 1.0)
# KR: 7 | GE for correct key (224): 1.0)
# KR: 8 | GE for correct key (224): 1.0)
# KR: 9 | GE for correct key (224): 1.0)
# KR: 10 | GE for correct key (224): 1.0)
# KR: 11 | GE for correct key (224): 1.0)
# KR: 12 | GE for correct key (224): 1.0)
# KR: 13 | GE for correct key (224): 1.0)
# KR: 14 | GE for correct key (224): 1.0)
# KR: 15 | GE for correct key (224): 1.0)
# KR: 16 | GE for correct key (224): 1.0)
# KR: 17 | GE for correct key (224): 1.0)
# KR: 18 | GE for correct key (224): 1.0)
# KR: 19 | GE for correct key (224): 1.0)
# KR: 20 | GE for correct key (224): 1.0)
# KR: 21 | GE for correct key (224): 1.0)
# KR: 22 | GE for correct key (224): 1.0)
# KR: 23 | GE for correct key (224): 1.0)
# KR: 24 | GE for correct key (224): 1.0)
# KR: 25 | GE for correct key (224): 1.0)
# KR: 26 | GE for correct key (224): 1.0)
# KR: 27 | GE for correct key (224): 1.0)
# KR: 28 | GE for correct key (224): 1.0)
# KR: 29 | GE for correct key (224): 1.0)
# KR: 30 | GE for correct key (224): 1.0)
# KR: 31 | GE for correct key (224): 1.0)
# KR: 32 | GE for correct key (224): 1.0)
# KR: 33 | GE for correct key (224): 1.0)
# KR: 34 | GE for correct key (224): 1.0)
# KR: 35 | GE for correct key (224): 1.0)
# KR: 36 | GE for correct key (224): 1.0)
# KR: 37 | GE for correct key (224): 1.0)
# KR: 38 | GE for correct key (224): 1.0)
# KR: 39 | GE for correct key (224): 1.0)
# KR: 40 | GE for correct key (224): 1.0)
# KR: 41 | GE for correct key (224): 1.0)
# KR: 42 | GE for correct key (224): 1.0)
# KR: 43 | GE for correct key (224): 1.0)
# KR: 44 | GE for correct key (224): 1.0)
# KR: 45 | GE for correct key (224): 1.0)
# KR: 46 | GE for correct key (224): 1.0)
# KR: 47 | GE for correct key (224): 1.0)
# KR: 48 | GE for correct key (224): 1.0)
# KR: 49 | GE for correct key (224): 1.0)
# KR: 50 | GE for correct key (224): 1.0)
# KR: 51 | GE for correct key (224): 1.0)
# KR: 52 | GE for correct key (224): 1.0)
# KR: 53 | GE for correct key (224): 1.0)
# KR: 54 | GE for correct key (224): 1.0)
# KR: 55 | GE for correct key (224): 1.0)
# KR: 56 | GE for correct key (224): 1.0)
# KR: 57 | GE for correct key (224): 1.0)
# KR: 58 | GE for correct key (224): 1.0)
# KR: 59 | GE for correct key (224): 1.0)
# KR: 60 | GE for correct key (224): 1.0)
# KR: 61 | GE for correct key (224): 1.0)
# KR: 62 | GE for correct key (224): 1.0)
# KR: 63 | GE for correct key (224): 1.0)
# KR: 64 | GE for correct key (224): 1.0)
# KR: 65 | GE for correct key (224): 1.0)
# KR: 66 | GE for correct key (224): 1.0)
# KR: 67 | GE for correct key (224): 1.0)
# KR: 68 | GE for correct key (224): 1.0)
# KR: 69 | GE for correct key (224): 1.0)
# KR: 70 | GE for correct key (224): 1.0)
# KR: 71 | GE for correct key (224): 1.0)
# KR: 72 | GE for correct key (224): 1.0)
# KR: 73 | GE for correct key (224): 1.0)
# KR: 74 | GE for correct key (224): 1.0)
# KR: 75 | GE for correct key (224): 1.0)
# KR: 76 | GE for correct key (224): 1.0)
# KR: 77 | GE for correct key (224): 1.0)
# KR: 78 | GE for correct key (224): 1.0)
# KR: 79 | GE for correct key (224): 1.0)
# KR: 80 | GE for correct key (224): 1.0)
# KR: 81 | GE for correct key (224): 1.0)
# KR: 82 | GE for correct key (224): 1.0)
# KR: 83 | GE for correct key (224): 1.0)
# KR: 84 | GE for correct key (224): 1.0)
# KR: 85 | GE for correct key (224): 1.0)
# KR: 86 | GE for correct key (224): 1.0)
# KR: 87 | GE for correct key (224): 1.0)
# KR: 88 | GE for correct key (224): 1.0)
# KR: 89 | GE for correct key (224): 1.0)
# KR: 90 | GE for correct key (224): 1.0)
# KR: 91 | GE for correct key (224): 1.0)
# KR: 92 | GE for correct key (224): 1.0)
# KR: 93 | GE for correct key (224): 1.0)
# KR: 94 | GE for correct key (224): 1.0)
# KR: 95 | GE for correct key (224): 1.0)
# KR: 96 | GE for correct key (224): 1.0)
# KR: 97 | GE for correct key (224): 1.0)
# KR: 98 | GE for correct key (224): 1.0)
# KR: 99 | GE for correct key (224): 1.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 139, 12)           132
#
#  flatten (Flatten)           (None, 1668)              0
#
#  dense (Dense)               (None, 600)               1001400
#
#  dense_1 (Dense)             (None, 600)               360600
#
#  dense_2 (Dense)             (None, 600)               360600
#
#  dense_3 (Dense)             (None, 600)               360600
#
#  dense_4 (Dense)             (None, 600)               360600
#
#  dense_5 (Dense)             (None, 600)               360600
#
#  dense_6 (Dense)             (None, 9)                 5409
#
# =================================================================
# Total params: 2,809,941
# Trainable params: 2,809,941
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 125/125 [==============================] - 4s 26ms/step - loss: 1.7922 - accuracy: 0.2589 - val_loss: 1.7929 - val_accuracy: 0.2670
# Epoch 2/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7660 - accuracy: 0.2674 - val_loss: 1.7979 - val_accuracy: 0.2178
# Epoch 3/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7628 - accuracy: 0.2675 - val_loss: 1.7934 - val_accuracy: 0.2696
# Epoch 4/50
# 125/125 [==============================] - 3s 21ms/step - loss: 1.7610 - accuracy: 0.2707 - val_loss: 1.7984 - val_accuracy: 0.2390
# Epoch 5/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7579 - accuracy: 0.2734 - val_loss: 1.7947 - val_accuracy: 0.2706
# Epoch 6/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.7542 - accuracy: 0.2733 - val_loss: 1.7939 - val_accuracy: 0.2624
# Epoch 7/50
# ...
# KR: 19 | GE for correct key (224): 3.0)
# KR: 20 | GE for correct key (224): 3.0)
# KR: 21 | GE for correct key (224): 3.0)
# KR: 22 | GE for correct key (224): 3.0)
# KR: 23 | GE for correct key (224): 3.0)
# KR: 24 | GE for correct key (224): 3.0)
# KR: 25 | GE for correct key (224): 3.0)
# KR: 26 | GE for correct key (224): 3.0)
# KR: 27 | GE for correct key (224): 3.0)
# KR: 28 | GE for correct key (224): 3.0)
# KR: 29 | GE for correct key (224): 3.0)
# KR: 30 | GE for correct key (224): 3.0)
# KR: 31 | GE for correct key (224): 3.0)
# KR: 32 | GE for correct key (224): 3.0)
# KR: 33 | GE for correct key (224): 3.0)
# KR: 34 | GE for correct key (224): 3.0)
# KR: 35 | GE for correct key (224): 3.0)
# KR: 36 | GE for correct key (224): 3.0)
# KR: 37 | GE for correct key (224): 3.0)
# KR: 38 | GE for correct key (224): 3.0)
# KR: 39 | GE for correct key (224): 3.0)
# KR: 40 | GE for correct key (224): 3.0)
# KR: 41 | GE for correct key (224): 3.0)
# KR: 42 | GE for correct key (224): 3.0)
# KR: 43 | GE for correct key (224): 3.0)
# KR: 44 | GE for correct key (224): 3.0)
# KR: 45 | GE for correct key (224): 3.0)
# KR: 46 | GE for correct key (224): 3.0)
# KR: 47 | GE for correct key (224): 3.0)
# KR: 48 | GE for correct key (224): 3.0)
# KR: 49 | GE for correct key (224): 3.0)
# KR: 50 | GE for correct key (224): 3.0)
# KR: 51 | GE for correct key (224): 3.0)
# KR: 52 | GE for correct key (224): 3.0)
# KR: 53 | GE for correct key (224): 3.0)
# KR: 54 | GE for correct key (224): 3.0)
# KR: 55 | GE for correct key (224): 3.0)
# KR: 56 | GE for correct key (224): 3.0)
# KR: 57 | GE for correct key (224): 3.0)
# KR: 58 | GE for correct key (224): 3.0)
# KR: 59 | GE for correct key (224): 3.0)
# KR: 60 | GE for correct key (224): 3.0)
# KR: 61 | GE for correct key (224): 3.0)
# KR: 62 | GE for correct key (224): 3.0)
# KR: 63 | GE for correct key (224): 3.0)
# KR: 64 | GE for correct key (224): 3.0)
# KR: 65 | GE for correct key (224): 3.0)
# KR: 66 | GE for correct key (224): 3.0)
# KR: 67 | GE for correct key (224): 3.0)
# KR: 68 | GE for correct key (224): 3.0)
# KR: 69 | GE for correct key (224): 3.0)
# KR: 70 | GE for correct key (224): 3.0)
# KR: 71 | GE for correct key (224): 3.0)
# KR: 72 | GE for correct key (224): 3.0)
# KR: 73 | GE for correct key (224): 3.0)
# KR: 74 | GE for correct key (224): 3.0)
# KR: 75 | GE for correct key (224): 3.0)
# KR: 76 | GE for correct key (224): 3.0)
# KR: 77 | GE for correct key (224): 3.0)
# KR: 78 | GE for correct key (224): 3.0)
# KR: 79 | GE for correct key (224): 3.0)
# KR: 80 | GE for correct key (224): 3.0)
# KR: 81 | GE for correct key (224): 3.0)
# KR: 82 | GE for correct key (224): 3.0)
# KR: 83 | GE for correct key (224): 3.0)
# KR: 84 | GE for correct key (224): 3.0)
# KR: 85 | GE for correct key (224): 3.0)
# KR: 86 | GE for correct key (224): 3.0)
# KR: 87 | GE for correct key (224): 3.0)
# KR: 88 | GE for correct key (224): 3.0)
# KR: 89 | GE for correct key (224): 3.0)
# KR: 90 | GE for correct key (224): 3.0)
# KR: 91 | GE for correct key (224): 3.0)
# KR: 92 | GE for correct key (224): 3.0)
# KR: 93 | GE for correct key (224): 3.0)
# KR: 94 | GE for correct key (224): 3.0)
# KR: 95 | GE for correct key (224): 3.0)
# KR: 96 | GE for correct key (224): 3.0)
# KR: 97 | GE for correct key (224): 3.0)
# KR: 98 | GE for correct key (224): 3.0)
# KR: 99 | GE for correct key (224): 3.0)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 137, 20)           380
#
#  flatten (Flatten)           (None, 2740)              0
#
#  dense (Dense)               (None, 700)               1918700
#
#  dense_1 (Dense)             (None, 700)               490700
#
#  dense_2 (Dense)             (None, 700)               490700
#
#  dense_3 (Dense)             (None, 700)               490700
#
#  dense_4 (Dense)             (None, 9)                 6309
#
# =================================================================
# Total params: 3,397,489
# Trainable params: 3,397,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 125/125 [==============================] - 4s 25ms/step - loss: 1.7985 - accuracy: 0.2564 - val_loss: 1.7919 - val_accuracy: 0.2628
# Epoch 2/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7674 - accuracy: 0.2677 - val_loss: 1.7944 - val_accuracy: 0.2480
# Epoch 3/50
# 125/125 [==============================] - 3s 24ms/step - loss: 1.7635 - accuracy: 0.2673 - val_loss: 1.7934 - val_accuracy: 0.2706
# Epoch 4/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7597 - accuracy: 0.2705 - val_loss: 1.7922 - val_accuracy: 0.2552
# Epoch 5/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7538 - accuracy: 0.2717 - val_loss: 1.8007 - val_accuracy: 0.2526
# Epoch 6/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7485 - accuracy: 0.2755 - val_loss: 1.8032 - val_accuracy: 0.2680
# Epoch 7/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7413 - accuracy: 0.2813 - val_loss: 1.8042 - val_accuracy: 0.2584
# Epoch 8/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7322 - accuracy: 0.2847 - val_loss: 1.8105 - val_accuracy: 0.2454
# Epoch 9/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7218 - accuracy: 0.2923 - val_loss: 1.8305 - val_accuracy: 0.2398
# Epoch 10/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7143 - accuracy: 0.2955 - val_loss: 1.8477 - val_accuracy: 0.2398
# Epoch 11/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.7025 - accuracy: 0.3001 - val_loss: 1.8601 - val_accuracy: 0.2422
# Epoch 12/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6928 - accuracy: 0.3030 - val_loss: 1.8568 - val_accuracy: 0.2492
# Epoch 13/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6848 - accuracy: 0.3082 - val_loss: 1.8721 - val_accuracy: 0.2322
# Epoch 14/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6764 - accuracy: 0.3092 - val_loss: 1.8596 - val_accuracy: 0.2558
# Epoch 15/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6666 - accuracy: 0.3132 - val_loss: 1.8725 - val_accuracy: 0.2404
# Epoch 16/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6594 - accuracy: 0.3178 - val_loss: 1.8823 - val_accuracy: 0.2374
# Epoch 17/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6499 - accuracy: 0.3250 - val_loss: 1.9046 - val_accuracy: 0.2370
# Epoch 18/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6458 - accuracy: 0.3269 - val_loss: 1.9087 - val_accuracy: 0.2350
# Epoch 19/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6399 - accuracy: 0.3275 - val_loss: 1.9178 - val_accuracy: 0.2264
# Epoch 20/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6319 - accuracy: 0.3304 - val_loss: 1.9261 - val_accuracy: 0.2432
# Epoch 21/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6288 - accuracy: 0.3314 - val_loss: 1.9422 - val_accuracy: 0.2306
# Epoch 22/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6211 - accuracy: 0.3375 - val_loss: 1.9508 - val_accuracy: 0.2468
# Epoch 23/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6198 - accuracy: 0.3364 - val_loss: 1.9726 - val_accuracy: 0.2330
# Epoch 24/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6131 - accuracy: 0.3391 - val_loss: 1.9768 - val_accuracy: 0.2344
# Epoch 25/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6061 - accuracy: 0.3393 - val_loss: 1.9873 - val_accuracy: 0.2316
# Epoch 26/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.6002 - accuracy: 0.3440 - val_loss: 1.9946 - val_accuracy: 0.2254
# Epoch 27/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5918 - accuracy: 0.3476 - val_loss: 2.0203 - val_accuracy: 0.2224
# Epoch 28/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5889 - accuracy: 0.3500 - val_loss: 2.0164 - val_accuracy: 0.2348
# Epoch 29/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5845 - accuracy: 0.3508 - val_loss: 2.0517 - val_accuracy: 0.2314
# Epoch 30/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5777 - accuracy: 0.3535 - val_loss: 2.0485 - val_accuracy: 0.2228
# Epoch 31/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5692 - accuracy: 0.3581 - val_loss: 2.0679 - val_accuracy: 0.2304
# Epoch 32/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.5596 - accuracy: 0.3629 - val_loss: 2.0601 - val_accuracy: 0.2124
# Epoch 33/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.5468 - accuracy: 0.3702 - val_loss: 2.0819 - val_accuracy: 0.2268
# Epoch 34/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.5354 - accuracy: 0.3742 - val_loss: 2.1207 - val_accuracy: 0.2118
# Epoch 35/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5192 - accuracy: 0.3832 - val_loss: 2.1062 - val_accuracy: 0.2306
# Epoch 36/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5041 - accuracy: 0.3897 - val_loss: 2.1516 - val_accuracy: 0.2112
# Epoch 37/50
# 125/125 [==============================] - 3s 22ms/step - loss: 1.4831 - accuracy: 0.3992 - val_loss: 2.2140 - val_accuracy: 0.2192
# Epoch 38/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.4600 - accuracy: 0.4126 - val_loss: 2.2313 - val_accuracy: 0.2064
# Epoch 39/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.4312 - accuracy: 0.4249 - val_loss: 2.2597 - val_accuracy: 0.2078
# Epoch 40/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.4097 - accuracy: 0.4350 - val_loss: 2.3158 - val_accuracy: 0.2016
# Epoch 41/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.3778 - accuracy: 0.4525 - val_loss: 2.3628 - val_accuracy: 0.2068
# Epoch 42/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.3404 - accuracy: 0.4694 - val_loss: 2.3790 - val_accuracy: 0.1988
# Epoch 43/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.2997 - accuracy: 0.4854 - val_loss: 2.4631 - val_accuracy: 0.2038
# Epoch 44/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.2602 - accuracy: 0.5036 - val_loss: 2.5637 - val_accuracy: 0.1856
# Epoch 45/50
# 125/125 [==============================] - 3s 24ms/step - loss: 1.2156 - accuracy: 0.5235 - val_loss: 2.6126 - val_accuracy: 0.1936
# Epoch 46/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.1698 - accuracy: 0.5420 - val_loss: 2.7028 - val_accuracy: 0.1904
# Epoch 47/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.1134 - accuracy: 0.5683 - val_loss: 2.7502 - val_accuracy: 0.2028
# Epoch 48/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.0615 - accuracy: 0.5920 - val_loss: 2.8553 - val_accuracy: 0.1912
# Epoch 49/50
# 125/125 [==============================] - 3s 23ms/step - loss: 1.0046 - accuracy: 0.6146 - val_loss: 3.0224 - val_accuracy: 0.1846
# Epoch 50/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.9540 - accuracy: 0.6366 - val_loss: 3.1108 - val_accuracy: 0.2002
# KR: 0 | GE for correct key (224): 254.0)
# KR: 1 | GE for correct key (224): 254.0)
# KR: 2 | GE for correct key (224): 254.0)
# KR: 3 | GE for correct key (224): 254.0)
# KR: 4 | GE for correct key (224): 254.0)
# KR: 5 | GE for correct key (224): 254.0)
# KR: 6 | GE for correct key (224): 254.0)
# KR: 7 | GE for correct key (224): 254.0)
# KR: 8 | GE for correct key (224): 254.0)
# KR: 9 | GE for correct key (224): 254.0)
# KR: 10 | GE for correct key (224): 254.0)
# KR: 11 | GE for correct key (224): 254.0)
# KR: 12 | GE for correct key (224): 254.0)
# KR: 13 | GE for correct key (224): 254.0)
# KR: 14 | GE for correct key (224): 254.0)
# KR: 15 | GE for correct key (224): 254.0)
# KR: 16 | GE for correct key (224): 254.0)
# KR: 17 | GE for correct key (224): 254.0)
# KR: 18 | GE for correct key (224): 254.0)
# KR: 19 | GE for correct key (224): 254.0)
# KR: 20 | GE for correct key (224): 254.0)
# KR: 21 | GE for correct key (224): 254.0)
# KR: 22 | GE for correct key (224): 254.0)
# KR: 23 | GE for correct key (224): 254.0)
# KR: 24 | GE for correct key (224): 254.0)
# KR: 25 | GE for correct key (224): 254.0)
# KR: 26 | GE for correct key (224): 254.0)
# KR: 27 | GE for correct key (224): 254.0)
# KR: 28 | GE for correct key (224): 254.0)
# KR: 29 | GE for correct key (224): 254.0)
# KR: 30 | GE for correct key (224): 254.0)
# KR: 31 | GE for correct key (224): 254.0)
# KR: 32 | GE for correct key (224): 254.0)
# KR: 33 | GE for correct key (224): 254.0)
# KR: 34 | GE for correct key (224): 254.0)
# KR: 35 | GE for correct key (224): 254.0)
# KR: 36 | GE for correct key (224): 254.0)
# KR: 37 | GE for correct key (224): 254.0)
# KR: 38 | GE for correct key (224): 254.0)
# KR: 39 | GE for correct key (224): 254.0)
# KR: 40 | GE for correct key (224): 254.0)
# KR: 41 | GE for correct key (224): 254.0)
# KR: 42 | GE for correct key (224): 254.0)
# KR: 43 | GE for correct key (224): 254.0)
# KR: 44 | GE for correct key (224): 254.0)
# KR: 45 | GE for correct key (224): 254.0)
# KR: 46 | GE for correct key (224): 254.0)
# KR: 47 | GE for correct key (224): 254.0)
# KR: 48 | GE for correct key (224): 254.0)
# KR: 49 | GE for correct key (224): 254.0)
# KR: 50 | GE for correct key (224): 254.0)
# KR: 51 | GE for correct key (224): 254.0)
# KR: 52 | GE for correct key (224): 254.0)
# KR: 53 | GE for correct key (224): 254.0)
# KR: 54 | GE for correct key (224): 254.0)
# KR: 55 | GE for correct key (224): 254.0)
# KR: 56 | GE for correct key (224): 254.0)
# KR: 57 | GE for correct key (224): 254.0)
# KR: 58 | GE for correct key (224): 254.0)
# KR: 59 | GE for correct key (224): 254.0)
# KR: 60 | GE for correct key (224): 254.0)
# KR: 61 | GE for correct key (224): 254.0)
# KR: 62 | GE for correct key (224): 254.0)
# KR: 63 | GE for correct key (224): 254.0)
# KR: 64 | GE for correct key (224): 254.0)
# KR: 65 | GE for correct key (224): 254.0)
# KR: 66 | GE for correct key (224): 254.0)
# KR: 67 | GE for correct key (224): 254.0)
# KR: 68 | GE for correct key (224): 254.0)
# KR: 69 | GE for correct key (224): 254.0)
# KR: 70 | GE for correct key (224): 254.0)
# KR: 71 | GE for correct key (224): 254.0)
# KR: 72 | GE for correct key (224): 254.0)
# KR: 73 | GE for correct key (224): 254.0)
# KR: 74 | GE for correct key (224): 254.0)
# KR: 75 | GE for correct key (224): 254.0)
# KR: 76 | GE for correct key (224): 254.0)
# KR: 77 | GE for correct key (224): 254.0)
# KR: 78 | GE for correct key (224): 254.0)
# KR: 79 | GE for correct key (224): 254.0)
# KR: 80 | GE for correct key (224): 254.0)
# KR: 81 | GE for correct key (224): 254.0)
# KR: 82 | GE for correct key (224): 254.0)
# KR: 83 | GE for correct key (224): 254.0)
# KR: 84 | GE for correct key (224): 254.0)
# KR: 85 | GE for correct key (224): 254.0)
# KR: 86 | GE for correct key (224): 254.0)
# KR: 87 | GE for correct key (224): 254.0)
# KR: 88 | GE for correct key (224): 254.0)
# KR: 89 | GE for correct key (224): 254.0)
# KR: 90 | GE for correct key (224): 254.0)
# KR: 91 | GE for correct key (224): 254.0)
# KR: 92 | GE for correct key (224): 254.0)
# KR: 93 | GE for correct key (224): 254.0)
# KR: 94 | GE for correct key (224): 254.0)
# KR: 95 | GE for correct key (224): 254.0)
# KR: 96 | GE for correct key (224): 254.0)
# KR: 97 | GE for correct key (224): 254.0)
# KR: 98 | GE for correct key (224): 254.0)
# KR: 99 | GE for correct key (224): 254.0)

# %%
# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('CNN_Ensembles_Tuning.png')
plt.savefig('CNN_Ensembles_Tuning.pdf')

# %%
plt.rc('figure', figsize=(15, 8))

# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('MLP_ASCAD_Ensembles_Tuning.png')
plt.savefig('MLP_ASCAD_Ensembles_Tuning.pdf')

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')

# %%
plt.rc('figure', figsize=(15, 8))

ensemble_aes = EnsembleAES()
ensemble_aes.set_dataset("ches_ctf")  # "ascad_fixed_key", "ascad_random_key" or "ches_ctf"
ensemble_aes.set_leakage_model("HW")
ensemble_aes.set_target_byte(0)
ensemble_aes.set_mini_batch(400)
ensemble_aes.set_epochs(10)
ensemble_aes.run_ensemble(number_of_models=50, number_of_best_models=[1,5,10,20])

# %%
# plotting GE and SR
plt.subplot(1, 2, 1)
#plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
#plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models (50)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models1(), label="GE Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models2(), label="GE Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_ge_ensemble_best_models3(), label="GE Ensemble Best Models3 (20)")

plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.grid()
plt.subplot(1, 2, 2)
#plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
#plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models (50)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models (1)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models1(), label="SR Ensemble Best Models1 (5)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models2(), label="SR Ensemble Best Models2 (10)")
plt.plot(ensemble_aes.get_sr_ensemble_best_models3(), label="SR Ensemble Best Models3 (20)")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.grid()
#plt.show()
plt.savefig('CNN_Ensembles_Tuning.png')
plt.savefig('CNN_Ensembles_Tuning.pdf')

# %%
# plotting GE and SR
plt.subplot(1, 2, 1)
plt.plot(ensemble_aes.get_ge_best_model_validation(), label="GE best validation")
plt.plot(ensemble_aes.get_ge_best_model_attack(), label="GE best attack")
plt.plot(ensemble_aes.get_ge_ensemble(), label="GE Ensemble All Models")
plt.plot(ensemble_aes.get_ge_ensemble_best_models(), label="GE Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Guessing Entropy")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(ensemble_aes.get_sr_best_model_validation(), label="SR best validation")
plt.plot(ensemble_aes.get_sr_best_model_attack(), label="SR best attack")
plt.plot(ensemble_aes.get_sr_ensemble(), label="SR Ensemble All Models")
plt.plot(ensemble_aes.get_sr_ensemble_best_models(), label="SR Ensemble Best Models")
plt.xlabel("Traces")
plt.ylabel("Success Rate")
plt.legend()
plt.show()

# %%
a = [10, 20, 30, 40]
for i in range(4):
  print(a[i])

a[3]
